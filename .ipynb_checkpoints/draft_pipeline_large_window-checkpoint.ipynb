# %%
# %load_ext autoreload
# %autoreload 2
import torch; torch.manual_seed(955)
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from dataGen import Gen
from Encoders import LongShort_TCVAE_Encoder#, RnnEncoder, MST_VAE_Encoder, MST_VAE_Encoder_dist
from Decoders import LongShort_TCVAE_Decoder#, RnnDecoder, MST_VAE_Decoder, MST_VAE_Decoder_dist
from vae import Variational_Autoencoder, VQ_MST_VAE, VQ_Quantizer
from utils import train_on_effect, generate_data, extract_parameters, suppress_prints, add_mu_std
from train import train, train_MCMC, stridedWindow, slidingWindow, criterion, tune

import numpy as np
import matplotlib.pyplot as plt
import pprint
# all parameters for generating the time series should be configured in this cell
periode = 365 #days
step = 5 # mess interval in minutes
val = 500
n_channels = 1
effects = {
    "Pulse": {
        "occurances":0,
        "max_amplitude":1.5,   
        "interval":40
        },
    "Trend": {
        "occurances":0,
        "max_slope":0.0002,
        "type":"linear"
        },
    "Seasonality": {
        "occurances":1,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
# pprint.pprint(params)
pprint.pprint(e_params)
X.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [18],
#                  'channel': [0],
#                  'frequency_per_week': [7.779558433216872],
#                  'phaseshift': [160]},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}

# %%
### Init Model
latent_dims = 30 # 6 # 17
L= 2016# 39 #32
device = 'cuda' if torch.cuda.is_available() else 'cpu'


# v = Variational_Autoencoder(n_channels = n_channels,
#                             num_layers =  3,#4, #3
#                             latent_dims= latent_dims,
#                             v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
#                             v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
#                             L=L,
#                             slope = 0,
#                             first_kernel = 20, #11, #20
#                             ß = 1.5,
#                             modified=True,
#                             reduction = True)
v = VQ_MST_VAE(n_channels = n_channels,
                            num_layers =  4,#4, #3
                            latent_dims= latent_dims,
                            v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
                            v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
                            v_quantizer = VQ_Quantizer,
                            L=L,
                            slope = 0,
                            first_kernel = 1008, #11, #20
                            commit_loss = 1.5,
                            modified=True,
                            reduction = True) #10 5


v = v.to(device)

opt = optim.Adam(v.parameters(), lr = 0.005043529186448577) # 0.005043529186448577 0.006819850049647945
print(v)
# Out:
# 1
# 8
# 1
# 8
# VQ_MST_VAE(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): Conv1d(6, 8, kernel_size=(2,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=126, out_features=30, bias=True)
#       (encoder_logvar): Linear(in_features=126, out_features=30, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(1008,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): Conv1d(6, 8, kernel_size=(2,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=63, out_features=30, bias=True)
#       (encoder_logvar): Linear(in_features=63, out_features=30, bias=True)
#     )
#     (reduction_layer): Conv1d(16, 8, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(8, 4, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(4, 2, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(2, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): ConvTranspose1d(1, 1, kernel_size=(1008,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=1486, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=1486, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=1486, out_features=2016, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(8, 4, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(4, 2, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(2, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=480, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=480, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=480, out_features=2016, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (quantizer): VQ_Quantizer(
#     (_embedding): Embedding(8, 30)
#   )
#   (bn): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
x = torch.FloatTensor(x)
n = x.shape[1]

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

train_data = DataLoader(stridedWindow(train_, L),# slidingWindow, stridedWindow
                        batch_size= 10,# 59, # 22
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=500,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=500,
                        shuffle = False
                        )

# %%
# v, X, train_data = train_on_effect(v, opt, device, n_channels=n_channels, effect='no_effect', n_samples=5, epochs_per_sample=1000)
# v, X, train_data = train_on_effect(v, opt, device, n_channels=n_channels, effect='trend', n_samples=5, epochs_per_sample=1000)
# v, X, train_data = train_on_effect(v, opt, device, n_channels=n_channels, effect='seasonality', n_samples=5, epochs_per_sample=1000)

# %%
for epoch in range(1, 2):
    x, rec, quantizer_output = tune(v, train_data, criterion, opt, device, epoch, VQ = True)
quantizer_output.detach()
quantized_data = DataLoader(quantizer_output,# slidingWindow, stridedWindow
                        batch_size= 10,# 59, # 22
                        shuffle = False
                        )

for batch, data in enumerate(quantized_data):
    print(batch, data.shape)
    print(data)
# Out:
# 0 torch.Size([10, 8, 30])
# tensor([[[ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ 10.4940,   4.3902,  -6.6837,  ...,  -4.0812,   7.2001,   8.1159],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          ...,
#          [-11.4734, -11.4532, -12.9869,  ...,  -0.8708,  -1.5603,   0.7306],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915]],
#
#         [[ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          ...,
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915]],
#
#         [[ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          ...,
#          [ -3.1847,   1.6720,  -2.4427,  ...,  -7.2534,  -8.7681,  -5.6968],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915]],
#
#         ...,
#
#         [[ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          ...,
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915]],
#
#         [[ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ 10.4940,   4.3902,  -6.6837,  ...,  -4.0812,   7.2001,   8.1159],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          ...,
#          [-11.4734, -11.4532, -12.9869,  ...,  -0.8708,  -1.5603,   0.7306],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915]],
#
#         [[ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ 10.4940,   4.3902,  -6.6837,  ...,  -4.0812,   7.2001,   8.1159],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          ...,
#          [-11.4734, -11.4532, -12.9869,  ...,  -0.8708,  -1.5603,   0.7306],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915],
#          [ -0.5162,   0.0666,   0.0614,  ...,   0.2162,  -0.6088,  -0.0915]]],
#        grad_fn=<StackBackward0>)
# 1 torch.Size([10, 8, 30])
# tensor([[[ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          ...,
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849]],
#
#         [[ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          ...,
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849]],
#
#         [[ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          ...,
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849]],
#
#         ...,
#
#         [[ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ 10.5643,   4.3899,  -6.7174,  ...,  -4.0851,   7.1144,   8.1670],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          ...,
#          [-11.4800, -11.4601, -12.9957,  ...,  -0.8793,  -1.5649,   0.6951],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849]],
#
#         [[ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ 10.5643,   4.3899,  -6.7174,  ...,  -4.0851,   7.1144,   8.1670],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          ...,
#          [-11.4800, -11.4601, -12.9957,  ...,  -0.8793,  -1.5649,   0.6951],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849]],
#
#         [[ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          ...,
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849],
#          [ -0.5076,   0.0658,   0.0614,  ...,   0.2202,  -0.6103,  -0.0849]]],
#        grad_fn=<StackBackward0>)
# 2 torch.Size([10, 8, 30])
# tensor([[[ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          ...,
#          [ -3.1119,   1.6410,  -2.3899,  ...,  -7.2156,  -8.7223,  -5.6551],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792]],
#
#         [[ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          ...,
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792]],
#
#         [[ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ 10.5735,   4.3959,  -6.7164,  ...,  -4.0839,   7.1417,   8.3483],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          ...,
#          [-11.4887, -11.4646, -12.9989,  ...,  -0.8948,  -1.5766,   0.6708],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792]],
#
#         ...,
#
#         [[ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ 10.5735,   4.3959,  -6.7164,  ...,  -4.0839,   7.1417,   8.3483],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          ...,
#          [-11.4887, -11.4646, -12.9989,  ...,  -0.8948,  -1.5766,   0.6708],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792]],
#
#         [[ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          ...,
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792]],
#
#         [[ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          ...,
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0792],
#          [ -0.5124,   0.0701,   0.0698,  ...,   0.2239,  -0.6148,  -0.0
= model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
            print(e.shape)
            rec = torch.cat((rec, (x_rec*v).view(n_channels, -1)), dim=1)
            x = torch.cat((x, (data*v).view(n_channels, -1)), dim=1)
#             x.extend((data*v).view(1, -1).detach().numpy())
#             rec.extend((x_rec*v).view(1, -1).detach().numpy())
    print(rec.shape)
    print(x.shape)
    print(rec)
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(rec.T[:2000,:], "r--", alpha = 0.5)
    ax.plot(x.T[:2000,:], "b-", alpha=0.2)
    
#     plt.ylim(50,600)
    ax.grid()
#     plt.show()
    
    new_train_data = DataLoader(slidingWindow(np.array(rec).T, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
    return new_train_data

# %%
# a = 15* avg_norm
# v.quantizer._embedding.weight.detach()[0,5] = a
v.cpu()
rec = compare(train_data, v, n_channels, VQ=True)
v.to(device)
# Out:
# 84096
# torch.Size([10, 8, 30])
# torch.Size([10, 8, 30])
# torch.Size([10, 8, 30])
# torch.Size([10, 8, 30])
# torch.Size([1, 8, 30])
# torch.Size([1, 82656])
# torch.Size([1, 82656])
# tensor([[36.8227, 36.4673, 37.2994,  ..., 43.0865, 36.0157, 36.6208]])
# VQ_MST_VAE(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): Conv1d(6, 8, kernel_size=(2,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=126, out_features=30, bias=True)
#       (encoder_logvar): Linear(in_features=126, out_features=30, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(1008,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): Conv1d(6, 8, kernel_size=(2,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=63, out_features=30, bias=True)
#       (encoder_logvar): Linear(in_features=63, out_features=30, bias=True)
#     )
#     (reduction_layer): Conv1d(16, 8, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(8, 4, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(4, 2, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(2, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): ConvTranspose1d(1, 1, kernel_size=(1008,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=1486, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=1486, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=1486, out_features=2016, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(8, 4, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(4, 2, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(2, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (10): LeakyReLU(negative_slope=0, inplace=True)
#         (11): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=480, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=480, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=480, out_features=2016, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (quantizer): VQ_Quantizer(
#     (_embedding): Embedding(8, 30)
#   )
#   (bn): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def plot_heatmap(ax_heatmap, codebook):
    ax_heatmap.clear()
    heatmap = ax_heatmap.imshow(codebook)
    ax_heatmap.set_title('Codebook Heatmap')
    ax_heatmap


    return heatmap
def create_heatmap(codebook):
    fig, ax_heatmap = plt.subplots(figsize=(12, 6), dpi=100)
    heatmap = plot_heatmap(ax_heatmap, codebook.T)
#     heatmap_canvas = FigureCanvasTkAgg(fig, master=heatmap_frame)
#     heatmap_canvas.draw()
#     heatmap_canvas.get_tk_widget().pack(fill="both", expand=True)
    cbar = fig.colorbar(heatmap)
    ax_heatmap.set_xlabel('Num of Embeddings')
    ax_heatmap.set_ylabel('Latent Dimensions')
    
    return ax_heatmap

def get_average_norm_scale(train_data, model):
    n_channels = model._n_channels
    n_batchs = x_size = len(train_data)
    
    norm = torch.empty(n_channels, 0)

    for i, (data, norm_scale) in enumerate(train_data):
        reshaped_norm = norm_scale.permute(1,0,2).flatten(1)
        norm = torch.cat((norm, reshaped_norm), 1)
        
    avg_norm = torch.mean(norm, dim=1)
    return avg_norm

def get_latent_variables(train_data, model):
    model.eval()
    
    n_channels = model._n_channels
    latent_dims = model._latent_dims
    n_batchs = x_size = len(train_data)
    
    latents = torch.empty(n_channels, latent_dims, 0, device = device)

    for i, (data, norm_scale) in enumerate(train_data):
        data = data.to(device)
        
        mu, logvar = model.encoder(data)
        z = model.reparametrization_trick(mu, logvar)
        
        reshaped_mu, reshaped_logvar, reshaped_z = (t.permute(1,2,0) for t in [mu, logvar, z])

        latents = torch.cat((latents, reshaped_z), 2)

        
    avg_latents = torch.mean(latents, dim=2)
    return latents, avg_latents

# %%
def sample_vae(train_data, model, n):
    model.eval()
    
    n_channels = model._n_channels
    latent_dims = model._latent_dims
#     n_batchs = x_size = len(train_data)
    x_len = len(train_data.dataset)
    L = model._L
    bs = train_data.batch_size
    
    latents = torch.empty(n_channels, latent_dims, 0, device = device)
    x_rec, mu_dec, logvar_dec = (torch.empty(0, n_channels, x_len, device = device) for _ in range(3))
    mu_enc, logvar_enc = (torch.empty(0, n_channels, latent_dims, x_len, device = device) for _ in range(2))
    
    for j in range(n):
        # create temp tensors to store data in each repetition
        x, x_rec_temp, mu_rec_temp, logvar_rec_temp = (torch.empty(n_channels, 0, device = device) for _ in range(4))
        mu_temp, logvar_temp = (torch.empty(n_channels, latent_dims, 0, device = device) for _ in range(2))
        
        for i, (batch, norm_scale) in enumerate(train_data):
            batch = batch.to(device)
            #sample from model
            rec, loss, _mu, _logvar, mu_rec, logvar_rec = model(batch)

            #reshape data -> (Channel, latent_dims, BS) or (Channel, BS)
            _mu, _logvar= (t.permute(1,2,0) for t in [_mu, _logvar])
            batch, rec, norm_scale, mu_rec, logvar_rec = (t.permute(1,0,2)[:,:,0] for t in [batch, rec, norm_scale, mu_rec, logvar_rec])
            
            # Temp store data
            mu_temp = torch.cat((mu_temp, _mu), dim=2)
            logvar_temp = torch.cat((logvar_temp, _logvar), dim=2)
            mu_rec_temp = torch.cat((mu_rec_temp, mu_rec*norm_scale), dim=1)
            logvar_rec_temp  = torch.cat((logvar_rec_temp, logvar_rec*norm_scale), dim=1)            
            x_rec_temp = torch.cat((x_rec_temp, rec*norm_scale), dim=1)
#             print(batch.shape)
#             print(norm_scale.shape)
#             print(x.shape)
            x = torch.cat((x, batch*norm_scale), dim=1)

        # Store data after each reconstruction
        x_rec = torch.cat((x_rec, x_rec_temp.unsqueeze(0)), dim=0)
        mu_dec = torch.cat((mu_dec, mu_rec_temp.unsqueeze(0)), dim=0)
        logvar_dec = torch.cat((logvar_dec, logvar_rec_temp.unsqueeze(0)), dim=0)
        mu_enc = torch.cat((mu_enc, mu_temp.unsqueeze(0)), dim=0)
        logvar_enc = torch.cat((logvar_enc, logvar_temp.unsqueeze(0)), dim=0)
        print(x.shape)

    # join repetition and Channels and get the mean
#     x_rec, mu_dec, logvar_dec = (t.view(-1, x_len)for t in [x_rec, mu_dec, logvar_dec])
    x_rec_mean, mu_enc_mean, logvar_enc_mean, mu_dec_mean, logvar_dec_mean = (torch.mean(t, dim=0) for t in [x_rec, mu_enc, logvar_enc, mu_dec, logvar_dec])
#     x_rec_mean = x_rec.mean(0)
    print(x_rec.shape)
    print(x_rec_mean.shape)
    print(mu_enc_mean.shape)
    print(mu_dec_mean.shape)
    
    return x_rec, x_rec_mean, mu_enc_mean, logvar_enc_mean, mu_dec_mean, logvar_dec_mean

# %%
sample_vae(train_data, v, 5)
# Out:
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([5, 1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 7, 3396])
# torch.Size([1, 3396])
# (tensor([[[270.6336, 270.8838, 264.7929,  ..., 264.1872, 266.1580, 266.2314]],
#
#          [[267.2577, 267.1277, 265.2807,  ..., 263.2624, 269.6062, 269.7383]],
#
#          [[267.2337, 268.0678, 267.6342,  ..., 269.5417, 268.7584, 265.9521]],
#
#          [[264.8954, 275.5269, 271.7399,  ..., 270.9635, 260.7353, 267.1324]],
#
#          [[263.9909, 263.8148, 270.3807,  ..., 263.0367, 270.1438, 264.7582]]],
#         grad_fn=<CatBackward0>),
#  tensor([[266.8022, 269.0842, 267.9657,  ..., 266.1983, 267.0803, 266.7625]],
#         grad_fn=<MeanBackward1>),
#  tensor([[[ 4.8745e-05,  2.3223e-04,  1.9234e-04,  ..., -5.7731e-05,
#             1.0282e-04,  7.4898e-05],
#           [ 1.7370e-04,  2.2830e-04,  1.7567e-04,  ...,  7.5044e-05,
#             2.1233e-04,  2.6535e-05],
#           [ 1.2812e-04,  2.7792e-04,  1.7135e-04,  ...,  1.8889e-04,
#             2.2300e-04,  4.6355e-05],
#           ...,
#           [ 2.5057e-04,  2.1517e-04,  1.7004e-04,  ...,  1.5335e-04,
#             1.1291e-04,  1.6399e-04],
#           [ 7.4474e-05,  1.8624e-04,  1.9586e-04,  ..., -6.3483e-05,
#             2.1118e-05,  8.9644e-05],
#           [ 8.8593e-05,  3.1113e-04,  2.5426e-04,  ...,  1.3487e-04,
#             3.0910e-04,  1.8012e-04]]], grad_fn=<MeanBackward1>),
#  tensor([[[ 8.0645e-06,  1.1592e-04,  6.2184e-05,  ...,  2.4536e-04,
#             8.6989e-05,  2.4370e-04],
#           [ 2.2218e-04,  1.7392e-04,  3.6434e-05,  ...,  6.0788e-05,
#             6.5963e-05,  1.3342e-04],
#           [ 1.5651e-04,  3.3104e-04,  2.7135e-04,  ...,  2.3599e-04,
#             3.4785e-04,  1.6050e-04],
#           ...,
#           [ 1.3706e-04,  2.5014e-04, -7.7466e-05,  ...,  1.2451e-04,
#             1.9108e-04,  1.0575e-04],
#           [ 1.7822e-04,  1.5590e-04,  1.2071e-04,  ...,  2.1486e-04,
#             1.7836e-04,  2.1034e-04],
#           [ 8.7711e-05,  2.6684e-04,  1.4536e-04,  ...,  5.6828e-05,
#             1.7663e-04,  1.2785e-04]]], grad_fn=<MeanBackward1>),
#  tensor([[266.2739, 269.1126, 267.4207,  ..., 267.0651, 267.9198, 267.0026]],
#         grad_fn=<MeanBackward1>),
#  tensor([[-2745.5405, -2759.0750, -2762.8022,  ..., -2742.6116, -2725.4800,
#           -2657.7097]], grad_fn=<MeanBackward1>))

# %%
get_latent_variables(train_data, v)
x, params, e_params = X.parameters()

# %%
pprint.pprint(params)
pprint.pprint(e_params)
# Out:
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([
#       315.0487        310.8116        256.02716      -283.3589
#      -384.63086       -84.18628  ]
#  [   -837.40656      -326.8936       -733.2799       -168.50275
#      1143.9006       1222.2172       2333.322        1763.5819
#      2513.5378       1294.1486       2298.0378        795.43854
#       -27.72138        33.632263      -39.502274       75.57823
#       -30.282753       46.530174      -79.26693        57.318798
#       579.9974       1040.6779       2300.618        1545.7842
#      2273.1572       1108.6847       2090.4792        710.3521
#        42.98237        54.573242 ]
#  [     59.4642         72.5947       -118.638466       71.24455
#      -136.29945       -14.928604     -372.2479       -101.97846
#       -23.94748       163.47934       339.43506       158.15588
#       367.06467       242.15775      -189.9748       -354.79297
#      -782.4056       -526.1687       -924.4847       -458.94366
#      -869.1985       -119.64753     -1011.75555     -1156.3448
#     -2663.6545      -1403.0394      -2058.5378       -931.6771
#     -1558.8513       -534.06256  ]]

# %%
from datetime import datetime

def get_duration_dates(dates):    
    reference_time = np.datetime64('2023-03-01T00:00:00')
    reference_time = datetime.strptime(reference_time.astype(str), "%Y-%m-%dT%H:%M:%S")
    durations = []
    for date in dates:
        date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%S")
        duration = int((date - reference_time).total_seconds()//60)
        durations.append(duration)
    
    return durations

# %%
mu = torch.FloatTensor(params["mu"]).mean()
std = torch.diagonal(torch.FloatTensor(params["cov"])).mean()
labels = [mu, std]
for param in e_params["Seasonality"]:
    if param != "channel":
        labels.append(torch.FloatTensor(e_params["Seasonality"][param]))
labels = torch.FloatTensor(labels).squeeze(dim=0)

# %%
def extract_labels(params, e_params):
    mu = torch.FloatTensor(params["mu"]).mean()
    std = torch.diagonal(torch.FloatTensor(params["cov"])).mean()
    labels = [mu, std]
    for param in e_params["Seasonality"]:
        if param != "channel":
            labels.append(torch.FloatTensor(e_params["Seasonality"][param]))
    labels = torch.FloatTensor(labels).squeeze(dim=0)
    return labels

# %%
labels
# Out:
# tensor([141.1412,   1.0000,   7.3779,  13.0000, 169.0000])

# %%
# @suppress_prints
class identifier(nn.Module):
    def __init__(self, input_size, num_layers, output_size, slope):
        super(identifier, self).__init__()   
        
        self.input_size =  input_size      
        self.num_layers = num_layers
        self.output_size = output_size
        self.lin_layers = nn.ModuleList()
        self.n = 1
        
        def init_weights(m):
            if isinstance(m, nn.Linear):
                torch.nn.init.kamin(m.weight, a=0.0, b=1.0)
                m.bias.data.fill_(0.01)
                
        # CNN Layers that double the channels each time
        for i in range(0, num_layers):
            
            if i == num_layers -1:
                self.lin_layers.append(nn.Linear(self.input_size, output_size))
                self.lin_layers.append(nn.LeakyReLU(slope, True))
                self.lin_layers.append(nn.BatchNorm1d(self.n))
                self.input_size = self.input_size // (2 ** num_layers)
            else:
                print(self.input_size, self.input_size * 2)
                self.lin_layers.append(nn.Linear(self.input_size, self.input_size * 2))
                self.lin_layers.append(nn.LeakyReLU(slope, True))
                self.lin_layers.append(nn.BatchNorm1d(self.n))
                self.input_size = self.input_size * 2
        
#         self.lin_layers.apply(init_weights)
            
         
    def forward(self, x):
        print("x input", x.shape)
        x_shape = x.shape
        x = x.view(x.size(0), -1).unsqueeze(1)
        print("x before lin", x.shape)
        for i, lin in enumerate(self.lin_layers):
            x = lin(x)        
        print("x after lin", x.shape)
        x = x.squeeze(1).view(x_shape[0], -1, 2)
        print("x out", x.shape)
        return x

# %%
def compare(dataset, model, n_channels, VQ=True):
    model.eval()
    for p in model.parameters():
        p.requires_grad = False
    data_size = train_data.dataset.data.shape[-1]
    print(data_size)
    rec = torch.empty(n_channels, 0)
    x = torch.empty(n_channels, 0)
    with torch.no_grad():
        for i, (data, v) in enumerate(dataset):
            if VQ:
                x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
            else:
                x_rec, mu, logvar = model(data)
#             z = model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
#             print(i)
            rec = torch.cat((rec, (x_rec*v).view(n_channels, -1)), dim=1)
            x = torch.cat((x, (data*v).view(n_channels, -1)), dim=1)
#             x.extend((data*v).view(1, -1).detach().numpy())
#             rec.extend((x_rec*v).view(1, -1).detach().numpy())
    print(rec.shape)
    print(x.shape)
    print(rec)
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(rec.T[:2000,:], "r--", alpha = 0.5)
    ax.plot(x.T[:2000,:], "b-", alpha=0.2)
    
# #     plt.ylim(50,600)
    ax.grid()
#     plt.show()
    
    new_train_data = DataLoader(slidingWindow(np.array(rec).T, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
    return new_train_data

# %%
labels = extract_parameters(n_channels, e_params, effects)
labels = add_mu_std(labels, params)
n = n_channels * 4 * 2

id_model = identifier(input_size=n*n_channels*latent_dims, num_layers=5, output_size=labels.numel(), slope=0.1)
id_model = id_model.to(device)

id_opt = optim.Adam(id_model.parameters(), lr = 100)
# Out:
# 240 480
# 480 960
# 960 1920
# 1920 3840

# %%
def debug_hook(grad):
    # This function will be called whenever gradients are computed
    print('Gradient:', grad.shape)

# %%
def train_identifier(model, id_model, labels, train_loader, criterion, optimizer, device, epoch, VQ=True):
    model.eval()
    id_model.train()
    for p in model.parameters():
        p.requires_grad = False
    for p in id_model.parameters():
        p.requires_grad = True
    train_loss = 0
    labels = labels.to(device)

    for batch_idx, (data, v) in enumerate(train_loader):

        data = data.to(device)
        v = v.to(device)
        optimizer.zero_grad()

        if VQ:
            x_rec, loss, mu, logvar, mu_rec, logvar_rec, e = model(data)
        else:
            #             x_rec, mu, logvar = model(data)
            x_rec, mu, logvar = sample_mean(model, data, 10)
            if v.dim() == 1:
                v = v.unsqueeze(-1)
                v = v.unsqueeze(-1)
            # x_rec_window_length = x_rec.shape[2]
            loss = criterion(x_rec * v, data[:, :, 0], mu, logvar)
        identified = id_model(e)
#         print(torch.mean(identified, dim=0))
#         print(labels)
        
        loss = F.mse_loss(torch.mean(identified, dim=0), labels, reduction='sum')
        print(loss)
        # print(x_rec.shape)
        # print(data[:, :, 0].shape)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(train_loader.dataset)))

    return train_loss / len(train_loader.dataset)

# %%
def tune_identifier(model, labels, train_loader, optimizer, device, epoch):
    model.train()
    labels.retain_graph=True
    for p in model.parameters():
        p.requires_grad = True
        
    train_loss = 0
    labels = labels.to(device)

    for batch_idx, data in enumerate(train_loader):

        data = data.to(device)
        data.register_hook(debug_hook)
        optimizer.zero_grad()
        labels.retain_graph=True
        data.retain_graph=True

        identified = model(data)
#         print(torch.mean(identified, dim=0))
#         print(labels)
        print(labels.shape)
        print(torch.mean(identified, dim=0).shape)
        
        loss = F.mse_loss(torch.mean(identified, dim=0), labels, reduction='sum')
        print(loss.shape)
        # print(x_rec.shape)
        # print(data[:, :, 0].shape)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(train_loader.dataset)))

    return train_loss / len(train_loader.dataset)

# %%
for epoch in range(1, 2):
    x, rec, quantizer_output = tune(v, train_data, criterion, opt, device, epoch, VQ = True)
quantizer_output.detach()
quantizer_output.requires_gradire_rad = True
quantized_data = DataLoader(quantizer_output,# slidingWindow, stridedWindow
                        batch_size= 50,# 59, # 22
                        shuffle = False
                        )
for epoch in range(1, 50):
    tune_identifier(id_model, labels, quantized_data, id_opt, device, epoch)
# Out:
# torch.Size([10, 8, 30])
# torch.Size([0, 8, 30])
# torch.Size([10, 8, 30])
# Train Epoch: 1 [0/41 (0%)]	Loss: 27.496820
# torch.Size([10, 8, 30])
# torch.Size([10, 8, 30])
# torch.Size([20, 8, 30])
# torch.Size([10, 8, 30])
# torch.Size([20, 8, 30])
# torch.Size([30, 8, 30])
# torch.Size([10, 8, 30])
# torch.Size([30, 8, 30])
# torch.Size([40, 8, 30])
# torch.Size([1, 8, 30])
# torch.Size([40, 8, 30])
# torch.Size([41, 8, 30])
# ====> Epoch: 1 Average loss: 32.5385
# x input torch.Size([41, 8, 30])
# x before lin torch.Size([41, 1, 240])
# x after lin torch.Size([41, 1, 10])
# x out torch.Size([41, 5, 2])
# torch.Size([5, 2])
# torch.Size([5, 2])
# torch.Size([])
# Gradient: torch.Size([41, 8, 30])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[102], line 10
#       5 quantized_data = DataLoader(quantizer_output,# slidingWindow, stridedWindow
#       6                         batch_size= 50,# 59, # 22
#       7                         shuffle = False
#       8                         )
#       9 for epoch in range(1, 50):
# ---> 10     tune_identifier(id_model, labels, quantized_data, id_opt, device, epoch)
#
# Cell In[96], line 28, in tune_identifier(model, labels, train_loader, optimizer, device, epoch)
#      25 print(loss.shape)
#      26 # print(x_rec.shape)
#      27 # print(data[:, :, 0].shape)
# ---> 28 loss.backward()
#      30 optimizer.step()
#      31 train_loss += loss.item()
#
# File ~\.conda\envs\testenv\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\.conda\envs\testenv\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: Trying to backward through the graph a second time (or directly access saved tensors after they have already been freed). Saved intermediate values of the graph are freed when you call .backward() or autograd.grad(). Specify retain_graph=True if you need to backward through the graph a second time or if you need to access saved tensors after calling backward.

# %%
labels = torch.FloatTensor(labels)
labels = torch.FloatTensor(labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 labels = torch.FloatTensor(labels)
#       2 labels = torch.FloatTensor(labels)
#
# TypeError: expected TensorOptions(dtype=float, device=cpu, layout=Strided, requires_grad=false (default), pinned_memory=false (default), memory_format=(nullopt)) (got TensorOptions(dtype=double, device=cpu, layout=Strided, requires_grad=false (default), pinned_memory=false (default), memory_format=(nullopt)))

# %%
labels
# Out:
# tensor([[  0.0000, 266.5914],
#         [  0.0000,   1.0000],
#         [  0.0000,   9.0913],
#         [  0.0000,   5.0000],
#         [  0.0000, 113.0000]])

# %%
def test_identifier(model, id_model, labels, train_loader, criterion, optimizer, device, epoch, VQ=True):
    model.eval()
    id_model.eval()
    for p in model.parameters():
        p.requires_grad = False
    for p in id_model.parameters():
        p.requires_grad = False
    train_loss = 0
    labels = labels.to(device)

    for batch_idx, (data, v) in enumerate(train_loader):

        data = data.to(device)
        v = v.to(device)
        optimizer.zero_grad()

        if VQ:
            x_rec, loss, mu, logvar, mu_rec, logvar_rec, e = model(data)
        else:
            #             x_rec, mu, logvar = model(data)
            x_rec, mu, logvar = sample_mean(model, data, 10)
            if v.dim() == 1:
                v = v.unsqueeze(-1)
                v = v.unsqueeze(-1)
            # x_rec_window_length = x_rec.shape[2]
            loss = criterion(x_rec * v, data[:, :, 0], mu, logvar)
        identified = id_model(e)
#         loss = F.mse_loss(torch.mean(identified, dim=0), labels)
        # print(x_rec.shape)
        # print(data[:, :, 0].shape)
#         loss.backward()

#         optimizer.step()
#         train_loss += loss.item()
#         if batch_idx % 100 == 0:
#             print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
#                 epoch, batch_idx * len(data), len(train_loader.dataset),
#                        100. * batch_idx / len(train_loader), loss.item() / len(data)))
#     print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(train_loader.dataset)))
    print("identified", torch.mean(identified, dim=0))

    return train_loss / len(train_loader.dataset)

# %%
train_identifier(v, id_model, labels, train_data, criterion, id_opt, device, epoch, VQ=True)
# Out:
# x input torch.Size([10, 8, 30])
# x before lin torch.Size([10, 1, 240])
# x after lin torch.Size([10, 1, 10])
# x out torch.Size([10, 5, 2])
# tensor(27713.4512, grad_fn=<MseLossBackward0>)
# Train Epoch: 1 [0/41 (0%)]	Loss: 2771.345117
# x input torch.Size([10, 8, 30])
# x before lin torch.Size([10, 1, 240])
# x after lin torch.Size([10, 1, 10])
# x out torch.Size([10, 5, 2])
# tensor(258035.7812, grad_fn=<MseLossBackward0>)
# x input torch.Size([10, 8, 30])
# x before lin torch.Size([10, 1, 240])
# x after lin torch.Size([10, 1, 10])
# x out torch.Size([10, 5, 2])
# tensor(47711.1562, grad_fn=<MseLossBackward0>)
# x input torch.Size([10, 8, 30])
# x before lin torch.Size([10, 1, 240])
# x after lin torch.Size([10, 1, 10])
# x out torch.Size([10, 5, 2])
# tensor(59019.3242, grad_fn=<MseLossBackward0>)
# x input torch.Size([1, 8, 30])
# x before lin torch.Size([1, 1, 240])
# x after lin torch.Size([1, 1, 10])
# x out torch.Size([1, 5, 2])
# tensor(133392.8438, grad_fn=<MseLossBackward0>)
# ====> Epoch: 1 Average loss: 12826.1599
# 12826.159918064024

# %%
test_identifier(v, id_model, labels, train_data, criterion, id_opt, device, epoch, VQ=True)
# Out:
# identified tensor([428.6902,  57.1317,  65.0840,  67.5340, -44.7187])
# 0.0

# %%
labels
# Out:
# tensor([436.8202,   1.0000,   7.6674,  12.0000, 123.0000])

# %%
# Original lists
main_list = [4, 2, 1, 3, 0]
order_list = ['b', 'c', 'a', 'd', 'f']

# Sort the main list based on the order list
sorted_list = sorted(main_list, key=lambda x: order_list.index(x))

print(sorted_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       3 order_list = ['b', 'c', 'a', 'd', 'f']
#       5 # Sort the main list based on the order list
# ----> 6 sorted_list = sorted(main_list, key=lambda x: order_list.index(x))
#       8 print(sorted_list)
#
# Cell In[16], line 6, in <lambda>(x)
#       3 order_list = ['b', 'c', 'a', 'd', 'f']
#       5 # Sort the main list based on the order list
# ----> 6 sorted_list = sorted(main_list, key=lambda x: order_list.index(x))
#       8 print(sorted_list)
#
# ValueError: 4 is not in list

# %%
def extract_param_per_channel(effect):
    for chanel in e_params[effect]["channel"]:
        for param in e_params[effect]:
            if param != "channel":
                labels.append(torch.FloatTensor(e_params["Seasonality"][param]))

# %%
def extract_labels(params, e_params):
    mu = torch.FloatTensor(params["mu"]).mean()
    std = torch.diagonal(torch.FloatTensor(params["cov"])).mean()
    labels = [mu, std]
    for param in e_params["Seasonality"]:
        if param != "channel":
            labels.append(torch.FloatTensor(e_params["Seasonality"][param]))
    print(labels)
    labels = torch.FloatTensor(labels).squeeze(dim=0)
    return labels

# %%
def train_on_effect_and_parameters(model, id_model, opt, id_opt, device, n_channels=1, effect='no_effect', n_samples=10, epochs_per_sample=1000):
    L = model._L
    latent_dims = model._latent_dims
    for i in range(n_samples):
        for p in model.parameters():
            p.requires_grad = True
        for p in model.quantizer.parameters():
            p.requires_grad = False
        X, train_data, test_data, effects = generate_data(n_channels, effect, L)
        x, params, e_params = X.parameters()
        labels = extract_parameters(n_channels, e_params, effects)
        labels = add_mu_std(labels, params)
        codebook = model.quantizer._embedding.weights

        for epoch in range(1, epochs_per_sample):
            x, rec, quantizer_output = tune(v, train_data, criterion, opt, device, epoch, VQ = True)   
        
        quantized_data = DataLoader(quantizer_output,# slidingWindow, stridedWindow
                        batch_size= 10,# 59, # 22
                        shuffle = False
                        )
            
        for epoch in range(1, 100):
            train_identifier(model, id_model, labels, train_data, criterion, id_opt, device, epoch, VQ=True)
            
        test_identifier(model, id_model, labels, train_data, criterion, id_opt, device, epoch, VQ=True)
        print(labels)
#         save(x, "data", effect, n_channels, latent_dims, L, i)
#         save(params, "params", effect, n_channels, latent_dims, L, i)
#         save(e_params, "e_params", effect, n_channels, latent_dims, L, i)
#         save(model, "model", effect, n_channels, latent_dims, L, i)
    return model, X, train_data

# %%
model, X, train_data = train_on_effect_and_parameters(v, id_model, opt, id_opt, device, n_channels, effect="seasonality", n_samples=50, epochs_per_sample=50)
# Out:
# Train Epoch: 1 [0/41 (0%)]	Loss: 3.275693
# ====> Epoch: 1 Average loss: 3.3007
# Train Epoch: 2 [0/41 (0%)]	Loss: 3.117174
# ====> Epoch: 2 Average loss: 3.2302
# Train Epoch: 3 [0/41 (0%)]	Loss: 3.245716
# ====> Epoch: 3 Average loss: 3.2564
# Train Epoch: 4 [0/41 (0%)]	Loss: 3.083074
# ====> Epoch: 4 Average loss: 3.1877
# Train Epoch: 5 [0/41 (0%)]	Loss: 3.138388
# ====> Epoch: 5 Average loss: 3.2045
# Train Epoch: 6 [0/41 (0%)]	Loss: 3.079087
# ====> Epoch: 6 Average loss: 3.1653
# Train Epoch: 7 [0/41 (0%)]	Loss: 3.166815
# ====> Epoch: 7 Average loss: 3.1915
# Train Epoch: 8 [0/41 (0%)]	Loss: 3.092848
# ====> Epoch: 8 Average loss: 3.1665
# Train Epoch: 9 [0/41 (0%)]	Loss: 3.076466
# ====> Epoch: 9 Average loss: 3.1535
# Train Epoch: 10 [0/41 (0%)]	Loss: 3.062019
# ====> Epoch: 10 Average loss: 3.1430
# Train Epoch: 11 [0/41 (0%)]	Loss: 3.068768
# ====> Epoch: 11 Average loss: 3.1392
# Train Epoch: 12 [0/41 (0%)]	Loss: 3.064903
# ====> Epoch: 12 Average loss: 3.1296
# Train Epoch: 83 [0/41 (0%)]	Loss: nan
# ====> Epoch: 83 Average loss: nan
# Train Epoch: 84 [0/41 (0%)]	Loss: nan
# ====> Epoch: 84 Average loss: nan
# Train Epoch: 85 [0/41 (0%)]	Loss: nan
# ====> Epoch: 85 Average loss: nan
# Train Epoch: 86 [0/41 (0%)]	Loss: nan
# ====> Epoch: 86 Average loss: nan
# Train Epoch: 87 [0/41 (0%)]	Loss: nan
# ====> Epoch: 87 Average loss: nan
# Train Epoch: 88 [0/41 (0%)]	Loss: nan
# ====> Epoch: 88 Average loss: nan
# Train Epoch: 89 [0/41 (0%)]	Loss: nan
# ====> Epoch: 89 Average loss: nan
# Train Epoch: 90 [0/41 (0%)]	Loss: nan
# ====> Epoch: 90 Average loss: nan
# Train Epoch: 91 [0/41 (0%)]	Loss: nan
# ====> Epoch: 91 Average loss: nan
# Train Epoch: 92 [0/41 (0%)]	Loss: nan
# ====> Epoch: 92 Average loss: nan
# Train Epoch: 93 [0/41 (0%)]	Loss: nan
# ====> Epoch: 93 Average loss: nan
# Train Epoch: 94 [0/41 (0%)]	Loss: nan
# ====> Epoch: 94 Average loss: nan
# Train Epoch: 95 [0/41 (0%)]	Loss: nan
# ====> Epoch: 95 Average loss: nan
# Train Epoch: 96 [0/41 (0%)]	Loss: nan
# ====> Epoch: 96 Average loss: nan
# Train Epoch: 97 [0/41 (0%)]	Loss: nan
# ====> Epoch: 97 Average loss: nan
# Train Epoch: 98 [0/41 (0%)]	Loss: nan
# ====> Epoch: 98 Average loss: nan
# Train Epoch: 99 [0/41 (0%)]	Loss: nan
# ====> Epoch: 99 Average loss: nan
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 model, X, train_data = train_on_effect_and_parameters(v, id_model, opt, id_opt, device, n_channels, effect="seasonality", n_samples=50, epochs_per_sample=50)
#
# Cell In[59], line 20, in train_on_effect_and_parameters(model, id_model, opt, id_opt, device, n_channels, effect, n_samples, epochs_per_sample)
#      17         for epoch in range(1, 100):
#      18             train_identifier(model, id_model, labels, train_data, criterion, id_opt, device, epoch, VQ=True)
# ---> 20         test_identifier(model, id_model, labels, train_data, criterion, id_opt, device, epoch, VQ=True)
#      21         print(labels)
#      22 #         save(x, "data", effect, n_channels, latent_dims, L, i)
#      23 #         save(params, "params", effect, n_channels, latent_dims, L, i)
#      24 #         save(e_params, "e_params", effect, n_channels, latent_dims, L, i)
#      25 #         save(model, "model", effect, n_channels, latent_dims, L, i)
#
# NameError: name 'test_identifier' is not defined

# %%
extract_labels(params, e_params)
# Out:
# [tensor(506.3865), tensor(1.), tensor([11.0833,  7.1762]), tensor([15., 13.]), tensor([73.,  0.])]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 extract_labels(params, e_params)
#
# Cell In[13], line 9, in extract_labels(params, e_params)
#       7         labels.append(torch.FloatTensor(e_params["Seasonality"][param]))
#       8 print(labels)
# ----> 9 labels = torch.FloatTensor(labels.squeeze(dim=0))
#      10 return labels
#
# AttributeError: 'list' object has no attribute 'squeeze'

# %%
labels = extract_parameters(n_channels, e_params, effects)
labels = add_mu_std(labels, params)

# %%
labels
# Out:
# tensor([[  0.0000, 436.8202],
#         [  0.0000,   1.0000],
#         [  0.0000,   7.6674],
#         [  0.0000,  12.0000],
#         [  0.0000, 123.0000]])

# %%
e_params
# Out:
# {'Pulse': {'channel': [], 'index': [], 'amplitude': []},
#  'Trend': {'channel': [0, 0],
#   'index': ['2024-01-23T22:35:00', '2023-08-23T08:00:00'],
#   'slope': [-0.0005698505231139161, 0.0033191135897120095]},
#  'Seasonality': {'channel': [0, 0],
#   'frequency_per_week': [11.083252158564154, 7.176202098924219],
#   'amplitude': [15, 13],
#   'phaseshift': [73, 0]},
#  'Std_variation': {'channel': [], 'interval': [], 'amplitude': []},
#  'Channels_Coupling': {'channels': [], 'amplitude': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []}}

# %%
mu = torch.FloatTensor(params["mu"]).mean()
std = torch.diagonal(torch.FloatTensor(params["cov"])).mean()

# %%
mu = torch.tensor((0, mu))
mu
# Out:
# tensor([ 0.0000, 40.7223])

# %%
std = torch.tensor((0, std))
std
# Out:
# tensor([0., 1.])

# %%
mu_std = torch.cat((mu, std), dim=0).view(-1,2)

# %%
torch.set_printoptions(sci_mode=False)

# %%
labels = torch.cat((mu_std, labels), dim=0)

# %%
labels.shape
# Out:
# torch.Size([5, 2])

# %%
labels.shape
# Out:
# torch.Size([5, 2])

# %%
labels.squeeze(0).shape
# Out:
# torch.Size([5, 2])

# %%
labels = labels[:,1]

# %%
def compare(dataset, model, VQ=True):
    model.eval()
    rec = []
    x = []
    T = dataset.dataset.data.shape[1]- L
    idx = 0
    _mu_rec, _logvar_rec = [], []
    _mu, _logvar = [], []
#     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
#     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
    with torch.no_grad():
        for i, (data, v) in enumerate(dataset):
            bs = data.shape[0]
            if VQ:
                x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
            else:
                x_rec, mu, logvar = model(data)
            z = model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
#             print(i)
#             print(mu.shape)

            x.extend((data)[0,:,0].detach().numpy())
            rec.extend(((x_rec)[0,:,0]).detach().numpy())
            _mu_rec.extend((mu_rec)[0,:,:].detach().numpy())
            _logvar_rec.extend(((torch.exp(0.5 * logvar_rec)))[0,:,:].detach().numpy())
            
            _mu.extend((mu)[0,:,0].detach().numpy())
            _logvar.extend(((torch.exp(0.5 * logvar)))[0,:,:].detach().numpy())
#             _mu[idx: idx + bs, :, :] = mu
#             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
#     print(np.array(_mu).shape)
    
#     x = np.array(x).T
#     rec = np.array(rec).T
#     _mu = np.tile(np.array(_mu), (3455, 1))
#     _logvar = np.tile(np.array(_logvar), (3455, 1))
#     _mu_rec = np.tile(np.array(_mu_rec), (3455, 1))
#     _logvar_rec = np.tile(np.array(_logvar_rec), (3455, 1))
#     print(_logvar.shape)
#     print(x.shape)
#     print(rec.shape)
#     print(T)
#     print(params["cov"][0,:,:L].T)
    fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10, 15))
    ax = axs[0]
    ax.plot(rec, "r-")
    ax.plot(x[:], "b-", alpha=0.2)
    ax.plot(_mu_rec)
    ax.plot(params["mu"].T[:_mu.shape[0],:])
    ax.grid()
    
    ax_std = axs[1]
    ax_std.plot(_logvar_rec, "r")
    ax_std.plot(params["cov"][0,:,:L].T, "b")
    ax_std.grid()
    
    ax_enc = axs[2]
    for (i,l) in enumerate(_mu.T):        
        ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
#     ax_enc.plot(_mu, alpha = 0.2)
    ax_enc.grid()
    
    ax_log = axs[3]
    for (i,l) in enumerate(_logvar.T):        
        ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
    ax_log.grid()
    
    # Setting legend
    blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
    red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
    titles = ['Prediction of Train Data', 'Std plot', 'mu encoder vs mu from gen', 'logvar encoder vs cov']
    for (i,ax) in enumerate(axs):
        # ax.set_title('Reconstruction of Train Data')
        ax.set_title(titles[i])
        ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
    # Axes labels
    ax_std.set_xlabel('Time')
    ax.set_ylabel('Values')
    ax_std.set_ylabel('Values')
#     plt.ylim(-100,500)
#     plt.grid(True)
    fig.tight_layout()
    plt.show()
# def compare(dataset, model, VQ=True):
#     model.eval()
#     rec = []
#     x = []
#     T = dataset.dataset.data.shape[1]- L
#     idx = 0
#     _mu_rec, _logvar_rec = [], []
#     _mu, _logvar = [], []
# #     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
# #     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
#     with torch.no_grad():
#         for i, (data, v) in enumerate(dataset):
#             bs = data.shape[0]
#             if VQ:
#                 x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
#             else:
#                 x_rec, mu, logvar = model(data)
#             z = model.reparametrization_trick(mu, logvar)
#             print(v.shape)
#             if v.dim() == 1:
#                 v = v.unsqueeze(0)
#                 v = v.T
#                 v = v.unsqueeze(-1)
# #             print(v.shape)
# #             print(x_rec.shape)
# #             print((x_rec * v).shape)
# #             print(i)
# #             print(mu.shape)

#             x.extend((data)[:,:,:].detach().numpy())
#             rec.extend(((x_rec)[:,:,:]).detach().numpy())
# #             _mu_rec.extend((mu_rec*v)[:,:,0].detach().numpy())
# #             _logvar_rec.extend(((torch.exp(0.5 * logvar_rec))*v)[:,:,0].detach().numpy())
            
# #             _mu.extend((mu*v)[:,:,0].detach().numpy())
# #             _logvar.extend(((torch.exp(0.5 * logvar))*v)[:,:,0].detach().numpy())
# #             _mu[idx: idx + bs, :, :] = mu
# #             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
# #     print(np.array(rec).shape)
# #     _mu = np.array(_mu)
# #     _logvar = np.array(_logvar)
    
#     rec = np.array(rec).squeeze(0).T
#     x = np.array(x).squeeze(0).T
# #     print(x.shape)
# #     print(rec)
#     fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(10, 4))
#     ax = axs#[0]
#     ax.plot(rec, "r-")
#     ax.plot(x, "b-", alpha=0.2)
# #     ax.plot(_mu_rec)
# #     ax.plot(params["mu"].T[:_mu.shape[0],:])
#     ax.grid()
    
# #     ax_std = axs[1]
# #     ax_std.plot(_logvar_rec, "r")
# #     ax_std.plot(params["cov"][0,:,:T].T, "b")
# #     ax_std.grid()
    
# #     ax_enc = axs[2]
# #     for (i,l) in enumerate(_mu.T):        
# #         ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
# # #     ax_enc.plot(_mu, alpha = 0.2)
# #     ax_enc.grid()
    
# #     ax_log = axs[3]
# #     for (i,l) in enumerate(_logvar.T):        
# #         ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
# #     ax_log.grid()
    
#     # Setting legend
#     blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
#     red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
# #     for ax in axs:
#         # ax.set_title('Reconstruction of Train Data')
#     ax.set_title('Prediction of Test (unseen) Data')
#     ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
#     # Axes labels
# #     ax_std.set_xlabel('Time')
# #     ax.set_ylabel('Values')
# #     ax_std.set_ylabel('Values')
# #     plt.ylim(-100,500)
#     plt.grid(True)
#     fig.tight_layout()
#     plt.show()

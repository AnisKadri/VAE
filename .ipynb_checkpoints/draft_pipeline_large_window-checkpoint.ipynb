# %%
# %load_ext autoreload
# %autoreload 2
import torch; torch.manual_seed(955)
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from dataGen import Gen
from Encoders import LongShort_TCVAE_Encoder#, RnnEncoder, MST_VAE_Encoder, MST_VAE_Encoder_dist
from Decoders import LongShort_TCVAE_Decoder#, RnnDecoder, MST_VAE_Decoder, MST_VAE_Decoder_dist
from vae import Variational_Autoencoder, VQ_MST_VAE, VQ_Quantizer
from utils import train_on_effect
from train import train, train_MCMC, stridedWindow, slidingWindow, criterion

import numpy as np
import matplotlib.pyplot as plt
import pprint
# all parameters for generating the time series should be configured in this cell
periode = 61 #days
step = 5 # mess interval in minutes
val = 500
n_channels = 1
effects = {
    "Pulse": {
        "occurances":0,
        "max_amplitude":1.5,   
        "interval":40
        },
    "Trend": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        },
    "Seasonality": {
        "occurances":1,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
# pprint.pprint(params)
pprint.pprint(e_params)
X.show()
# Out:
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [5],
#                  'channel': [0],
#                  'frequency_per_week': [9.091328063199398],
#                  'phaseshift': [113]},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}

# %%
### Init Model
latent_dims = 7 # 6 # 17
L= 2016# 39 #32
device = 'cuda' if torch.cuda.is_available() else 'cpu'


# v = Variational_Autoencoder(n_channels = n_channels,
#                             num_layers =  3,#4, #3
#                             latent_dims= latent_dims,
#                             v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
#                             v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
#                             L=L,
#                             slope = 0,
#                             first_kernel = 20, #11, #20
#                             ß = 1.5,
#                             modified=True,
#                             reduction = True)
v = VQ_MST_VAE(n_channels = n_channels,
                            num_layers =  3,#4, #3
                            latent_dims= latent_dims,
                            v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
                            v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
                            v_quantizer = VQ_Quantizer,
                            L=L,
                            slope = 0,
                            first_kernel = 15, #11, #20
                            commit_loss = 2,
                            modified=True,
                            reduction = True) #10 5


v = v.to(device)

opt = optim.Adam(v.parameters(), lr = 0.005043529186448577) # 0.005043529186448577 0.006819850049647945
print(v)
x = torch.FloatTensor(x)
n = x.shape[1]

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

train_data = DataLoader(slidingWindow(train_, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=22,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=22,
                        shuffle = False
                        )
# Out:
# 1
# 6
# 1
# 6
# VQ_MST_VAE(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=252, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=252, out_features=7, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(15,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=250, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=250, out_features=7, bias=True)
#     )
#     (reduction_layer): Conv1d(12, 6, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(6, 3, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(3, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(15,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=69, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=69, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=69, out_features=2016, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(6, 3, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(3, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=56, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=56, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=56, out_features=2016, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (quantizer): VQ_Quantizer(
#     (_embedding): Embedding(6, 7)
#   )
#   (bn): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
train_data = DataLoader(stridedWindow(train_, L, stride = 0),
                        batch_size= 1,# 59, # 22
                        shuffle = False
                        )

# %%
for i, (batch, norm) in enumerate(train_data):
    print(i, batch.shape)
# Out:
# 0 torch.Size([1, 1, 4032])
# 1 torch.Size([1, 1, 4032])
# 2 torch.Size([1, 1, 4032])

# %%
288*7
# Out:
# 2016

# %%
v, X, train_data = train_on_effect(v, opt, device, n_channels=n_channels, effect='no_effect', n_samples=3, epochs_per_sample=15)
v, X, train_data = train_on_effect(v, opt, device, n_channels=n_channels, effect='trend', n_samples=3, epochs_per_sample=15)
v, X, train_data = train_on_effect(v, opt, device, n_channels=n_channels, effect='seasonality', n_samples=3, epochs_per_sample=15)
# Out:
# Train Epoch: 1 [0/12038 (0%)]	Loss: 10.287684
# Train Epoch: 1 [2200/12038 (18%)]	Loss: 12.089530
# Train Epoch: 1 [4400/12038 (36%)]	Loss: 10.947139
# Train Epoch: 1 [6600/12038 (55%)]	Loss: 11.292496
# Train Epoch: 1 [8800/12038 (73%)]	Loss: 11.092896
# Train Epoch: 1 [11000/12038 (91%)]	Loss: 11.190076
# ====> Epoch: 1 Average loss: 11.3793
# Train Epoch: 2 [0/12038 (0%)]	Loss: 11.117416
# Train Epoch: 2 [2200/12038 (18%)]	Loss: 11.436493
# Train Epoch: 2 [4400/12038 (36%)]	Loss: 10.711026
# Train Epoch: 2 [6600/12038 (55%)]	Loss: 11.218045
# Train Epoch: 2 [8800/12038 (73%)]	Loss: 10.972451
# Train Epoch: 2 [11000/12038 (91%)]	Loss: 11.236454
# ====> Epoch: 2 Average loss: 11.1192
# Train Epoch: 3 [0/12038 (0%)]	Loss: 10.940177
# Train Epoch: 3 [2200/12038 (18%)]	Loss: 11.428839
# Train Epoch: 3 [4400/12038 (36%)]	Loss: 10.600596
# Train Epoch: 3 [6600/12038 (55%)]	Loss: 11.066813
# Train Epoch: 3 [8800/12038 (73%)]	Loss: 10.867518
# Train Epoch: 3 [11000/12038 (91%)]	Loss: 11.241883
# ====> Epoch: 3 Average loss: 11.0266
# Train Epoch: 4 [0/12038 (0%)]	Loss: 10.644854
# Train Epoch: 4 [2200/12038 (18%)]	Loss: 11.342022
# Train Epoch: 4 [4400/12038 (36%)]	Loss: 10.535301
# Train Epoch: 4 [6600/12038 (55%)]	Loss: 10.968720
# Train Epoch: 4 [8800/12038 (73%)]	Loss: 10.801543
# Train Epoch: 4 [11000/12038 (91%)]	Loss: 11.090915
# ====> Epoch: 4 Average loss: 10.9392
# Train Epoch: 5 [0/12038 (0%)]	Loss: 10.510879
# Train Epoch: 5 [2200/12038 (18%)]	Loss: 11.250746
# Train Epoch: 5 [4400/12038 (36%)]	Loss: 10.497815
# Train Epoch: 5 [6600/12038 (55%)]	Loss: 10.951689
# Train Epoch: 5 [8800/12038 (73%)]	Loss: 10.748710
# Train Epoch: 5 [11000/12038 (91%)]	Loss: 10.861641
# ====> Epoch: 5 Average loss: 10.8712
# Train Epoch: 6 [0/12038 (0%)]	Loss: 10.616362
# Train Epoch: 6 [2200/12038 (18%)]	Loss: 11.198919
# Train Epoch: 6 [4400/12038 (36%)]	Loss: 10.476575
# Train Epoch: 6 [6600/12038 (55%)]	Loss: 10.934305
# Train Epoch: 6 [8800/12038 (73%)]	Loss: 10.696993
# Train Epoch: 6 [11000/12038 (91%)]	Loss: 10.920199
# ====> Epoch: 6 Average loss: 10.8269
# Train Epoch: 7 [0/12038 (0%)]	Loss: 10.421390
# Train Epoch: 7 [2200/12038 (18%)]	Loss: 11.035943
# Train Epoch: 7 [4400/12038 (36%)]	Loss: 10.447218
# Train Epoch: 7 [6600/12038 (55%)]	Loss: 10.879029
# Train Epoch: 7 [8800/12038 (73%)]	Loss: 10.689800
# Train Epoch: 7 [11000/12038 (91%)]	Loss: 10.647711
# ====> Epoch: 7 Average loss: 10.7863
# Train Epoch: 8 [0/12038 (0%)]	Loss: 10.476381
# Train Epoch: 8 [2200/12038 (18%)]	Loss: 10.819160
# Train Epoch: 8 [4400/12038 (36%)]	Loss: 10.467326
# Train Epoch: 8 [6600/12038 (55%)]	Loss: 10.910304
# Train Epoch: 8 [8800/12038 (73%)]	Loss: 10.645450
# Train Epoch: 8 [11000/12038 (91%)]	Loss: 10.980899
# ====> Epoch: 8 Average loss: 10.7580
# Train Epoch: 9 [0/12038 (0%)]	Loss: 10.421772
# Train Epoch: 9 [2200/12038 (18%)]	Loss: 10.939590
# Train Epoch: 9 [4400/12038 (36%)]	Loss: 10.449449
# Train Epoch: 9 [6600/12038 (55%)]	Loss: 10.890339
# Train Epoch: 9 [8800/12038 (73%)]	Loss: 10.594394
# Train Epoch: 9 [11000/12038 (91%)]	Loss: 11.015744
# ====> Epoch: 9 Average loss: 10.7368
# Train Epoch: 10 [0/12038 (0%)]	Loss: 10.380658
# Train Epoch: 10 [2200/12038 (18%)]	Loss: 11.109629
# Train Epoch: 10 [4400/12038 (36%)]	Loss: 10.418039
# Train Epoch: 10 [6600/12038 (55%)]	Loss: 10.891638
# Train Epoch: 10 [8800/12038 (73%)]	Loss: 10.678897
# Train Epoch: 10 [11000/12038 (91%)]	Loss: 10.866287
# ====> Epoch: 10 Average loss: 10.7339
# Train Epoch: 11 [0/12038 (0%)]	Loss: 10.404737
# Train Epoch: 11 [2200/12038 (18%)]	Loss: 11.023754
# Train Epoch: 11 [4400/12038 (36%)]	Loss: 10.443769
# Train Epoch: 11 [6600/12038 (55%)]	Loss: 10.901391
# Train Epoch: 11 [8800/12038 (73%)]	Loss: 10.599988
# Train Epoch: 11 [11000/12038 (91%)]	Loss: 10.707719
# ====> Epoch: 11 Average loss: 10.7279
# Train Epoch: 12 [0/12038 (0%)]	Loss: 10.325821
# Train Epoch: 12 [2200/12038 (18%)]	Loss: 10.920067
# Train Epoch: 12 [4400/12038 (36%)]	Loss: 10.445517
# Train Epoch: 12 [6600/12038 (55%)]	Loss: 10.905391
# Train Epoch: 12 [8800/12038 (73%)]	Loss: 10.653050
# Train Epoch: 12 [11000/12038 (91%)]	Loss: 10.757464
# ====> Epoch: 12 Average loss: 10.7137
# Train Epoch: 13 [0/12038 (0%)]	Loss: 10.351576
# Train Epoch: 13 [2200/12038 (18%)]	Loss: 10.869406
# Train Epoch: 13 [4400/12038 (36%)]	Loss: 10.424273
# Train Epoch: 13 [6600/12038 (55%)]	Loss: 10.900082
# Train Epoch: 13 [8800/12038 (73%)]	Loss: 10.619003
# Train Epoch: 13 [11000/12038 (91%)]	Loss: 10.671761
# ====> Epoch: 13 Average loss: 10.7115
# Train Epoch: 14 [0/12038 (0%)]	Loss: 10.364653
# Train Epoch: 14 [2200/12038 (18%)]	Loss: 10.878434
# Train Epoch: 14 [4400/12038 (36%)]	Loss: 10.428764
# Train Epoch: 14 [6600/12038 (55%)]	Loss: 10.842637
# Train Epoch: 14 [8800/12038 (73%)]	Loss: 10.539534
# Train Epoch: 14 [11000/12038 (91%)]	Loss: 10.664273
# ====> Epoch: 14 Average loss: 10.6920
# Train Epoch: 1 [0/12038 (0%)]	Loss: 0.273597
# Train Epoch: 1 [2200/12038 (18%)]	Loss: 0.022724
# Train Epoch: 1 [4400/12038 (36%)]	Loss: 0.020263
# Train Epoch: 1 [6600/12038 (55%)]	Loss: 0.017133
# Train Epoch: 1 [8800/12038 (73%)]	Loss: 0.019327
# Train Epoch: 1 [11000/12038 (91%)]	Loss: 0.016209
# ====> Epoch: 1 Average loss: 0.0270
# Train Epoch: 2 [0/12038 (0%)]	Loss: 0.045724
# Train Epoch: 2 [2200/12038 (18%)]	Loss: 0.016246
# Train Epoch: 2 [4400/12038 (36%)]	Loss: 0.016768
# Train Epoch: 2 [6600/12038 (55%)]	Loss: 0.017891
# Train Epoch: 2 [8800/12038 (73%)]	Loss: 0.016469
# Train Epoch: 2 [11000/12038 (91%)]	Loss: 0.015923
# ====> Epoch: 2 Average loss: 0.0185
# Train Epoch: 3 [0/12038 (0%)]	Loss: 0.042124
# Train Epoch: 3 [2200/12038 (18%)]	Loss: 0.016334
# Train Epoch: 3 [4400/12038 (36%)]	Loss: 0.016145
# Train Epoch: 3 [6600/12038 (55%)]	Loss: 0.014114
# Train Epoch: 3 [8800/12038 (73%)]	Loss: 0.017588
# Train Epoch: 3 [11000/12038 (91%)]	Loss: 0.014284
# ====> Epoch: 3 Average loss: 0.0195
# Train Epoch: 4 [0/12038 (0%)]	Loss: 0.014867
# Train Epoch: 4 [2200/12038 (18%)]	Loss: 0.013131
# Train Epoch: 4 [4400/12038 (36%)]	Loss: 0.015708
# Train Epoch: 4 [6600/12038 (55%)]	Loss: 0.013319
# Train Epoch: 4 [8800/12038 (73%)]	Loss: 0.015309
# Train Epoch: 4 [11000/12038 (91%)]	Loss: 0.014271
# ====> Epoch: 4 Average loss: 0.0155
# Train Epoch: 5 [0/12038 (0%)]	Loss: 0.021029
# Train Epoch: 5 [2200/12038 (18%)]	Loss: 0.014328
# Train Epoch: 5 [4400/12038 (36%)]	Loss: 0.015322
# Train Epoch: 5 [6600/12038 (55%)]	Loss: 0.014514
# Train Epoch: 5 [8800/12038 (73%)]	Loss: 0.015972
# Train Epoch: 5 [11000/12038 (91%)]	Loss: 0.012889
# ====> Epoch: 5 Average loss: 0.0162
# Train Epoch: 6 [0/12038 (0%)]	Loss: 0.014437
# Train Epoch: 6 [2200/12038 (18%)]	Loss: 0.017973
# Train Epoch: 6 [4400/12038 (36%)]	Loss: 0.014253
# Train Epoch: 6 [6600/12038 (55%)]	Loss: 0.050493
# Train Epoch: 6 [8800/12038 (73%)]	Loss: 0.014464
# Train Epoch: 6 [11000/12038 (91%)]	Loss: 0.013027
# ====> Epoch: 6 Average loss: 0.0148
# Train Epoch: 7 [0/12038 (0%)]	Loss: 0.014809
# Train Epoch: 7 [2200/12038 (18%)]	Loss: 0.013191
# Train Epoch: 7 [4400/12038 (36%)]	Loss: 0.014056
# Train Epoch: 7 [6600/12038 (55%)]	Loss: 0.015195
# Train Epoch: 7 [8800/12038 (73%)]	Loss: 0.013604
# Train Epoch: 7 [11000/12038 (91%)]	Loss: 0.012474
# ====> Epoch: 7 Average loss: 0.0147
# Train Epoch: 8 [0/12038 (0%)]	Loss: 0.013137
# Train Epoch: 8 [2200/12038 (18%)]	Loss: 0.013231
# Train Epoch: 8 [4400/12038 (36%)]	Loss: 0.013880
# Train Epoch: 8 [6600/12038 (55%)]	Loss: 0.012867
# Train Epoch: 8 [8800/12038 (73%)]	Loss: 0.013039
# Train Epoch: 8 [11000/12038 (91%)]	Loss: 0.012986
# ====> Epoch: 8 Average loss: 0.0146
# Train Epoch: 9 [0/12038 (0%)]	Loss: 0.013645
# Train Epoch: 9 [2200/12038 (18%)]	Loss: 0.012350
# Train Epoch: 9 [4400/12038 (36%)]	Loss: 0.013705
# Train Epoch: 9 [6600/12038 (55%)]	Loss: 0.016637
# Train Epoch: 9 [8800/12038 (73%)]	Loss: 0.013154
# Train Epoch: 9 [11000/12038 (91%)]	Loss: 0.012382
# ====> Epoch: 9 Average loss: 0.0139
# Train Epoch: 10 [0/12038 (0%)]	Loss: 0.019266
# Train Epoch: 10 [2200/12038 (18%)]	Loss: 0.013017
# Train Epoch: 10 [4400/12038 (36%)]	Loss: 0.015717
# Train Epoch: 10 [6600/12038 (55%)]	Loss: 0.012864
# Train Epoch: 10 [8800/12038 (73%)]	Loss: 0.012506
# Train Epoch: 10 [11000/12038 (91%)]	Loss: 0.014343
# ====> Epoch: 10 Average loss: 0.0141
# Train Epoch: 11 [0/12038 (0%)]	Loss: 0.013997
# Train Epoch: 11 [2200/12038 (18%)]	Loss: 0.012964
# Train Epoch: 11 [4400/12038 (36%)]	Loss: 0.014775
# Train Epoch: 11 [6600/12038 (55%)]	Loss: 0.013058
# Train Epoch: 11 [8800/12038 (73%)]	Loss: 0.010820
# Train Epoch: 11 [11000/12038 (91%)]	Loss: 0.012424
# ====> Epoch: 11 Average loss: 0.0141
# Train Epoch: 12 [0/12038 (0%)]	Loss: 0.013942
# Train Epoch: 12 [2200/12038 (18%)]	Loss: 0.013911
# Train Epoch: 12 [4400/12038 (36%)]	Loss: 0.014270
# Train Epoch: 12 [6600/12038 (55%)]	Loss: 0.012135
# Train Epoch: 12 [8800/12038 (73%)]	Loss: 0.010953
# Train Epoch: 12 [11000/12038 (91%)]	Loss: 0.012463
# ====> Epoch: 12 Average loss: 0.0139
# Train Epoch: 13 [0/12038 (0%)]	Loss: 0.035175
# Train Epoch: 13 [2200/12038 (18%)]	Loss: 0.012662
# Train Epoch: 13 [4400/12038 (36%)]	Loss: 0.012923
# Train Epoch: 13 [6600/12038 (55%)]	Loss: 0.010901
# Train Epoch: 13 [8800/12038 (73%)]	Loss: 0.010753
# Train Epoch: 13 [11000/12038 (91%)]	Loss: 0.011701
# ====> Epoch: 13 Average loss: 0.0141
# Train Epoch: 14 [0/12038 (0%)]	Loss: 0.012548
# Train Epoch: 14 [2200/12038 (18%)]	Loss: 0.013048
# Train Epoch: 14 [4400/12038 (36%)]	Loss: 0.012685
# Train Epoch: 14 [6600/12038 (55%)]	Loss: 0.012060
# Train Epoch: 14 [8800/12038 (73%)]	Loss: 0.010261
# Train Epoch: 14 [11000/12038 (91%)]	Loss: 0.011892
# ====> Epoch: 14 Average loss: 0.0125
# Train Epoch: 1 [0/12038 (0%)]	Loss: 0.020699
# Train Epoch: 1 [2200/12038 (18%)]	Loss: 0.014087
# Train Epoch: 1 [4400/12038 (36%)]	Loss: 0.014969
# Train Epoch: 1 [6600/12038 (55%)]	Loss: 0.014523
# Train Epoch: 1 [8800/12038 (73%)]	Loss: 0.014373
# Train Epoch: 1 [11000/12038 (91%)]	Loss: 0.014190
# ====> Epoch: 1 Average loss: 0.0160
# Train Epoch: 2 [0/12038 (0%)]	Loss: 0.018664
# Train Epoch: 2 [2200/12038 (18%)]	Loss: 0.018098
# Train Epoch: 2 [4400/12038 (36%)]	Loss: 0.015195
# Train Epoch: 2 [6600/12038 (55%)]	Loss: 0.014140
# Train Epoch: 2 [8800/12038 (73%)]	Loss: 0.014307
# Train Epoch: 2 [11000/12038 (91%)]	Loss: 0.014280
# ====> Epoch: 2 Average loss: 0.0151
# Train Epoch: 3 [0/12038 (0%)]	Loss: 0.018444
# Train Epoch: 3 [2200/12038 (18%)]	Loss: 0.015359
# Train Epoch: 3 [4400/12038 (36%)]	Loss: 0.014524
# Train Epoch: 3 [6600/12038 (55%)]	Loss: 0.013359
# Train Epoch: 3 [8800/12038 (73%)]	Loss: 0.014179
# Train Epoch: 3 [11000/12038 (91%)]	Loss: 0.013400
# ====> Epoch: 3 Average loss: 0.0148
# Train Epoch: 4 [0/12038 (0%)]	Loss: 0.017756
# Train Epoch: 4 [2200/12038 (18%)]	Loss: 0.014994
# Train Epoch: 4 [4400/12038 (36%)]	Loss: 0.013805
# Train Epoch: 4 [6600/12038 (55%)]	Loss: 0.013079
# Train Epoch: 4 [8800/12038 (73%)]	Loss: 0.012905
# Train Epoch: 4 [11000/12038 (91%)]	Loss: 0.019894
# ====> Epoch: 4 Average loss: 0.0145
# Train Epoch: 5 [0/12038 (0%)]	Loss: 0.016364
# Train Epoch: 5 [2200/12038 (18%)]	Loss: 0.014234
# Train Epoch: 5 [4400/12038 (36%)]	Loss: 0.013543
# Train Epoch: 5 [6600/12038 (55%)]	Loss: 0.013371
# Train Epoch: 5 [8800/12038 (73%)]	Loss: 0.013506
# Train Epoch: 5 [11000/12038 (91%)]	Loss: 0.015181
# ====> Epoch: 5 Average loss: 0.0142
# Train Epoch: 6 [0/12038 (0%)]	Loss: 0.016193
# Train Epoch: 6 [2200/12038 (18%)]	Loss: 0.013569
# Train Epoch: 6 [4400/12038 (36%)]	Loss: 0.012986
# Train Epoch: 6 [6600/12038 (55%)]	Loss: 0.013814
# Train Epoch: 6 [8800/12038 (73%)]	Loss: 0.020723
# Train Epoch: 6 [11000/12038 (91%)]	Loss: 0.014132
# ====> Epoch: 6 Average loss: 0.0142
# Train Epoch: 7 [0/12038 (0%)]	Loss: 0.017392
# Train Epoch: 7 [2200/12038 (18%)]	Loss: 0.012939
# Train Epoch: 7 [4400/12038 (36%)]	Loss: 0.013046
# Train Epoch: 7 [6600/12038 (55%)]	Loss: 0.013720
# Train Epoch: 7 [8800/12038 (73%)]	Loss: 0.012079
# Train Epoch: 7 [11000/12038 (91%)]	Loss: 0.013441
# ====> Epoch: 7 Average loss: 0.0147
# Train Epoch: 8 [0/12038 (0%)]	Loss: 0.014849
# Train Epoch: 8 [2200/12038 (18%)]	Loss: 0.012737
# Train Epoch: 8 [4400/12038 (36%)]	Loss: 0.012608
# Train Epoch: 8 [6600/12038 (55%)]	Loss: 0.014028
# Train Epoch: 8 [8800/12038 (73%)]	Loss: 0.012106
# Train Epoch: 8 [11000/12038 (91%)]	Loss: 0.013669
# ====> Epoch: 8 Average loss: 0.0136
# Train Epoch: 9 [0/12038 (0%)]	Loss: 0.013876
# Train Epoch: 9 [2200/12038 (18%)]	Loss: 0.013289
# Train Epoch: 9 [4400/12038 (36%)]	Loss: 0.013047
# Train Epoch: 9 [6600/12038 (55%)]	Loss: 0.013168
# Train Epoch: 9 [8800/12038 (73%)]	Loss: 0.011869
# Train Epoch: 9 [11000/12038 (91%)]	Loss: 0.013115
# ====> Epoch: 9 Average loss: 0.0136
# Train Epoch: 10 [0/12038 (0%)]	Loss: 0.017228
# Train Epoch: 10 [2200/12038 (18%)]	Loss: 0.012399
# Train Epoch: 10 [4400/12038 (36%)]	Loss: 0.012828
# Train Epoch: 10 [6600/12038 (55%)]	Loss: 0.012613
# Train Epoch: 10 [8800/12038 (73%)]	Loss: 0.012159
# Train Epoch: 10 [11000/12038 (91%)]	Loss: 0.013178
# ====> Epoch: 10 Average loss: 0.0133
# Train Epoch: 11 [0/12038 (0%)]	Loss: 0.014187
# Train Epoch: 11 [2200/12038 (18%)]	Loss: 0.012742
# Train Epoch: 11 [4400/12038 (36%)]	Loss: 0.012818
# Train Epoch: 11 [6600/12038 (55%)]	Loss: 0.012239
# Train Epoch: 11 [8800/12038 (73%)]	Loss: 0.012970
# Train Epoch: 11 [11000/12038 (91%)]	Loss: 0.012804
# ====> Epoch: 11 Average loss: 0.0133
# Train Epoch: 12 [0/12038 (0%)]	Loss: 0.042265
# Train Epoch: 12 [2200/12038 (18%)]	Loss: 0.012244
# Train Epoch: 12 [4400/12038 (36%)]	Loss: 0.011442
# Train Epoch: 12 [6600/12038 (55%)]	Loss: 0.011596
# Train Epoch: 12 [8800/12038 (73%)]	Loss: 0.011443
# Train Epoch: 12 [11000/12038 (91%)]	Loss: 0.011769
# ====> Epoch: 12 Average loss: 0.0228
# Train Epoch: 13 [0/12038 (0%)]	Loss: 0.011495
# Train Epoch: 13 [2200/12038 (18%)]	Loss: 0.011548
# Train Epoch: 13 [4400/12038 (36%)]	Loss: 0.011725
# Train Epoch: 13 [6600/12038 (55%)]	Loss: 0.011547
# Train Epoch: 13 [8800/12038 (73%)]	Loss: 0.011234
# Train Epoch: 13 [11000/12038 (91%)]	Loss: 0.012143
# ====> Epoch: 13 Average loss: 0.0116
# Train Epoch: 14 [0/12038 (0%)]	Loss: 0.011631
# Train Epoch: 14 [2200/12038 (18%)]	Loss: 0.011871
# Train Epoch: 14 [4400/12038 (36%)]	Loss: 0.012252
# Train Epoch: 14 [6600/12038 (55%)]	Loss: 0.011797
# Train Epoch: 14 [8800/12038 (73%)]	Loss: 0.011248
# Train Epoch: 14 [11000/12038 (91%)]	Loss: 0.012225
# ====> Epoch: 14 Average loss: 0.0119
# Train Epoch: 1 [0/12038 (0%)]	Loss: 0.016732
# Train Epoch: 1 [2200/12038 (18%)]	Loss: 0.019626
# Train Epoch: 1 [4400/12038 (36%)]	Loss: 0.016524
# Train Epoch: 1 [6600/12038 (55%)]	Loss: 0.013131
# Train Epoch: 1 [8800/12038 (73%)]	Loss: 0.009596
# Train Epoch: 1 [11000/12038 (91%)]	Loss: 0.008614
# ====> Epoch: 1 Average loss: 0.0138
# Train Epoch: 2 [0/12038 (0%)]	Loss: 1.307463
# Train Epoch: 2 [2200/12038 (18%)]	Loss: 0.019658
# Train Epoch: 2 [4400/12038 (36%)]	Loss: 0.019446
# Train Epoch: 2 [6600/12038 (55%)]	Loss: 0.013014
# Train Epoch: 2 [8800/12038 (73%)]	Loss: 0.010070
# Train Epoch: 2 [11000/12038 (91%)]	Loss: 0.008485
# ====> Epoch: 2 Average loss: 0.0238
# Train Epoch: 3 [0/12038 (0%)]	Loss: 1.307373
# Train Epoch: 3 [2200/12038 (18%)]	Loss: 0.019333
# Train Epoch: 3 [4400/12038 (36%)]	Loss: 0.017328
# Train Epoch: 3 [6600/12038 (55%)]	Loss: 0.012224
# Train Epoch: 3 [8800/12038 (73%)]	Loss: 0.009559
# Train Epoch: 3 [11000/12038 (91%)]	Loss: 0.008125
# ====> Epoch: 3 Average loss: 0.0216
# Train Epoch: 4 [0/12038 (0%)]	Loss: 1.144732
# Train Epoch: 4 [2200/12038 (18%)]	Loss: 0.019124
# Train Epoch: 4 [4400/12038 (36%)]	Loss: 0.016542
# Train Epoch: 4 [6600/12038 (55%)]	Loss: 0.012427
# Train Epoch: 4 [8800/12038 (73%)]	Loss: 0.009542
# Train Epoch: 4 [11000/12038 (91%)]	Loss: 0.008181
# ====> Epoch: 4 Average loss: 0.0249
# Train Epoch: 5 [0/12038 (0%)]	Loss: 1.309174
# Train Epoch: 5 [2200/12038 (18%)]	Loss: 0.018875
# Train Epoch: 5 [4400/12038 (36%)]	Loss: 0.016706
# Train Epoch: 5 [6600/12038 (55%)]	Loss: 0.012602
# Train Epoch: 5 [8800/12038 (73%)]	Loss: 0.009530
# Train Epoch: 5 [11000/12038 (91%)]	Loss: 0.008206
# ====> Epoch: 5 Average loss: 0.0235
# Train Epoch: 6 [0/12038 (0%)]	Loss: 1.314541
# Train Epoch: 6 [2200/12038 (18%)]	Loss: 0.018548
# Train Epoch: 6 [4400/12038 (36%)]	Loss: 0.016305
# Train Epoch: 6 [6600/12038 (55%)]	Loss: 0.012423
# Train Epoch: 6 [8800/12038 (73%)]	Loss: 0.009531
# Train Epoch: 6 [11000/12038 (91%)]	Loss: 0.008123
# ====> Epoch: 6 Average loss: 0.0235
# Train Epoch: 7 [0/12038 (0%)]	Loss: 1.304450
# Train Epoch: 7 [2200/12038 (18%)]	Loss: 0.019568
# Train Epoch: 7 [4400/12038 (36%)]	Loss: 0.017070
# Train Epoch: 7 [6600/12038 (55%)]	Loss: 0.012570
# Train Epoch: 7 [8800/12038 (73%)]	Loss: 0.009572
# Train Epoch: 7 [11000/12038 (91%)]	Loss: 0.008457
# ====> Epoch: 7 Average loss: 0.0219
# Train Epoch: 8 [0/12038 (0%)]	Loss: 1.300014
# Train Epoch: 8 [2200/12038 (18%)]	Loss: 0.018478
# Train Epoch: 8 [4400/12038 (36%)]	Loss: 0.016281
# Train Epoch: 8 [6600/12038 (55%)]	Loss: 0.012024
# Train Epoch: 8 [8800/12038 (73%)]	Loss: 0.009298
# Train Epoch: 8 [11000/12038 (91%)]	Loss: 0.007928
# ====> Epoch: 8 Average loss: 0.0240
# Train Epoch: 9 [0/12038 (0%)]	Loss: 1.310573
# Train Epoch: 9 [2200/12038 (18%)]	Loss: 0.019279
# Train Epoch: 9 [4400/12038 (36%)]	Loss: 0.016718
# Train Epoch: 9 [6600/12038 (55%)]	Loss: 0.012612
# Train Epoch: 9 [8800/12038 (73%)]	Loss: 0.009616
# Train Epoch: 9 [11000/12038 (91%)]	Loss: 0.008166
# ====> Epoch: 9 Average loss: 0.0245
# Train Epoch: 10 [0/12038 (0%)]	Loss: 1.290531
# Train Epoch: 10 [2200/12038 (18%)]	Loss: 0.018552
# Train Epoch: 10 [4400/12038 (36%)]	Loss: 0.017045
# Train Epoch: 10 [6600/12038 (55%)]	Loss: 0.012001
# Train Epoch: 10 [8800/12038 (73%)]	Loss: 0.009384
# Train Epoch: 10 [11000/12038 (91%)]	Loss: 0.007959
# ====> Epoch: 10 Average loss: 0.0230
# Train Epoch: 11 [0/12038 (0%)]	Loss: 1.304264
# Train Epoch: 11 [2200/12038 (18%)]	Loss: 0.018868
# Train Epoch: 11 [4400/12038 (36%)]	Loss: 0.016279
# Train Epoch: 11 [6600/12038 (55%)]	Loss: 0.012259
# Train Epoch: 11 [8800/12038 (73%)]	Loss: 0.009433
# Train Epoch: 11 [11000/12038 (91%)]	Loss: 0.007937
# ====> Epoch: 11 Average loss: 0.0249
# Train Epoch: 12 [0/12038 (0%)]	Loss: 1.317850
# Train Epoch: 12 [2200/12038 (18%)]	Loss: 0.018424
# Train Epoch: 12 [4400/12038 (36%)]	Loss: 0.016993
# Train Epoch: 12 [6600/12038 (55%)]	Loss: 0.011994
# Train Epoch: 12 [8800/12038 (73%)]	Loss: 0.009396
# Train Epoch: 12 [11000/12038 (91%)]	Loss: 0.007920
# ====> Epoch: 12 Average loss: 0.0226
# Train Epoch: 13 [0/12038 (0%)]	Loss: 1.294823
# Train Epoch: 13 [2200/12038 (18%)]	Loss: 0.018931
# Train Epoch: 13 [4400/12038 (36%)]	Loss: 0.016868
# Train Epoch: 13 [6600/12038 (55%)]	Loss: 0.012482
# Train Epoch: 13 [8800/12038 (73%)]	Loss: 0.009623
# Train Epoch: 13 [11000/12038 (91%)]	Loss: 0.008325
# ====> Epoch: 13 Average loss: 0.0231
# Train Epoch: 14 [0/12038 (0%)]	Loss: 1.301152
# Train Epoch: 14 [2200/12038 (18%)]	Loss: 0.018213
# Train Epoch: 14 [4400/12038 (36%)]	Loss: 0.016440
# Train Epoch: 14 [6600/12038 (55%)]	Loss: 0.012026
# Train Epoch: 14 [8800/12038 (73%)]	Loss: 0.009333
# Train Epoch: 14 [11000/12038 (91%)]	Loss: 0.007919
# ====> Epoch: 14 Average loss: 0.0241
# Train Epoch: 1 [0/12038 (0%)]	Loss: 2.259666
# Train Epoch: 1 [2200/12038 (18%)]	Loss: 0.975711
# Train Epoch: 1 [4400/12038 (36%)]	Loss: 0.773414
# Train Epoch: 1 [6600/12038 (55%)]	Loss: 0.357776
# Train Epoch: 1 [8800/12038 (73%)]	Loss: 0.204443
# Train Epoch: 1 [11000/12038 (91%)]	Loss: 0.127896
# ====> Epoch: 1 Average loss: 0.5471
# Train Epoch: 2 [0/12038 (0%)]	Loss: 5.555353
# Train Epoch: 2 [2200/12038 (18%)]	Loss: 0.975310
# Train Epoch: 2 [4400/12038 (36%)]	Loss: 0.762857
# Train Epoch: 2 [6600/12038 (55%)]	Loss: 0.353315
# Train Epoch: 2 [8800/12038 (73%)]	Loss: 0.203649
# Train Epoch: 2 [11000/12038 (91%)]	Loss: 0.128403
# ====> Epoch: 2 Average loss: 0.5738
# Train Epoch: 3 [0/12038 (0%)]	Loss: 5.587747
# Train Epoch: 3 [2200/12038 (18%)]	Loss: 0.977514
# Train Epoch: 3 [4400/12038 (36%)]	Loss: 0.764750
# Train Epoch: 3 [6600/12038 (55%)]	Loss: 0.352827
# Train Epoch: 3 [8800/12038 (73%)]	Loss: 0.201126
# Train Epoch: 3 [11000/12038 (91%)]	Loss: 0.126329
# ====> Epoch: 3 Average loss: 0.5783
# Train Epoch: 4 [0/12038 (0%)]	Loss: 5.584689
# Train Epoch: 4 [2200/12038 (18%)]	Loss: 0.974657
# Train Epoch: 4 [4400/12038 (36%)]	Loss: 0.759287
# Train Epoch: 4 [6600/12038 (55%)]	Loss: 0.349359
# Train Epoch: 4 [8800/12038 (73%)]	Loss: 0.201922
# Train Epoch: 4 [11000/12038 (91%)]	Loss: 0.128047
# ====> Epoch: 4 Average loss: 0.5691
# Train Epoch: 5 [0/12038 (0%)]	Loss: 5.620256
# Train Epoch: 5 [2200/12038 (18%)]	Loss: 0.963508
# Train Epoch: 5 [4400/12038 (36%)]	Loss: 0.759098
# Train Epoch: 5 [6600/12038 (55%)]	Loss: 0.349602
# Train Epoch: 5 [8800/12038 (73%)]	Loss: 0.200828
# Train Epoch: 5 [11000/12038 (91%)]	Loss: 0.127663
# ====> Epoch: 5 Average loss: 0.5721
# Train Epoch: 6 [0/12038 (0%)]	Loss: 5.572424
# Train Epoch: 6 [2200/12038 (18%)]	Loss: 0.976029
# Train Epoch: 6 [4400/12038 (36%)]	Loss: 0.759667
# Train Epoch: 6 [6600/12038 (55%)]	Loss: 0.351230
# Train Epoch: 6 [8800/12038 (73%)]	Loss: 0.201642
# Train Epoch: 6 [11000/12038 (91%)]	Loss: 0.126676
# ====> Epoch: 6 Average loss: 0.5688
# Train Epoch: 7 [0/12038 (0%)]	Loss: 5.574972
# Train Epoch: 7 [2200/12038 (18%)]	Loss: 0.965167
# Train Epoch: 7 [4400/12038 (36%)]	Loss: 0.769283
# Train Epoch: 7 [6600/12038 (55%)]	Loss: 0.351636
# Train Epoch: 7 [8800/12038 (73%)]	Loss: 0.201133
# Train Epoch: 7 [11000/12038 (91%)]	Loss: 0.126616
# ====> Epoch: 7 Average loss: 0.5667
# Train Epoch: 8 [0/12038 (0%)]	Loss: 5.588766
# Train Epoch: 8 [2200/12038 (18%)]	Loss: 0.967599
# Train Epoch: 8 [4400/12038 (36%)]	Loss: 0.762729
# Train Epoch: 8 [6600/12038 (55%)]	Loss: 0.351969
# Train Epoch: 8 [8800/12038 (73%)]	Loss: 0.202316
# Train Epoch: 8 [11000/12038 (91%)]	Loss: 0.127185
# ====> Epoch: 8 Average loss: 0.5781
# Train Epoch: 9 [0/12038 (0%)]	Loss: 5.630625
# Train Epoch: 9 [2200/12038 (18%)]	Loss: 0.963798
# Train Epoch: 9 [4400/12038 (36%)]	Loss: 0.760534
# Train Epoch: 9 [6600/12038 (55%)]	Loss: 0.350384
# Train Epoch: 9 [8800/12038 (73%)]	Loss: 0.201467
# Train Epoch: 9 [11000/12038 (91%)]	Loss: 0.127388
# ====> Epoch: 9 Average loss: 0.5707
# Train Epoch: 10 [0/12038 (0%)]	Loss: 5.614417
# Train Epoch: 10 [2200/12038 (18%)]	Loss: 0.978750
# Train Epoch: 10 [4400/12038 (36%)]	Loss: 0.767837
# Train Epoch: 10 [6600/12038 (55%)]	Loss: 0.353583
# Train Epoch: 10 [8800/12038 (73%)]	Loss: 0.201630
# Train Epoch: 10 [11000/12038 (91%)]	Loss: 0.126251
# ====> Epoch: 10 Average loss: 0.5718
# Train Epoch: 11 [0/12038 (0%)]	Loss: 5.588607
# Train Epoch: 11 [2200/12038 (18%)]	Loss: 0.974994
# Train Epoch: 11 [4400/12038 (36%)]	Loss: 0.761036
# Train Epoch: 11 [6600/12038 (55%)]	Loss: 0.350303
# Train Epoch: 11 [8800/12038 (73%)]	Loss: 0.200407
# Train Epoch: 11 [11000/12038 (91%)]	Loss: 0.126533
# ====> Epoch: 11 Average loss: 0.5648
# Train Epoch: 12 [0/12038 (0%)]	Loss: 5.613489
# Train Epoch: 12 [2200/12038 (18%)]	Loss: 0.961943
# Train Epoch: 12 [4400/12038 (36%)]	Loss: 0.764593
# Train Epoch: 12 [6600/12038 (55%)]	Loss: 0.352830
# Train Epoch: 12 [8800/12038 (73%)]	Loss: 0.200551
# Train Epoch: 12 [11000/12038 (91%)]	Loss: 0.125998
# ====> Epoch: 12 Average loss: 0.5671
# Train Epoch: 13 [0/12038 (0%)]	Loss: 5.564920
# Train Epoch: 13 [2200/12038 (18%)]	Loss: 0.967913
# Train Epoch: 13 [4400/12038 (36%)]	Loss: 0.763969
# Train Epoch: 13 [6600/12038 (55%)]	Loss: 0.351710
# Train Epoch: 13 [8800/12038 (73%)]	Loss: 0.201519
# Train Epoch: 13 [11000/12038 (91%)]	Loss: 0.126412
# ====> Epoch: 13 Average loss: 0.5667
# Train Epoch: 14 [0/12038 (0%)]	Loss: 5.585655
# Train Epoch: 14 [2200/12038 (18%)]	Loss: 0.975069
# Train Epoch: 14 [4400/12038 (36%)]	Loss: 0.774329
# Train Epoch: 14 [6600/12038 (55%)]	Loss: 0.354917
# Train Epoch: 14 [8800/12038 (73%)]	Loss: 0.201949
# Train Epoch: 14 [11000/12038 (91%)]	Loss: 0.126215
# ====> Epoch: 14 Average loss: 0.5628
# Train Epoch: 1 [0/12038 (0%)]	Loss: 5.157676
# Train Epoch: 1 [2200/12038 (18%)]	Loss: 0.499054
# Train Epoch: 1 [4400/12038 (36%)]	Loss: 0.507360
# Train Epoch: 1 [6600/12038 (55%)]	Loss: 0.799084
# Train Epoch: 1 [8800/12038 (73%)]	Loss: 3.801459
# Train Epoch: 1 [11000/12038 (91%)]	Loss: 12231.872159
# ====> Epoch: 1 Average loss: 521568740301828231989821440.0000
# Train Epoch: 2 [0/12038 (0%)]	Loss: 87.201682
# Train Epoch: 2 [2200/12038 (18%)]	Loss: 66.932950
# Train Epoch: 2 [4400/12038 (36%)]	Loss: 55.704518
# Train Epoch: 2 [6600/12038 (55%)]	Loss: 88.917980
# Train Epoch: 2 [8800/12038 (73%)]	Loss: 200.003196
# Train Epoch: 2 [11000/12038 (91%)]	Loss: 5935.745028
# ====> Epoch: 2 Average loss: 48250504306115242257098473472.0000
# Train Epoch: 3 [0/12038 (0%)]	Loss: 57.630782
# Train Epoch: 3 [2200/12038 (18%)]	Loss: 49.527688
# Train Epoch: 3 [4400/12038 (36%)]	Loss: 44.385448
# Train Epoch: 3 [6600/12038 (55%)]	Loss: 78.979365
# Train Epoch: 3 [8800/12038 (73%)]	Loss: 186.378107
# Train Epoch: 3 [11000/12038 (91%)]	Loss: 6171.989347
# ====> Epoch: 3 Average loss: 11515634042003311541492908032.0000
# Train Epoch: 4 [0/12038 (0%)]	Loss: 65.810081
# Train Epoch: 4 [2200/12038 (18%)]	Loss: 29.729409
# Train Epoch: 4 [4400/12038 (36%)]	Loss: 24.077709
# Train Epoch: 4 [6600/12038 (55%)]	Loss: 59.957531
# Train Epoch: 4 [8800/12038 (73%)]	Loss: 161.700229
# Train Epoch: 4 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 4 Average loss: nan
# Train Epoch: 5 [0/12038 (0%)]	Loss: nan
# Train Epoch: 5 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 5 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 5 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 5 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 5 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 5 Average loss: nan
# Train Epoch: 6 [0/12038 (0%)]	Loss: nan
# Train Epoch: 6 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 6 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 6 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 6 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 6 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 6 Average loss: nan
# Train Epoch: 7 [0/12038 (0%)]	Loss: nan
# Train Epoch: 7 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 7 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 7 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 7 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 7 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 7 Average loss: nan
# Train Epoch: 8 [0/12038 (0%)]	Loss: nan
# Train Epoch: 8 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 8 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 8 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 8 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 8 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 8 Average loss: nan
# Train Epoch: 9 [0/12038 (0%)]	Loss: nan
# Train Epoch: 9 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 9 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 9 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 9 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 9 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 9 Average loss: nan
# Train Epoch: 10 [0/12038 (0%)]	Loss: nan
# Train Epoch: 10 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 10 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 10 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 10 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 10 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 10 Average loss: nan
# Train Epoch: 11 [0/12038 (0%)]	Loss: nan
# Train Epoch: 11 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 11 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 11 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 11 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 11 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 11 Average loss: nan
# Train Epoch: 12 [0/12038 (0%)]	Loss: nan
# Train Epoch: 12 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 12 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 12 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 12 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 12 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 12 Average loss: nan
# Train Epoch: 13 [0/12038 (0%)]	Loss: nan
# Train Epoch: 13 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 13 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 13 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 13 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 13 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 13 Average loss: nan
# Train Epoch: 14 [0/12038 (0%)]	Loss: nan
# Train Epoch: 14 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 14 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 14 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 14 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 14 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 14 Average loss: nan
# Train Epoch: 1 [0/12038 (0%)]	Loss: nan
# Train Epoch: 1 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 1 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 1 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 1 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 1 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 1 Average loss: nan
# Train Epoch: 2 [0/12038 (0%)]	Loss: nan
# Train Epoch: 2 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 2 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 2 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 2 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 2 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 2 Average loss: nan
# Train Epoch: 3 [0/12038 (0%)]	Loss: nan
# Train Epoch: 3 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 3 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 3 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 3 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 3 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 3 Average loss: nan
# Train Epoch: 4 [0/12038 (0%)]	Loss: nan
# Train Epoch: 4 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 4 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 4 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 4 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 4 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 4 Average loss: nan
# Train Epoch: 5 [0/12038 (0%)]	Loss: nan
# Train Epoch: 5 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 5 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 5 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 5 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 5 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 5 Average loss: nan
# Train Epoch: 6 [0/12038 (0%)]	Loss: nan
# Train Epoch: 6 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 6 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 6 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 6 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 6 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 6 Average loss: nan
# Train Epoch: 7 [0/12038 (0%)]	Loss: nan
# Train Epoch: 7 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 7 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 7 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 7 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 7 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 7 Average loss: nan
# Train Epoch: 8 [0/12038 (0%)]	Loss: nan
# Train Epoch: 8 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 8 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 8 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 8 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 8 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 8 Average loss: nan
# Train Epoch: 9 [0/12038 (0%)]	Loss: nan
# Train Epoch: 9 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 9 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 9 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 9 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 9 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 9 Average loss: nan
# Train Epoch: 10 [0/12038 (0%)]	Loss: nan
# Train Epoch: 10 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 10 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 10 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 10 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 10 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 10 Average loss: nan
# Train Epoch: 11 [0/12038 (0%)]	Loss: nan
# Train Epoch: 11 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 11 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 11 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 11 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 11 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 11 Average loss: nan
# Train Epoch: 12 [0/12038 (0%)]	Loss: nan
# Train Epoch: 12 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 12 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 12 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 12 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 12 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 12 Average loss: nan
# Train Epoch: 13 [0/12038 (0%)]	Loss: nan
# Train Epoch: 13 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 13 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 13 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 13 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 13 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 13 Average loss: nan
# Train Epoch: 14 [0/12038 (0%)]	Loss: nan
# Train Epoch: 14 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 14 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 14 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 14 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 14 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 14 Average loss: nan
# Train Epoch: 1 [0/12038 (0%)]	Loss: nan
# Train Epoch: 1 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 1 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 1 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 1 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 1 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 1 Average loss: nan
# Train Epoch: 2 [0/12038 (0%)]	Loss: nan
# Train Epoch: 2 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 2 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 2 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 2 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 2 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 2 Average loss: nan
# Train Epoch: 3 [0/12038 (0%)]	Loss: nan
# Train Epoch: 3 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 3 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 3 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 3 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 3 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 3 Average loss: nan
# Train Epoch: 4 [0/12038 (0%)]	Loss: nan
# Train Epoch: 4 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 4 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 4 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 4 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 4 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 4 Average loss: nan
# Train Epoch: 5 [0/12038 (0%)]	Loss: nan
# Train Epoch: 5 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 5 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 5 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 5 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 5 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 5 Average loss: nan
# Train Epoch: 6 [0/12038 (0%)]	Loss: nan
# Train Epoch: 6 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 6 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 6 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 6 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 6 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 6 Average loss: nan
# Train Epoch: 7 [0/12038 (0%)]	Loss: nan
# Train Epoch: 7 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 7 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 7 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 7 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 7 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 7 Average loss: nan
# Train Epoch: 8 [0/12038 (0%)]	Loss: nan
# Train Epoch: 8 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 8 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 8 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 8 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 8 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 8 Average loss: nan
# Train Epoch: 9 [0/12038 (0%)]	Loss: nan
# Train Epoch: 9 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 9 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 9 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 9 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 9 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 9 Average loss: nan
# Train Epoch: 10 [0/12038 (0%)]	Loss: nan
# Train Epoch: 10 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 10 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 10 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 10 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 10 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 10 Average loss: nan
# Train Epoch: 11 [0/12038 (0%)]	Loss: nan
# Train Epoch: 11 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 11 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 11 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 11 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 11 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 11 Average loss: nan
# Train Epoch: 12 [0/12038 (0%)]	Loss: nan
# Train Epoch: 12 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 12 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 12 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 12 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 12 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 12 Average loss: nan
# Train Epoch: 13 [0/12038 (0%)]	Loss: nan
# Train Epoch: 13 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 13 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 13 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 13 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 13 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 13 Average loss: nan
# Train Epoch: 14 [0/12038 (0%)]	Loss: nan
# Train Epoch: 14 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 14 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 14 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 14 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 14 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 14 Average loss: nan
# Train Epoch: 1 [0/12038 (0%)]	Loss: nan
# Train Epoch: 1 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 1 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 1 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 1 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 1 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 1 Average loss: nan
# Train Epoch: 2 [0/12038 (0%)]	Loss: nan
# Train Epoch: 2 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 2 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 2 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 2 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 2 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 2 Average loss: nan
# Train Epoch: 3 [0/12038 (0%)]	Loss: nan
# Train Epoch: 3 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 3 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 3 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 3 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 3 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 3 Average loss: nan
# Train Epoch: 4 [0/12038 (0%)]	Loss: nan
# Train Epoch: 4 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 4 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 4 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 4 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 4 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 4 Average loss: nan
# Train Epoch: 5 [0/12038 (0%)]	Loss: nan
# Train Epoch: 5 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 5 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 5 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 5 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 5 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 5 Average loss: nan
# Train Epoch: 6 [0/12038 (0%)]	Loss: nan
# Train Epoch: 6 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 6 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 6 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 6 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 6 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 6 Average loss: nan
# Train Epoch: 7 [0/12038 (0%)]	Loss: nan
# Train Epoch: 7 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 7 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 7 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 7 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 7 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 7 Average loss: nan
# Train Epoch: 8 [0/12038 (0%)]	Loss: nan
# Train Epoch: 8 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 8 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 8 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 8 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 8 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 8 Average loss: nan
# Train Epoch: 9 [0/12038 (0%)]	Loss: nan
# Train Epoch: 9 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 9 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 9 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 9 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 9 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 9 Average loss: nan
# Train Epoch: 10 [0/12038 (0%)]	Loss: nan
# Train Epoch: 10 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 10 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 10 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 10 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 10 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 10 Average loss: nan
# Train Epoch: 11 [0/12038 (0%)]	Loss: nan
# Train Epoch: 11 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 11 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 11 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 11 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 11 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 11 Average loss: nan
# Train Epoch: 12 [0/12038 (0%)]	Loss: nan
# Train Epoch: 12 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 12 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 12 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 12 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 12 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 12 Average loss: nan
# Train Epoch: 13 [0/12038 (0%)]	Loss: nan
# Train Epoch: 13 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 13 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 13 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 13 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 13 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 13 Average loss: nan
# Train Epoch: 14 [0/12038 (0%)]	Loss: nan
# Train Epoch: 14 [2200/12038 (18%)]	Loss: nan
# Train Epoch: 14 [4400/12038 (36%)]	Loss: nan
# Train Epoch: 14 [6600/12038 (55%)]	Loss: nan
# Train Epoch: 14 [8800/12038 (73%)]	Loss: nan
# Train Epoch: 14 [11000/12038 (91%)]	Loss: nan
# ====> Epoch: 14 Average loss: nan

# %%
for epoch in range(1, 5):
    train(v, train_data, criterion, opt, device, epoch, VQ = True)
# Out:
# Train Epoch: 1 [0/12038 (0%)]	Loss: 1.691314
# Train Epoch: 1 [2200/12038 (18%)]	Loss: 4.485812
# Train Epoch: 1 [4400/12038 (36%)]	Loss: 9.896546
# Train Epoch: 1 [6600/12038 (55%)]	Loss: 2.379386
# Train Epoch: 1 [8800/12038 (73%)]	Loss: 1.442263
# Train Epoch: 1 [11000/12038 (91%)]	Loss: 1.283441
# ====> Epoch: 1 Average loss: 2.5855
# Train Epoch: 2 [0/12038 (0%)]	Loss: 0.692192
# Train Epoch: 2 [2200/12038 (18%)]	Loss: 0.574403
# Train Epoch: 2 [4400/12038 (36%)]	Loss: 0.622559
# Train Epoch: 2 [6600/12038 (55%)]	Loss: 1.172370
# Train Epoch: 2 [8800/12038 (73%)]	Loss: 1.055771
# Train Epoch: 2 [11000/12038 (91%)]	Loss: 0.941490
# ====> Epoch: 2 Average loss: 1.0461
# Train Epoch: 3 [0/12038 (0%)]	Loss: 0.821264
# Train Epoch: 3 [2200/12038 (18%)]	Loss: 1.774756
# Train Epoch: 3 [4400/12038 (36%)]	Loss: 1.472454
# Train Epoch: 3 [6600/12038 (55%)]	Loss: 64.741577
# Train Epoch: 3 [8800/12038 (73%)]	Loss: 3.422020
# Train Epoch: 3 [11000/12038 (91%)]	Loss: 1.966259
# ====> Epoch: 3 Average loss: 24.9889
# Train Epoch: 4 [0/12038 (0%)]	Loss: 1.094108
# Train Epoch: 4 [2200/12038 (18%)]	Loss: 1.355099
# Train Epoch: 4 [4400/12038 (36%)]	Loss: 1.348673
# Train Epoch: 4 [6600/12038 (55%)]	Loss: 1.105460
# Train Epoch: 4 [8800/12038 (73%)]	Loss: 0.787617
# Train Epoch: 4 [11000/12038 (91%)]	Loss: 0.656411
# ====> Epoch: 4 Average loss: 1.7508

# %%
for epoch in range(1, 5):
    train_MCMC(v, train_data, criterion, opt, device, epoch, VQ = True, repetitions=3)
# Out:
# Train Epoch: 1 [0/3 (0%)]	Loss: 16.480002
# ====> Epoch: 1 Average loss: 16.4800
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 for epoch in range(1, 5):
# ----> 2     train_MCMC(v, train_data, criterion, opt, device, epoch, VQ = True, repetitions=3)
#
# File /mnt/c/Studium/Master/VAE/train.py:322, in train_MCMC(model, train_loader, criterion, optimizer, device, epoch, VQ, repetitions)
#     320     ax.plot(new_x.T.detach().numpy(), "r--")
#     321     ax.plot(label_data.T.detach().numpy(), "b", alpha=0.2)
# --> 322     train_loader = DataLoader(slidingWindow(x, L),
#     323                               batch_size=22,  # 59, # 22
#     324                               shuffle=False
#     325                               )
#     326 fig, ax = plt.subplots(figsize=(10, 5))
#     327 ax.plot(new_x.T.detach().numpy(), "r--")
#
# NameError: name 'L' is not defined

# %%
def compare(dataset, model, VQ=True):
    model.eval()
    data_size = train_data.dataset.data.shape[-1]
    print(data_size)
    rec = torch.empty(1, 0)
    x = torch.empty(1, 0)
    with torch.no_grad():
        for i, (data, v) in enumerate(dataset):
            if VQ:
                x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
            else:
                x_rec, mu, logvar = model(data)
#             z = model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
#             print(i)
            rec = torch.cat((rec, (x_rec*v)[...,0].view(1, -1)), dim=1)
            x = torch.cat((x, (data*v)[...,0].view(1, -1)), dim=1)
#             x.extend((data*v).view(1, -1).detach().numpy())
#             rec.extend((x_rec*v).view(1, -1).detach().numpy())
    print(rec.shape)
    print(x.shape)
    print(rec)
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(rec.T[:2000,:], "r--", alpha = 0.5)
    ax.plot(x.T[:2000,:], "b-", alpha=0.2)
# #     plt.ylim(50,600)
#     plt.grid(True)
#     plt.show()
    
    new_train_data = DataLoader(slidingWindow(np.array(rec).T, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
    return new_train_data

# %%
# a = 15* avg_norm
# v.quantizer._embedding.weight.detach()[0,5] = a
v.cpu()
rec = compare(train_data, v, VQ=True)
v.to(device)
# Out:
# 14054
# torch.Size([1, 12038])
# torch.Size([1, 12038])
# tensor([[nan, nan, nan,  ..., nan, nan, nan]])
# VQ_MST_VAE(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=252, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=252, out_features=7, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(15,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=250, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=250, out_features=7, bias=True)
#     )
#     (reduction_layer): Conv1d(12, 6, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(6, 3, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(3, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(15,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=69, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=69, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=69, out_features=2016, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(6, 3, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(3, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=56, out_features=2016, bias=True)
#       (decoder_mu): Linear(in_features=56, out_features=2016, bias=True)
#       (decoder_logvar): Linear(in_features=56, out_features=2016, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (quantizer): VQ_Quantizer(
#     (_embedding): Embedding(6, 7)
#   )
#   (bn): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def plot_heatmap(ax_heatmap, codebook):
    ax_heatmap.clear()
    heatmap = ax_heatmap.imshow(codebook)
    ax_heatmap.set_title('Codebook Heatmap')
    ax_heatmap


    return heatmap
def create_heatmap(codebook):
    fig, ax_heatmap = plt.subplots(figsize=(12, 6), dpi=100)
    heatmap = plot_heatmap(ax_heatmap, codebook.T)
#     heatmap_canvas = FigureCanvasTkAgg(fig, master=heatmap_frame)
#     heatmap_canvas.draw()
#     heatmap_canvas.get_tk_widget().pack(fill="both", expand=True)
    cbar = fig.colorbar(heatmap)
    ax_heatmap.set_xlabel('Num of Embeddings')
    ax_heatmap.set_ylabel('Latent Dimensions')
    
    return ax_heatmap

def get_average_norm_scale(train_data, model):
    n_channels = model._n_channels
    n_batchs = x_size = len(train_data)
    
    norm = torch.empty(n_channels, 0)

    for i, (data, norm_scale) in enumerate(train_data):
        reshaped_norm = norm_scale.permute(1,0,2).flatten(1)
        norm = torch.cat((norm, reshaped_norm), 1)
        
    avg_norm = torch.mean(norm, dim=1)
    return avg_norm

def get_latent_variables(train_data, model):
    model.eval()
    
    n_channels = model._n_channels
    latent_dims = model._latent_dims
    n_batchs = x_size = len(train_data)
    
    latents = torch.empty(n_channels, latent_dims, 0, device = device)

    for i, (data, norm_scale) in enumerate(train_data):
        data = data.to(device)
        
        mu, logvar = model.encoder(data)
        z = model.reparametrization_trick(mu, logvar)
        
        reshaped_mu, reshaped_logvar, reshaped_z = (t.permute(1,2,0) for t in [mu, logvar, z])

        latents = torch.cat((latents, reshaped_z), 2)

        
    avg_latents = torch.mean(latents, dim=2)
    return latents, avg_latents

# %%
def sample_vae(train_data, model, n):
    model.eval()
    
    n_channels = model._n_channels
    latent_dims = model._latent_dims
#     n_batchs = x_size = len(train_data)
    x_len = len(train_data.dataset)
    L = model._L
    bs = train_data.batch_size
    
    latents = torch.empty(n_channels, latent_dims, 0, device = device)
    x_rec, mu_dec, logvar_dec = (torch.empty(0, n_channels, x_len, device = device) for _ in range(3))
    mu_enc, logvar_enc = (torch.empty(0, n_channels, latent_dims, x_len, device = device) for _ in range(2))
    
    for j in range(n):
        # create temp tensors to store data in each repetition
        x, x_rec_temp, mu_rec_temp, logvar_rec_temp = (torch.empty(n_channels, 0, device = device) for _ in range(4))
        mu_temp, logvar_temp = (torch.empty(n_channels, latent_dims, 0, device = device) for _ in range(2))
        
        for i, (batch, norm_scale) in enumerate(train_data):
            batch = batch.to(device)
            #sample from model
            rec, loss, _mu, _logvar, mu_rec, logvar_rec = model(batch)

            #reshape data -> (Channel, latent_dims, BS) or (Channel, BS)
            _mu, _logvar= (t.permute(1,2,0) for t in [_mu, _logvar])
            batch, rec, norm_scale, mu_rec, logvar_rec = (t.permute(1,0,2)[:,:,0] for t in [batch, rec, norm_scale, mu_rec, logvar_rec])
            
            # Temp store data
            mu_temp = torch.cat((mu_temp, _mu), dim=2)
            logvar_temp = torch.cat((logvar_temp, _logvar), dim=2)
            mu_rec_temp = torch.cat((mu_rec_temp, mu_rec*norm_scale), dim=1)
            logvar_rec_temp  = torch.cat((logvar_rec_temp, logvar_rec*norm_scale), dim=1)            
            x_rec_temp = torch.cat((x_rec_temp, rec*norm_scale), dim=1)
#             print(batch.shape)
#             print(norm_scale.shape)
#             print(x.shape)
            x = torch.cat((x, batch*norm_scale), dim=1)

        # Store data after each reconstruction
        x_rec = torch.cat((x_rec, x_rec_temp.unsqueeze(0)), dim=0)
        mu_dec = torch.cat((mu_dec, mu_rec_temp.unsqueeze(0)), dim=0)
        logvar_dec = torch.cat((logvar_dec, logvar_rec_temp.unsqueeze(0)), dim=0)
        mu_enc = torch.cat((mu_enc, mu_temp.unsqueeze(0)), dim=0)
        logvar_enc = torch.cat((logvar_enc, logvar_temp.unsqueeze(0)), dim=0)
        print(x.shape)

    # join repetition and Channels and get the mean
#     x_rec, mu_dec, logvar_dec = (t.view(-1, x_len)for t in [x_rec, mu_dec, logvar_dec])
    x_rec_mean, mu_enc_mean, logvar_enc_mean, mu_dec_mean, logvar_dec_mean = (torch.mean(t, dim=0) for t in [x_rec, mu_enc, logvar_enc, mu_dec, logvar_dec])
#     x_rec_mean = x_rec.mean(0)
    print(x_rec.shape)
    print(x_rec_mean.shape)
    print(mu_enc_mean.shape)
    print(mu_dec_mean.shape)
    
    return x_rec, x_rec_mean, mu_enc_mean, logvar_enc_mean, mu_dec_mean, logvar_dec_mean

# %%
sample_vae(train_data, v, 5)
# Out:
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 3396])
# torch.Size([5, 1, 3396])
# torch.Size([1, 3396])
# torch.Size([1, 7, 3396])
# torch.Size([1, 3396])
# (tensor([[[270.6336, 270.8838, 264.7929,  ..., 264.1872, 266.1580, 266.2314]],
#
#          [[267.2577, 267.1277, 265.2807,  ..., 263.2624, 269.6062, 269.7383]],
#
#          [[267.2337, 268.0678, 267.6342,  ..., 269.5417, 268.7584, 265.9521]],
#
#          [[264.8954, 275.5269, 271.7399,  ..., 270.9635, 260.7353, 267.1324]],
#
#          [[263.9909, 263.8148, 270.3807,  ..., 263.0367, 270.1438, 264.7582]]],
#         grad_fn=<CatBackward0>),
#  tensor([[266.8022, 269.0842, 267.9657,  ..., 266.1983, 267.0803, 266.7625]],
#         grad_fn=<MeanBackward1>),
#  tensor([[[ 4.8745e-05,  2.3223e-04,  1.9234e-04,  ..., -5.7731e-05,
#             1.0282e-04,  7.4898e-05],
#           [ 1.7370e-04,  2.2830e-04,  1.7567e-04,  ...,  7.5044e-05,
#             2.1233e-04,  2.6535e-05],
#           [ 1.2812e-04,  2.7792e-04,  1.7135e-04,  ...,  1.8889e-04,
#             2.2300e-04,  4.6355e-05],
#           ...,
#           [ 2.5057e-04,  2.1517e-04,  1.7004e-04,  ...,  1.5335e-04,
#             1.1291e-04,  1.6399e-04],
#           [ 7.4474e-05,  1.8624e-04,  1.9586e-04,  ..., -6.3483e-05,
#             2.1118e-05,  8.9644e-05],
#           [ 8.8593e-05,  3.1113e-04,  2.5426e-04,  ...,  1.3487e-04,
#             3.0910e-04,  1.8012e-04]]], grad_fn=<MeanBackward1>),
#  tensor([[[ 8.0645e-06,  1.1592e-04,  6.2184e-05,  ...,  2.4536e-04,
#             8.6989e-05,  2.4370e-04],
#           [ 2.2218e-04,  1.7392e-04,  3.6434e-05,  ...,  6.0788e-05,
#             6.5963e-05,  1.3342e-04],
#           [ 1.5651e-04,  3.3104e-04,  2.7135e-04,  ...,  2.3599e-04,
#             3.4785e-04,  1.6050e-04],
#           ...,
#           [ 1.3706e-04,  2.5014e-04, -7.7466e-05,  ...,  1.2451e-04,
#             1.9108e-04,  1.0575e-04],
#           [ 1.7822e-04,  1.5590e-04,  1.2071e-04,  ...,  2.1486e-04,
#             1.7836e-04,  2.1034e-04],
#           [ 8.7711e-05,  2.6684e-04,  1.4536e-04,  ...,  5.6828e-05,
#             1.7663e-04,  1.2785e-04]]], grad_fn=<MeanBackward1>),
#  tensor([[266.2739, 269.1126, 267.4207,  ..., 267.0651, 267.9198, 267.0026]],
#         grad_fn=<MeanBackward1>),
#  tensor([[-2745.5405, -2759.0750, -2762.8022,  ..., -2742.6116, -2725.4800,
#           -2657.7097]], grad_fn=<MeanBackward1>))

# %%
get_latent_variables(train_data, v)
x, params, e_params = X.parameters()

# %%
pprint.pprint(params)
pprint.pprint(e_params)
# Out:
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[230., 230., 230., ..., 230., 230., 230.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [8],
#                  'channel': [0],
#                  'frequency_per_week': [10.700296455459206],
#                  'phaseshift': [112]},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}

# %%
from matplotlib.figure import Figure
np.set_printoptions(suppress=True)
avg_norm = get_average_norm_scale(train_data, v)
print(avg_norm)
# latents, avg_latents = get_latent_variables(train_data, v)
codebook = v.quantizer._embedding.weight
heatmap = create_heatmap(codebook.cpu().detach().numpy() * avg_norm.numpy())
print((codebook.cpu().detach().numpy() * avg_norm.numpy() ))
# Out:
# tensor([157.8198])
# [[nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan]]

# %%
def compare(dataset, model, VQ=True):
    model.eval()
    rec = []
    x = []
    T = dataset.dataset.data.shape[1]- L
    idx = 0
    _mu_rec, _logvar_rec = [], []
    _mu, _logvar = [], []
#     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
#     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
    with torch.no_grad():
        for i, (data, v) in enumerate(dataset):
            bs = data.shape[0]
            if VQ:
                x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
            else:
                x_rec, mu, logvar = model(data)
            z = model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
#             print(i)
#             print(mu.shape)

            x.extend((data)[0,:,0].detach().numpy())
            rec.extend(((x_rec)[0,:,0]).detach().numpy())
            _mu_rec.extend((mu_rec)[0,:,:].detach().numpy())
            _logvar_rec.extend(((torch.exp(0.5 * logvar_rec)))[0,:,:].detach().numpy())
            
            _mu.extend((mu)[0,:,0].detach().numpy())
            _logvar.extend(((torch.exp(0.5 * logvar)))[0,:,:].detach().numpy())
#             _mu[idx: idx + bs, :, :] = mu
#             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
#     print(np.array(_mu).shape)
    
#     x = np.array(x).T
#     rec = np.array(rec).T
#     _mu = np.tile(np.array(_mu), (3455, 1))
#     _logvar = np.tile(np.array(_logvar), (3455, 1))
#     _mu_rec = np.tile(np.array(_mu_rec), (3455, 1))
#     _logvar_rec = np.tile(np.array(_logvar_rec), (3455, 1))
#     print(_logvar.shape)
#     print(x.shape)
#     print(rec.shape)
#     print(T)
#     print(params["cov"][0,:,:L].T)
    fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10, 15))
    ax = axs[0]
    ax.plot(rec, "r-")
    ax.plot(x[:], "b-", alpha=0.2)
    ax.plot(_mu_rec)
    ax.plot(params["mu"].T[:_mu.shape[0],:])
    ax.grid()
    
    ax_std = axs[1]
    ax_std.plot(_logvar_rec, "r")
    ax_std.plot(params["cov"][0,:,:L].T, "b")
    ax_std.grid()
    
    ax_enc = axs[2]
    for (i,l) in enumerate(_mu.T):        
        ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
#     ax_enc.plot(_mu, alpha = 0.2)
    ax_enc.grid()
    
    ax_log = axs[3]
    for (i,l) in enumerate(_logvar.T):        
        ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
    ax_log.grid()
    
    # Setting legend
    blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
    red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
    titles = ['Prediction of Train Data', 'Std plot', 'mu encoder vs mu from gen', 'logvar encoder vs cov']
    for (i,ax) in enumerate(axs):
        # ax.set_title('Reconstruction of Train Data')
        ax.set_title(titles[i])
        ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
    # Axes labels
    ax_std.set_xlabel('Time')
    ax.set_ylabel('Values')
    ax_std.set_ylabel('Values')
#     plt.ylim(-100,500)
#     plt.grid(True)
    fig.tight_layout()
    plt.show()
# def compare(dataset, model, VQ=True):
#     model.eval()
#     rec = []
#     x = []
#     T = dataset.dataset.data.shape[1]- L
#     idx = 0
#     _mu_rec, _logvar_rec = [], []
#     _mu, _logvar = [], []
# #     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
# #     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
#     with torch.no_grad():
#         for i, (data, v) in enumerate(dataset):
#             bs = data.shape[0]
#             if VQ:
#                 x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
#             else:
#                 x_rec, mu, logvar = model(data)
#             z = model.reparametrization_trick(mu, logvar)
#             print(v.shape)
#             if v.dim() == 1:
#                 v = v.unsqueeze(0)
#                 v = v.T
#                 v = v.unsqueeze(-1)
# #             print(v.shape)
# #             print(x_rec.shape)
# #             print((x_rec * v).shape)
# #             print(i)
# #             print(mu.shape)

#             x.extend((data)[:,:,:].detach().numpy())
#             rec.extend(((x_rec)[:,:,:]).detach().numpy())
# #             _mu_rec.extend((mu_rec*v)[:,:,0].detach().numpy())
# #             _logvar_rec.extend(((torch.exp(0.5 * logvar_rec))*v)[:,:,0].detach().numpy())
            
# #             _mu.extend((mu*v)[:,:,0].detach().numpy())
# #             _logvar.extend(((torch.exp(0.5 * logvar))*v)[:,:,0].detach().numpy())
# #             _mu[idx: idx + bs, :, :] = mu
# #             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
# #     print(np.array(rec).shape)
# #     _mu = np.array(_mu)
# #     _logvar = np.array(_logvar)
    
#     rec = np.array(rec).squeeze(0).T
#     x = np.array(x).squeeze(0).T
# #     print(x.shape)
# #     print(rec)
#     fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(10, 4))
#     ax = axs#[0]
#     ax.plot(rec, "r-")
#     ax.plot(x, "b-", alpha=0.2)
# #     ax.plot(_mu_rec)
# #     ax.plot(params["mu"].T[:_mu.shape[0],:])
#     ax.grid()
    
# #     ax_std = axs[1]
# #     ax_std.plot(_logvar_rec, "r")
# #     ax_std.plot(params["cov"][0,:,:T].T, "b")
# #     ax_std.grid()
    
# #     ax_enc = axs[2]
# #     for (i,l) in enumerate(_mu.T):        
# #         ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
# # #     ax_enc.plot(_mu, alpha = 0.2)
# #     ax_enc.grid()
    
# #     ax_log = axs[3]
# #     for (i,l) in enumerate(_logvar.T):        
# #         ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
# #     ax_log.grid()
    
#     # Setting legend
#     blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
#     red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
# #     for ax in axs:
#         # ax.set_title('Reconstruction of Train Data')
#     ax.set_title('Prediction of Test (unseen) Data')
#     ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
#     # Axes labels
# #     ax_std.set_xlabel('Time')
# #     ax.set_ylabel('Values')
# #     ax_std.set_ylabel('Values')
# #     plt.ylim(-100,500)
#     plt.grid(True)
#     fig.tight_layout()
#     plt.show()

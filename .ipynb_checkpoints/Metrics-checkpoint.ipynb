# %%
# %load_ext autoreload
# %autoreload 2
# import torch; torch.manual_seed(955)
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from dataGen import Gen, FastGen, Gen2
from Encoders import LongShort_TCVAE_Encoder, RnnEncoder, MST_VAE_Encoder, MST_VAE_Encoder_dist
from Decoders import LongShort_TCVAE_Decoder, RnnDecoder, MST_VAE_Decoder, MST_VAE_Decoder_dist
from vae import Variational_Autoencoder, VQ_MST_VAE, VQ_Quantizer
from utils import * #train_on_effect, generate_data, extract_parameters, suppress_prints, add_mu_std
from train import *
import argparse
import numpy as np
import matplotlib.pyplot as plt
import pprint
torch.set_printoptions(sci_mode=False)

# all parameters for generating the time series should be configured in this cell
        
p=2       
args = GENV(n_channels=2,
            latent_dims=10,
            n_samples=500,
            shuffle=False,
            periode=p,
            L=288*p,
            min_max=False,
            num_layers=3,
            first_kernel=288)
effects = {
    "Pulse": {
        "occurances":1,
        "max_amplitude":5,   
        "interval":40,
        "start":None
        },
    "Trend": {
        "occurances":10,
        "max_slope":0.002,
        "type":"linear",
        "start":None
        },
    "Seasonality": {
        "occurances":10,
        "frequency_per_week":(14, 21), # min and max occurances per week
        "amplitude_range":(5, 20),
        "start":-5
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":30,
        "start":None
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

# %%
from importlib import reload
from Encoders import LongShort_TCVAE_Encoder#, RnnEncoder, MST_VAE_Encoder, MST_VAE_Encoder_dist
from Decoders import LongShort_TCVAE_Decoder#, RnnDecoder, MST_VAE_Decoder, MST_VAE_Decoder_dist
from vae import Variational_Autoencoder, VQ_MST_VAE, VQ_Quantizer
args.num_embed = args.enc_out**2 
args.robust = False
vae = Variational_Autoencoder(args,
                            v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
                            v_decoder = LongShort_TCVAE_Decoder #MST_VAE_Decoder,
                           )
vq = VQ_MST_VAE(args,
                v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
                v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
                v_quantizer = VQ_Quantizer) #10 5

vae = vae.to(args.device)
vq = vq.to(args.device)

opt_vae = optim.Adam(vae.parameters(), lr = 0.002043529186448577) # 0.005043529186448577 0.006819850049647945
opt_vq = optim.Adam(vq.parameters(), lr = 0.002043529186448577) # 0.005043529186448577 0.006819850049647945

# %%
train_data, val_data, test_data, X = generate_labeled_data(args,
                                                           effects,
                                                           effect="both",
                                                           occurance=2,
                                                           return_gen=True,
                                                           anomalies=False)
# Out:
# generating:  1
# generating:  2
# generating:  3
# generating:  4
# generating:  5
# generating:  6
# generating:  7
# generating:  8
# generating:  9

# %%
# args.min_max=False
# args.n_channels = 10
train_data_long, val_data_long, test_data_long, X_long = generate_long_data(args,
                                                                            effects,
                                                                            effect="both",
                                                                            occurance=2,
                                                                            return_gen=True,
                                                                            anomalies=False)

# %%
Origin_norm_long, REC_norm_long, _ = rebuild_TS_non_overlapping(v, train_data_long, args, keep_norm=False)
denoised_rec_long = denoise_data(REC_norm_long.T.cpu())
denoised_orig_long = denoise_data(Origin_norm_long.T.cpu())
train_data_long_denoised = DataLoader(StridedWindow(torch.from_numpy(denoised_orig_long), args),  # slidingWindow, stridedWindow
                            batch_size=args.bs,  # 59, # 22
                            shuffle=False,
                            drop_last=False
                            )

# %%
x, params, e_params = X.parameters()
# Origin_vae_norm, REC_vae_norm, _ = rebuild_TS(vae, train_data, args, keep_norm=True)
# Origin_vae, REC_vae, z = rebuild_TS(vae, train_data, args, keep_norm=False)

# Origin_vq_norm, REC_vq_norm, _ = rebuild_TS(vq, train_data, args, keep_norm=True)
# Origin_vq, REC_vq, indices = rebuild_TS(vq, train_data, args, keep_norm=False)
# indices = indices.mean(axis=-1).type(torch.int32)

labels = extract_parameters(args, e_params=e_params, effects=effects)
labels = add_mu_std(labels, params)
# train_labels = labels[:Origin_norm.shape[0]]
                      
# denoised_rec = denoise_data(REC_norm.cpu())
# denoised_orig = denoise_data(Origin_norm.cpu())
# train_data_denoised = DataLoader(NoWindow(torch.from_numpy(denoised_orig), args, train_labels, norm=True),  # slidingWindow, stridedWindow
#                             batch_size=args.bs,  # 59, # 22
#                             shuffle=False,
#                             drop_last=False
#                             )

# %%
k=1
latent = z[k]
cb_index = indices[k]
# latent_vq
codebook = vq.quantizer._embedding.weight
latent_vq = codebook.index_select(0, cb_index)
heatmap = create_heatmap(latent)
heatmap = create_heatmap(latent_vq)

# %%
plt.plot(Origin_norm_long[:,1].cpu())
plt.plot(REC_norm_long[:,1].cpu(), "r-")

# %%
x, params, e_params = X.parameters()
frs = e_params["Seasonality"]["frequency_per_week"]
arr = np.array(frs)
arr[15]
# Out:
# array([12.94469474, 12.36471355,  7.28954081,  7.14528718,  9.44694033])

# %%
args.min_max= False
np.set_printoptions(suppress=True)
VAE_losses = []
VQ_losses = []

for epoch in range(1, 1000):
    loss_vae = train(vae, train_data_long, args, opt_vae, epoch)
    loss_vq = train(vq, train_data_long, args, opt_vq, epoch)
    
    if epoch%100 == 1:
        display.clear_output(wait=True)
        show_results_long(vae, train_data_long, args)
        show_results_long(vq, train_data_long, args, vq=True)
        
    VAE_losses.append(loss_vae)
    VQ_losses.append(loss_vq)
                
    print('====> VAE: Sample {} Average loss: {:.4f}'.format(epoch, loss_vae / len(train_data_long.dataset)))
    print('====> VQ: Sample {} Average loss: {:.4f}'.format(epoch, loss_vq / len(train_data_long.dataset)))
# Out:
# ====> VAE: Sample 901 Average loss: 0.2840
# ====> VQ: Sample 901 Average loss: 2.0885
# Train Epoch: 902 [0/1 (0%)]	Loss: 41.162274	 True Loss: 5968.529785
# Train Epoch: 902 [0/1 (0%)]	Loss: 295.125458	 True Loss: 42793.191406
# ====> VAE: Sample 902 Average loss: 0.2839
# ====> VQ: Sample 902 Average loss: 2.0353
# Train Epoch: 903 [0/1 (0%)]	Loss: 40.837180	 True Loss: 5921.391113
# Train Epoch: 903 [0/1 (0%)]	Loss: 292.751886	 True Loss: 42449.023438
# ====> VAE: Sample 903 Average loss: 0.2816
# ====> VQ: Sample 903 Average loss: 2.0190
# Train Epoch: 904 [0/1 (0%)]	Loss: 40.846555	 True Loss: 5922.750488
# Train Epoch: 904 [0/1 (0%)]	Loss: 304.167295	 True Loss: 44104.257812
# ====> VAE: Sample 904 Average loss: 0.2817
# ====> VQ: Sample 904 Average loss: 2.0977
# Train Epoch: 905 [0/1 (0%)]	Loss: 41.167039	 True Loss: 5969.220703
# Train Epoch: 905 [0/1 (0%)]	Loss: 300.081600	 True Loss: 43511.832031
# ====> VAE: Sample 905 Average loss: 0.2839
# ====> VQ: Sample 905 Average loss: 2.0695
# Train Epoch: 906 [0/1 (0%)]	Loss: 40.678785	 True Loss: 5898.423828
# Train Epoch: 906 [0/1 (0%)]	Loss: 295.582220	 True Loss: 42859.421875
# ====> VAE: Sample 906 Average loss: 0.2805
# ====> VQ: Sample 906 Average loss: 2.0385
# Train Epoch: 907 [0/1 (0%)]	Loss: 40.552893	 True Loss: 5880.169434
# Train Epoch: 907 [0/1 (0%)]	Loss: 290.014036	 True Loss: 42052.035156
# ====> VAE: Sample 907 Average loss: 0.2797
# ====> VQ: Sample 907 Average loss: 2.0001
# Train Epoch: 908 [0/1 (0%)]	Loss: 40.723458	 True Loss: 5904.901367
# Train Epoch: 908 [0/1 (0%)]	Loss: 294.797926	 True Loss: 42745.699219
# ====> VAE: Sample 908 Average loss: 0.2809
# ====> VQ: Sample 908 Average loss: 2.0331
# Train Epoch: 909 [0/1 (0%)]	Loss: 40.433459	 True Loss: 5862.851562
# Train Epoch: 909 [0/1 (0%)]	Loss: 300.882947	 True Loss: 43628.027344
# ====> VAE: Sample 909 Average loss: 0.2789
# ====> VQ: Sample 909 Average loss: 2.0751
# Train Epoch: 910 [0/1 (0%)]	Loss: 40.718279	 True Loss: 5904.150391
# Train Epoch: 910 [0/1 (0%)]	Loss: 297.758351	 True Loss: 43174.960938
# ====> VAE: Sample 910 Average loss: 0.2808
# ====> VQ: Sample 910 Average loss: 2.0535
# Train Epoch: 911 [0/1 (0%)]	Loss: 40.640120	 True Loss: 5892.817383
# Train Epoch: 911 [0/1 (0%)]	Loss: 297.902883	 True Loss: 43195.917969
# ====> VAE: Sample 911 Average loss: 0.2803
# ====> VQ: Sample 911 Average loss: 2.0545
# Train Epoch: 912 [0/1 (0%)]	Loss: 40.498606	 True Loss: 5872.297852
# Train Epoch: 912 [0/1 (0%)]	Loss: 290.206600	 True Loss: 42079.957031
# ====> VAE: Sample 912 Average loss: 0.2793
# ====> VQ: Sample 912 Average loss: 2.0014
# Train Epoch: 913 [0/1 (0%)]	Loss: 41.032779	 True Loss: 5949.752930
# Train Epoch: 913 [0/1 (0%)]	Loss: 291.250700	 True Loss: 42231.351562
# ====> VAE: Sample 913 Average loss: 0.2830
# ====> VQ: Sample 913 Average loss: 2.0086
# Train Epoch: 914 [0/1 (0%)]	Loss: 40.661217	 True Loss: 5895.876465
# Train Epoch: 914 [0/1 (0%)]	Loss: 292.749273	 True Loss: 42448.644531
# ====> VAE: Sample 914 Average loss: 0.2804
# ====> VQ: Sample 914 Average loss: 2.0190
# Train Epoch: 915 [0/1 (0%)]	Loss: 40.443548	 True Loss: 5864.314453
# Train Epoch: 915 [0/1 (0%)]	Loss: 291.979472	 True Loss: 42337.023438
# ====> VAE: Sample 915 Average loss: 0.2789
# ====> VQ: Sample 915 Average loss: 2.0137
# Train Epoch: 916 [0/1 (0%)]	Loss: 40.466655	 True Loss: 5867.665039
# Train Epoch: 916 [0/1 (0%)]	Loss: 297.293750	 True Loss: 43107.593750
# ====> VAE: Sample 916 Average loss: 0.2791
# ====> VQ: Sample 916 Average loss: 2.0503
# Train Epoch: 917 [0/1 (0%)]	Loss: 40.632452	 True Loss: 5891.705566
# Train Epoch: 917 [0/1 (0%)]	Loss: 293.513254	 True Loss: 42559.421875
# ====> VAE: Sample 917 Average loss: 0.2802
# ====> VQ: Sample 917 Average loss: 2.0242
# Train Epoch: 918 [0/1 (0%)]	Loss: 40.641945	 True Loss: 5893.082031
# Train Epoch: 918 [0/1 (0%)]	Loss: 282.637338	 True Loss: 40982.414062
# ====> VAE: Sample 918 Average loss: 0.2803
# ====> VQ: Sample 918 Average loss: 1.9492
# Train Epoch: 919 [0/1 (0%)]	Loss: 40.370107	 True Loss: 5853.665527
# Train Epoch: 919 [0/1 (0%)]	Loss: 299.058594	 True Loss: 43363.496094
# ====> VAE: Sample 919 Average loss: 0.2784
# ====> VQ: Sample 919 Average loss: 2.0625
# Train Epoch: 920 [0/1 (0%)]	Loss: 40.727559	 True Loss: 5905.496094
# Train Epoch: 920 [0/1 (0%)]	Loss: 283.338739	 True Loss: 41084.117188
# ====> VAE: Sample 920 Average loss: 0.2809
# ====> VQ: Sample 920 Average loss: 1.9541
# Train Epoch: 921 [0/1 (0%)]	Loss: 40.653472	 True Loss: 5894.753418
# Train Epoch: 921 [0/1 (0%)]	Loss: 286.985291	 True Loss: 41612.867188
# ====> VAE: Sample 921 Average loss: 0.2804
# ====> VQ: Sample 921 Average loss: 1.9792
# Train Epoch: 922 [0/1 (0%)]	Loss: 40.416463	 True Loss: 5860.387207
# Train Epoch: 922 [0/1 (0%)]	Loss: 289.841352	 True Loss: 42026.996094
# ====> VAE: Sample 922 Average loss: 0.2787
# ====> VQ: Sample 922 Average loss: 1.9989
# Train Epoch: 923 [0/1 (0%)]	Loss: 40.470925	 True Loss: 5868.284180
# Train Epoch: 923 [0/1 (0%)]	Loss: 296.349192	 True Loss: 42970.632812
# ====> VAE: Sample 923 Average loss: 0.2791
# ====> VQ: Sample 923 Average loss: 2.0438
# Train Epoch: 924 [0/1 (0%)]	Loss: 40.572239	 True Loss: 5882.974609
# Train Epoch: 924 [0/1 (0%)]	Loss: 296.104526	 True Loss: 42935.156250
# ====> VAE: Sample 924 Average loss: 0.2798
# ====> VQ: Sample 924 Average loss: 2.0421
# Train Epoch: 925 [0/1 (0%)]	Loss: 40.882055	 True Loss: 5927.897949
# Train Epoch: 925 [0/1 (0%)]	Loss: 293.693939	 True Loss: 42585.621094
# ====> VAE: Sample 925 Average loss: 0.2819
# ====> VQ: Sample 925 Average loss: 2.0255
# Train Epoch: 926 [0/1 (0%)]	Loss: 40.858742	 True Loss: 5924.517578
# Train Epoch: 926 [0/1 (0%)]	Loss: 294.895097	 True Loss: 42759.789062
# ====> VAE: Sample 926 Average loss: 0.2818
# ====> VQ: Sample 926 Average loss: 2.0338
# Train Epoch: 927 [0/1 (0%)]	Loss: 40.817693	 True Loss: 5918.565430
# Train Epoch: 927 [0/1 (0%)]	Loss: 295.712850	 True Loss: 42878.363281
# ====> VAE: Sample 927 Average loss: 0.2815
# ====> VQ: Sample 927 Average loss: 2.0394
# Train Epoch: 928 [0/1 (0%)]	Loss: 40.949980	 True Loss: 5937.747070
# Train Epoch: 928 [0/1 (0%)]	Loss: 290.231008	 True Loss: 42083.496094
# ====> VAE: Sample 928 Average loss: 0.2824
# ====> VQ: Sample 928 Average loss: 2.0016
# Train Epoch: 929 [0/1 (0%)]	Loss: 40.476552	 True Loss: 5869.100098
# Train Epoch: 929 [0/1 (0%)]	Loss: 293.869450	 True Loss: 42611.070312
# ====> VAE: Sample 929 Average loss: 0.2791
# ====> VQ: Sample 929 Average loss: 2.0267
# Train Epoch: 930 [0/1 (0%)]	Loss: 40.527135	 True Loss: 5876.434570
# Train Epoch: 930 [0/1 (0%)]	Loss: 290.930954	 True Loss: 42184.988281
# ====> VAE: Sample 930 Average loss: 0.2795
# ====> VQ: Sample 930 Average loss: 2.0064
# Train Epoch: 931 [0/1 (0%)]	Loss: 40.616612	 True Loss: 5889.408691
# Train Epoch: 931 [0/1 (0%)]	Loss: 285.288416	 True Loss: 41366.820312
# ====> VAE: Sample 931 Average loss: 0.2801
# ====> VQ: Sample 931 Average loss: 1.9675
# Train Epoch: 932 [0/1 (0%)]	Loss: 41.039271	 True Loss: 5950.694336
# Train Epoch: 932 [0/1 (0%)]	Loss: 295.336288	 True Loss: 42823.761719
# ====> VAE: Sample 932 Average loss: 0.2830
# ====> VQ: Sample 932 Average loss: 2.0368
# Train Epoch: 933 [0/1 (0%)]	Loss: 40.817086	 True Loss: 5918.477539
# Train Epoch: 933 [0/1 (0%)]	Loss: 296.283863	 True Loss: 42961.160156
# ====> VAE: Sample 933 Average loss: 0.2815
# ====> VQ: Sample 933 Average loss: 2.0433
# Train Epoch: 934 [0/1 (0%)]	Loss: 40.507934	 True Loss: 5873.650391
# Train Epoch: 934 [0/1 (0%)]	Loss: 289.876455	 True Loss: 42032.085938
# ====> VAE: Sample 934 Average loss: 0.2794
# ====> VQ: Sample 934 Average loss: 1.9991
# Train Epoch: 935 [0/1 (0%)]	Loss: 40.694423	 True Loss: 5900.691406
# Train Epoch: 935 [0/1 (0%)]	Loss: 289.141029	 True Loss: 41925.449219
# ====> VAE: Sample 935 Average loss: 0.2807
# ====> VQ: Sample 935 Average loss: 1.9941
# Train Epoch: 936 [0/1 (0%)]	Loss: 40.362214	 True Loss: 5852.520996
# Train Epoch: 936 [0/1 (0%)]	Loss: 301.043265	 True Loss: 43651.273438
# ====> VAE: Sample 936 Average loss: 0.2784
# ====> VQ: Sample 936 Average loss: 2.0762
# Train Epoch: 937 [0/1 (0%)]	Loss: 40.788143	 True Loss: 5914.280762
# Train Epoch: 937 [0/1 (0%)]	Loss: 288.028098	 True Loss: 41764.074219
# ====> VAE: Sample 937 Average loss: 0.2813
# ====> VQ: Sample 937 Average loss: 1.9864
# Train Epoch: 938 [0/1 (0%)]	Loss: 40.499801	 True Loss: 5872.471191
# Train Epoch: 938 [0/1 (0%)]	Loss: 296.430792	 True Loss: 42982.464844
# ====> VAE: Sample 938 Average loss: 0.2793
# ====> VQ: Sample 938 Average loss: 2.0444
# Train Epoch: 939 [0/1 (0%)]	Loss: 40.587527	 True Loss: 5885.191406
# Train Epoch: 939 [0/1 (0%)]	Loss: 298.912904	 True Loss: 43342.371094
# ====> VAE: Sample 939 Average loss: 0.2799
# ====> VQ: Sample 939 Average loss: 2.0615
# Train Epoch: 940 [0/1 (0%)]	Loss: 40.355475	 True Loss: 5851.543945
# Train Epoch: 940 [0/1 (0%)]	Loss: 294.686315	 True Loss: 42729.515625
# ====> VAE: Sample 940 Average loss: 0.2783
# ====> VQ: Sample 940 Average loss: 2.0323
# Train Epoch: 941 [0/1 (0%)]	Loss: 40.443871	 True Loss: 5864.361328
# Train Epoch: 941 [0/1 (0%)]	Loss: 281.116406	 True Loss: 40761.878906
# ====> VAE: Sample 941 Average loss: 0.2789
# ====> VQ: Sample 941 Average loss: 1.9387
# Train Epoch: 942 [0/1 (0%)]	Loss: 40.277522	 True Loss: 5840.240723
# Train Epoch: 942 [0/1 (0%)]	Loss: 295.859321	 True Loss: 42899.601562
# ====> VAE: Sample 942 Average loss: 0.2778
# ====> VQ: Sample 942 Average loss: 2.0404
# Train Epoch: 943 [0/1 (0%)]	Loss: 40.125418	 True Loss: 5818.185547
# Train Epoch: 943 [0/1 (0%)]	Loss: 283.831546	 True Loss: 41155.574219
# ====> VAE: Sample 943 Average loss: 0.2767
# ====> VQ: Sample 943 Average loss: 1.9575
# Train Epoch: 944 [0/1 (0%)]	Loss: 40.344164	 True Loss: 5849.903809
# Train Epoch: 944 [0/1 (0%)]	Loss: 289.605765	 True Loss: 41992.835938
# ====> VAE: Sample 944 Average loss: 0.2782
# ====> VQ: Sample 944 Average loss: 1.9973
# Train Epoch: 945 [0/1 (0%)]	Loss: 39.878159	 True Loss: 5782.333008
# Train Epoch: 945 [0/1 (0%)]	Loss: 288.985857	 True Loss: 41902.949219
# ====> VAE: Sample 945 Average loss: 0.2750
# ====> VQ: Sample 945 Average loss: 1.9930
# Train Epoch: 946 [0/1 (0%)]	Loss: 40.466851	 True Loss: 5867.693359
# Train Epoch: 946 [0/1 (0%)]	Loss: 297.349758	 True Loss: 43115.714844
# ====> VAE: Sample 946 Average loss: 0.2791
# ====> VQ: Sample 946 Average loss: 2.0507
# Train Epoch: 947 [0/1 (0%)]	Loss: 40.007422	 True Loss: 5801.076172
# Train Epoch: 947 [0/1 (0%)]	Loss: 286.675647	 True Loss: 41567.968750
# ====> VAE: Sample 947 Average loss: 0.2759
# ====> VQ: Sample 947 Average loss: 1.9771
# Train Epoch: 948 [0/1 (0%)]	Loss: 40.405869	 True Loss: 5858.851074
# Train Epoch: 948 [0/1 (0%)]	Loss: 304.724300	 True Loss: 44185.023438
# ====> VAE: Sample 948 Average loss: 0.2787
# ====> VQ: Sample 948 Average loss: 2.1015
# Train Epoch: 949 [0/1 (0%)]	Loss: 40.346713	 True Loss: 5850.273438
# Train Epoch: 949 [0/1 (0%)]	Loss: 300.861880	 True Loss: 43624.972656
# ====> VAE: Sample 949 Average loss: 0.2783
# ====> VQ: Sample 949 Average loss: 2.0749
# Train Epoch: 950 [0/1 (0%)]	Loss: 40.310166	 True Loss: 5844.974121
# Train Epoch: 950 [0/1 (0%)]	Loss: 291.150081	 True Loss: 42216.761719
# ====> VAE: Sample 950 Average loss: 0.2780
# ====> VQ: Sample 950 Average loss: 2.0079
# Train Epoch: 951 [0/1 (0%)]	Loss: 40.324798	 True Loss: 5847.095703
# Train Epoch: 951 [0/1 (0%)]	Loss: 296.183540	 True Loss: 42946.613281
# ====> VAE: Sample 951 Average loss: 0.2781
# ====> VQ: Sample 951 Average loss: 2.0426
# Train Epoch: 952 [0/1 (0%)]	Loss: 40.132678	 True Loss: 5819.238281
# Train Epoch: 952 [0/1 (0%)]	Loss: 294.693777	 True Loss: 42730.597656
# ====> VAE: Sample 952 Average loss: 0.2768
# ====> VQ: Sample 952 Average loss: 2.0324
# Train Epoch: 953 [0/1 (0%)]	Loss: 40.602313	 True Loss: 5887.335449
# Train Epoch: 953 [0/1 (0%)]	Loss: 290.353421	 True Loss: 42101.246094
# ====> VAE: Sample 953 Average loss: 0.2800
# ====> VQ: Sample 953 Average loss: 2.0024
# Train Epoch: 954 [0/1 (0%)]	Loss: 39.886840	 True Loss: 5783.591797
# Train Epoch: 954 [0/1 (0%)]	Loss: 294.681923	 True Loss: 42728.878906
# ====> VAE: Sample 954 Average loss: 0.2751
# ====> VQ: Sample 954 Average loss: 2.0323
# Train Epoch: 955 [0/1 (0%)]	Loss: 40.173983	 True Loss: 5825.227539
# Train Epoch: 955 [0/1 (0%)]	Loss: 310.615463	 True Loss: 45039.242188
# ====> VAE: Sample 955 Average loss: 0.2771
# ====> VQ: Sample 955 Average loss: 2.1422
# Train Epoch: 956 [0/1 (0%)]	Loss: 40.103179	 True Loss: 5814.960938
# Train Epoch: 956 [0/1 (0%)]	Loss: 287.465679	 True Loss: 41682.523438
# ====> VAE: Sample 956 Average loss: 0.2766
# ====> VQ: Sample 956 Average loss: 1.9825
# Train Epoch: 957 [0/1 (0%)]	Loss: 40.534853	 True Loss: 5877.553711
# Train Epoch: 957 [0/1 (0%)]	Loss: 292.081762	 True Loss: 42351.855469
# ====> VAE: Sample 957 Average loss: 0.2796
# ====> VQ: Sample 957 Average loss: 2.0144
# Train Epoch: 958 [0/1 (0%)]	Loss: 40.095818	 True Loss: 5813.893555
# Train Epoch: 958 [0/1 (0%)]	Loss: 286.801455	 True Loss: 41586.210938
# ====> VAE: Sample 958 Average loss: 0.2765
# ====> VQ: Sample 958 Average loss: 1.9779
# Train Epoch: 959 [0/1 (0%)]	Loss: 40.244632	 True Loss: 5835.471680
# Train Epoch: 959 [0/1 (0%)]	Loss: 292.118050	 True Loss: 42357.117188
# ====> VAE: Sample 959 Average loss: 0.2775
# ====> VQ: Sample 959 Average loss: 2.0146
# Train Epoch: 960 [0/1 (0%)]	Loss: 40.301798	 True Loss: 5843.760742
# Train Epoch: 960 [0/1 (0%)]	Loss: 290.226724	 True Loss: 42082.875000
# ====> VAE: Sample 960 Average loss: 0.2779
# ====> VQ: Sample 960 Average loss: 2.0016
# Train Epoch: 961 [0/1 (0%)]	Loss: 39.960372	 True Loss: 5794.253906
# Train Epoch: 961 [0/1 (0%)]	Loss: 292.035129	 True Loss: 42345.093750
# ====> VAE: Sample 961 Average loss: 0.2756
# ====> VQ: Sample 961 Average loss: 2.0140
# Train Epoch: 962 [0/1 (0%)]	Loss: 39.938571	 True Loss: 5791.092773
# Train Epoch: 962 [0/1 (0%)]	Loss: 289.838982	 True Loss: 42026.652344
# ====> VAE: Sample 962 Average loss: 0.2754
# ====> VQ: Sample 962 Average loss: 1.9989
# Train Epoch: 963 [0/1 (0%)]	Loss: 39.897104	 True Loss: 5785.080078
# Train Epoch: 963 [0/1 (0%)]	Loss: 286.771309	 True Loss: 41581.839844
# ====> VAE: Sample 963 Average loss: 0.2752
# ====> VQ: Sample 963 Average loss: 1.9777
# Train Epoch: 964 [0/1 (0%)]	Loss: 40.090891	 True Loss: 5813.179199
# Train Epoch: 964 [0/1 (0%)]	Loss: 290.351724	 True Loss: 42101.000000
# ====> VAE: Sample 964 Average loss: 0.2765
# ====> VQ: Sample 964 Average loss: 2.0024
# Train Epoch: 965 [0/1 (0%)]	Loss: 39.979991	 True Loss: 5797.098633
# Train Epoch: 965 [0/1 (0%)]	Loss: 289.527909	 True Loss: 41981.546875
# ====> VAE: Sample 965 Average loss: 0.2757
# ====> VQ: Sample 965 Average loss: 1.9967
# Train Epoch: 966 [0/1 (0%)]	Loss: 39.887645	 True Loss: 5783.708496
# Train Epoch: 966 [0/1 (0%)]	Loss: 293.877263	 True Loss: 42612.203125
# ====> VAE: Sample 966 Average loss: 0.2751
# ====> VQ: Sample 966 Average loss: 2.0267
# Train Epoch: 967 [0/1 (0%)]	Loss: 39.674623	 True Loss: 5752.820312
# Train Epoch: 967 [0/1 (0%)]	Loss: 283.647441	 True Loss: 41128.878906
# ====> VAE: Sample 967 Average loss: 0.2736
# ====> VQ: Sample 967 Average loss: 1.9562
# Train Epoch: 968 [0/1 (0%)]	Loss: 40.233196	 True Loss: 5833.813477
# Train Epoch: 968 [0/1 (0%)]	Loss: 295.649030	 True Loss: 42869.109375
# ====> VAE: Sample 968 Average loss: 0.2775
# ====> VQ: Sample 968 Average loss: 2.0390
# Train Epoch: 969 [0/1 (0%)]	Loss: 39.709005	 True Loss: 5757.805664
# Train Epoch: 969 [0/1 (0%)]	Loss: 305.370339	 True Loss: 44278.699219
# ====> VAE: Sample 969 Average loss: 0.2739
# ====> VQ: Sample 969 Average loss: 2.1060
# Train Epoch: 970 [0/1 (0%)]	Loss: 40.071670	 True Loss: 5810.392090
# Train Epoch: 970 [0/1 (0%)]	Loss: 291.212662	 True Loss: 42225.835938
# ====> VAE: Sample 970 Average loss: 0.2764
# ====> VQ: Sample 970 Average loss: 2.0084
# Train Epoch: 971 [0/1 (0%)]	Loss: 40.010944	 True Loss: 5801.586914
# Train Epoch: 971 [0/1 (0%)]	Loss: 302.522225	 True Loss: 43865.722656
# ====> VAE: Sample 971 Average loss: 0.2759
# ====> VQ: Sample 971 Average loss: 2.0864
# Train Epoch: 972 [0/1 (0%)]	Loss: 39.988234	 True Loss: 5798.293945
# Train Epoch: 972 [0/1 (0%)]	Loss: 299.508351	 True Loss: 43428.710938
# ====> VAE: Sample 972 Average loss: 0.2758
# ====> VQ: Sample 972 Average loss: 2.0656
# Train Epoch: 973 [0/1 (0%)]	Loss: 39.854654	 True Loss: 5778.924805
# Train Epoch: 973 [0/1 (0%)]	Loss: 295.154472	 True Loss: 42797.398438
# ====> VAE: Sample 973 Average loss: 0.2749
# ====> VQ: Sample 973 Average loss: 2.0355
# Train Epoch: 974 [0/1 (0%)]	Loss: 39.912786	 True Loss: 5787.354004
# Train Epoch: 974 [0/1 (0%)]	Loss: 291.324865	 True Loss: 42242.105469
# ====> VAE: Sample 974 Average loss: 0.2753
# ====> VQ: Sample 974 Average loss: 2.0091
# Train Epoch: 975 [0/1 (0%)]	Loss: 39.970137	 True Loss: 5795.669922
# Train Epoch: 975 [0/1 (0%)]	Loss: 286.727317	 True Loss: 41575.460938
# ====> VAE: Sample 975 Average loss: 0.2757
# ====> VQ: Sample 975 Average loss: 1.9774
# Train Epoch: 976 [0/1 (0%)]	Loss: 39.812194	 True Loss: 5772.768066
# Train Epoch: 976 [0/1 (0%)]	Loss: 293.856897	 True Loss: 42609.250000
# ====> VAE: Sample 976 Average loss: 0.2746
# ====> VQ: Sample 976 Average loss: 2.0266
# Train Epoch: 977 [0/1 (0%)]	Loss: 39.685671	 True Loss: 5754.422363
# Train Epoch: 977 [0/1 (0%)]	Loss: 299.030550	 True Loss: 43359.429688
# ====> VAE: Sample 977 Average loss: 0.2737
# ====> VQ: Sample 977 Average loss: 2.0623
# Train Epoch: 978 [0/1 (0%)]	Loss: 39.641996	 True Loss: 5748.089355
# Train Epoch: 978 [0/1 (0%)]	Loss: 288.516918	 True Loss: 41834.953125
# ====> VAE: Sample 978 Average loss: 0.2734
# ====> VQ: Sample 978 Average loss: 1.9898
# Train Epoch: 979 [0/1 (0%)]	Loss: 39.839665	 True Loss: 5776.751465
# Train Epoch: 979 [0/1 (0%)]	Loss: 287.627478	 True Loss: 41705.984375
# ====> VAE: Sample 979 Average loss: 0.2748
# ====> VQ: Sample 979 Average loss: 1.9836
# Train Epoch: 980 [0/1 (0%)]	Loss: 40.036658	 True Loss: 5805.315430
# Train Epoch: 980 [0/1 (0%)]	Loss: 298.270339	 True Loss: 43249.199219
# ====> VAE: Sample 980 Average loss: 0.2761
# ====> VQ: Sample 980 Average loss: 2.0570
# Train Epoch: 981 [0/1 (0%)]	Loss: 39.759947	 True Loss: 5765.192383
# Train Epoch: 981 [0/1 (0%)]	Loss: 298.632435	 True Loss: 43301.703125
# ====> VAE: Sample 981 Average loss: 0.2742
# ====> VQ: Sample 981 Average loss: 2.0595
# Train Epoch: 982 [0/1 (0%)]	Loss: 40.149815	 True Loss: 5821.723145
# Train Epoch: 982 [0/1 (0%)]	Loss: 294.233809	 True Loss: 42663.902344
# ====> VAE: Sample 982 Average loss: 0.2769
# ====> VQ: Sample 982 Average loss: 2.0292
# Train Epoch: 983 [0/1 (0%)]	Loss: 39.570326	 True Loss: 5737.697266
# Train Epoch: 983 [0/1 (0%)]	Loss: 295.049165	 True Loss: 42782.128906
# ====> VAE: Sample 983 Average loss: 0.2729
# ====> VQ: Sample 983 Average loss: 2.0348
# Train Epoch: 984 [0/1 (0%)]	Loss: 39.799630	 True Loss: 5770.946289
# Train Epoch: 984 [0/1 (0%)]	Loss: 289.599407	 True Loss: 41991.914062
# ====> VAE: Sample 984 Average loss: 0.2745
# ====> VQ: Sample 984 Average loss: 1.9972
# Train Epoch: 985 [0/1 (0%)]	Loss: 39.533991	 True Loss: 5732.428711
# Train Epoch: 985 [0/1 (0%)]	Loss: 291.452802	 True Loss: 42260.656250
# ====> VAE: Sample 985 Average loss: 0.2726
# ====> VQ: Sample 985 Average loss: 2.0100
# Train Epoch: 986 [0/1 (0%)]	Loss: 39.756984	 True Loss: 5764.762695
# Train Epoch: 986 [0/1 (0%)]	Loss: 289.479122	 True Loss: 41974.472656
# ====> VAE: Sample 986 Average loss: 0.2742
# ====> VQ: Sample 986 Average loss: 1.9964
# Train Epoch: 987 [0/1 (0%)]	Loss: 39.609062	 True Loss: 5743.313965
# Train Epoch: 987 [0/1 (0%)]	Loss: 300.044423	 True Loss: 43506.441406
# ====> VAE: Sample 987 Average loss: 0.2732
# ====> VQ: Sample 987 Average loss: 2.0693
# Train Epoch: 988 [0/1 (0%)]	Loss: 39.598141	 True Loss: 5741.730469
# Train Epoch: 988 [0/1 (0%)]	Loss: 301.344612	 True Loss: 43694.968750
# ====> VAE: Sample 988 Average loss: 0.2731
# ====> VQ: Sample 988 Average loss: 2.0782
# Train Epoch: 989 [0/1 (0%)]	Loss: 39.762894	 True Loss: 5765.619629
# Train Epoch: 989 [0/1 (0%)]	Loss: 292.600189	 True Loss: 42427.027344
# ====> VAE: Sample 989 Average loss: 0.2742
# ====> VQ: Sample 989 Average loss: 2.0179
# Train Epoch: 990 [0/1 (0%)]	Loss: 39.711668	 True Loss: 5758.191895
# Train Epoch: 990 [0/1 (0%)]	Loss: 286.880819	 True Loss: 41597.718750
# ====> VAE: Sample 990 Average loss: 0.2739
# ====> VQ: Sample 990 Average loss: 1.9785
# Train Epoch: 991 [0/1 (0%)]	Loss: 39.637375	 True Loss: 5747.419434
# Train Epoch: 991 [0/1 (0%)]	Loss: 301.489224	 True Loss: 43715.937500
# ====> VAE: Sample 991 Average loss: 0.2734
# ====> VQ: Sample 991 Average loss: 2.0792
# Train Epoch: 992 [0/1 (0%)]	Loss: 39.947966	 True Loss: 5792.455078
# Train Epoch: 992 [0/1 (0%)]	Loss: 296.043912	 True Loss: 42926.367188
# ====> VAE: Sample 992 Average loss: 0.2755
# ====> VQ: Sample 992 Average loss: 2.0417
# Train Epoch: 993 [0/1 (0%)]	Loss: 39.651387	 True Loss: 5749.451172
# Train Epoch: 993 [0/1 (0%)]	Loss: 299.015086	 True Loss: 43357.187500
# ====> VAE: Sample 993 Average loss: 0.2735
# ====> VQ: Sample 993 Average loss: 2.0622
# Train Epoch: 994 [0/1 (0%)]	Loss: 39.600091	 True Loss: 5742.013184
# Train Epoch: 994 [0/1 (0%)]	Loss: 298.944935	 True Loss: 43347.015625
# ====> VAE: Sample 994 Average loss: 0.2731
# ====> VQ: Sample 994 Average loss: 2.0617
# Train Epoch: 995 [0/1 (0%)]	Loss: 39.910244	 True Loss: 5786.985352
# Train Epoch: 995 [0/1 (0%)]	Loss: 307.254095	 True Loss: 44551.843750
# ====> VAE: Sample 995 Average loss: 0.2752
# ====> VQ: Sample 995 Average loss: 2.1190
# Train Epoch: 996 [0/1 (0%)]	Loss: 39.793945	 True Loss: 5770.122070
# Train Epoch: 996 [0/1 (0%)]	Loss: 293.280496	 True Loss: 42525.671875
# ====> VAE: Sample 996 Average loss: 0.2744
# ====> VQ: Sample 996 Average loss: 2.0226
# Train Epoch: 997 [0/1 (0%)]	Loss: 39.675586	 True Loss: 5752.959961
# Train Epoch: 997 [0/1 (0%)]	Loss: 292.491325	 True Loss: 42411.242188
# ====> VAE: Sample 997 Average loss: 0.2736
# ====> VQ: Sample 997 Average loss: 2.0172
# Train Epoch: 998 [0/1 (0%)]	Loss: 39.909739	 True Loss: 5786.912109
# Train Epoch: 998 [0/1 (0%)]	Loss: 294.887473	 True Loss: 42758.683594
# ====> VAE: Sample 998 Average loss: 0.2752
# ====> VQ: Sample 998 Average loss: 2.0337
# Train Epoch: 999 [0/1 (0%)]	Loss: 39.626165	 True Loss: 5745.793945
# Train Epoch: 999 [0/1 (0%)]	Loss: 291.637069	 True Loss: 42287.375000
# ====> VAE: Sample 999 Average loss: 0.2733
# ====> VQ: Sample 999 Average loss: 2.0113

# %%
x_long, params_long, e_params_long = X_long.parameters()
channels = np.array(e_params_long["Pulse"]["channel"]).reshape(-1)
indexs = np.array(e_params_long["Pulse"]["index"]).reshape(-1)

# %%
pulses_indexs = indexs[np.where(channels == 1)]
pulses_indexs.sort(axis=0)
pulses_indexs.shape
# Out:
# (863,)

# %%
plt.plot(pulses_indexs)
plt.plot(anomalies)

# %%
rec_loss = (REC - Origin)**2
anomalies = np.where(rec_loss[:,1]>1200)[0]
anomalies.shape
# plt.plot(rec_loss[:2000,0])
# plt.ylim(0,20)
# Out:
# (871,)

# %%
days = 7
# N = 288 * days
N=len(denoised[1,0])
n=2
results = []
i = 0
while len(results) < n:
    i += 1
    Amps = sf.rfft(denoised[15,0]) #/ N
    freqs = sf.rfftfreq(n=N, d=1/(24*12*7))
    
    max_freq_ind = np.argpartition(np.abs(Amps), -i)[-i:]
    results = filter_close_values(freqs[max_freq_ind], 0.02)
#     results = freqs[max_freq_ind]
# print(max_freq_ind)
print(abs(Amps[max_freq_ind]))
# print((freqs))
print(results)
print([result%14 for result in results])

plt.stem(freqs[max_freq_ind])
# frs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 days = 7
#       2 # N = 288 * days
# ----> 3 N=len(denoised[1,0])
#       4 n=2
#       5 results = []
#
# NameError: name 'denoised' is not defined

# %%
np.set_printoptions(suppress=True)
VAE_losses = []
VQ_losses = []

for epoch in range(1, 100):
    loss_vae = train(vae, train_data, args, opt_vae, epoch)
    loss_vq = train(vq, train_data, args, opt_vq, epoch)
    
    if epoch%10 == 1:
        display.clear_output(wait=True)
        show_results(vae, train_data, args)
        show_results(vq, train_data, args, vq=True)
        
    VAE_losses.append(loss_vae)
    VQ_losses.append(loss_vq)
        
    print('====> VAE: Sample {} Average loss: {:.4f}'.format(epoch, loss_vae / len(train_data.dataset)))
    print('====> VQ: Sample {} Average loss: {:.4f}'.format(epoch, loss_vq / len(train_data.dataset)))
# Out:
# ====> VAE: Sample 91 Average loss: 0.0801
# ====> VQ: Sample 91 Average loss: 0.1716
# Train Epoch: 92 [0/16 (0%)]	Loss: 309.156372	 True Loss: 79144.031250
# Train Epoch: 92 [0/16 (0%)]	Loss: 682.442810	 True Loss: 174705.359375
# ====> VAE: Sample 92 Average loss: 0.0801
# ====> VQ: Sample 92 Average loss: 0.1728
# Train Epoch: 93 [0/16 (0%)]	Loss: 308.695984	 True Loss: 79026.171875
# Train Epoch: 93 [0/16 (0%)]	Loss: 684.559387	 True Loss: 175247.203125
# ====> VAE: Sample 93 Average loss: 0.0801
# ====> VQ: Sample 93 Average loss: 0.1743
# Train Epoch: 94 [0/16 (0%)]	Loss: 308.768951	 True Loss: 79044.851562
# Train Epoch: 94 [0/16 (0%)]	Loss: 683.923767	 True Loss: 175084.484375
# ====> VAE: Sample 94 Average loss: 0.0801
# ====> VQ: Sample 94 Average loss: 0.1764
# Train Epoch: 95 [0/16 (0%)]	Loss: 308.509003	 True Loss: 78978.304688
# Train Epoch: 95 [0/16 (0%)]	Loss: 702.359558	 True Loss: 179804.046875
# ====> VAE: Sample 95 Average loss: 0.0801
# ====> VQ: Sample 95 Average loss: 0.1770
# Train Epoch: 96 [0/16 (0%)]	Loss: 308.491302	 True Loss: 78973.773438
# Train Epoch: 96 [0/16 (0%)]	Loss: 698.512268	 True Loss: 178819.140625
# ====> VAE: Sample 96 Average loss: 0.0800
# ====> VQ: Sample 96 Average loss: 0.1796
# Train Epoch: 97 [0/16 (0%)]	Loss: 308.231995	 True Loss: 78907.390625
# Train Epoch: 97 [0/16 (0%)]	Loss: 710.490295	 True Loss: 181885.515625
# ====> VAE: Sample 97 Average loss: 0.0800
# ====> VQ: Sample 97 Average loss: 0.1810
# Train Epoch: 98 [0/16 (0%)]	Loss: 308.282471	 True Loss: 78920.312500
# Train Epoch: 98 [0/16 (0%)]	Loss: 715.918030	 True Loss: 183275.015625
# ====> VAE: Sample 98 Average loss: 0.0800
# ====> VQ: Sample 98 Average loss: 0.1829
# Train Epoch: 99 [0/16 (0%)]	Loss: 307.888947	 True Loss: 78819.570312
# Train Epoch: 99 [0/16 (0%)]	Loss: 717.829224	 True Loss: 183764.281250
# ====> VAE: Sample 99 Average loss: 0.0799
# ====> VQ: Sample 99 Average loss: 0.1848

# %%
shape = train_data_long.dataset.data.shape
shape[:-1]
np.expand_dims(np.empty(shape[:-1]), axis=-1).shape
# Out:
# (1, 1)

# %%
2/365
# Out:
# 0.005479452054794521

# %%
def rescale_x_axis(ts, args):
    n = len(ts)
    t = np.arange(n)
    scale_factor = 365 / args.periode
    new_n = int(scale_factor * n)

    # Generate new time vector and zero-padded time series
    new_t = np.linspace(0, n - 1, new_n)
    new_ts = np.interp(new_t, t, ts)
    return new_ts

# %%
def find_freqs_p(denoised, n):
    new_ts = rescale_x_axis(denoised, args)
#     new_ts = denoised
    freqs_w = []
    i = 0
    sample_rate = 12*24*7
#     sample_rate = 1
    N=len(new_ts)
#     print(new_ts.shape)
    while len(freqs_w) < n:
        i += 1
        X = sf.rfft(new_ts) #/ N
        freqs = sf.rfftfreq(n=N, d=1/sample_rate)
#         print(X.shape)
#         print(np.argpartition(np.abs(X), -i))
        max_freq_ind = np.argpartition(np.abs(X), -i)[-i:]
#         print(i, freqs_w, len(freqs_w))
        freqs_w = filter_close_values(freqs[max_freq_ind][:n], 0.005)
#         print(freqs_w, len(freqs_w))
    
        
    results = [fs*364/2% 14 for fs in freqs_w]
    return np.array(results, dtype=np.float64)

# %%
k=707
res_rec = find_freqs_p(denoised_orig[k,0],5)
res_orig = find_freqs_p(denoised_rec[k,0],5)
# print(find_freqs_p(denoised[k,0],2))
print(np.sort(res_orig))
print(np.sort(res_rec))
print(np.sort(arr[k]))
# Out:
# [ 3.45205479  6.94246575  6.98082192 10.47123288 13.96164384]
# [ 3.45205479  6.94246575  6.98082192 10.47123288 13.96164384]
# [ 8.11374354 10.61894943 11.00803731 13.17960892 13.74469536]

# %%
denoised_orig.shape
# Out:
# (4000, 10, 576)

# %%
plt.plot(denoised_orig[k].T)
plt.plot(denoised_rec[k].T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f42586d74f0>,
#  <matplotlib.lines.Line2D at 0x7f42586f8f10>,
#  <matplotlib.lines.Line2D at 0x7f42586f8f40>,
#  <matplotlib.lines.Line2D at 0x7f42586f9030>,
#  <matplotlib.lines.Line2D at 0x7f42586f9120>,
#  <matplotlib.lines.Line2D at 0x7f42586f9210>,
#  <matplotlib.lines.Line2D at 0x7f42586f9300>,
#  <matplotlib.lines.Line2D at 0x7f42586f93f0>,
#  <matplotlib.lines.Line2D at 0x7f42586f94e0>,
#  <matplotlib.lines.Line2D at 0x7f42586f95d0>]

# %%
13.2406695/res[1]
# Out:
# /tmp/ipykernel_9500/3347500641.py:1: RuntimeWarning: divide by zero encountered in double_scalars
#   13.2406695/res[1]
# inf

# %%
from scipy.signal import find_peaks

# Create a time series with low-frequency seasonality
n = 500
t = np.arange(n)
frequency = 0.005  # Low-frequency seasonality
seasonality = 5 * np.sin(2 * np.pi * frequency * t)
noise = np.random.normal(0, 0.5, n)
time_series = seasonality + noise

# Compute the FFT
fft_result = np.fft.fft(time_series)
sampling_frequency = 1  # Assuming unit sampling frequency
frequencies = np.fft.fftfreq(n, d=1 / sampling_frequency)

# Identify the peaks in the FFT magnitude plot
peaks, _ = find_peaks(np.abs(fft_result), 600)

# Extract corresponding frequencies
peak_frequencies = frequencies[peaks]

# Plot the time series and the estimated frequencies
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(t, time_series)
plt.title('Time Series with Low-Frequency Seasonality')

plt.subplot(2, 1, 2)
plt.plot(frequencies, np.abs(fft_result))
plt.title('FFT of Time Series')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')

# Plot the estimated frequencies
for freq in peak_frequencies:
    plt.axvline(x=freq, color='r', linestyle='--', label=f'Estimated Frequency: {freq:.4f}')
plt.legend()

plt.tight_layout()
plt.show()

# %%
11.27865253/res[0]
# Out:
# 1.0741573838095237

# %%
Origin_norm, REC_norm, _ = rebuild_TS(v, train_data, args, keep_norm=True)
denoised = denoise_data(Origin_norm.cpu())

# %%
plt.plot(Origin_norm[1,0], alpha=0.2)
plt.plot(denoised[1,0], "r-")

# %%
find_freqs_p(denoised[1,0],2)
arr[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 find_freqs_p(denoised[1,0],2)
#       2 arr[1]
#
# NameError: name 'find_freqs_p' is not defined

# %%
def find_freqs(denoised, n):
    freqs_w = []
    i = 0
    sample_rate = 24*12*7
    N=len(denoised)
    print(denoised.shape)
    while len(freqs_w) < n:
        i += 1
        X = sf.rfft(denoised) #/ N
        freqs = sf.rfftfreq(n=N, d=1/sample_rate)
#         print(X.shape)

        max_freq_ind = np.argpartition(np.abs(X), -i)[-i:]
#         print(freqs[max_freq_ind])
        freqs_w = filter_close_values(freqs[max_freq_ind], 0.2)
#         print(freqs_w)
    
        
    results = [fs % 14 for fs in freqs_w]
    return np.array(results, dtype=np.float64)

# %%
def get_frequencies_per_week_long(v, train_data, args, n):
#     data = train_data.dataset.data
#     shape = data.shape[:-1]
#     N = data.shape[-1]

    Origin_norm, REC_norm, _ = rebuild_TS_non_overlapping(v, train_data, args, keep_norm=True)
    denoised = denoise_data(REC_norm.T.cpu())


    
    freqs = np.empty((args.n_channels, n))
    for i, fs in enumerate(freqs):
        fs = find_freqs(denoised[i], n)
    

#     print(freqs_w)
#     print([fs % 14 for fs in freqs_w])

    return fs

# %%
def get_frequencies_per_week(v, train_data, args, n):

    Origin_norm, REC_norm, _ = rebuild_TS(v, train_data, args, keep_norm=True)
    denoised = denoise_data(Origin_norm.cpu())


    freqs = np.empty((denoised.shape[0], args.n_channels, n))
    for i, sample in enumerate(freqs):
#         print(i)
        for j, fs in enumerate(sample):
            fs = find_freqs_p(denoised[i, j], n)
            freqs[i,j] = fs
    return freqs

# %%
arr.shape
# Out:
# (5000, 5)

# %%
fs = get_frequencies_per_week(v, train_data, args, n=5)
x, params, e_params = X.parameters()
frs = e_params["Seasonality"]["frequency_per_week"]
arr = np.array(frs)
arr[0]

# print(fs)
# frs
# Out:
# array([11.07251433, 13.40359696, 11.66289372, 13.41735455,  9.39057982])

# %%
fs = get_frequencies_per_week_long(v, train_data_long, args, n=3)
x_long, params_long, e_params_long = X_long.parameters()
frs = e_params_long["Seasonality"]["frequency_per_week"][0]
print(fs)
frs
# Out:
# (83520,)
# input [13.73448276 13.75862069]
# 13.758620689655174 13.734482758620691
# 0.024137931034482918
# input [13.15517241 13.73448276 13.75862069]
# 13.734482758620691 13.155172413793105
# 0.5793103448275865
# 13.758620689655174 13.734482758620691
# 0.024137931034482918
# input [13.15517241 13.17931034 13.73448276 13.75862069]
# 13.179310344827588 13.155172413793105
# 0.024137931034482918
# 13.734482758620691 13.155172413793105
# 0.5793103448275865
# 13.758620689655174 13.734482758620691
# 0.024137931034482918
# input [12.52758621 13.15517241 13.17931034 13.73448276 13.75862069]
# 13.155172413793105 12.527586206896553
# 0.6275862068965523
# 13.179310344827588 13.155172413793105
# 0.024137931034482918
# 13.734482758620691 13.155172413793105
# 0.5793103448275865
# 13.758620689655174 13.734482758620691
# 0.024137931034482918
# [12.52758621 13.15517241 13.73448276]
# array([13.74697078, 12.51960769, 13.16560254])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Create an example time series dataset
np.random.seed(0)
n = 100
t = np.arange(n)
noise = np.random.normal(0, 0.5, n)
time_series = 2 * t + 10 * np.sin(0.1 * t) + noise

# Convert the data to a pandas Series (with dates) for time-based analysis
# date_range = pd.date_range(start='2023-01-01', periods=, freq='D')
ts_data = pd.Series(denoised[0][:288*7])

# Apply exponential smoothing
exponential_smoothing = sm.tsa.ExponentialSmoothing(ts_data, trend='add', seasonal=None)
fitted_model = exponential_smoothing.fit()

# Forecast using the fitted model
forecast = fitted_model.forecast(steps=100)  # Forecast the next 10 time points

# Plot the original time series and the forecasted values
plt.figure(figsize=(10, 6))
plt.plot(ts_data, label='Original Time Series')
plt.plot(fitted_model.fittedvalues, label='Fitted Values', linestyle='--')
plt.plot(forecast, label='Forecasted Values', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.title('Exponential Smoothing')
plt.show()

# %%
data = train_data_long.dataset.data
data.numpy().shape
# Out:
# (2, 83865)

# %%
from matplotlib.ticker import MultipleLocator

days = 7
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(data.T[:288*days])
plt.grid(True)
x_locator = MultipleLocator(base=288)
ax.xaxis.set_major_locator(x_locator)
ax.set_xticklabels([f'{a}' for a in range(days+1)])
# ax.xaxis.set_major_formatter('{:.0f}'.format)
plt.show()
# Out:
# /tmp/ipykernel_9355/464481837.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f'{a}' for a in range(days+1)])

# %%
mean_global = data.mean(dim=1, keepdim=True)
std_global = data.std(dim=1, keepdim=True)
for i, (data, label, norm) in enumerate(train_data_long):
    denorm_data = revert_standarization(data, norm)
    mean_window = denorm_data.mean(dim=-1)
    std_window = denorm_data.std(dim=-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 4
#       2 std_global = data.std(dim=1, keepdim=True)
#       3 for i, (data, label, norm) in enumerate(train_data_long):
# ----> 4     denorm_data = revert_standarization(data, norm)
#       5     mean_window = denorm_data.mean(dim=-1)
#       6     std_window = denorm_data.std(dim=-1)
#
# File ~/git/lab/utils.py:162, in revert_standarization(data, norm)
#     160 def revert_standarization(data, norm):
#     161     std, mean = norm[2], norm[3]
# --> 162     original_val = (std * data) + mean
#     163     return original_val
#
# TypeError: only integer tensors of a single element can be converted to an index

# %%
x_long, params_long, e_params_long = X_long.parameters()
frs = e_params_long["Seasonality"]["frequency_per_week"][0]
frs
# Out:
# array([ 9.12847645,  8.751179  , 11.507779  ])

# %%
e_params_long["Seasonality"]["amplitude"][0]
# Out:
# array([18,  6])

# %%
def denoise_data(data):
    denoised = np.empty_like(data)
    for i, d in enumerate(data):
        denoised[i] = denoise(d.unsqueeze(0).cpu())
    return denoised

Origin_norm, REC_norm, _ = rebuild_TS_non_overlapping(v, train_data_long, args, keep_norm=True)
denoised = denoise_data(Origin_norm.T.cpu())

# %%
def filter_close_values(input_list, threshold):
    if len(input_list) <= 1:
        return input_list  # Nothing to filter if the list has 0 or 1 element

    input_list.sort()  # Sort the list in ascending order
    filtered_list = [input_list[0]]

    for value in input_list[1:]:
        if abs(value - filtered_list[-1]) > threshold and (abs(value % filtered_list) > threshold).all():
            filtered_list.append(value)

    return filtered_list

# %%
denoised.shape
# Out:
# (4000, 1, 8064)

# %%
from scipy.signal import find_peaks

# # Sample data with two seasonalities
n = len(denoised[0]) # 400
sampling_rate  = 1
# t = np.arange(0, n)
# sampling_rate = 10  # Increase the sampling rate
# t = t / sampling_rate  # Adjust the time vector accordingly
# time_series = 5 * np.sin(0.1 * t * 2 * np.pi) + 2 * np.sin(0.4 * t * 2 * np.pi)

# Compute the FFT
fft_result = np.fft.fft(denoised[0,0])

# Calculate frequencies
frequencies = np.fft.fftfreq(n, d=1/(24*12*7))
print(frequencies)

# Find peaks in the FFT magnitude
peaks, _ = find_peaks(np.abs(fft_result), height=np.max(fft_result))  # Adjust the height threshold as needed

# Extract corresponding frequencies
peak_frequencies = np.abs(frequencies[peaks])

print("Dominant frequencies:", peak_frequencies)

# Plot the FFT
plt.figure(figsize=(10, 6))
plt.plot(frequencies, np.abs(fft_result))
plt.title('FFT of Time Series')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid()
plt.show()
# Out:
# [0.]
# Dominant frequencies: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1059], line 28
#      26 # Plot the FFT
#      27 plt.figure(figsize=(10, 6))
# ---> 28 plt.plot(frequencies, np.abs(fft_result))
#      29 plt.title('FFT of Time Series')
#      30 plt.xlabel('Frequency (Hz)')
#
# File ~/testenv/lib/python3.10/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/testenv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/testenv/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/testenv/lib/python3.10/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (8064,)

# %%
1008/(24*12*7)
# Out:
# 0.5

# %%
days = 7
# N = 288 * days
N=len(denoised[0,0])
n=2
results = []
i = 0
while len(results) < n:
    i += 1
    X = sf.rfft(denoised[0,0]) #/ N
    freqs = sf.rfftfreq(n=N, d=1/(24*12*7))
    
    max_freq_ind = np.argpartition(np.abs(X), -i)[-i:]
#     results = filter_close_values(freqs[max_freq_ind], 0.2)
    results = freqs[max_freq_ind]
print(max_freq_ind)
print(abs(X[max_freq_ind]))
print((freqs))
# print(results)
# print([result%14 for result in results])

plt.stem(freqs[max_freq_ind])
# frs
# Out:
# [37  0]
# [1002.93164 3740.3425 ]
# [   0.      0.25    0.5  ... 1007.5  1007.75 1008.  ]
# <StemContainer object of 3 artists>

# %%
def get_frequencies_per_week(v, train_data, args, n):
    
    Origin_norm, REC_norm, _ = rebuild_TS_non_overlapping(v, train_data, args, keep_norm=True)
    denoised = denoise_data(Origin_norm.T.cpu())

    N=len(denoised[0])
    freqs_w = []
    i = 0
    while len(freqs_w) < n:
        i += 1
        X = sf.rfft(denoised[0]) #/ N
        freqs = sf.rfftfreq(n=N, d=1/(24*12*7))

        max_freq_ind = np.argpartition(np.abs(X), -i)[-i:]
        freqs_w = filter_close_values(freqs[max_freq_ind], 0.2)

#     print(freqs_w)
#     print([fs % 14 for fs in freqs_w])
    results = [fs % 14 for fs in freqs_w]

    return results

# %%
get_frequencies_per_week(v, train_data_long, args, n=3)
x_long, params_long, e_params_long = X_long.parameters()
frs = e_params_long["Seasonality"]["frequency_per_week"][0]
frs
# Out:
# [8.810344827586208, 10.210344827586209, 13.493103448275864]
# [8.810344827586208, 10.210344827586209, 13.493103448275864]
# array([ 8.82219493, 13.48370278, 10.20135647])

# %%
N/(288*7)
# Out:
# 1.0

# %%
import scipy.fft as sf
import matplotlib.ticker as tck

days = 7
N = 288 * days
# N = denoised.shape[-1]
X = sf.rfft(denoised[0][:N]) #/ N
freqs = sf.rfftfreq(n=N, d=1/(days*2))

print(X.shape)
# Plot signal
fig, axes = plt.subplots(figsize=(15,3), ncols=2)
ax=axes[0]
ax.plot(denoised[0])
# ax.xaxis.set_major_locator(tck.MultipleLocator(50))
ax.grid()

# # Plot DFT
ax=axes[1]
extent = 288*7 -1#288*7#N
ax.set_xlabel('period, days')
# ax.stem(freqs[:extent], abs(X[:extent]))
ax.stem(freqs, abs(X))

# x_locator = MultipleLocator(base=288)
# ax.xaxis.set_major_locator(x_locator)
# ax.set_xticklabels([f'{a}' for a in range(days+1)])
# ticks = ax.get_xticks()
# ax.set_xticklabels([f'{a}' for a in range(1000)])
# ax.invert_xaxis()
ax.grid()
np.set_printoptions(suppress=True)

# print(np.argmax(X))
n=5
max_freq_ind = np.argpartition(np.abs(X), -n)[-n:]
print(max_freq_ind)
print(abs(X[max_freq_ind]))
print(freqs[max_freq_ind]*N)
frs
# Out:
# (1009,)
# [ 8  6  7 11 15]
# [255.40695 298.44864 699.44946 662.7711  397.8458 ]
# [112.  84.  98. 154. 210.]
# array([ 9.40703251, 10.85850522, 10.41877301,  7.38420925])

# %%
Origin_norm.shape
# Out:
# torch.Size([83520, 1])

# %%
# Define your time series data with a 3-day seasonality
sampling_rate = 5  # 5 minutes between data points
num_points = Origin_norm.shape[0]  # Number of data points (assuming 5-minute intervals in a day)

# Create a time vector in minutes
time = np.arange(0, num_points)# * sampling_rate

# # Create a synthetic time series with a 3-day seasonality
# seasonality_freq = 1 / (3 * 24 * 60)  # Frequency in Hz (3 days in minutes)
# amplitude = 10  # Amplitude of the seasonality
# noise = np.random.normal(0, 1, num_points)  # Add some random noise
# data = amplitude * np.sin(2 * np.pi * seasonality_freq * time) + noise

# Perform FFT on the data
fft_result = np.fft.fft(Origin_norm[:,0].cpu())
frequencies = np.fft.fftfreq(denoised.shape[-1], d=sampling_rate)

# Plot the original data
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, denoised[0])
plt.title("Original Time Series Data")
plt.xlabel("Time (minutes)")
plt.ylabel("Value")

# Plot the FFT results
plt.subplot(2, 1, 2)
plt.plot(frequencies, np.abs(fft_result))
plt.title("FFT Decomposition")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.xlim(0, 0.01)  # Limit the x-axis to relevant frequencies

plt.tight_layout()
plt.show()

# %%
N = 10  # Adjust N as needed
max_amplitude_indices = np.argpartition(np.abs(fft_result), -N)[-N:]
# Get the corresponding frequency in Hertz
max_frequencies = frequencies[max_amplitude_indices]
positive_frequencies = max_frequencies[max_frequencies > 0]
print("Dominant Frequency:", positive_frequencies, "Hz")
np.set_printoptions(suppress=True)
# Out:
# Dominant Frequency: [0.00215517 0.00093391 0.00107759 0.00073276 0.00146552] Hz

# %%
np.sort(7 / (positive_frequencies * 24 * 60))
# Out:
# array([2.25555556, 3.31699346, 4.51111111, 5.20512821, 6.63398693])

# %%
np.sort(frs)
# Out:
# array([ 7.38420925,  9.40703251, 10.41877301, 10.85850522])

# %%
x_long, params_long, e_params_long = X_long.parameters()
frs = e_params_long["Seasonality"]["frequency_per_week"][0]
frs/(7*288)
# Out:
# array([0.00466619, 0.00538616, 0.00516804, 0.0036628 ])

# %%
plot_rec(data.T[:args.L*5], denoised.T[:args.L*5])

# %%
denoised.shape
# Out:
# (2, 83520)

# %%
r = np.correlate(denoised[0][:args.L*20], denoised[0][:args.L], mode='full')[args.L*10:]
print(denoised.shape, r.shape)
# Out:
# (2, 83520) (6335,)

# %%
plt.figure(figsize=(14, 5))
plt.plot(r)
plt.xlabel('Lag (samples)')
# plt.xlim(0, 10000)
# Out:
# Text(0.5, 0, 'Lag (samples)')

# %%
idx=np.argpartition(r, -10)[-10:]

# %%
x= np.arange(len(denoised[0][:args.L*20]))
y = denoised[0][:args.L*20]
plt.plot(y, alpha=0.2)
plt.scatter(x[idx], y[idx], color='red', label='Dot at Index {}'.format(2901))

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
def autocorr1(x,lags):
    '''numpy.corrcoef, partial'''

    corr=[1. if l==0 else np.corrcoef(x[l:],x[:-l])[0][1] for l in lags]
    return np.array(corr)

def autocorr2(x,lags):
    '''manualy compute, non partial'''

    mean=np.mean(x)
    var=np.var(x)
    xp=x-mean
    corr=[1. if l==0 else np.sum(xp[l:]*xp[:-l])/len(x)/var for l in lags]

    return np.array(corr)

def autocorr3(x,lags):
    '''fft, pad 0s, non partial'''

    n=len(x)
    # pad 0s to 2n-1
    ext_size=2*n-1
    # nearest power of 2
    fsize=2**np.ceil(np.log2(ext_size)).astype('int')

    xp=x-np.mean(x)
    var=np.var(x)

    # do fft and ifft
    cf=np.fft.fft(xp,fsize)
    sf=cf.conjugate()*cf
    corr=np.fft.ifft(sf).real
    corr=corr/var/n

    return corr[:len(lags)]

def autocorr4(x,lags):
    '''fft, don't pad 0s, non partial'''
    mean=x.mean()
    var=np.var(x)
    xp=x-mean

    cf=np.fft.fft(xp)
    sf=cf.conjugate()*cf
    corr=np.fft.ifft(sf).real/var/len(x)

    return corr[:len(lags)]

def autocorr5(x,lags):
    '''numpy.correlate, non partial'''
    mean=x.mean()
    var=np.var(x)
    xp=x-mean
    corr=np.correlate(xp,xp,'full')[len(x)-1:]/var/len(x)

    return corr[:len(lags)]

# %%
y=[28,28,26,19,16,24,26,24,24,29,29,27,31,26,38,23,13,14,28,19,19,\
            17,22,2,4,5,7,8,14,14,23]
y=np.array(y).astype('float')

# lags=range(15)
lags=range(args.L)
fig,ax=plt.subplots()

for funcii, labelii in zip([autocorr1, autocorr2, autocorr3, autocorr4,
    autocorr5], ['np.corrcoef, partial', 'manual, non-partial',
        'fft, pad 0s, non-partial', 'fft, no padding, non-partial',
        'np.correlate, non-partial']):

    cii=funcii(denoised[0],lags)
#     print(labelii)
#     print(cii)
    ax.plot(lags,cii,label=labelii)

ax.set_xlabel('lag')
ax.set_ylabel('correlation coefficient')
ax.legend()
plt.show()

# %%
plt.plot(denoised[0][:576])

# %%
# ?plot_acf

# %%
plot_acf(denoised[0][:576*40], lags=576*1)

# %%
plot_acf(Origin_norm[0,0][:576*2].cpu(), lags=576*1)

# %%
fft_signal, freqs = fft_freq(denoised[0][:2000], args.step*60, 10)

# %%
plot_fft(denoised[0][:2000], fft_signal, freqs)
# Out:
# Dominant Frequency: [ 0.     1.728 -1.728 -1.584  1.584  3.312 -3.312  1.872 -1.872 -3.456
#   3.456 -1.44   1.44  -2.016  2.016  3.168 -3.168  2.16  -2.16   1.296] Hz
# Dominant Amplitude: [700.55273  403.97562  403.97562  139.17421  139.17421  101.54321
#  101.54321   85.815414  85.815414  83.31932   83.31932   65.075
#   65.075     44.328068  44.328068  38.753223  38.753223  33.267147
#   33.267147  31.328114]

# %%
import tsfel
# Retrieves a pre-defined feature configuration file to extract all available features
cfg = tsfel.get_features_by_domain("spectral")

# Extract features
X = tsfel.time_series_features_extractor(cfg, data.T, fs=1/5, window_size=args.L, overlap=0)
# Y = tsfel.time_series_features_extractor(cfg, denoised)
# Out:
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='145'
#                   max='145',
#                   style='width: 25%',
#               >
#                   145
#               </progress>
# *** Feature extraction finished ***

# %%
# ?tsfel.time_series_features_extractor

# %%
import pandas as pd
pd.options.display.max_rows = None
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
# X.T.columns = ["val"]
X.T
# Out:
#                                              0             1             2    \
# 0_FFT mean coefficient_0                 122.461       170.533       197.777
# 0_FFT mean coefficient_1                2294.586      1919.005      1628.834
# 0_FFT mean coefficient_10                206.542       177.248       418.546
# 0_FFT mean coefficient_100                13.760         0.756        15.874
# 0_FFT mean coefficient_101                 2.716        31.314         5.477
# 0_FFT mean coefficient_102                13.267         6.863         1.896
# 0_FFT mean coefficient_103                19.452        16.515         7.418
# 0_FFT mean coefficient_104                10.780        14.428         8.753
# 0_FFT mean coefficient_105                 3.820         0.091        23.638
# 0_FFT mean coefficient_106                 2.482         2.492         0.690
# 0_FFT mean coefficient_107                 6.871         0.961        36.573
# 0_FFT mean coefficient_108                 7.319         2.029        45.161
# 0_FFT mean coefficient_109                 0.078         0.626        20.586
# 0_FFT mean coefficient_11                356.114       306.172       649.362
# 0_FFT mean coefficient_110                34.342         1.188         4.947
# 0_FFT mean coefficient_111                11.232         9.811        43.186
# 0_FFT mean coefficient_112                 1.959        15.713         5.895
# 0_FFT mean coefficient_113                 2.465         3.917         0.191
# 0_FFT mean coefficient_114                 8.538         1.107        23.419
# 0_FFT mean coefficient_115                20.091         5.923         0.309
# 0_FFT mean coefficient_116                 3.121        14.507         3.926
# 0_FFT mean coefficient_117                 1.469        33.033         8.303
# 0_FFT mean coefficient_118                11.719        29.947         4.688
# 0_FFT mean coefficient_119                13.811        16.573         4.739
# 0_FFT mean coefficient_12                 18.489        60.996         2.074
# 0_FFT mean coefficient_120                 6.018         4.229         7.684
# 0_FFT mean coefficient_121                21.754        13.098        15.992
# 0_FFT mean coefficient_122                39.696        11.569         3.255
# 0_FFT mean coefficient_123                 3.072        28.239         1.358
# 0_FFT mean coefficient_124                10.290         8.408         0.667
# 0_FFT mean coefficient_125                 3.433         9.927        10.184
# 0_FFT mean coefficient_126                 6.110         6.788         5.746
# 0_FFT mean coefficient_127                 7.184         3.573         2.249
# 0_FFT mean coefficient_128                 8.657         2.146        17.501
# 0_FFT mean coefficient_129                 0.992         2.463        12.322
# 0_FFT mean coefficient_13                 20.076        18.022        14.839
# 0_FFT mean coefficient_130                 9.294        14.167         2.113
# 0_FFT mean coefficient_131                12.787        20.447         4.892
# 0_FFT mean coefficient_132                 0.061         2.811         5.313
# 0_FFT mean coefficient_133                 1.862         3.211         7.671
# 0_FFT mean coefficient_134                23.056        18.357         0.201
# 0_FFT mean coefficient_135                 8.871         7.094         7.017
# 0_FFT mean coefficient_136                 4.503         2.991         2.070
# 0_FFT mean coefficient_137                11.992        13.052         1.325
# 0_FFT mean coefficient_138                 0.817        14.705         1.610
# 0_FFT mean coefficient_139                10.557         3.241         0.698
# 0_FFT mean coefficient_14                  0.809        17.063        22.364
# 0_FFT mean coefficient_140                 4.522         0.438        20.221
# 0_FFT mean coefficient_141                36.009        10.569         0.499
# 0_FFT mean coefficient_142                 4.115        17.130         1.027
# 0_FFT mean coefficient_143                 0.920        15.373         7.710
# 0_FFT mean coefficient_144                14.929        15.248         4.812
# 0_FFT mean coefficient_145                 0.611        10.846        10.142
# 0_FFT mean coefficient_146                 3.957         5.700         5.668
# 0_FFT mean coefficient_147                 2.698         5.634         8.317
# 0_FFT mean coefficient_148                 3.459        16.685         7.129
# 0_FFT mean coefficient_149                 4.748         4.828         9.223
# 0_FFT mean coefficient_15                  0.526        16.620        19.229
# 0_FFT mean coefficient_150                 6.107         7.213         3.123
# 0_FFT mean coefficient_151                 1.406         1.161         6.231
# 0_FFT mean coefficient_152                 6.185        36.836         5.783
# 0_FFT mean coefficient_153                 5.146         2.328         0.941
# 0_FFT mean coefficient_154                32.013        13.348         8.018
# 0_FFT mean coefficient_155                 1.469         4.043         2.226
# 0_FFT mean coefficient_156                18.199         3.490        29.326
# 0_FFT mean coefficient_157                20.968         2.348        25.508
# 0_FFT mean coefficient_158                 2.705         8.271         0.333
# 0_FFT mean coefficient_159                10.357         5.398         6.436
# 0_FFT mean coefficient_16                131.568       181.030       107.876
# 0_FFT mean coefficient_160                26.329         4.239         1.960
# 0_FFT mean coefficient_161                 6.043        18.424         4.272
# 0_FFT mean coefficient_162                 4.520         1.901         5.533
# 0_FFT mean coefficient_163                22.125         1.495        14.813
# 0_FFT mean coefficient_164                21.768         5.095         0.881
# 0_FFT mean coefficient_165                 2.118         8.330         0.932
# 0_FFT mean coefficient_166                 0.621        10.711         3.512
# 0_FFT mean coefficient_167                 0.172         0.264         0.762
# 0_FFT mean coefficient_168                24.265         0.412        35.214
# 0_FFT mean coefficient_169                16.673         3.618        10.883
# 0_FFT mean coefficient_17                  7.846         8.041        13.122
# 0_FFT mean coefficient_170                 7.462         4.434        11.809
# 0_FFT mean coefficient_171                 1.194         4.215        20.103
# 0_FFT mean coefficient_172                 1.660        24.033        14.318
# 0_FFT mean coefficient_173                14.453         5.242        10.077
# 0_FFT mean coefficient_174                 2.648        14.634        21.613
# 0_FFT mean coefficient_175                 5.584        12.911         9.008
# 0_FFT mean coefficient_176                 7.449         6.554        12.732
# 0_FFT mean coefficient_177                 6.760        10.057         3.119
# 0_FFT mean coefficient_178                 1.886         1.788         0.364
# 0_FFT mean coefficient_179                11.427         3.288        11.474
# 0_FFT mean coefficient_18                  5.518         6.666        11.833
# 0_FFT mean coefficient_180                 4.413         4.566         6.944
# 0_FFT mean coefficient_181                18.380         4.092        26.805
# 0_FFT mean coefficient_182                 0.669         1.169         8.112
# 0_FFT mean coefficient_183                14.312        35.164        22.912
# 0_FFT mean coefficient_184                 6.748        15.997         3.706
# 0_FFT mean coefficient_185                 7.837         8.348         7.768
# 0_FFT mean coefficient_186                12.733        15.039         0.834
# 0_FFT mean coefficient_187                 5.085         5.334         2.293
# 0_FFT mean coefficient_188                15.686        26.710         7.251
# 0_FFT mean coefficient_189                18.586        29.751         6.741
# 0_FFT mean coefficient_19                 28.695        15.549         7.010
# 0_FFT mean coefficient_190                 4.389        12.327        13.839
# 0_FFT mean coefficient_191                15.388        10.480         0.186
# 0_FFT mean coefficient_192                19.734        13.726         8.976
# 0_FFT mean coefficient_193                 4.847         0.788         1.304
# 0_FFT mean coefficient_194                 5.271         2.197         1.595
# 0_FFT mean coefficient_195                 5.326        10.990         1.281
# 0_FFT mean coefficient_196                15.414         8.067         4.118
# 0_FFT mean coefficient_197                 2.588         3.425        22.091
# 0_FFT mean coefficient_198                 4.040        17.179         6.526
# 0_FFT mean coefficient_199                 0.999        38.980         1.665
# 0_FFT mean coefficient_2               18666.289     18459.880     18816.417
# 0_FFT mean coefficient_20                 28.018         2.061        13.573
# 0_FFT mean coefficient_200                 2.444         1.029        16.988
# 0_FFT mean coefficient_201                 0.847        14.442         4.380
# 0_FFT mean coefficient_202                17.560        28.355         1.564
# 0_FFT mean coefficient_203                 2.798         8.219         1.318
# 0_FFT mean coefficient_204                 2.504         7.539         1.795
# 0_FFT mean coefficient_205                 4.726        10.188        12.715
# 0_FFT mean coefficient_206                16.023        15.299         4.511
# 0_FFT mean coefficient_207                 0.550         1.006        28.909
# 0_FFT mean coefficient_208                27.286         1.486        12.730
# 0_FFT mean coefficient_209                32.098        13.309         4.567
# 0_FFT mean coefficient_21                 11.831        25.121        49.947
# 0_FFT mean coefficient_210                28.048         2.322         3.936
# 0_FFT mean coefficient_211                 0.194        22.449         5.096
# 0_FFT mean coefficient_212                 2.151         7.049         5.415
# 0_FFT mean coefficient_213                31.912        10.957         0.033
# 0_FFT mean coefficient_214                 7.822         9.540         2.249
# 0_FFT mean coefficient_215                 1.059         0.632         4.015
# 0_FFT mean coefficient_216                18.415         5.474         0.342
# 0_FFT mean coefficient_217                18.201         5.143         0.289
# 0_FFT mean coefficient_218                 6.405        21.632         0.278
# 0_FFT mean coefficient_219                17.469         7.009         7.951
# 0_FFT mean coefficient_22                 33.612         9.151        12.723
# 0_FFT mean coefficient_220                 7.727         3.372        19.867
# 0_FFT mean coefficient_221                 7.824        23.308        10.824
# 0_FFT mean coefficient_222                 1.520         6.342         0.368
# 0_FFT mean coefficient_223                 8.485        32.378         1.633
# 0_FFT mean coefficient_224                 3.969         1.037         5.650
# 0_FFT mean coefficient_225                18.288         5.013         6.688
# 0_FFT mean coefficient_226                 3.351         3.235        34.780
# 0_FFT mean coefficient_227                10.411        17.851         7.426
# 0_FFT mean coefficient_228                 8.064         8.748        27.494
# 0_FFT mean coefficient_229                 6.008        23.985        28.348
# 0_FFT mean coefficient_23                 23.146        12.517         3.826
# 0_FFT mean coefficient_230                 6.783         9.381        17.945
# 0_FFT mean coefficient_231                 4.810        25.176        11.520
# 0_FFT mean coefficient_232                 2.757         6.578         0.826
# 0_FFT mean coefficient_233                 0.127        23.996         3.069
# 0_FFT mean coefficient_234                19.595        31.692        21.487
# 0_FFT mean coefficient_235                42.342         2.692         2.488
# 0_FFT mean coefficient_236                18.507         4.341        17.566
# 0_FFT mean coefficient_237                 2.989         5.045         8.824
# 0_FFT mean coefficient_238                22.870         5.994        10.825
# 0_FFT mean coefficient_239                 2.469         5.711         4.221
# 0_FFT mean coefficient_24                  3.533        14.029         8.461
# 0_FFT mean coefficient_240                 5.893        24.038        55.109
# 0_FFT mean coefficient_241                19.883        28.283        22.995
# 0_FFT mean coefficient_242                28.705        27.001         0.797
# 0_FFT mean coefficient_243                 1.219         5.391        11.990
# 0_FFT mean coefficient_244                13.143         5.767         2.930
# 0_FFT mean coefficient_245                18.811         2.411         8.586
# 0_FFT mean coefficient_246                 1.650         5.708         4.824
# 0_FFT mean coefficient_247                 0.864        17.152        29.850
# 0_FFT mean coefficient_248                 4.536        14.687        23.899
# 0_FFT mean coefficient_249                 0.672         2.942         6.654
# 0_FFT mean coefficient_25                 12.357        17.115         2.759
# 0_FFT mean coefficient_250                19.725        11.639        13.591
# 0_FFT mean coefficient_251                 5.293        14.023        14.690
# 0_FFT mean coefficient_252                14.362         8.275        19.810
# 0_FFT mean coefficient_253                 0.087         9.709        14.003
# 0_FFT mean coefficient_254                12.826         9.767         5.998
# 0_FFT mean coefficient_255                 1.653         1.179         1.397
# 0_FFT mean coefficient_26                 13.221        14.774         4.972
# 0_FFT mean coefficient_27                 42.989         1.927         6.107
# 0_FFT mean coefficient_28                  4.917        13.442        14.172
# 0_FFT mean coefficient_29                  0.581         2.951        11.363
# 0_FFT mean coefficient_3               55769.844     56590.274     55311.845
# 0_FFT mean coefficient_30                 18.777        27.481        15.792
# 0_FFT mean coefficient_31                 24.455        11.892         1.930
# 0_FFT mean coefficient_32                 11.223         5.571        71.623
# 0_FFT mean coefficient_33                  6.130         7.735        46.981
# 0_FFT mean coefficient_34                  0.594         6.586         3.544
# 0_FFT mean coefficient_35                  6.236         3.188        10.101
# 0_FFT mean coefficient_36                  3.515         6.308        22.919
# 0_FFT mean coefficient_37                  2.842        60.292        15.221
# 0_FFT mean coefficient_38                  1.691         4.587        22.158
# 0_FFT mean coefficient_39                 11.236        20.521        18.591
# 0_FFT mean coefficient_4                1720.585      1711.330      1635.750
# 0_FFT mean coefficient_40                  5.597        25.719         8.187
# 0_FFT mean coefficient_41                 13.919         7.776         4.221
# 0_FFT mean coefficient_42                 20.731         0.735         1.445
# 0_FFT mean coefficient_43                 28.718         3.485         6.813
# 0_FFT mean coefficient_44                  8.391         2.377         2.453
# 0_FFT mean coefficient_45                  1.910         1.364        15.841
# 0_FFT mean coefficient_46                  5.407        14.330         8.175
# 0_FFT mean coefficient_47                  6.152        13.038         0.395
# 0_FFT mean coefficient_48                  6.992         2.915         6.198
# 0_FFT mean coefficient_49                  4.572         4.588         6.061
# 0_FFT mean coefficient_5                9330.483      9382.955      9470.382
# 0_FFT mean coefficient_50                  8.964        12.557        29.839
# 0_FFT mean coefficient_51                  8.251         3.012         3.737
# 0_FFT mean coefficient_52                 66.240         0.682         2.867
# 0_FFT mean coefficient_53                  0.922         3.917        12.189
# 0_FFT mean coefficient_54                  4.364        19.561         1.928
# 0_FFT mean coefficient_55                  1.181         2.994        25.560
# 0_FFT mean coefficient_56                  2.750         4.689         1.200
# 0_FFT mean coefficient_57                  0.677         0.870        15.125
# 0_FFT mean coefficient_58                 13.696        20.582         1.056
# 0_FFT mean coefficient_59                  8.614         0.763         1.438
# 0_FFT mean coefficient_6                4987.762      4526.696      4211.300
# 0_FFT mean coefficient_60                 24.962        14.522        19.229
# 0_FFT mean coefficient_61                  5.507        11.412         5.740
# 0_FFT mean coefficient_62                  3.148         3.181        38.430
# 0_FFT mean coefficient_63                  8.884         0.280         5.789
# 0_FFT mean coefficient_64                  7.678         4.444        15.641
# 0_FFT mean coefficient_65                  5.402         2.340         5.268
# 0_FFT mean coefficient_66                  0.631         9.505         1.786
# 0_FFT mean coefficient_67                 12.048         6.924         7.097
# 0_FFT mean coefficient_68                  9.111         1.219        25.549
# 0_FFT mean coefficient_69                  1.006         2.483         7.894
# 0_FFT mean coefficient_7                 905.719       809.070       695.465
# 0_FFT mean coefficient_70                 14.977         4.729         6.176
# 0_FFT mean coefficient_71                  3.754        27.586         3.026
# 0_FFT mean coefficient_72                  2.869         0.354         2.555
# 0_FFT mean coefficient_73                  7.715         2.527         5.394
# 0_FFT mean coefficient_74                 13.570         6.553         5.086
# 0_FFT mean coefficient_75                  9.376         8.665         8.418
# 0_FFT mean coefficient_76                 14.987        22.121         2.007
# 0_FFT mean coefficient_77                 13.652        55.547         1.155
# 0_FFT mean coefficient_78                 32.202         6.894         5.446
# 0_FFT mean coefficient_79                 46.707        25.757        19.218
# 0_FFT mean coefficient_8                 374.087       450.633       443.914
# 0_FFT mean coefficient_80                  5.820         9.698         1.597
# 0_FFT mean coefficient_81                  5.604         8.404        17.774
# 0_FFT mean coefficient_82                  9.102        15.984        12.082
# 0_FFT mean coefficient_83                  7.541         7.516         1.606
# 0_FFT mean coefficient_84                  0.966         9.082         0.941
# 0_FFT mean coefficient_85                  1.581         3.259         8.251
# 0_FFT mean coefficient_86                 14.073         1.867         0.545
# 0_FFT mean coefficient_87                  6.117         6.131         2.139
# 0_FFT mean coefficient_88                 12.888        33.705         0.348
# 0_FFT mean coefficient_89                 38.492         2.114         2.994
# 0_FFT mean coefficient_9                 437.744       393.330       322.902
# 0_FFT mean coefficient_90                  4.583         6.538         7.365
# 0_FFT mean coefficient_91                  3.103         1.315        10.072
# 0_FFT mean coefficient_92                 32.431         5.006         6.930
# 0_FFT mean coefficient_93                  6.727         3.418        25.466
# 0_FFT mean coefficient_94                 27.027        11.862         0.722
# 0_FFT mean coefficient_95                  5.459         5.419        10.451
# 0_FFT mean coefficient_96                 11.393         3.307         0.253
# 0_FFT mean coefficient_97                 10.523         1.307         4.377
# 0_FFT mean coefficient_98                  0.187         5.743         7.852
# 0_FFT mean coefficient_99                 16.547         0.673        12.037
# 0_Fundamental frequency                    0.000         0.000         0.000
# 0_Human range energy                       0.000         0.000         0.000
# 0_LPCC_0                                   0.563         0.558         0.547
# 0_LPCC_1                                   1.445         1.426         1.445
# 0_LPCC_10                                  1.030         1.080         1.036
# 0_LPCC_11                                  1.445         1.426         1.445
# 0_LPCC_2                                   1.030         1.080         1.036
# 0_LPCC_3                                   0.965         0.921         0.936
# 0_LPCC_4                                   0.858         0.871         0.849
# 0_LPCC_5                                   0.828         0.794         0.783
# 0_LPCC_6                                   0.784         0.802         0.841
# 0_LPCC_7                                   0.828         0.794         0.783
# 0_LPCC_8                                   0.858         0.871         0.849
# 0_LPCC_9                                   0.965         0.921         0.936
# 0_MFCC_0                                 -17.184       -13.565       -13.881
# 0_MFCC_1                                  -2.446        11.848        -0.106
# 0_MFCC_10                                 17.951        11.443         4.936
# 0_MFCC_11                                 -6.902         4.186       -12.064
# 0_MFCC_2                                  12.818         0.341        -0.814
# 0_MFCC_3                                   4.995         1.656        33.383
# 0_MFCC_4                                  10.589        21.380        -8.065
# 0_MFCC_5                                   2.595        -0.458        32.773
# 0_MFCC_6                                  18.568        27.818       -35.361
# 0_MFCC_7                                  17.484        43.066        36.023
# 0_MFCC_8                                  46.395       -30.609        60.564
# 0_MFCC_9                                  39.567        -1.993         7.667
# 0_Max power spectrum                    1565.207      1565.313      1571.945
# 0_Maximum frequency                        0.000         0.000         0.000
# 0_Median frequency                         0.000         0.000         0.000
# 0_Power bandwidth                          0.002         0.002         0.002
# 0_Spectral centroid                        0.000         0.000         0.000
# 0_Spectral decrease                      -11.897       -12.262       -12.042
# 0_Spectral distance                 -3251000.014  -3238463.234  -3263436.241
# 0_Spectral entropy                         0.128         0.124         0.129
# 0_Spectral kurtosis                        0.000         0.000         0.000
# 0_Spectral positive turning points        98.000        98.000        88.000
# 0_Spectral roll-off                        0.000         0.000         0.000
# 0_Spectral roll-on                         0.000         0.000         0.000
# 0_Spectral skewness                        0.000         0.000         0.000
# 0_Spectral slope                           0.000         0.000         0.000
# 0_Spectral spread                          0.000         0.000         0.000
# 0_Spectral variation                       0.984         0.980         0.982
# 0_Wavelet absolute mean_0                  0.112         0.113         0.116
# 0_Wavelet absolute mean_1                  0.326         0.335         0.342
# 0_Wavelet absolute mean_2                  0.604         0.622         0.633
# 0_Wavelet absolute mean_3                  0.931         0.958         0.977
# 0_Wavelet absolute mean_4                  1.298         1.334         1.366
# 0_Wavelet absolute mean_5                  1.701         1.747         1.792
# 0_Wavelet absolute mean_6                  2.137         2.193         2.250
# 0_Wavelet absolute mean_7                  2.601         2.668         2.736
# 0_Wavelet absolute mean_8                  3.091         3.169         3.247
# 0_Wavelet energy_0                         1.772         1.710         1.771
# 0_Wavelet energy_1                         2.864         2.953         2.963
# 0_Wavelet energy_2                         4.208         4.376         4.392
# 0_Wavelet energy_3                         5.652         5.839         5.936
# 0_Wavelet energy_4                         7.166         7.361         7.572
# 0_Wavelet energy_5                         8.755         8.990         9.318
# 0_Wavelet energy_6                        10.406        10.720        11.165
# 0_Wavelet energy_7                        12.103        12.525        13.075
# 0_Wavelet energy_8                        13.852        14.388        15.023
# 0_Wavelet entropy                          1.994         1.982         1.984
# 0_Wavelet standard deviation_0             1.768         1.706         1.767
# 0_Wavelet standard deviation_1             2.845         2.934         2.943
# 0_Wavelet standard deviation_2             4.164         4.331         4.346
# 0_Wavelet standard deviation_3             5.575         5.760         5.855
# 0_Wavelet standard deviation_4             7.048         7.239         7.448
# 0_Wavelet standard deviation_5             8.589         8.818         9.144
# 0_Wavelet standard deviation_6            10.184        10.494        10.936
# 0_Wavelet standard deviation_7            11.820        12.238        12.785
# 0_Wavelet standard deviation_8            13.502        14.035        14.668
# 0_Wavelet variance_0                       3.127         2.911         3.122
# 0_Wavelet variance_1                       8.095         8.610         8.662
# 0_Wavelet variance_2                      17.340        18.758        18.888
# 0_Wavelet variance_3                      31.079        33.183        34.282
# 0_Wavelet variance_4                      49.670        52.398        55.470
# 0_Wavelet variance_5                      73.763        77.760        83.621
# 0_Wavelet variance_6                     103.715       110.118       119.592
# 0_Wavelet variance_7                     139.708       149.771       163.464
# 0_Wavelet variance_8                     182.310       196.967       215.144
# 1_FFT mean coefficient_0                  21.857        99.169         1.878
# 1_FFT mean coefficient_1                 154.018        21.615      3914.883
# 1_FFT mean coefficient_10                109.033        76.712       166.607
# 1_FFT mean coefficient_100                 3.922        17.867        19.932
# 1_FFT mean coefficient_101                 9.758         0.226         5.612
# 1_FFT mean coefficient_102                 3.458        19.128         9.514
# 1_FFT mean coefficient_103                12.862         0.639         3.433
# 1_FFT mean coefficient_104                 8.841        34.155         5.322
# 1_FFT mean coefficient_105                 7.621         0.679        11.882
# 1_FFT mean coefficient_106                 9.951         8.325        25.241
# 1_FFT mean coefficient_107                 2.925        23.652         2.683
# 1_FFT mean coefficient_108                36.766         6.187         3.739
# 1_FFT mean coefficient_109                 0.007         1.240         1.794
# 1_FFT mean coefficient_11                265.735         8.402       259.323
# 1_FFT mean coefficient_110                12.385         5.202        10.545
# 1_FFT mean coefficient_111                 7.778         2.539        16.535
# 1_FFT mean coefficient_112                11.187        12.137        11.784
# 1_FFT mean coefficient_113                14.434         7.256         1.400
# 1_FFT mean coefficient_114                11.617         4.173        27.861
# 1_FFT mean coefficient_115                10.588         1.466        11.331
# 1_FFT mean coefficient_116                 9.504         7.337         6.215
# 1_FFT mean coefficient_117                 5.663        13.090         3.254
# 1_FFT mean coefficient_118                 2.353        28.429        15.060
# 1_FFT mean coefficient_119                 6.169         0.209         1.780
# 1_FFT mean coefficient_12                 54.786       172.787        83.401
# 1_FFT mean coefficient_120                 0.156         7.422        15.389
# 1_FFT mean coefficient_121                 9.147         8.536        17.194
# 1_FFT mean coefficient_122                 0.333        16.897         5.719
# 1_FFT mean coefficient_123                 3.080        11.964        12.317
# 1_FFT mean coefficient_124                 0.617        24.639        25.253
# 1_FFT mean coefficient_125                 3.912         2.881         5.764
# 1_FFT mean coefficient_126                15.028        38.202        14.962
# 1_FFT mean coefficient_127                12.171        13.193         0.245
# 1_FFT mean coefficient_128                 7.521        14.803        21.340
# 1_FFT mean coefficient_129                 4.824         6.851        14.255
# 1_FFT mean coefficient_13                 47.044       146.118       145.521
# 1_FFT mean coefficient_130                 1.509         4.435         5.441
# 1_FFT mean coefficient_131                 2.389        10.338         0.186
# 1_FFT mean coefficient_132                12.855         1.514         0.850
# 1_FFT mean coefficient_133                18.055        18.667        13.507
# 1_FFT mean coefficient_134                16.483         1.393        20.785
# 1_FFT mean coefficient_135                17.505         1.535         0.108
# 1_FFT mean coefficient_136                15.449        19.797         9.153
# 1_FFT mean coefficient_137                 4.959         2.627         2.215
# 1_FFT mean coefficient_138                 4.175         5.277        31.941
# 1_FFT mean coefficient_139                14.213         2.714         2.085
# 1_FFT mean coefficient_14                 18.901        18.701        16.705
# 1_FFT mean coefficient_140                14.171         2.206         0.335
# 1_FFT mean coefficient_141                11.963        77.396        25.808
# 1_FFT mean coefficient_142                16.738         0.368         4.075
# 1_FFT mean coefficient_143                 5.195         1.681        11.470
# 1_FFT mean coefficient_144                11.471        16.438         1.271
# 1_FFT mean coefficient_145                14.977         0.883         3.941
# 1_FFT mean coefficient_146                 0.122        23.582        15.587
# 1_FFT mean coefficient_147                 0.789        15.534         8.909
# 1_FFT mean coefficient_148                 2.643         8.193         5.417
# 1_FFT mean coefficient_149                 5.101         0.911        14.502
# 1_FFT mean coefficient_15                 14.188        85.714        25.022
# 1_FFT mean coefficient_150                 2.661        33.759        12.073
# 1_FFT mean coefficient_151                 8.781         3.801         6.378
# 1_FFT mean coefficient_152                12.222        23.908         0.167
# 1_FFT mean coefficient_153                 1.502         0.585        19.006
# 1_FFT mean coefficient_154                 5.103         1.384         8.196
# 1_FFT mean coefficient_155                12.172         5.704         3.158
# 1_FFT mean coefficient_156                 5.409         9.535         9.250
# 1_FFT mean coefficient_157                 5.478        20.416        15.156
# 1_FFT mean coefficient_158                 3.436         9.966        10.590
# 1_FFT mean coefficient_159                24.654         2.278        19.654
# 1_FFT mean coefficient_16                 62.633        80.450        14.564
# 1_FFT mean coefficient_160                 6.601        24.390         2.423
# 1_FFT mean coefficient_161                 5.659         2.378         6.443
# 1_FFT mean coefficient_162                 5.572         2.284        14.353
# 1_FFT mean coefficient_163                 9.991        29.278        35.504
# 1_FFT mean coefficient_164                10.433         1.391         7.658
# 1_FFT mean coefficient_165                25.769         9.932         0.413
# 1_FFT mean coefficient_166                 4.909         4.185        24.521
# 1_FFT mean coefficient_167                18.742         9.954        35.826
# 1_FFT mean coefficient_168                10.068         2.275         9.095
# 1_FFT mean coefficient_169                15.515         5.647        27.166
# 1_FFT mean coefficient_17                  4.500        46.553         9.821
# 1_FFT mean coefficient_170                32.552         3.827         0.602
# 1_FFT mean coefficient_171                17.073         1.764        17.495
# 1_FFT mean coefficient_172                11.534         0.028         6.653
# 1_FFT mean coefficient_173                 1.722         1.961         6.581
# 1_FFT mean coefficient_174                 7.287         7.495        31.865
# 1_FFT mean coefficient_175                 9.189        12.733         1.108
# 1_FFT mean coefficient_176                 5.085         2.894         6.449
# 1_FFT mean coefficient_177                 1.698        15.412         1.339
# 1_FFT mean coefficient_178                 7.136         1.755         3.583
# 1_FFT mean coefficient_179                11.275         6.989        11.999
# 1_FFT mean coefficient_18                 79.036        56.542         2.906
# 1_FFT mean coefficient_180                 2.324         8.196        14.067
# 1_FFT mean coefficient_181                 1.071         5.150         5.797
# 1_FFT mean coefficient_182                 3.370         4.864         3.806
# 1_FFT mean coefficient_183                 7.261         2.770         0.841
# 1_FFT mean coefficient_184                 1.542         9.633        26.069
# 1_FFT mean coefficient_185                15.883        20.836         0.560
# 1_FFT mean coefficient_186                 0.085        66.170        20.974
# 1_FFT mean coefficient_187                 3.174         3.084         1.722
# 1_FFT mean coefficient_188                 5.311         6.046         5.767
# 1_FFT mean coefficient_189                 8.797         2.635         2.675
# 1_FFT mean coefficient_19                 25.079        29.762        34.231
# 1_FFT mean coefficient_190                 0.099         3.952         5.462
# 1_FFT mean coefficient_191                 1.177        38.190         3.599
# 1_FFT mean coefficient_192                 0.103         9.510        20.572
# 1_FFT mean coefficient_193                 0.326         9.371        10.526
# 1_FFT mean coefficient_194                 4.376        47.595         3.409
# 1_FFT mean coefficient_195                23.852         9.498        25.177
# 1_FFT mean coefficient_196                24.705         3.474        21.308
# 1_FFT mean coefficient_197                 4.506         4.282         3.356
# 1_FFT mean coefficient_198                 5.585         1.308         3.212
# 1_FFT mean coefficient_199                 1.677         4.153        30.638
# 1_FFT mean coefficient_2                2336.936      3749.934      3493.214
# 1_FFT mean coefficient_20                  8.632        24.673        22.041
# 1_FFT mean coefficient_200                 7.723        10.440         1.889
# 1_FFT mean coefficient_201                 5.508         9.921         1.163
# 1_FFT mean coefficient_202                 2.503         6.074         0.459
# 1_FFT mean coefficient_203                19.653         6.161         1.673
# 1_FFT mean coefficient_204                 0.121         9.168        40.176
# 1_FFT mean coefficient_205                12.669         3.911        14.389
# 1_FFT mean coefficient_206                19.919        17.574         7.523
# 1_FFT mean coefficient_207                 6.398         2.004         0.355
# 1_FFT mean coefficient_208                11.365         5.364         4.725
# 1_FFT mean coefficient_209                 4.293         2.563        14.586
# 1_FFT mean coefficient_21                  9.293         7.273         4.097
# 1_FFT mean coefficient_210                 4.183         0.494         5.140
# 1_FFT mean coefficient_211                20.322         3.125         8.854
# 1_FFT mean coefficient_212                10.817         5.575         0.040
# 1_FFT mean coefficient_213                 2.586         5.562         8.733
# 1_FFT mean coefficient_214                24.005         0.088         2.251
# 1_FFT mean coefficient_215                27.875         1.572        17.015
# 1_FFT mean coefficient_216                 1.680         5.359         1.172
# 1_FFT mean coefficient_217                35.754         1.390         8.954
# 1_FFT mean coefficient_218                14.897         7.806         1.266
# 1_FFT mean coefficient_219                29.470        19.367        29.377
# 1_FFT mean coefficient_22                  2.902         0.631         6.878
# 1_FFT mean coefficient_220                 6.297        15.817         4.476
# 1_FFT mean coefficient_221                 3.822         9.925         3.657
# 1_FFT mean coefficient_222                 8.661        15.761         4.734
# 1_FFT mean coefficient_223                 1.540        10.088         7.461
# 1_FFT mean coefficient_224                 8.446         5.163         8.101
# 1_FFT mean coefficient_225                17.129        16.784        11.154
# 1_FFT mean coefficient_226                 7.761         7.522         7.753
# 1_FFT mean coefficient_227                27.503         3.356         7.117
# 1_FFT mean coefficient_228                 3.190         0.342         3.918
# 1_FFT mean coefficient_229                 8.079         6.327        14.241
# 1_FFT mean coefficient_23                  2.522        13.250         1.443
# 1_FFT mean coefficient_230                 4.378        19.020         1.420
# 1_FFT mean coefficient_231                17.316        16.762         9.901
# 1_FFT mean coefficient_232                17.329        15.782        34.644
# 1_FFT mean coefficient_233                 3.412         0.465        29.195
# 1_FFT mean coefficient_234                12.546         0.342        16.799
# 1_FFT mean coefficient_235                 1.343        10.073         4.313
# 1_FFT mean coefficient_236                 0.726         7.247         0.935
# 1_FFT mean coefficient_237                 1.376         9.196        16.604
# 1_FFT mean coefficient_238                 5.846         1.732         5.671
# 1_FFT mean coefficient_239                 4.323         2.414        10.659
# 1_FFT mean coefficient_24                  5.283         2.703         4.983
# 1_FFT mean coefficient_240                 0.933        13.254         1.028
# 1_FFT mean coefficient_241                 0.877        21.135         2.796
# 1_FFT mean coefficient_242                 3.666        31.117         5.201
# 1_FFT mean coefficient_243                12.446        19.893         0.531
# 1_FFT mean coefficient_244                19.957        12.136        10.213
# 1_FFT mean coefficient_245                45.418         3.444        15.098
# 1_FFT mean coefficient_246                13.569         6.414         1.669
# 1_FFT mean coefficient_247                11.409        22.142         5.944
# 1_FFT mean coefficient_248                 2.853        13.856        35.436
# 1_FFT mean coefficient_249                 7.940         0.446         7.040
# 1_FFT mean coefficient_25                  1.928         2.517         0.413
# 1_FFT mean coefficient_250                 1.319         7.743         5.684
# 1_FFT mean coefficient_251                 8.351        12.195        19.630
# 1_FFT mean coefficient_252                 3.039         6.688         6.917
# 1_FFT mean coefficient_253                 3.437         9.639         7.906
# 1_FFT mean coefficient_254                15.068        10.762         2.645
# 1_FFT mean coefficient_255                 1.726         6.350        14.895
# 1_FFT mean coefficient_26                 22.892         2.628        11.713
# 1_FFT mean coefficient_27                  3.916        42.091        35.095
# 1_FFT mean coefficient_28                 59.190         2.739        40.113
# 1_FFT mean coefficient_29                 10.292         6.346         1.021
# 1_FFT mean coefficient_3               22592.231       868.213     14127.860
# 1_FFT mean coefficient_30                  9.929         7.303         6.896
# 1_FFT mean coefficient_31                 31.691        36.246        24.284
# 1_FFT mean coefficient_32                  8.099        40.997        12.664
# 1_FFT mean coefficient_33                  7.836        12.603         1.957
# 1_FFT mean coefficient_34                  3.127         1.174        10.298
# 1_FFT mean coefficient_35                  0.280        12.931         3.286
# 1_FFT mean coefficient_36                  4.523         4.803        46.413
# 1_FFT mean coefficient_37                  5.799         1.755        12.211
# 1_FFT mean coefficient_38                 11.700        37.682         8.278
# 1_FFT mean coefficient_39                 22.869         8.139         7.263
# 1_FFT mean coefficient_4                1517.729      1505.997       955.178
# 1_FFT mean coefficient_40                  5.673         1.285         7.062
# 1_FFT mean coefficient_41                  1.978         5.749         8.957
# 1_FFT mean coefficient_42                  9.099        13.024         0.304
# 1_FFT mean coefficient_43                  0.889        18.671        16.616
# 1_FFT mean coefficient_44                  8.135        12.143         7.758
# 1_FFT mean coefficient_45                  1.485         8.739         9.985
# 1_FFT mean coefficient_46                  3.218         8.382         1.872
# 1_FFT mean coefficient_47                 11.860         7.713        17.341
# 1_FFT mean coefficient_48                 17.653        39.964         1.087
# 1_FFT mean coefficient_49                  3.343        17.006        10.804
# 1_FFT mean coefficient_5                 760.102      5814.612      1332.114
# 1_FFT mean coefficient_50                 28.148         0.129        11.296
# 1_FFT mean coefficient_51                 31.514         5.527        10.426
# 1_FFT mean coefficient_52                 33.242         1.673         2.105
# 1_FFT mean coefficient_53                 39.543         2.186        12.364
# 1_FFT mean coefficient_54                 32.238        25.217         9.921
# 1_FFT mean coefficient_55                 15.568         2.114         2.635
# 1_FFT mean coefficient_56                 10.935         3.022        10.194
# 1_FFT mean coefficient_57                  9.931        19.982        27.516
# 1_FFT mean coefficient_58                 10.828        53.106         3.961
# 1_FFT mean coefficient_59                 10.915         9.881         3.919
# 1_FFT mean coefficient_6                3615.072      4035.127      2222.889
# 1_FFT mean coefficient_60                  4.217        40.853         4.226
# 1_FFT mean coefficient_61                  1.801        51.078         2.241
# 1_FFT mean coefficient_62                  5.128         2.756         2.267
# 1_FFT mean coefficient_63                 36.903         7.381         0.960
# 1_FFT mean coefficient_64                 20.226        10.928         5.531
# 1_FFT mean coefficient_65                  5.109         3.007         0.493
# 1_FFT mean coefficient_66                  4.707        12.054         3.095
# 1_FFT mean coefficient_67                 22.233         0.474        20.990
# 1_FFT mean coefficient_68                 29.260        19.829        28.582
# 1_FFT mean coefficient_69                 19.259        11.558         4.044
# 1_FFT mean coefficient_7                 296.241        38.348       641.660
# 1_FFT mean coefficient_70                  3.717         4.639         7.574
# 1_FFT mean coefficient_71                  9.556        18.134         6.239
# 1_FFT mean coefficient_72                  7.544         9.430         9.040
# 1_FFT mean coefficient_73                  9.919         0.061         0.068
# 1_FFT mean coefficient_74                  5.857        10.646         7.531
# 1_FFT mean coefficient_75                  4.310         3.378        12.616
# 1_FFT mean coefficient_76                  4.089         0.529         4.705
# 1_FFT mean coefficient_77                  1.760         0.842         7.706
# 1_FFT mean coefficient_78                  7.036         0.908         1.602
# 1_FFT mean coefficient_79                  1.136         1.371         2.055
# 1_FFT mean coefficient_8                 174.392      1119.869       467.432
# 1_FFT mean coefficient_80                  4.511         0.641         5.714
# 1_FFT mean coefficient_81                  5.015         1.593         5.366
# 1_FFT mean coefficient_82                  5.040        20.769         0.577
# 1_FFT mean coefficient_83                 17.701        13.555         0.907
# 1_FFT mean coefficient_84                  2.991        19.785         8.915
# 1_FFT mean coefficient_85                  2.868         0.105        16.003
# 1_FFT mean coefficient_86                 18.915         2.196         0.355
# 1_FFT mean coefficient_87                  1.891         0.072         1.550
# 1_FFT mean coefficient_88                 13.651         0.871        10.782
# 1_FFT mean coefficient_89                  4.248         4.249         1.155
# 1_FFT mean coefficient_9                 423.155       596.336       494.352
# 1_FFT mean coefficient_90                  5.284         4.547         6.558
# 1_FFT mean coefficient_91                  5.401         8.812         4.070
# 1_FFT mean coefficient_92                 26.528         1.225         4.719
# 1_FFT mean coefficient_93                 23.826         2.592         0.924
# 1_FFT mean coefficient_94                  5.875        10.598        11.064
# 1_FFT mean coefficient_95                 22.257         8.368         4.644
# 1_FFT mean coefficient_96                  9.521        23.337        12.208
# 1_FFT mean coefficient_97                 34.985        24.780         7.085
# 1_FFT mean coefficient_98                  5.964        11.030         8.396
# 1_FFT mean coefficient_99                  0.269        38.271         2.372
# 1_Fundamental frequency                    0.000         0.000         0.000
# 1_Human range energy                       0.000         0.000         0.000
# 1_LPCC_0                                   0.641         0.644         0.642
# 1_LPCC_1                                   1.638         1.644         1.643
# 1_LPCC_10                                  1.148         1.153         1.152
# 1_LPCC_11                                  1.638         1.644         1.643
# 1_LPCC_2                                   1.148         1.153         1.152
# 1_LPCC_3                                   0.992         0.985         0.984
# ...
# 1_FFT mean coefficient_218                 1.385         4.903         8.565
# 1_FFT mean coefficient_219                12.512         4.835         4.948
# 1_FFT mean coefficient_22                 15.271         0.073         5.740
# 1_FFT mean coefficient_220                 1.438         4.838         3.861
# 1_FFT mean coefficient_221                22.506         5.669         0.623
# 1_FFT mean coefficient_222                 0.415         0.429         5.578
# 1_FFT mean coefficient_223                11.912        21.322        11.876
# 1_FFT mean coefficient_224                 8.998         0.771         0.948
# 1_FFT mean coefficient_225                 4.045         2.623         0.354
# 1_FFT mean coefficient_226                10.373         6.471         4.215
# 1_FFT mean coefficient_227                 5.290         3.309        10.765
# 1_FFT mean coefficient_228                 3.508        26.120        24.316
# 1_FFT mean coefficient_229                14.851        20.695        14.720
# 1_FFT mean coefficient_23                  5.337        24.961         3.088
# 1_FFT mean coefficient_230                 6.517         7.837         5.227
# 1_FFT mean coefficient_231                15.981        47.412         3.803
# 1_FFT mean coefficient_232                 3.339         3.726         1.989
# 1_FFT mean coefficient_233                 1.265         9.891        13.226
# 1_FFT mean coefficient_234                16.433        17.838        13.811
# 1_FFT mean coefficient_235                 1.258         7.604         8.192
# 1_FFT mean coefficient_236                 9.013        27.776        10.266
# 1_FFT mean coefficient_237                26.749        15.414        10.556
# 1_FFT mean coefficient_238                 0.449        49.990         1.727
# 1_FFT mean coefficient_239                52.417         0.971        16.190
# 1_FFT mean coefficient_24                  3.670         4.949         1.922
# 1_FFT mean coefficient_240                15.920         2.834         8.036
# 1_FFT mean coefficient_241                34.777        15.521         2.907
# 1_FFT mean coefficient_242                 6.284         3.262         6.395
# 1_FFT mean coefficient_243                34.384         1.436         6.079
# 1_FFT mean coefficient_244                 1.406        21.451        18.118
# 1_FFT mean coefficient_245                18.504         1.924         3.144
# 1_FFT mean coefficient_246                 2.490         6.011         3.716
# 1_FFT mean coefficient_247                22.638        24.761         6.162
# 1_FFT mean coefficient_248                 9.694        12.411         0.829
# 1_FFT mean coefficient_249                 1.598         1.000         2.296
# 1_FFT mean coefficient_25                 46.596         2.863         2.277
# 1_FFT mean coefficient_250                50.651         5.521         8.916
# 1_FFT mean coefficient_251                20.161         5.371         0.219
# 1_FFT mean coefficient_252                24.847         0.004        10.095
# 1_FFT mean coefficient_253                 2.544         8.926         7.576
# 1_FFT mean coefficient_254                 4.045         2.883        14.925
# 1_FFT mean coefficient_255                 3.346         9.243         5.801
# 1_FFT mean coefficient_26                  4.208        72.589        21.144
# 1_FFT mean coefficient_27                 18.631        23.358         1.834
# 1_FFT mean coefficient_28                 19.722        28.381        46.810
# 1_FFT mean coefficient_29                 13.039         5.775         2.664
# 1_FFT mean coefficient_3                7496.745     11014.403       722.019
# 1_FFT mean coefficient_30                  3.203         7.265         8.662
# 1_FFT mean coefficient_31                  3.980        21.873         2.369
# 1_FFT mean coefficient_32                  7.616         2.822        17.419
# 1_FFT mean coefficient_33                  0.286        15.267        39.764
# 1_FFT mean coefficient_34                  2.063         1.536         3.143
# 1_FFT mean coefficient_35                 21.437         2.874         1.527
# 1_FFT mean coefficient_36                 16.457         0.620         0.368
# 1_FFT mean coefficient_37                 18.298        19.241         1.750
# 1_FFT mean coefficient_38                  0.918        14.650         8.367
# 1_FFT mean coefficient_39                  6.585         1.603         7.844
# 1_FFT mean coefficient_4                 347.265       328.464       473.708
# 1_FFT mean coefficient_40                  5.625         2.800        14.012
# 1_FFT mean coefficient_41                 13.159        15.980        25.869
# 1_FFT mean coefficient_42                  2.843         5.029        31.474
# 1_FFT mean coefficient_43                  6.103         2.947         7.649
# 1_FFT mean coefficient_44                  7.221         0.584        21.468
# 1_FFT mean coefficient_45                 17.154         4.263        13.468
# 1_FFT mean coefficient_46                 15.587         5.486        13.377
# 1_FFT mean coefficient_47                  9.567        10.677         5.106
# 1_FFT mean coefficient_48                 12.929         5.885        16.059
# 1_FFT mean coefficient_49                  2.789        18.364         8.934
# 1_FFT mean coefficient_5                1786.629       804.359      4084.960
# 1_FFT mean coefficient_50                  6.831         1.335         1.169
# 1_FFT mean coefficient_51                  5.365         1.575         0.410
# 1_FFT mean coefficient_52                 13.948         2.032         0.479
# 1_FFT mean coefficient_53                  5.126         4.454         1.645
# 1_FFT mean coefficient_54                 11.384         8.324         2.779
# 1_FFT mean coefficient_55                  5.765        32.224         2.915
# 1_FFT mean coefficient_56                  7.361         8.100        33.112
# 1_FFT mean coefficient_57                 11.494         8.050         0.683
# 1_FFT mean coefficient_58                  3.492         6.213        12.065
# 1_FFT mean coefficient_59                  2.057         3.971         2.513
# 1_FFT mean coefficient_6                6598.102      3590.472      4909.120
# 1_FFT mean coefficient_60                 12.633        11.115         0.784
# 1_FFT mean coefficient_61                  3.832        12.742         3.819
# 1_FFT mean coefficient_62                  1.541        10.220        40.174
# 1_FFT mean coefficient_63                  2.174         0.333         5.301
# 1_FFT mean coefficient_64                  1.443         1.061        22.069
# 1_FFT mean coefficient_65                  7.348         8.193         6.741
# 1_FFT mean coefficient_66                  9.160         1.128        19.338
# 1_FFT mean coefficient_67                  1.587         2.663         2.499
# 1_FFT mean coefficient_68                  2.041         3.354         2.098
# 1_FFT mean coefficient_69                 17.823         6.558         4.713
# 1_FFT mean coefficient_7                1080.204       166.251       725.768
# 1_FFT mean coefficient_70                 20.356         1.608         9.741
# 1_FFT mean coefficient_71                 16.392         5.031         5.375
# 1_FFT mean coefficient_72                  9.785         0.804        12.566
# 1_FFT mean coefficient_73                 19.641        16.196         9.436
# 1_FFT mean coefficient_74                 31.440         1.436         6.037
# 1_FFT mean coefficient_75                  3.356         5.235        30.702
# 1_FFT mean coefficient_76                 14.641         2.473         3.591
# 1_FFT mean coefficient_77                  1.023         1.735         1.171
# 1_FFT mean coefficient_78                  0.403         1.186        17.985
# 1_FFT mean coefficient_79                 10.700         4.593         2.675
# 1_FFT mean coefficient_8                 249.337       159.364       253.761
# 1_FFT mean coefficient_80                 17.115         1.192         2.194
# 1_FFT mean coefficient_81                  5.373         8.612        15.498
# 1_FFT mean coefficient_82                  3.213        12.677         5.340
# 1_FFT mean coefficient_83                  2.415         3.676        23.024
# 1_FFT mean coefficient_84                  7.964        11.568         1.297
# 1_FFT mean coefficient_85                  8.116         0.509         4.944
# 1_FFT mean coefficient_86                  8.768         7.096         2.777
# 1_FFT mean coefficient_87                 11.607         3.265         6.876
# 1_FFT mean coefficient_88                  1.523        15.851         2.371
# 1_FFT mean coefficient_89                  5.212        14.982         9.459
# 1_FFT mean coefficient_9                1279.833       867.785      1339.849
# 1_FFT mean coefficient_90                 28.036         7.817         3.519
# 1_FFT mean coefficient_91                  8.490         4.720        14.603
# 1_FFT mean coefficient_92                 35.567         8.892         3.345
# 1_FFT mean coefficient_93                 13.989         7.663         6.333
# 1_FFT mean coefficient_94                  0.370        10.971        32.906
# 1_FFT mean coefficient_95                 20.808         2.505        22.125
# 1_FFT mean coefficient_96                  1.974         7.846         4.356
# 1_FFT mean coefficient_97                  5.000         2.929         1.384
# 1_FFT mean coefficient_98                  3.791        35.346         9.439
# 1_FFT mean coefficient_99                 12.724        22.164         6.734
# 1_Fundamental frequency                    0.000         0.000         0.000
# 1_Human range energy                       0.000         0.000         0.000
# 1_LPCC_0                                   0.644         0.642         0.643
# 1_LPCC_1                                   1.642         1.643         1.647
# 1_LPCC_10                                  1.153         1.145         1.147
# 1_LPCC_11                                  1.642         1.643         1.647
# 1_LPCC_2                                   1.153         1.145         1.147
# 1_LPCC_3                                   0.988         0.992         0.991
# 1_LPCC_4                                   0.921         0.920         0.922
# 1_LPCC_5                                   0.881         0.877         0.887
# 1_LPCC_6                                   0.876         0.876         0.866
# 1_LPCC_7                                   0.881         0.877         0.887
# 1_LPCC_8                                   0.921         0.920         0.922
# 1_LPCC_9                                   0.988         0.992         0.991
# 1_MFCC_0                                  -0.391        -0.583        -0.231
# 1_MFCC_1                                   0.816        -1.080         0.833
# 1_MFCC_10                                 -2.255         0.270        -0.414
# 1_MFCC_11                                  3.062         2.010        -1.443
# 1_MFCC_2                                  -1.347         2.890        -0.576
# 1_MFCC_3                                   1.340        -0.867        -0.130
# 1_MFCC_4                                  -0.727         2.038         0.028
# 1_MFCC_5                                   2.340        -0.269         0.504
# 1_MFCC_6                                  -0.158        -0.367        -5.083
# 1_MFCC_7                                   1.310        -1.094         5.540
# 1_MFCC_8                                  -1.506         2.063        -2.313
# 1_MFCC_9                                  -0.685        -0.438         4.338
# 1_Max power spectrum                     558.586      1070.343       720.078
# 1_Maximum frequency                        0.000         0.000         0.000
# 1_Median frequency                         0.000         0.000         0.000
# 1_Power bandwidth                          0.055         0.056         0.067
# 1_Spectral centroid                        0.000         0.000         0.000
# 1_Spectral decrease                     -195.980      -225.442      -225.712
# 1_Spectral distance                -48376345.899 -48516322.997 -48858275.613
# 1_Spectral entropy                         0.503         0.412         0.510
# 1_Spectral kurtosis                        0.000         0.000         0.000
# 1_Spectral positive turning points        89.000        95.000        93.000
# 1_Spectral roll-off                        0.000         0.000         0.000
# 1_Spectral roll-on                         0.000         0.000         0.000
# 1_Spectral skewness                        0.000         0.000         0.000
# 1_Spectral slope                           0.000         0.000         0.000
# 1_Spectral spread                          0.000         0.000         0.000
# 1_Spectral variation                       0.745         0.693         0.569
# 1_Wavelet absolute mean_0                  1.645         1.667         1.667
# 1_Wavelet absolute mean_1                  4.875         4.926         4.936
# 1_Wavelet absolute mean_2                  9.003         9.093         9.117
# 1_Wavelet absolute mean_3                 13.879        14.015        14.058
# 1_Wavelet absolute mean_4                 19.404        19.591        19.661
# 1_Wavelet absolute mean_5                 25.509        25.753        25.857
# 1_Wavelet absolute mean_6                 32.145        32.452        32.594
# 1_Wavelet absolute mean_7                 39.273        39.647        39.830
# 1_Wavelet absolute mean_8                 46.862        47.307        47.534
# 1_Wavelet energy_0                        20.914        21.228        21.197
# 1_Wavelet energy_1                        39.865        40.298        40.343
# 1_Wavelet energy_2                        59.289        59.925        59.909
# 1_Wavelet energy_3                        78.793        79.598        79.602
# 1_Wavelet energy_4                        98.289        99.270        99.407
# 1_Wavelet energy_5                       117.780       118.925       119.281
# 1_Wavelet energy_6                       137.303       138.555       139.206
# 1_Wavelet energy_7                       156.881       158.182       159.182
# 1_Wavelet energy_8                       176.521       177.835       179.216
# 1_Wavelet entropy                          1.942         1.945         1.942
# 1_Wavelet standard deviation_0            20.849        21.162        21.131
# 1_Wavelet standard deviation_1            39.566        39.996        40.040
# 1_Wavelet standard deviation_2            58.601        59.231        59.212
# 1_Wavelet standard deviation_3            77.561        78.355        78.350
# 1_Wavelet standard deviation_4            96.355        97.318        97.443
# 1_Wavelet standard deviation_5           114.984       116.103       116.444
# 1_Wavelet standard deviation_6           133.487       134.701       135.336
# 1_Wavelet standard deviation_7           151.885       153.133       154.118
# 1_Wavelet standard deviation_8           170.187       171.428       172.797
# 1_Wavelet variance_0                     434.698       447.845       446.521
# 1_Wavelet variance_1                    1565.439      1599.667      1603.170
# 1_Wavelet variance_2                    3434.105      3508.358      3506.009
# 1_Wavelet variance_3                    6015.655      6139.445      6138.800
# 1_Wavelet variance_4                    9284.241      9470.822      9495.192
# 1_Wavelet variance_5                   13221.370     13479.863     13559.290
# 1_Wavelet variance_6                   17818.739     18144.341     18315.958
# 1_Wavelet variance_7                   23069.184     23449.667     23752.458
# 1_Wavelet variance_8                   28963.591     29387.414     29858.813
#
# [670 rows x 145 columns]

# %%
class identifier(nn.Module):
    def __init__(self, args, n_layers, output_size):
        super(identifier, self).__init__()   
        
        self.n_channels =  args.n_channels      
        self.slope = args.slope
        self.n_layers = n_layers
        self.input_size = args.enc_out * args.latent_dims
        self.output_size = output_size
        self.lin_layers = nn.ModuleList()
#         self.n = 1
        
        def init_weights(m):
            if isinstance(m, nn.Linear):
                torch.nn.init.uniform_(m.weight, a=0.0, b=1.0)
                m.bias.data.fill_(0.01)
                
        # Linear Layers
        for i in range(0, n_layers):
            
            if i == self.n_layers -1:
                self.lin_layers.append(nn.Linear(self.input_size, self.output_size))
                self.lin_layers.append(nn.LeakyReLU(self.slope, True))
#                 self.lin_layers.append(nn.BatchNorm1d(self.n))
            else:
                self.lin_layers.append(nn.Linear(self.input_size, self.input_size))
                self.lin_layers.append(nn.LeakyReLU(self.slope, True))
#                 self.lin_layers.append(nn.BatchNorm1d(self.n))
        
        self.lin_layers.apply(init_weights)
            
         
    def forward(self, x):
#         print("x input", x.shape)
#         x_shape = x.shape
        x = x.view(x.size(0), -1)
#         print("x before lin", x.shape)
        for i, lin in enumerate(self.lin_layers):
            x = lin(x)        
#         print("x after lin", x.shape)
#         print("x out", x.shape)
        x = x.view(x.shape[0], -1, self.n_channels)
        return x

# %%
def train_identifier_modified(model, id_model, train_loader, optimizer, args, epoch):
    
    device=args.device
    labels_size = id_model.output_size
    n_channels = args.n_channels
    
    id_model.train()
    for p in id_model.parameters():
        p.requires_grad = True
    model.eval()
    for p in model.parameters():
        p.requires_grad = False
    train_loss = 0
    y_pred = torch.empty((0, labels_size//n_channels, n_channels), device=device)
    for batch_idx, (data_tup, label, norm) in enumerate(train_loader):
#         print(data.shape)

        data = pick_data(data_tup, args)
        norm = [n.to(device) for n in norm]
        bs   = data.shape[0]  
        
        x_rec, loss, mu, logvar, mu_rec, logvar_rec, e, indices = model(data, ouput_indices=True)
        label_pred = id_model(e)
#         print(pred.shape)
#         print(label.shape)
        
#         label = label[:,:,1].to(device)
        optimizer.zero_grad()
#         data = data.view(-1, data.shape[2], data.shape[3])
        
#         identified = id_model(data)
# #         print(identified.shape)
# #         print(torch.mean(identified, dim=0))
# #         print(label.shape)
        
#         loss = F.mse_loss(torch.mean(identified, dim=0), labels, reduction='mean')
        loss = F.mse_loss(label_pred, label, reduction='mean')
#         print(loss.shape)
#         # print(x_rec.shape)
#         # print(data[:, :, 0].shape)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        y_pred = torch.cat((y_pred, label_pred), dim = 0) 
        if batch_idx % 1000 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(train_loader.dataset)))

    return y_pred

def test_identifier_modified(id_model, train_loader, optimizer, device, epoch):
    id_model.train()
    for p in id_model.parameters():
        p.requires_grad = False
    train_loss = 0

    for batch_idx, (data, label, norm) in enumerate(train_loader):

        data = data.to(device)
        label = label[:,:,1].to(device)
#         optimizer.zero_grad()
#         data = data.view(-1, data.shape[2], data.shape[3])
        
        identified = id_model(data)
#         print(identified.shape)
#         print(torch.mean(identified, dim=0))
#         print(label.shape)
#         print(data.shape)
        
#         loss = F.mse_loss(torch.mean(identified, dim=0), labels, reduction='mean')
        loss = F.mse_loss(identified, label, reduction='mean')
#         print(loss)
        # print(x_rec.shape)
        # print(data[:, :, 0].shape)
#         loss.backward()

#         optimizer.step()
        train_loss += loss.item()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(train_loader.dataset)))
#     print(batch_idx)

    return identified

# %%
id_mlp_vae = identifier(args=args, n_layers=1, output_size=20)
id_mlp_vq = identifier(args=args, n_layers=1, output_size=20)

id_mlp_vae = id_mlp_vae.to(args.device)
id_mlp_vq = id_mlp_vq.to(args.device)

id_mlp_vae_opt = optim.Adam(id_mlp_vae.parameters(), lr = 0.01)
id_mlp_vq_opt = optim.Adam(id_mlp_vq.parameters(), lr = 0.01)

# print(id_mlp)

# %%
for epoch in range(1,100):
    y_train_pred_mlp_vae = train_identifier_modified(vae, id_mlp_vae,train_data, id_mlp_vae_opt, args, epoch)
    y_train_pred_mlp_vq = train_identifier_modified(vq, id_mlp_vq,train_data, id_mlp_vq_opt, args, epoch)
# y_test_pred_mlp = test_identifier_modified(id_mlp,test_data, id_mlp_opt, args.device, epoch)
# Out:
# Train Epoch: 1 [0/4000 (0%)]	Loss: 33.415825
# ====> Epoch: 1 Average loss: 33.0058
# Train Epoch: 1 [0/4000 (0%)]	Loss: 1720.242432
# ====> Epoch: 1 Average loss: 1372.0538
# Train Epoch: 2 [0/4000 (0%)]	Loss: 33.211868
# ====> Epoch: 2 Average loss: 32.8836
# Train Epoch: 2 [0/4000 (0%)]	Loss: 711.498657
# ====> Epoch: 2 Average loss: 594.9055
# Train Epoch: 3 [0/4000 (0%)]	Loss: 33.095497
# ====> Epoch: 3 Average loss: 32.7545
# Train Epoch: 3 [0/4000 (0%)]	Loss: 298.247253
# ====> Epoch: 3 Average loss: 253.9264
# Train Epoch: 4 [0/4000 (0%)]	Loss: 33.047302
# ====> Epoch: 4 Average loss: 32.6527
# Train Epoch: 4 [0/4000 (0%)]	Loss: 136.119019
# ====> Epoch: 4 Average loss: 119.4066
# Train Epoch: 5 [0/4000 (0%)]	Loss: 32.830284
# ====> Epoch: 5 Average loss: 32.4903
# Train Epoch: 5 [0/4000 (0%)]	Loss: 77.314735
# ====> Epoch: 5 Average loss: 72.2171
# Train Epoch: 6 [0/4000 (0%)]	Loss: 32.721630
# ====> Epoch: 6 Average loss: 32.3726
# Train Epoch: 6 [0/4000 (0%)]	Loss: 54.907581
# ====> Epoch: 6 Average loss: 55.8459
# Train Epoch: 7 [0/4000 (0%)]	Loss: 32.602692
# ====> Epoch: 7 Average loss: 32.2184
# Train Epoch: 7 [0/4000 (0%)]	Loss: 46.250267
# ====> Epoch: 7 Average loss: 49.0880
# Train Epoch: 8 [0/4000 (0%)]	Loss: 32.545616
# ====> Epoch: 8 Average loss: 32.0942
# Train Epoch: 8 [0/4000 (0%)]	Loss: 42.673012
# ====> Epoch: 8 Average loss: 44.9105
# Train Epoch: 9 [0/4000 (0%)]	Loss: 32.187370
# ====> Epoch: 9 Average loss: 31.9710
# Train Epoch: 9 [0/4000 (0%)]	Loss: 39.984688
# ====> Epoch: 9 Average loss: 41.9196
# Train Epoch: 10 [0/4000 (0%)]	Loss: 32.189865
# ====> Epoch: 10 Average loss: 31.8481
# Train Epoch: 10 [0/4000 (0%)]	Loss: 37.608997
# ====> Epoch: 10 Average loss: 39.6023
# Train Epoch: 11 [0/4000 (0%)]	Loss: 32.165947
# ====> Epoch: 11 Average loss: 31.7215
# Train Epoch: 11 [0/4000 (0%)]	Loss: 36.925076
# ====> Epoch: 11 Average loss: 38.0486
# Train Epoch: 12 [0/4000 (0%)]	Loss: 31.898605
# ====> Epoch: 12 Average loss: 31.5801
# Train Epoch: 12 [0/4000 (0%)]	Loss: 35.131565
# ====> Epoch: 12 Average loss: 36.4954
# Train Epoch: 13 [0/4000 (0%)]	Loss: 32.084759
# ====> Epoch: 13 Average loss: 31.4621
# Train Epoch: 13 [0/4000 (0%)]	Loss: 33.678978
# ====> Epoch: 13 Average loss: 35.0835
# Train Epoch: 14 [0/4000 (0%)]	Loss: 31.779057
# ====> Epoch: 14 Average loss: 31.3596
# Train Epoch: 14 [0/4000 (0%)]	Loss: 32.900570
# ====> Epoch: 14 Average loss: 34.0002
# Train Epoch: 15 [0/4000 (0%)]	Loss: 31.512012
# ====> Epoch: 15 Average loss: 31.2165
# Train Epoch: 15 [0/4000 (0%)]	Loss: 31.180618
# ====> Epoch: 15 Average loss: 33.0359
# Train Epoch: 16 [0/4000 (0%)]	Loss: 31.350702
# ====> Epoch: 16 Average loss: 31.0741
# Train Epoch: 16 [0/4000 (0%)]	Loss: 31.467356
# ====> Epoch: 16 Average loss: 32.1039
# Train Epoch: 17 [0/4000 (0%)]	Loss: 31.261581
# ====> Epoch: 17 Average loss: 30.9100
# Train Epoch: 17 [0/4000 (0%)]	Loss: 30.091293
# ====> Epoch: 17 Average loss: 31.2590
# Train Epoch: 18 [0/4000 (0%)]	Loss: 31.098221
# ====> Epoch: 18 Average loss: 30.8327
# Train Epoch: 18 [0/4000 (0%)]	Loss: 30.636799
# ====> Epoch: 18 Average loss: 30.6089
# Train Epoch: 19 [0/4000 (0%)]	Loss: 31.253784
# ====> Epoch: 19 Average loss: 30.7100
# Train Epoch: 19 [0/4000 (0%)]	Loss: 29.239416
# ====> Epoch: 19 Average loss: 29.8675
# Train Epoch: 20 [0/4000 (0%)]	Loss: 30.907034
# ====> Epoch: 20 Average loss: 30.5822
# Train Epoch: 20 [0/4000 (0%)]	Loss: 28.944071
# ====> Epoch: 20 Average loss: 29.3922
# Train Epoch: 21 [0/4000 (0%)]	Loss: 30.925949
# ====> Epoch: 21 Average loss: 30.4723
# Train Epoch: 21 [0/4000 (0%)]	Loss: 28.696880
# ====> Epoch: 21 Average loss: 28.7404
# Train Epoch: 22 [0/4000 (0%)]	Loss: 30.668324
# ====> Epoch: 22 Average loss: 30.3805
# Train Epoch: 22 [0/4000 (0%)]	Loss: 27.797535
# ====> Epoch: 22 Average loss: 28.3159
# Train Epoch: 23 [0/4000 (0%)]	Loss: 30.804489
# ====> Epoch: 23 Average loss: 30.3033
# Train Epoch: 23 [0/4000 (0%)]	Loss: 27.456924
# ====> Epoch: 23 Average loss: 27.7565
# Train Epoch: 24 [0/4000 (0%)]	Loss: 30.623297
# ====> Epoch: 24 Average loss: 30.1432
# Train Epoch: 24 [0/4000 (0%)]	Loss: 27.213343
# ====> Epoch: 24 Average loss: 27.5120
# Train Epoch: 25 [0/4000 (0%)]	Loss: 30.424301
# ====> Epoch: 25 Average loss: 29.9808
# Train Epoch: 25 [0/4000 (0%)]	Loss: 26.887371
# ====> Epoch: 25 Average loss: 27.0547
# Train Epoch: 26 [0/4000 (0%)]	Loss: 30.025040
# ====> Epoch: 26 Average loss: 29.8576
# Train Epoch: 26 [0/4000 (0%)]	Loss: 26.802265
# ====> Epoch: 26 Average loss: 26.7659
# Train Epoch: 27 [0/4000 (0%)]	Loss: 29.878677
# ====> Epoch: 27 Average loss: 29.8480
# Train Epoch: 27 [0/4000 (0%)]	Loss: 26.391315
# ====> Epoch: 27 Average loss: 26.3201
# Train Epoch: 28 [0/4000 (0%)]	Loss: 30.042149
# ====> Epoch: 28 Average loss: 29.7023
# Train Epoch: 28 [0/4000 (0%)]	Loss: 26.047863
# ====> Epoch: 28 Average loss: 26.1521
# Train Epoch: 29 [0/4000 (0%)]	Loss: 30.072199
# ====> Epoch: 29 Average loss: 29.6607
# Train Epoch: 29 [0/4000 (0%)]	Loss: 26.166763
# ====> Epoch: 29 Average loss: 25.8371
# Train Epoch: 30 [0/4000 (0%)]	Loss: 29.941431
# ====> Epoch: 30 Average loss: 29.5188
# Train Epoch: 30 [0/4000 (0%)]	Loss: 26.146723
# ====> Epoch: 30 Average loss: 25.6578
# Train Epoch: 31 [0/4000 (0%)]	Loss: 29.580353
# ====> Epoch: 31 Average loss: 29.4612
# Train Epoch: 31 [0/4000 (0%)]	Loss: 25.616232
# ====> Epoch: 31 Average loss: 25.3911
# Train Epoch: 32 [0/4000 (0%)]	Loss: 29.848047
# ====> Epoch: 32 Average loss: 29.2974
# Train Epoch: 32 [0/4000 (0%)]	Loss: 25.670410
# ====> Epoch: 32 Average loss: 25.1149
# Train Epoch: 33 [0/4000 (0%)]	Loss: 29.511740
# ====> Epoch: 33 Average loss: 29.2459
# Train Epoch: 33 [0/4000 (0%)]	Loss: 25.671009
# ====> Epoch: 33 Average loss: 24.9071
# Train Epoch: 34 [0/4000 (0%)]	Loss: 29.509943
# ====> Epoch: 34 Average loss: 29.2008
# Train Epoch: 34 [0/4000 (0%)]	Loss: 25.734949
# ====> Epoch: 34 Average loss: 24.7028
# Train Epoch: 35 [0/4000 (0%)]	Loss: 29.533930
# ====> Epoch: 35 Average loss: 29.1006
# Train Epoch: 35 [0/4000 (0%)]	Loss: 24.823364
# ====> Epoch: 35 Average loss: 24.5107
# Train Epoch: 36 [0/4000 (0%)]	Loss: 29.129620
# ====> Epoch: 36 Average loss: 28.9566
# Train Epoch: 36 [0/4000 (0%)]	Loss: 24.948360
# ====> Epoch: 36 Average loss: 24.3248
# Train Epoch: 37 [0/4000 (0%)]	Loss: 29.297089
# ====> Epoch: 37 Average loss: 28.8896
# Train Epoch: 37 [0/4000 (0%)]	Loss: 24.820852
# ====> Epoch: 37 Average loss: 24.2334
# Train Epoch: 38 [0/4000 (0%)]	Loss: 29.209818
# ====> Epoch: 38 Average loss: 28.7717
# Train Epoch: 38 [0/4000 (0%)]	Loss: 24.601669
# ====> Epoch: 38 Average loss: 23.9163
# Train Epoch: 39 [0/4000 (0%)]	Loss: 29.461924
# ====> Epoch: 39 Average loss: 28.7395
# Train Epoch: 39 [0/4000 (0%)]	Loss: 24.632765
# ====> Epoch: 39 Average loss: 23.8046
# Train Epoch: 40 [0/4000 (0%)]	Loss: 28.906729
# ====> Epoch: 40 Average loss: 28.6216
# Train Epoch: 40 [0/4000 (0%)]	Loss: 24.892557
# ====> Epoch: 40 Average loss: 23.7715
# Train Epoch: 41 [0/4000 (0%)]	Loss: 28.974186
# ====> Epoch: 41 Average loss: 28.5208
# Train Epoch: 41 [0/4000 (0%)]	Loss: 24.294134
# ====> Epoch: 41 Average loss: 23.5268
# Train Epoch: 42 [0/4000 (0%)]	Loss: 28.657974
# ====> Epoch: 42 Average loss: 28.4765
# Train Epoch: 42 [0/4000 (0%)]	Loss: 24.129452
# ====> Epoch: 42 Average loss: 23.5120
# Train Epoch: 43 [0/4000 (0%)]	Loss: 29.019756
# ====> Epoch: 43 Average loss: 28.4246
# Train Epoch: 43 [0/4000 (0%)]	Loss: 23.862040
# ====> Epoch: 43 Average loss: 23.3152
# Train Epoch: 44 [0/4000 (0%)]	Loss: 28.943100
# ====> Epoch: 44 Average loss: 28.4384
# Train Epoch: 44 [0/4000 (0%)]	Loss: 24.203482
# ====> Epoch: 44 Average loss: 23.2497
# Train Epoch: 45 [0/4000 (0%)]	Loss: 28.469233
# ====> Epoch: 45 Average loss: 28.2727
# Train Epoch: 45 [0/4000 (0%)]	Loss: 24.089151
# ====> Epoch: 45 Average loss: 23.2554
# Train Epoch: 46 [0/4000 (0%)]	Loss: 28.368221
# ====> Epoch: 46 Average loss: 28.1582
# Train Epoch: 46 [0/4000 (0%)]	Loss: 24.041937
# ====> Epoch: 46 Average loss: 23.0344
# Train Epoch: 47 [0/4000 (0%)]	Loss: 28.572760
# ====> Epoch: 47 Average loss: 28.1118
# Train Epoch: 47 [0/4000 (0%)]	Loss: 23.732981
# ====> Epoch: 47 Average loss: 22.9314
# Train Epoch: 48 [0/4000 (0%)]	Loss: 28.435553
# ====> Epoch: 48 Average loss: 28.0171
# Train Epoch: 48 [0/4000 (0%)]	Loss: 23.518709
# ====> Epoch: 48 Average loss: 22.8466
# Train Epoch: 49 [0/4000 (0%)]	Loss: 28.264942
# ====> Epoch: 49 Average loss: 28.0361
# Train Epoch: 49 [0/4000 (0%)]	Loss: 23.392246
# ====> Epoch: 49 Average loss: 22.7973
# Train Epoch: 50 [0/4000 (0%)]	Loss: 28.068975
# ====> Epoch: 50 Average loss: 27.9106
# Train Epoch: 50 [0/4000 (0%)]	Loss: 23.649879
# ====> Epoch: 50 Average loss: 22.6609
# Train Epoch: 51 [0/4000 (0%)]	Loss: 28.232727
# ====> Epoch: 51 Average loss: 27.8627
# Train Epoch: 51 [0/4000 (0%)]	Loss: 23.282825
# ====> Epoch: 51 Average loss: 22.5990
# Train Epoch: 52 [0/4000 (0%)]	Loss: 27.737583
# ====> Epoch: 52 Average loss: 27.7759
# Train Epoch: 52 [0/4000 (0%)]	Loss: 23.362514
# ====> Epoch: 52 Average loss: 22.5820
# Train Epoch: 53 [0/4000 (0%)]	Loss: 27.836460
# ====> Epoch: 53 Average loss: 27.8285
# Train Epoch: 53 [0/4000 (0%)]	Loss: 23.479275
# ====> Epoch: 53 Average loss: 22.4435
# Train Epoch: 54 [0/4000 (0%)]	Loss: 27.697901
# ====> Epoch: 54 Average loss: 27.6571
# Train Epoch: 54 [0/4000 (0%)]	Loss: 23.161978
# ====> Epoch: 54 Average loss: 22.4185
# Train Epoch: 55 [0/4000 (0%)]	Loss: 27.930653
# ====> Epoch: 55 Average loss: 27.6455
# Train Epoch: 55 [0/4000 (0%)]	Loss: 23.270355
# ====> Epoch: 55 Average loss: 22.3205
# Train Epoch: 56 [0/4000 (0%)]	Loss: 27.808640
# ====> Epoch: 56 Average loss: 27.5354
# Train Epoch: 56 [0/4000 (0%)]	Loss: 22.988901
# ====> Epoch: 56 Average loss: 22.2325
# Train Epoch: 57 [0/4000 (0%)]	Loss: 27.770519
# ====> Epoch: 57 Average loss: 27.5123
# Train Epoch: 57 [0/4000 (0%)]	Loss: 23.118603
# ====> Epoch: 57 Average loss: 22.1328
# Train Epoch: 58 [0/4000 (0%)]	Loss: 27.817310
# ====> Epoch: 58 Average loss: 27.4359
# Train Epoch: 58 [0/4000 (0%)]	Loss: 23.290255
# ====> Epoch: 58 Average loss: 22.2025
# Train Epoch: 59 [0/4000 (0%)]	Loss: 27.156994
# ====> Epoch: 59 Average loss: 27.2729
# Train Epoch: 59 [0/4000 (0%)]	Loss: 22.738092
# ====> Epoch: 59 Average loss: 22.0656
# Train Epoch: 60 [0/4000 (0%)]	Loss: 27.643991
# ====> Epoch: 60 Average loss: 27.2137
# Train Epoch: 60 [0/4000 (0%)]	Loss: 23.004524
# ====> Epoch: 60 Average loss: 22.1089
# Train Epoch: 61 [0/4000 (0%)]	Loss: 27.610241
# ====> Epoch: 61 Average loss: 27.2355
# Train Epoch: 61 [0/4000 (0%)]	Loss: 22.846025
# ====> Epoch: 61 Average loss: 21.8902
# Train Epoch: 62 [0/4000 (0%)]	Loss: 27.522694
# ====> Epoch: 62 Average loss: 27.2143
# Train Epoch: 62 [0/4000 (0%)]	Loss: 22.775986
# ====> Epoch: 62 Average loss: 21.9232
# Train Epoch: 63 [0/4000 (0%)]	Loss: 27.629681
# ====> Epoch: 63 Average loss: 27.1721
# Train Epoch: 63 [0/4000 (0%)]	Loss: 22.893213
# ====> Epoch: 63 Average loss: 21.9035
# Train Epoch: 64 [0/4000 (0%)]	Loss: 27.299688
# ====> Epoch: 64 Average loss: 26.9917
# Train Epoch: 64 [0/4000 (0%)]	Loss: 22.869116
# ====> Epoch: 64 Average loss: 21.8981
# Train Epoch: 65 [0/4000 (0%)]	Loss: 27.648159
# ====> Epoch: 65 Average loss: 26.9943
# Train Epoch: 65 [0/4000 (0%)]	Loss: 22.588600
# ====> Epoch: 65 Average loss: 21.7935
# Train Epoch: 66 [0/4000 (0%)]	Loss: 27.174328
# ====> Epoch: 66 Average loss: 26.9042
# Train Epoch: 66 [0/4000 (0%)]	Loss: 22.753738
# ====> Epoch: 66 Average loss: 21.7298
# Train Epoch: 67 [0/4000 (0%)]	Loss: 26.816696
# ====> Epoch: 67 Average loss: 26.8136
# Train Epoch: 67 [0/4000 (0%)]	Loss: 22.652767
# ====> Epoch: 67 Average loss: 21.7192
# Train Epoch: 68 [0/4000 (0%)]	Loss: 27.203857
# ====> Epoch: 68 Average loss: 26.8006
# Train Epoch: 68 [0/4000 (0%)]	Loss: 22.199741
# ====> Epoch: 68 Average loss: 21.5861
# Train Epoch: 69 [0/4000 (0%)]	Loss: 27.296976
# ====> Epoch: 69 Average loss: 26.7014
# Train Epoch: 69 [0/4000 (0%)]	Loss: 22.499144
# ====> Epoch: 69 Average loss: 21.6604
# Train Epoch: 70 [0/4000 (0%)]	Loss: 26.980658
# ====> Epoch: 70 Average loss: 26.6525
# Train Epoch: 70 [0/4000 (0%)]	Loss: 22.395710
# ====> Epoch: 70 Average loss: 21.5455
# Train Epoch: 71 [0/4000 (0%)]	Loss: 27.054977
# ====> Epoch: 71 Average loss: 26.7156
# Train Epoch: 71 [0/4000 (0%)]	Loss: 22.753742
# ====> Epoch: 71 Average loss: 21.5967
# Train Epoch: 72 [0/4000 (0%)]	Loss: 26.566891
# ====> Epoch: 72 Average loss: 26.6638
# Train Epoch: 72 [0/4000 (0%)]	Loss: 22.336672
# ====> Epoch: 72 Average loss: 21.4838
# Train Epoch: 73 [0/4000 (0%)]	Loss: 26.980555
# ====> Epoch: 73 Average loss: 26.5699
# Train Epoch: 73 [0/4000 (0%)]	Loss: 22.252731
# ====> Epoch: 73 Average loss: 21.4184
# Train Epoch: 74 [0/4000 (0%)]	Loss: 26.635605
# ====> Epoch: 74 Average loss: 26.5604
# Train Epoch: 74 [0/4000 (0%)]	Loss: 22.470480
# ====> Epoch: 74 Average loss: 21.5528
# Train Epoch: 75 [0/4000 (0%)]	Loss: 26.519558
# ====> Epoch: 75 Average loss: 26.4281
# Train Epoch: 75 [0/4000 (0%)]	Loss: 22.396090
# ====> Epoch: 75 Average loss: 21.4214
# Train Epoch: 76 [0/4000 (0%)]	Loss: 26.910278
# ====> Epoch: 76 Average loss: 26.3687
# Train Epoch: 76 [0/4000 (0%)]	Loss: 22.135218
# ====> Epoch: 76 Average loss: 21.3606
# Train Epoch: 77 [0/4000 (0%)]	Loss: 26.513342
# ====> Epoch: 77 Average loss: 26.3191
# Train Epoch: 77 [0/4000 (0%)]	Loss: 22.345669
# ====> Epoch: 77 Average loss: 21.3173
# Train Epoch: 78 [0/4000 (0%)]	Loss: 27.018017
# ====> Epoch: 78 Average loss: 26.3860
# Train Epoch: 78 [0/4000 (0%)]	Loss: 22.198503
# ====> Epoch: 78 Average loss: 21.3081
# Train Epoch: 79 [0/4000 (0%)]	Loss: 26.303522
# ====> Epoch: 79 Average loss: 26.3182
# Train Epoch: 79 [0/4000 (0%)]	Loss: 22.170790
# ====> Epoch: 79 Average loss: 21.2628
# Train Epoch: 80 [0/4000 (0%)]	Loss: 26.763187
# ====> Epoch: 80 Average loss: 26.2499
# Train Epoch: 80 [0/4000 (0%)]	Loss: 21.672279
# ====> Epoch: 80 Average loss: 21.2315
# Train Epoch: 81 [0/4000 (0%)]	Loss: 25.985052
# ====> Epoch: 81 Average loss: 26.1344
# Train Epoch: 81 [0/4000 (0%)]	Loss: 21.830503
# ====> Epoch: 81 Average loss: 21.2358
# Train Epoch: 82 [0/4000 (0%)]	Loss: 26.798702
# ====> Epoch: 82 Average loss: 26.1676
# Train Epoch: 82 [0/4000 (0%)]	Loss: 22.160610
# ====> Epoch: 82 Average loss: 21.2250
# Train Epoch: 83 [0/4000 (0%)]	Loss: 26.488586
# ====> Epoch: 83 Average loss: 26.0250
# Train Epoch: 83 [0/4000 (0%)]	Loss: 21.909550
# ====> Epoch: 83 Average loss: 21.1545
# Train Epoch: 84 [0/4000 (0%)]	Loss: 26.169031
# ====> Epoch: 84 Average loss: 26.1111
# Train Epoch: 84 [0/4000 (0%)]	Loss: 21.949402
# ====> Epoch: 84 Average loss: 21.1057
# Train Epoch: 85 [0/4000 (0%)]	Loss: 26.171154
# ====> Epoch: 85 Average loss: 25.9191
# Train Epoch: 85 [0/4000 (0%)]	Loss: 22.336712
# ====> Epoch: 85 Average loss: 21.1290
# Train Epoch: 86 [0/4000 (0%)]	Loss: 26.394894
# ====> Epoch: 86 Average loss: 25.8911
# Train Epoch: 86 [0/4000 (0%)]	Loss: 22.089691
# ====> Epoch: 86 Average loss: 21.1568
# Train Epoch: 87 [0/4000 (0%)]	Loss: 26.182114
# ====> Epoch: 87 Average loss: 25.8657
# Train Epoch: 87 [0/4000 (0%)]	Loss: 21.888174
# ====> Epoch: 87 Average loss: 21.0125
# Train Epoch: 88 [0/4000 (0%)]	Loss: 26.064762
# ====> Epoch: 88 Average loss: 25.8820
# Train Epoch: 88 [0/4000 (0%)]	Loss: 22.084064
# ====> Epoch: 88 Average loss: 21.0046
# Train Epoch: 89 [0/4000 (0%)]	Loss: 26.201305
# ====> Epoch: 89 Average loss: 25.8084
# Train Epoch: 89 [0/4000 (0%)]	Loss: 22.025509
# ====> Epoch: 89 Average loss: 21.0500
# Train Epoch: 90 [0/4000 (0%)]	Loss: 26.171917
# ====> Epoch: 90 Average loss: 25.7843
# Train Epoch: 90 [0/4000 (0%)]	Loss: 22.140457
# ====> Epoch: 90 Average loss: 21.0106
# Train Epoch: 91 [0/4000 (0%)]	Loss: 26.394903
# ====> Epoch: 91 Average loss: 25.8888
# Train Epoch: 91 [0/4000 (0%)]	Loss: 21.991043
# ====> Epoch: 91 Average loss: 20.9733
# Train Epoch: 92 [0/4000 (0%)]	Loss: 26.064861
# ====> Epoch: 92 Average loss: 25.6791
# Train Epoch: 92 [0/4000 (0%)]	Loss: 21.848185
# ====> Epoch: 92 Average loss: 20.9511
# Train Epoch: 93 [0/4000 (0%)]	Loss: 25.850185
# ====> Epoch: 93 Average loss: 25.6610
# Train Epoch: 93 [0/4000 (0%)]	Loss: 22.238747
# ====> Epoch: 93 Average loss: 20.9762
# Train Epoch: 94 [0/4000 (0%)]	Loss: 25.778143
# ====> Epoch: 94 Average loss: 25.6578
# Train Epoch: 94 [0/4000 (0%)]	Loss: 21.968466
# ====> Epoch: 94 Average loss: 20.9807
# Train Epoch: 95 [0/4000 (0%)]	Loss: 25.510376
# ====> Epoch: 95 Average loss: 25.5861
# Train Epoch: 95 [0/4000 (0%)]	Loss: 21.723288
# ====> Epoch: 95 Average loss: 20.8919
# Train Epoch: 96 [0/4000 (0%)]	Loss: 25.893208
# ====> Epoch: 96 Average loss: 25.5429
# Train Epoch: 96 [0/4000 (0%)]	Loss: 21.843540
# ====> Epoch: 96 Average loss: 20.9257
# Train Epoch: 97 [0/4000 (0%)]	Loss: 25.379898
# ====> Epoch: 97 Average loss: 25.4706
# Train Epoch: 97 [0/4000 (0%)]	Loss: 22.068481
# ====> Epoch: 97 Average loss: 20.8503
# Train Epoch: 98 [0/4000 (0%)]	Loss: 25.931400
# ====> Epoch: 98 Average loss: 25.4544
# Train Epoch: 98 [0/4000 (0%)]	Loss: 21.913082
# ====> Epoch: 98 Average loss: 20.8917
# Train Epoch: 99 [0/4000 (0%)]	Loss: 25.283880
# ====> Epoch: 99 Average loss: 25.4265
# Train Epoch: 99 [0/4000 (0%)]	Loss: 22.222952
# ====> Epoch: 99 Average loss: 20.8627

# %%
print(abs(y_train_pred_mlp_vae[1]- labels[1]))
# Out:
# tensor([[    0.0571,   404.6551],
#         [    0.0788,     0.0000],
#         [    0.0741,    16.0176],
#         [    0.6370,     7.0117],
#         [    0.5416,    11.1664],
#         [    0.1083,    32.8817],
#         [    0.0516,     1.1178],
#         [    0.0493,     8.7128],
#         [    0.0000,     9.5703],
#         [    0.0000,     8.5221]], grad_fn=<AbsBackward0>)

# %%
for batch_idx, (data, label, norm) in enumerate(train_data):

    data = data.to(args.device)
    label = label[:,:,1].to(args.device)
#         optimizer.zero_grad()
#         data = data.view(-1, data.shape[2], data.shape[3])

    identified = id_mlp(data)
    print(identified[0], label[0])
# Out:
# tensor([153.8879,  -0.0000,   6.9853,   3.4626], device='cuda:0') tensor([373.0000,   1.0000,  12.3177,   8.3686], device='cuda:0')
# tensor([45.6966, -0.0000, -0.0000, 11.7521], device='cuda:0') tensor([96.0000,  1.0000,  7.8325, 11.1604], device='cuda:0')
# tensor([177.7629,   1.6209,  -0.0000,   8.9965], device='cuda:0') tensor([394.0000,   1.0000,   7.1965,  13.0473], device='cuda:0')
# tensor([186.5321,   0.2891,   0.5423,   8.1666], device='cuda:0') tensor([469.0000,   1.0000,  11.8901,  13.8836], device='cuda:0')
# tensor([-0.0000, -0.0000, 14.8344, -0.0000], device='cuda:0') tensor([133.0000,   1.0000,  13.0515,  13.6680], device='cuda:0')
# tensor([291.0201,   0.7340,  -0.0000,  10.4569], device='cuda:0') tensor([377.0000,   1.0000,   7.3017,  11.3262], device='cuda:0')
# tensor([-0.0000, -0.0000, 10.8225,  8.2450], device='cuda:0') tensor([217.0000,   1.0000,   8.8992,   9.6648], device='cuda:0')
# tensor([-0.0000, -0.0000, 17.6824, -0.0000], device='cuda:0') tensor([229.0000,   1.0000,  13.5268,   7.1764], device='cuda:0')
# tensor([-0., -0., -0., -0.], device='cuda:0') tensor([391.0000,   1.0000,   8.9839,   8.8797], device='cuda:0')
# tensor([-0.0000, -0.0000, 2.9607, -0.0000], device='cuda:0') tensor([179.0000,   1.0000,   9.0496,  11.6553], device='cuda:0')
# tensor([-0.0000, -0.0000, 7.7728, -0.0000], device='cuda:0') tensor([51.0000,  1.0000, 12.0136,  7.0648], device='cuda:0')
# tensor([-0.0000, -0.0000, 10.8146,  6.6501], device='cuda:0') tensor([464.0000,   1.0000,  11.3972,  13.5139], device='cuda:0')
# tensor([72.0805,  0.2425, -0.0000,  6.0705], device='cuda:0') tensor([209.0000,   1.0000,   7.4751,  13.2490], device='cuda:0')
# tensor([-0.0000,  0.1442, 12.2176, -0.0000], device='cuda:0') tensor([65.0000,  1.0000,  8.3578, 12.9132], device='cuda:0')
# tensor([-0.0000, -0.0000, 3.7920, -0.0000], device='cuda:0') tensor([78.0000,  1.0000, 10.2044, 13.9992], device='cuda:0')
# tensor([183.1552,  -0.0000,   6.1568,   8.3684], device='cuda:0') tensor([80.0000,  1.0000,  8.8098, 11.5364], device='cuda:0')

# %%
def extract_id_data(model, train_loader, device):
    X, Y = torch.empty((0, 8, 10), device=device), torch.empty((0,4), device=device)
    for batch_idx, (data, label, norm) in enumerate(train_loader):

        data = data.to(device)
        label = label[:,:,1].to(device)
#         norm = norm.to(device)
        
        mu, logvar = encoder(data)
        z = model.reparametrization_trick(mu, logvar).squeeze(1)
#         print(z.shape)
        
        X = torch.cat((X, z), dim=0)
        Y = torch.cat((Y, label), dim=0)
    return X.cpu().detach(), Y.cpu().detach()

# %%
X_train, Y_train = extract_id_data(v, train_data, args.device)
X_val, Y_val = extract_id_data(v, val_data, args.device)
X_test, Y_test = extract_id_data(v, test_data, args.device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 X_train, Y_train = extract_id_data(v, train_data, args.device)
#       2 X_val, Y_val = extract_id_data(v, val_data, args.device)
#       3 X_test, Y_test = extract_id_data(v, test_data, args.device)
#
# Cell In[184], line 13, in extract_id_data(model, train_loader, device)
#      10         z = model.reparametrization_trick(mu, logvar).squeeze(1)
#      11 #         print(z.shape)
# ---> 13         X = torch.cat((X, z), dim=0)
#      14         Y = torch.cat((Y, label), dim=0)
#      15     return X.cpu().detach(), Y.cpu().detach()
#
# RuntimeError: Sizes of tensors must match except in dimension 0. Expected size 8 but got size 6 for tensor number 1 in the list.

# %%
def plot_parameter_scatter(labels, prediction_lin, prediction_f):
    n_features = labels.shape[1]
    x_axis = np.arange(len(labels))
    
    blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
    red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
    titles = ["mean", "Std", "Freaquency per Week", "Amplitude", "Phase"]

    fig, ax = plt.subplots(nrows=n_features, ncols=2,figsize=(20, 16))
    for i in range(n_features):    
        ax[i, 0].scatter(x_axis, labels[:, i], c="b", alpha = 0.5)
        ax[i, 0].scatter(x_axis, prediction_lin[:, i], c="r" , alpha = 0.2)
        ax[i, 0].set_title(titles[i])
        ax[i, 0].legend(handles=[blue_handle, red_handle], loc="upper right")
        
        ax[i, 1].scatter(x_axis, labels[:, i], c="b", alpha = 0.5)
        ax[i, 1].scatter(x_axis, prediction_f[:, i], c="r" , alpha = 0.2)
        ax[i, 1].set_title(titles[i])
        ax[i, 1].legend(handles=[blue_handle, red_handle], loc="upper right")
        set_y_lim(ax[i, 0], i)
        set_y_lim(ax[i, 1], i)
    fig.tight_layout()

# %%
def test_identifier(model, id_model, labels, train_loader, criterion, optimizer, device, epoch, VQ=True):
    model.train()
    id_model.train()
    for p in model.parameters():
        p.requires_grad = False
    for p in id_model.parameters():
        p.requires_grad = False
    train_loss = 0
    labels = labels.to(device)

    for batch_idx, (data, v) in enumerate(train_loader):

        data = data.to(device)
        v = v.to(device)
        optimizer.zero_grad()

        if VQ:
            x_rec, loss, mu, logvar, mu_rec, logvar_rec, e = model(data)
        else:
            #             x_rec, mu, logvar = model(data)
            x_rec, mu, logvar = sample_mean(model, data, 10)
            if v.dim() == 1:
                v = v.unsqueeze(-1)
                v = v.unsqueeze(-1)
            # x_rec_window_length = x_rec.shape[2]
            loss = criterion(x_rec * v, data[:, :, 0], mu, logvar)
        identified = id_model(e)

    return torch.mean(identified, dim=0)

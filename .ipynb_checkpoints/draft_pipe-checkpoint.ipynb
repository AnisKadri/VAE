# %%
# %matplotlib inline
# %matplotlib notebook
from dataGen import Gen
from multiscale_vae import vae
from train import slidingWindow, criterion, train, test
from Encoders import LongShort_TCVAE_Encoder
from Decoders import LongShort_TCVAE_Decoder
from vae import VariationalAutoencoder

import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torch.distributions


import numpy as np
import matplotlib.pyplot as plt
import pprint

# %%
# all parameters for generating the time series should be configured in this cell
periode = 15 #days
step = 5 # mess interval in minutes
val = 100
n_channels = 3
effects = {
    "Pulse": {
        "occurances":0,
        "max_amplitude":2,   
        "interval":20
        },
    "Trend": {
        "occurances":1,
        "max_slope":0.005,
        "type":"mixed"
        },
    "Seasonality": {
        "occurances":2,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

### Init Model
latent_dims = 15
L = 30
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# v = vae(n_channels, L, latent_dims)
v = VariationalAutoencoder(input_size = n_channels,
                           hidden_size = 10,
                           num_layers = 3,
                           latent_dims= latent_dims,
                           v_encoder = LongShort_TCVAE_Encoder,
                           v_decoder = LongShort_TCVAE_Decoder,
                           L = L,
                           first_kernel = 15)
opt = optim.Adam(v.parameters(), lr = 0.001)

# %%
X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
# pprint.pprint(params)
pprint.pprint(e_params)
X.show()
# Out:
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [5, 15],
#                  'channel': [0, 1],
#                  'frequency_per_week': [8.386440053317369, 12.323714985392712],
#                  'phaseshift': [40, 164]},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [1],
#            'index': ['2023-03-05T02:20:00'],
#            'slope': [-1.4929876974096104e-05]}}

# %%
# serie = torch.tensor(serie).float()
x = torch.FloatTensor(x)
n = x.shape[1]

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

# train_set = slidingWindow(train, 30)
# val_set = slidingWindow(val, 30)
# test_set = slidingWindow(test, 30)

train_data = DataLoader(slidingWindow(train_, L),
                        batch_size=10,
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=10,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=10,
                        shuffle = False
                        )

# %%
print(v)
# Out:
# VariationalAutoencoder(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(3, 6, kernel_size=(2,), stride=(2,))
#         (1): ReLU(inplace=True)
#         (2): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(6, 12, kernel_size=(2,), stride=(2,))
#         (4): ReLU(inplace=True)
#         (5): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(12, 18, kernel_size=(2,), stride=(2,))
#         (7): ReLU(inplace=True)
#         (8): BatchNorm1d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=54, out_features=15, bias=True)
#       (encoder_logvar): Linear(in_features=54, out_features=15, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(3, 6, kernel_size=(15,), stride=(2,))
#         (1): ReLU(inplace=True)
#         (2): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(6, 12, kernel_size=(2,), stride=(2,))
#         (4): ReLU(inplace=True)
#         (5): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(12, 18, kernel_size=(2,), stride=(2,))
#         (7): ReLU(inplace=True)
#         (8): BatchNorm1d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=36, out_features=15, bias=True)
#       (encoder_logvar): Linear(in_features=36, out_features=15, bias=True)
#     )
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (decoder_lin): Linear(in_features=30, out_features=18, bias=True)
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(18, 12, kernel_size=(2,), stride=(2,))
#         (1): ReLU(inplace=True)
#         (2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(12, 6, kernel_size=(2,), stride=(2,))
#         (4): ReLU(inplace=True)
#         (5): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(6, 3, kernel_size=(2,), stride=(2,))
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
# )

# %%
for epoch in range(1, 100):
    train(v, train_data, criterion, opt, device, epoch)
# Out:
# Train Epoch: 1 [0/3426 (0%)]	Loss: 4885.156250
# Train Epoch: 1 [1000/3426 (29%)]	Loss: 4712.251172
# Train Epoch: 1 [2000/3426 (58%)]	Loss: 3986.816797
# Train Epoch: 1 [3000/3426 (87%)]	Loss: 3041.542383
# ====> Epoch: 1 Average loss: 3845.4166
# Train Epoch: 2 [0/3426 (0%)]	Loss: 3037.599219
# Train Epoch: 2 [1000/3426 (29%)]	Loss: 2557.177344
# Train Epoch: 2 [2000/3426 (58%)]	Loss: 1959.522656
# Train Epoch: 2 [3000/3426 (87%)]	Loss: 1397.850195
# ====> Epoch: 2 Average loss: 1994.6785
# Train Epoch: 3 [0/3426 (0%)]	Loss: 1310.526172
# Train Epoch: 3 [1000/3426 (29%)]	Loss: 1040.735059
# Train Epoch: 3 [2000/3426 (58%)]	Loss: 729.641650
# Train Epoch: 3 [3000/3426 (87%)]	Loss: 475.278760
# ====> Epoch: 3 Average loss: 794.7603
# Train Epoch: 4 [0/3426 (0%)]	Loss: 411.294971
# Train Epoch: 4 [1000/3426 (29%)]	Loss: 323.196655
# Train Epoch: 4 [2000/3426 (58%)]	Loss: 196.545081
# Train Epoch: 4 [3000/3426 (87%)]	Loss: 100.482806
# ====> Epoch: 4 Average loss: 228.4237
# Train Epoch: 5 [0/3426 (0%)]	Loss: 96.034680
# Train Epoch: 5 [1000/3426 (29%)]	Loss: 121.930347
# Train Epoch: 5 [2000/3426 (58%)]	Loss: 68.401917
# Train Epoch: 5 [3000/3426 (87%)]	Loss: 20.728481
# ====> Epoch: 5 Average loss: 66.7648
# Train Epoch: 6 [0/3426 (0%)]	Loss: 41.502170
# Train Epoch: 6 [1000/3426 (29%)]	Loss: 97.666479
# Train Epoch: 6 [2000/3426 (58%)]	Loss: 55.361627
# Train Epoch: 6 [3000/3426 (87%)]	Loss: 11.238589
# ====> Epoch: 6 Average loss: 43.5653
# Train Epoch: 7 [0/3426 (0%)]	Loss: 38.533737
# Train Epoch: 7 [1000/3426 (29%)]	Loss: 98.051819
# Train Epoch: 7 [2000/3426 (58%)]	Loss: 55.239954
# Train Epoch: 7 [3000/3426 (87%)]	Loss: 10.763057
# ====> Epoch: 7 Average loss: 41.6857
# Train Epoch: 8 [0/3426 (0%)]	Loss: 39.093607
# Train Epoch: 8 [1000/3426 (29%)]	Loss: 99.216858
# Train Epoch: 8 [2000/3426 (58%)]	Loss: 55.313055
# Train Epoch: 8 [3000/3426 (87%)]	Loss: 9.998581
# ====> Epoch: 8 Average loss: 41.3611
# Train Epoch: 9 [0/3426 (0%)]	Loss: 38.990018
# Train Epoch: 9 [1000/3426 (29%)]	Loss: 98.260205
# Train Epoch: 9 [2000/3426 (58%)]	Loss: 55.734760
# Train Epoch: 9 [3000/3426 (87%)]	Loss: 10.087952
# ====> Epoch: 9 Average loss: 41.1856
# Train Epoch: 10 [0/3426 (0%)]	Loss: 38.615475
# Train Epoch: 10 [1000/3426 (29%)]	Loss: 98.427026
# Train Epoch: 10 [2000/3426 (58%)]	Loss: 55.347125
# Train Epoch: 10 [3000/3426 (87%)]	Loss: 9.509879
# ====> Epoch: 10 Average loss: 41.0342
# Train Epoch: 11 [0/3426 (0%)]	Loss: 39.262976
# Train Epoch: 11 [1000/3426 (29%)]	Loss: 98.460754
# Train Epoch: 11 [2000/3426 (58%)]	Loss: 55.238422
# Train Epoch: 11 [3000/3426 (87%)]	Loss: 9.723926
# ====> Epoch: 11 Average loss: 40.9867
# Train Epoch: 12 [0/3426 (0%)]	Loss: 38.649640
# Train Epoch: 12 [1000/3426 (29%)]	Loss: 98.308405
# Train Epoch: 12 [2000/3426 (58%)]	Loss: 55.060718
# Train Epoch: 12 [3000/3426 (87%)]	Loss: 9.630711
# ====> Epoch: 12 Average loss: 40.8966
# Train Epoch: 13 [0/3426 (0%)]	Loss: 38.576474
# Train Epoch: 13 [1000/3426 (29%)]	Loss: 98.416895
# Train Epoch: 13 [2000/3426 (58%)]	Loss: 54.894635
# Train Epoch: 13 [3000/3426 (87%)]	Loss: 9.676903
# ====> Epoch: 13 Average loss: 40.8484
# Train Epoch: 14 [0/3426 (0%)]	Loss: 38.792267
# Train Epoch: 14 [1000/3426 (29%)]	Loss: 99.205945
# Train Epoch: 14 [2000/3426 (58%)]	Loss: 55.343494
# Train Epoch: 14 [3000/3426 (87%)]	Loss: 9.569837
# ====> Epoch: 14 Average loss: 40.8403
# Train Epoch: 15 [0/3426 (0%)]	Loss: 38.435959
# Train Epoch: 15 [1000/3426 (29%)]	Loss: 98.466827
# Train Epoch: 15 [2000/3426 (58%)]	Loss: 54.584106
# Train Epoch: 15 [3000/3426 (87%)]	Loss: 9.511334
# ====> Epoch: 15 Average loss: 40.8226
# Train Epoch: 16 [0/3426 (0%)]	Loss: 38.925916
# Train Epoch: 16 [1000/3426 (29%)]	Loss: 98.168750
# Train Epoch: 16 [2000/3426 (58%)]	Loss: 54.731268
# Train Epoch: 16 [3000/3426 (87%)]	Loss: 9.456242
# ====> Epoch: 16 Average loss: 40.8151
# Train Epoch: 17 [0/3426 (0%)]	Loss: 38.600296
# Train Epoch: 17 [1000/3426 (29%)]	Loss: 97.880078
# Train Epoch: 17 [2000/3426 (58%)]	Loss: 55.071832
# Train Epoch: 17 [3000/3426 (87%)]	Loss: 9.483146
# ====> Epoch: 17 Average loss: 40.8777
# Train Epoch: 18 [0/3426 (0%)]	Loss: 38.692807
# Train Epoch: 18 [1000/3426 (29%)]	Loss: 97.907544
# Train Epoch: 18 [2000/3426 (58%)]	Loss: 54.478107
# Train Epoch: 18 [3000/3426 (87%)]	Loss: 9.335342
# ====> Epoch: 18 Average loss: 40.8077
# Train Epoch: 19 [0/3426 (0%)]	Loss: 37.865305
# Train Epoch: 19 [1000/3426 (29%)]	Loss: 99.377911
# Train Epoch: 19 [2000/3426 (58%)]	Loss: 55.208112
# Train Epoch: 19 [3000/3426 (87%)]	Loss: 9.247578
# ====> Epoch: 19 Average loss: 40.8606
# Train Epoch: 20 [0/3426 (0%)]	Loss: 40.475577
# Train Epoch: 20 [1000/3426 (29%)]	Loss: 102.114594
# Train Epoch: 20 [2000/3426 (58%)]	Loss: 54.578864
# Train Epoch: 20 [3000/3426 (87%)]	Loss: 10.167326
# ====> Epoch: 20 Average loss: 40.7618
# Train Epoch: 21 [0/3426 (0%)]	Loss: 38.419705
# Train Epoch: 21 [1000/3426 (29%)]	Loss: 93.935657
# Train Epoch: 21 [2000/3426 (58%)]	Loss: 53.939716
# Train Epoch: 21 [3000/3426 (87%)]	Loss: 10.073649
# ====> Epoch: 21 Average loss: 40.5110
# Train Epoch: 22 [0/3426 (0%)]	Loss: 37.755551
# Train Epoch: 22 [1000/3426 (29%)]	Loss: 94.040936
# Train Epoch: 22 [2000/3426 (58%)]	Loss: 49.053711
# Train Epoch: 22 [3000/3426 (87%)]	Loss: 11.839520
# ====> Epoch: 22 Average loss: 40.1141
# Train Epoch: 23 [0/3426 (0%)]	Loss: 35.445206
# Train Epoch: 23 [1000/3426 (29%)]	Loss: 101.420520
# Train Epoch: 23 [2000/3426 (58%)]	Loss: 46.436572
# Train Epoch: 23 [3000/3426 (87%)]	Loss: 13.758444
# ====> Epoch: 23 Average loss: 39.1094
# Train Epoch: 24 [0/3426 (0%)]	Loss: 43.888306
# Train Epoch: 24 [1000/3426 (29%)]	Loss: 82.249316
# Train Epoch: 24 [2000/3426 (58%)]	Loss: 45.644818
# Train Epoch: 24 [3000/3426 (87%)]	Loss: 12.758858
# ====> Epoch: 24 Average loss: 37.4933
# Train Epoch: 25 [0/3426 (0%)]	Loss: 29.969699
# Train Epoch: 25 [1000/3426 (29%)]	Loss: 79.451917
# Train Epoch: 25 [2000/3426 (58%)]	Loss: 38.180890
# Train Epoch: 25 [3000/3426 (87%)]	Loss: 11.343873
# ====> Epoch: 25 Average loss: 34.9989
# Train Epoch: 26 [0/3426 (0%)]	Loss: 47.595111
# Train Epoch: 26 [1000/3426 (29%)]	Loss: 65.656274
# Train Epoch: 26 [2000/3426 (58%)]	Loss: 59.772644
# Train Epoch: 26 [3000/3426 (87%)]	Loss: 10.562687
# ====> Epoch: 26 Average loss: 31.7697
# Train Epoch: 27 [0/3426 (0%)]	Loss: 22.275131
# Train Epoch: 27 [1000/3426 (29%)]	Loss: 51.960358
# Train Epoch: 27 [2000/3426 (58%)]	Loss: 34.701834
# Train Epoch: 27 [3000/3426 (87%)]	Loss: 10.398790
# ====> Epoch: 27 Average loss: 27.5568
# Train Epoch: 28 [0/3426 (0%)]	Loss: 30.331479
# Train Epoch: 28 [1000/3426 (29%)]	Loss: 38.856744
# Train Epoch: 28 [2000/3426 (58%)]	Loss: 15.732072
# Train Epoch: 28 [3000/3426 (87%)]	Loss: 8.858704
# ====> Epoch: 28 Average loss: 23.5640
# Train Epoch: 29 [0/3426 (0%)]	Loss: 59.623157
# Train Epoch: 29 [1000/3426 (29%)]	Loss: 31.340121
# Train Epoch: 29 [2000/3426 (58%)]	Loss: 10.007555
# Train Epoch: 29 [3000/3426 (87%)]	Loss: 9.080750
# ====> Epoch: 29 Average loss: 20.4686
# Train Epoch: 30 [0/3426 (0%)]	Loss: 7.980288
# Train Epoch: 30 [1000/3426 (29%)]	Loss: 24.378972
# Train Epoch: 30 [2000/3426 (58%)]	Loss: 11.096850
# Train Epoch: 30 [3000/3426 (87%)]	Loss: 9.694506
# ====> Epoch: 30 Average loss: 18.8965
# Train Epoch: 31 [0/3426 (0%)]	Loss: 5.991735
# Train Epoch: 31 [1000/3426 (29%)]	Loss: 19.297318
# Train Epoch: 31 [2000/3426 (58%)]	Loss: 8.346260
# Train Epoch: 31 [3000/3426 (87%)]	Loss: 11.094187
# ====> Epoch: 31 Average loss: 16.6426
# Train Epoch: 32 [0/3426 (0%)]	Loss: 6.253580
# Train Epoch: 32 [1000/3426 (29%)]	Loss: 17.057458
# Train Epoch: 32 [2000/3426 (58%)]	Loss: 9.282533
# Train Epoch: 32 [3000/3426 (87%)]	Loss: 13.747490
# ====> Epoch: 32 Average loss: 16.2626
# Train Epoch: 33 [0/3426 (0%)]	Loss: 7.243760
# Train Epoch: 33 [1000/3426 (29%)]	Loss: 13.178059
# Train Epoch: 33 [2000/3426 (58%)]	Loss: 7.978938
# Train Epoch: 33 [3000/3426 (87%)]	Loss: 14.234259
# ====> Epoch: 33 Average loss: 14.7840
# Train Epoch: 34 [0/3426 (0%)]	Loss: 8.271841
# Train Epoch: 34 [1000/3426 (29%)]	Loss: 10.976260
# Train Epoch: 34 [2000/3426 (58%)]	Loss: 8.631365
# Train Epoch: 34 [3000/3426 (87%)]	Loss: 9.710837
# ====> Epoch: 34 Average loss: 15.2489
# Train Epoch: 35 [0/3426 (0%)]	Loss: 8.161816
# Train Epoch: 35 [1000/3426 (29%)]	Loss: 12.000463
# Train Epoch: 35 [2000/3426 (58%)]	Loss: 9.591327
# Train Epoch: 35 [3000/3426 (87%)]	Loss: 7.242013
# ====> Epoch: 35 Average loss: 14.6931
# Train Epoch: 36 [0/3426 (0%)]	Loss: 9.269613
# Train Epoch: 36 [1000/3426 (29%)]	Loss: 10.049888
# Train Epoch: 36 [2000/3426 (58%)]	Loss: 9.524563
# Train Epoch: 36 [3000/3426 (87%)]	Loss: 7.352218
# ====> Epoch: 36 Average loss: 14.5166
# Train Epoch: 37 [0/3426 (0%)]	Loss: 5.630051
# Train Epoch: 37 [1000/3426 (29%)]	Loss: 9.905753
# Train Epoch: 37 [2000/3426 (58%)]	Loss: 15.661450
# Train Epoch: 37 [3000/3426 (87%)]	Loss: 12.292707
# ====> Epoch: 37 Average loss: 13.1586
# Train Epoch: 38 [0/3426 (0%)]	Loss: 9.101783
# Train Epoch: 38 [1000/3426 (29%)]	Loss: 10.748497
# Train Epoch: 38 [2000/3426 (58%)]	Loss: 8.440295
# Train Epoch: 38 [3000/3426 (87%)]	Loss: 11.553000
# ====> Epoch: 38 Average loss: 14.3149
# Train Epoch: 39 [0/3426 (0%)]	Loss: 9.349607
# Train Epoch: 39 [1000/3426 (29%)]	Loss: 9.118963
# Train Epoch: 39 [2000/3426 (58%)]	Loss: 9.050566
# Train Epoch: 39 [3000/3426 (87%)]	Loss: 12.411168
# ====> Epoch: 39 Average loss: 13.2260
# Train Epoch: 40 [0/3426 (0%)]	Loss: 10.760740
# Train Epoch: 40 [1000/3426 (29%)]	Loss: 8.656879
# Train Epoch: 40 [2000/3426 (58%)]	Loss: 9.711905
# Train Epoch: 40 [3000/3426 (87%)]	Loss: 8.691792
# ====> Epoch: 40 Average loss: 13.3637
# Train Epoch: 41 [0/3426 (0%)]	Loss: 11.329014
# Train Epoch: 41 [1000/3426 (29%)]	Loss: 9.164917
# Train Epoch: 41 [2000/3426 (58%)]	Loss: 9.383634
# Train Epoch: 41 [3000/3426 (87%)]	Loss: 7.215924
# ====> Epoch: 41 Average loss: 12.7891
# Train Epoch: 42 [0/3426 (0%)]	Loss: 9.767183
# Train Epoch: 42 [1000/3426 (29%)]	Loss: 9.009292
# Train Epoch: 42 [2000/3426 (58%)]	Loss: 8.149406
# Train Epoch: 42 [3000/3426 (87%)]	Loss: 7.935244
# ====> Epoch: 42 Average loss: 13.0569
# Train Epoch: 43 [0/3426 (0%)]	Loss: 11.315830
# Train Epoch: 43 [1000/3426 (29%)]	Loss: 10.276523
# Train Epoch: 43 [2000/3426 (58%)]	Loss: 8.487857
# Train Epoch: 43 [3000/3426 (87%)]	Loss: 10.628568
# ====> Epoch: 43 Average loss: 14.1549
# Train Epoch: 44 [0/3426 (0%)]	Loss: 6.767273
# Train Epoch: 44 [1000/3426 (29%)]	Loss: 10.339116
# Train Epoch: 44 [2000/3426 (58%)]	Loss: 9.197149
# Train Epoch: 44 [3000/3426 (87%)]	Loss: 9.237492
# ====> Epoch: 44 Average loss: 12.7086
# Train Epoch: 45 [0/3426 (0%)]	Loss: 5.420525
# Train Epoch: 45 [1000/3426 (29%)]	Loss: 9.658211
# Train Epoch: 45 [2000/3426 (58%)]	Loss: 7.721980
# Train Epoch: 45 [3000/3426 (87%)]	Loss: 7.061555
# ====> Epoch: 45 Average loss: 12.4482
# Train Epoch: 46 [0/3426 (0%)]	Loss: 10.224232
# Train Epoch: 46 [1000/3426 (29%)]	Loss: 9.640627
# Train Epoch: 46 [2000/3426 (58%)]	Loss: 7.931499
# Train Epoch: 46 [3000/3426 (87%)]	Loss: 6.525723
# ====> Epoch: 46 Average loss: 12.5284
# Train Epoch: 47 [0/3426 (0%)]	Loss: 9.447023
# Train Epoch: 47 [1000/3426 (29%)]	Loss: 7.962306
# Train Epoch: 47 [2000/3426 (58%)]	Loss: 8.512115
# Train Epoch: 47 [3000/3426 (87%)]	Loss: 7.005062
# ====> Epoch: 47 Average loss: 12.5494
# Train Epoch: 48 [0/3426 (0%)]	Loss: 7.158868
# Train Epoch: 48 [1000/3426 (29%)]	Loss: 8.674815
# Train Epoch: 48 [2000/3426 (58%)]	Loss: 9.015958
# Train Epoch: 48 [3000/3426 (87%)]	Loss: 6.778612
# ====> Epoch: 48 Average loss: 12.6973
# Train Epoch: 49 [0/3426 (0%)]	Loss: 10.118434
# Train Epoch: 49 [1000/3426 (29%)]	Loss: 7.728242
# Train Epoch: 49 [2000/3426 (58%)]	Loss: 10.318857
# Train Epoch: 49 [3000/3426 (87%)]	Loss: 8.079718
# ====> Epoch: 49 Average loss: 12.2786
# Train Epoch: 50 [0/3426 (0%)]	Loss: 6.337527
# Train Epoch: 50 [1000/3426 (29%)]	Loss: 8.526724
# Train Epoch: 50 [2000/3426 (58%)]	Loss: 8.986491
# Train Epoch: 50 [3000/3426 (87%)]	Loss: 7.847797
# ====> Epoch: 50 Average loss: 11.8936
# Train Epoch: 51 [0/3426 (0%)]	Loss: 9.004992
# Train Epoch: 51 [1000/3426 (29%)]	Loss: 8.837667
# Train Epoch: 51 [2000/3426 (58%)]	Loss: 10.001891
# Train Epoch: 51 [3000/3426 (87%)]	Loss: 8.837011
# ====> Epoch: 51 Average loss: 11.6856
# Train Epoch: 52 [0/3426 (0%)]	Loss: 9.789101
# Train Epoch: 52 [1000/3426 (29%)]	Loss: 9.713177
# Train Epoch: 52 [2000/3426 (58%)]	Loss: 15.248872
# Train Epoch: 52 [3000/3426 (87%)]	Loss: 9.281492
# ====> Epoch: 52 Average loss: 12.0007
# Train Epoch: 53 [0/3426 (0%)]	Loss: 28.694202
# Train Epoch: 53 [1000/3426 (29%)]	Loss: 9.550277
# Train Epoch: 53 [2000/3426 (58%)]	Loss: 9.882000
# Train Epoch: 53 [3000/3426 (87%)]	Loss: 7.398500
# ====> Epoch: 53 Average loss: 11.8872
# Train Epoch: 54 [0/3426 (0%)]	Loss: 18.003172
# Train Epoch: 54 [1000/3426 (29%)]	Loss: 8.373769
# Train Epoch: 54 [2000/3426 (58%)]	Loss: 8.295824
# Train Epoch: 54 [3000/3426 (87%)]	Loss: 6.834683
# ====> Epoch: 54 Average loss: 11.8360
# Train Epoch: 55 [0/3426 (0%)]	Loss: 10.442868
# Train Epoch: 55 [1000/3426 (29%)]	Loss: 9.306464
# Train Epoch: 55 [2000/3426 (58%)]	Loss: 10.336230
# Train Epoch: 55 [3000/3426 (87%)]	Loss: 20.762215
# ====> Epoch: 55 Average loss: 12.2480
# Train Epoch: 56 [0/3426 (0%)]	Loss: 21.464935
# Train Epoch: 56 [1000/3426 (29%)]	Loss: 8.063124
# Train Epoch: 56 [2000/3426 (58%)]	Loss: 9.568254
# Train Epoch: 56 [3000/3426 (87%)]	Loss: 10.852154
# ====> Epoch: 56 Average loss: 11.8474
# Train Epoch: 57 [0/3426 (0%)]	Loss: 11.673226
# Train Epoch: 57 [1000/3426 (29%)]	Loss: 9.192399
# Train Epoch: 57 [2000/3426 (58%)]	Loss: 33.820178
# Train Epoch: 57 [3000/3426 (87%)]	Loss: 7.230787
# ====> Epoch: 57 Average loss: 11.9671
# Train Epoch: 58 [0/3426 (0%)]	Loss: 11.555078
# Train Epoch: 58 [1000/3426 (29%)]	Loss: 9.832877
# Train Epoch: 58 [2000/3426 (58%)]	Loss: 7.457619
# Train Epoch: 58 [3000/3426 (87%)]	Loss: 8.216789
# ====> Epoch: 58 Average loss: 11.7981
# Train Epoch: 59 [0/3426 (0%)]	Loss: 7.084103
# Train Epoch: 59 [1000/3426 (29%)]	Loss: 9.107281
# Train Epoch: 59 [2000/3426 (58%)]	Loss: 7.330403
# Train Epoch: 59 [3000/3426 (87%)]	Loss: 7.087604
# ====> Epoch: 59 Average loss: 11.5944
# Train Epoch: 60 [0/3426 (0%)]	Loss: 5.856575
# Train Epoch: 60 [1000/3426 (29%)]	Loss: 7.961237
# Train Epoch: 60 [2000/3426 (58%)]	Loss: 11.050788
# Train Epoch: 60 [3000/3426 (87%)]	Loss: 6.626778
# ====> Epoch: 60 Average loss: 11.2600
# Train Epoch: 61 [0/3426 (0%)]	Loss: 8.244090
# Train Epoch: 61 [1000/3426 (29%)]	Loss: 7.307884
# Train Epoch: 61 [2000/3426 (58%)]	Loss: 10.751011
# Train Epoch: 61 [3000/3426 (87%)]	Loss: 7.790247
# ====> Epoch: 61 Average loss: 11.3146
# Train Epoch: 62 [0/3426 (0%)]	Loss: 8.741901
# Train Epoch: 62 [1000/3426 (29%)]	Loss: 8.188858
# Train Epoch: 62 [2000/3426 (58%)]	Loss: 15.326242
# Train Epoch: 62 [3000/3426 (87%)]	Loss: 6.258802
# ====> Epoch: 62 Average loss: 11.3481
# Train Epoch: 63 [0/3426 (0%)]	Loss: 11.908186
# Train Epoch: 63 [1000/3426 (29%)]	Loss: 7.493404
# Train Epoch: 63 [2000/3426 (58%)]	Loss: 9.375740
# Train Epoch: 63 [3000/3426 (87%)]	Loss: 6.764201
# ====> Epoch: 63 Average loss: 11.4021
# Train Epoch: 64 [0/3426 (0%)]	Loss: 14.234451
# Train Epoch: 64 [1000/3426 (29%)]	Loss: 17.015808
# Train Epoch: 64 [2000/3426 (58%)]	Loss: 11.620649
# Train Epoch: 64 [3000/3426 (87%)]	Loss: 59.085657
# ====> Epoch: 64 Average loss: 11.9112
# Train Epoch: 65 [0/3426 (0%)]	Loss: 5.762463
# Train Epoch: 65 [1000/3426 (29%)]	Loss: 8.274399
# Train Epoch: 65 [2000/3426 (58%)]	Loss: 9.722220
# Train Epoch: 65 [3000/3426 (87%)]	Loss: 8.577749
# ====> Epoch: 65 Average loss: 11.5178
# Train Epoch: 66 [0/3426 (0%)]	Loss: 13.290517
# Train Epoch: 66 [1000/3426 (29%)]	Loss: 8.742439
# Train Epoch: 66 [2000/3426 (58%)]	Loss: 11.807482
# Train Epoch: 66 [3000/3426 (87%)]	Loss: 8.453622
# ====> Epoch: 66 Average loss: 11.2205
# Train Epoch: 67 [0/3426 (0%)]	Loss: 5.700867
# Train Epoch: 67 [1000/3426 (29%)]	Loss: 9.420338
# Train Epoch: 67 [2000/3426 (58%)]	Loss: 8.693187
# Train Epoch: 67 [3000/3426 (87%)]	Loss: 7.290629
# ====> Epoch: 67 Average loss: 11.2497
# Train Epoch: 68 [0/3426 (0%)]	Loss: 5.522741
# Train Epoch: 68 [1000/3426 (29%)]	Loss: 8.523335
# Train Epoch: 68 [2000/3426 (58%)]	Loss: 8.488625
# Train Epoch: 68 [3000/3426 (87%)]	Loss: 7.172569
# ====> Epoch: 68 Average loss: 11.2902
# Train Epoch: 69 [0/3426 (0%)]	Loss: 5.658120
# Train Epoch: 69 [1000/3426 (29%)]	Loss: 7.782791
# Train Epoch: 69 [2000/3426 (58%)]	Loss: 8.306681
# Train Epoch: 69 [3000/3426 (87%)]	Loss: 8.825156
# ====> Epoch: 69 Average loss: 11.0988
# Train Epoch: 70 [0/3426 (0%)]	Loss: 5.879912
# Train Epoch: 70 [1000/3426 (29%)]	Loss: 6.802151
# Train Epoch: 70 [2000/3426 (58%)]	Loss: 13.800883
# Train Epoch: 70 [3000/3426 (87%)]	Loss: 12.410825
# ====> Epoch: 70 Average loss: 10.9557
# Train Epoch: 71 [0/3426 (0%)]	Loss: 5.991978
# Train Epoch: 71 [1000/3426 (29%)]	Loss: 7.760559
# Train Epoch: 71 [2000/3426 (58%)]	Loss: 10.213785
# Train Epoch: 71 [3000/3426 (87%)]	Loss: 7.207966
# ====> Epoch: 71 Average loss: 10.7277
# Train Epoch: 72 [0/3426 (0%)]	Loss: 5.583730
# Train Epoch: 72 [1000/3426 (29%)]	Loss: 6.801728
# Train Epoch: 72 [2000/3426 (58%)]	Loss: 9.882616
# Train Epoch: 72 [3000/3426 (87%)]	Loss: 7.464305
# ====> Epoch: 72 Average loss: 10.8505
# Train Epoch: 73 [0/3426 (0%)]	Loss: 5.528027
# Train Epoch: 73 [1000/3426 (29%)]	Loss: 7.314056
# Train Epoch: 73 [2000/3426 (58%)]	Loss: 9.174980
# Train Epoch: 73 [3000/3426 (87%)]	Loss: 7.585828
# ====> Epoch: 73 Average loss: 10.7649
# Train Epoch: 74 [0/3426 (0%)]	Loss: 8.655050
# Train Epoch: 74 [1000/3426 (29%)]	Loss: 7.645746
# Train Epoch: 74 [2000/3426 (58%)]	Loss: 9.669395
# Train Epoch: 74 [3000/3426 (87%)]	Loss: 7.276297
# ====> Epoch: 74 Average loss: 10.8072
# Train Epoch: 75 [0/3426 (0%)]	Loss: 9.209897
# Train Epoch: 75 [1000/3426 (29%)]	Loss: 7.320560
# Train Epoch: 75 [2000/3426 (58%)]	Loss: 9.382832
# Train Epoch: 75 [3000/3426 (87%)]	Loss: 12.655490
# ====> Epoch: 75 Average loss: 11.2048
# Train Epoch: 76 [0/3426 (0%)]	Loss: 14.198634
# Train Epoch: 76 [1000/3426 (29%)]	Loss: 8.347678
# Train Epoch: 76 [2000/3426 (58%)]	Loss: 10.601820
# Train Epoch: 76 [3000/3426 (87%)]	Loss: 15.507138
# ====> Epoch: 76 Average loss: 11.1190
# Train Epoch: 77 [0/3426 (0%)]	Loss: 5.824911
# Train Epoch: 77 [1000/3426 (29%)]	Loss: 7.904301
# Train Epoch: 77 [2000/3426 (58%)]	Loss: 9.085042
# Train Epoch: 77 [3000/3426 (87%)]	Loss: 9.616251
# ====> Epoch: 77 Average loss: 10.6946
# Train Epoch: 78 [0/3426 (0%)]	Loss: 11.939474
# Train Epoch: 78 [1000/3426 (29%)]	Loss: 8.300817
# Train Epoch: 78 [2000/3426 (58%)]	Loss: 10.769407
# Train Epoch: 78 [3000/3426 (87%)]	Loss: 12.785785
# ====> Epoch: 78 Average loss: 10.6348
# Train Epoch: 79 [0/3426 (0%)]	Loss: 6.567438
# Train Epoch: 79 [1000/3426 (29%)]	Loss: 8.760331
# Train Epoch: 79 [2000/3426 (58%)]	Loss: 9.206043
# Train Epoch: 79 [3000/3426 (87%)]	Loss: 13.421027
# ====> Epoch: 79 Average loss: 10.9150
# Train Epoch: 80 [0/3426 (0%)]	Loss: 15.748882
# Train Epoch: 80 [1000/3426 (29%)]	Loss: 7.779974
# Train Epoch: 80 [2000/3426 (58%)]	Loss: 11.383273
# Train Epoch: 80 [3000/3426 (87%)]	Loss: 6.298071
# ====> Epoch: 80 Average loss: 10.9020
# Train Epoch: 81 [0/3426 (0%)]	Loss: 9.502644
# Train Epoch: 81 [1000/3426 (29%)]	Loss: 8.094537
# Train Epoch: 81 [2000/3426 (58%)]	Loss: 9.384644
# Train Epoch: 81 [3000/3426 (87%)]	Loss: 7.121333
# ====> Epoch: 81 Average loss: 10.5935
# Train Epoch: 82 [0/3426 (0%)]	Loss: 7.612509
# Train Epoch: 82 [1000/3426 (29%)]	Loss: 7.216017
# Train Epoch: 82 [2000/3426 (58%)]	Loss: 9.468481
# Train Epoch: 82 [3000/3426 (87%)]	Loss: 6.574471
# ====> Epoch: 82 Average loss: 10.4055
# Train Epoch: 83 [0/3426 (0%)]	Loss: 10.578569
# Train Epoch: 83 [1000/3426 (29%)]	Loss: 7.845612
# Train Epoch: 83 [2000/3426 (58%)]	Loss: 7.668275
# Train Epoch: 83 [3000/3426 (87%)]	Loss: 9.725349
# ====> Epoch: 83 Average loss: 10.8356
# Train Epoch: 84 [0/3426 (0%)]	Loss: 5.810653
# Train Epoch: 84 [1000/3426 (29%)]	Loss: 7.613326
# Train Epoch: 84 [2000/3426 (58%)]	Loss: 9.971883
# Train Epoch: 84 [3000/3426 (87%)]	Loss: 7.300727
# ====> Epoch: 84 Average loss: 10.3125
# Train Epoch: 85 [0/3426 (0%)]	Loss: 5.895941
# Train Epoch: 85 [1000/3426 (29%)]	Loss: 8.237158
# Train Epoch: 85 [2000/3426 (58%)]	Loss: 8.830618
# Train Epoch: 85 [3000/3426 (87%)]	Loss: 10.666160
# ====> Epoch: 85 Average loss: 11.4130
# Train Epoch: 86 [0/3426 (0%)]	Loss: 14.585783
# Train Epoch: 86 [1000/3426 (29%)]	Loss: 9.071460
# Train Epoch: 86 [2000/3426 (58%)]	Loss: 9.348360
# Train Epoch: 86 [3000/3426 (87%)]	Loss: 9.056823
# ====> Epoch: 86 Average loss: 10.9336
# Train Epoch: 87 [0/3426 (0%)]	Loss: 37.088397
# Train Epoch: 87 [1000/3426 (29%)]	Loss: 7.015096
# Train Epoch: 87 [2000/3426 (58%)]	Loss: 9.584523
# Train Epoch: 87 [3000/3426 (87%)]	Loss: 11.597162
# ====> Epoch: 87 Average loss: 10.7003
# Train Epoch: 88 [0/3426 (0%)]	Loss: 8.866676
# Train Epoch: 88 [1000/3426 (29%)]	Loss: 8.145818
# Train Epoch: 88 [2000/3426 (58%)]	Loss: 8.711333
# Train Epoch: 88 [3000/3426 (87%)]	Loss: 9.245097
# ====> Epoch: 88 Average loss: 10.5287
# Train Epoch: 89 [0/3426 (0%)]	Loss: 5.549003
# Train Epoch: 89 [1000/3426 (29%)]	Loss: 8.327414
# Train Epoch: 89 [2000/3426 (58%)]	Loss: 7.806621
# Train Epoch: 89 [3000/3426 (87%)]	Loss: 7.273048
# ====> Epoch: 89 Average loss: 10.4751
# Train Epoch: 90 [0/3426 (0%)]	Loss: 7.066490
# Train Epoch: 90 [1000/3426 (29%)]	Loss: 7.647318
# Train Epoch: 90 [2000/3426 (58%)]	Loss: 8.162398
# Train Epoch: 90 [3000/3426 (87%)]	Loss: 14.978821
# ====> Epoch: 90 Average loss: 10.6711
# Train Epoch: 91 [0/3426 (0%)]	Loss: 7.115159
# Train Epoch: 91 [1000/3426 (29%)]	Loss: 7.080273
# Train Epoch: 91 [2000/3426 (58%)]	Loss: 9.904594
# Train Epoch: 91 [3000/3426 (87%)]	Loss: 7.044682
# ====> Epoch: 91 Average loss: 10.6375
# Train Epoch: 92 [0/3426 (0%)]	Loss: 5.827234
# Train Epoch: 92 [1000/3426 (29%)]	Loss: 7.378987
# Train Epoch: 92 [2000/3426 (58%)]	Loss: 8.595677
# Train Epoch: 92 [3000/3426 (87%)]	Loss: 9.919978
# ====> Epoch: 92 Average loss: 10.3629
# Train Epoch: 93 [0/3426 (0%)]	Loss: 7.709134
# Train Epoch: 93 [1000/3426 (29%)]	Loss: 7.146936
# Train Epoch: 93 [2000/3426 (58%)]	Loss: 8.649218
# Train Epoch: 93 [3000/3426 (87%)]	Loss: 12.127627
# ====> Epoch: 93 Average loss: 10.1987
# Train Epoch: 94 [0/3426 (0%)]	Loss: 12.345001
# Train Epoch: 94 [1000/3426 (29%)]	Loss: 8.214700
# Train Epoch: 94 [2000/3426 (58%)]	Loss: 8.126435
# Train Epoch: 94 [3000/3426 (87%)]	Loss: 8.335592
# ====> Epoch: 94 Average loss: 10.5486
# Train Epoch: 95 [0/3426 (0%)]	Loss: 9.157559
# Train Epoch: 95 [1000/3426 (29%)]	Loss: 9.205238
# Train Epoch: 95 [2000/3426 (58%)]	Loss: 8.223335
# Train Epoch: 95 [3000/3426 (87%)]	Loss: 17.259039
# ====> Epoch: 95 Average loss: 10.2682
# Train Epoch: 96 [0/3426 (0%)]	Loss: 10.182487
# Train Epoch: 96 [1000/3426 (29%)]	Loss: 7.739913
# Train Epoch: 96 [2000/3426 (58%)]	Loss: 8.809379
# Train Epoch: 96 [3000/3426 (87%)]	Loss: 8.196462
# ====> Epoch: 96 Average loss: 10.8565
# Train Epoch: 97 [0/3426 (0%)]	Loss: 8.405379
# Train Epoch: 97 [1000/3426 (29%)]	Loss: 7.233894
# Train Epoch: 97 [2000/3426 (58%)]	Loss: 14.805830
# Train Epoch: 97 [3000/3426 (87%)]	Loss: 7.380993
# ====> Epoch: 97 Average loss: 10.4643
# Train Epoch: 98 [0/3426 (0%)]	Loss: 5.870006
# Train Epoch: 98 [1000/3426 (29%)]	Loss: 7.123727
# Train Epoch: 98 [2000/3426 (58%)]	Loss: 7.643410
# Train Epoch: 98 [3000/3426 (87%)]	Loss: 7.436278
# ====> Epoch: 98 Average loss: 10.4994
# Train Epoch: 99 [0/3426 (0%)]	Loss: 9.457494
# Train Epoch: 99 [1000/3426 (29%)]	Loss: 7.681027
# Train Epoch: 99 [2000/3426 (58%)]	Loss: 7.717094
# Train Epoch: 99 [3000/3426 (87%)]	Loss: 12.315417
# ====> Epoch: 99 Average loss: 10.0624

# %%
def compare(dataset, model):
    model.eval()
    rec = []
    x = []
    with torch.no_grad():
        for i, data in enumerate(dataset):
            x_rec, mu, logvar = model(data)
            z = v.reparametrization_trick(mu, logvar)

            x.extend(data[:,:,0].detach().numpy())
            rec.extend(x_rec[:].detach().numpy())
        
    print(mu[-1, :], logvar[-1, :])
    plt.plot(rec, "r--")
    plt.plot(x[:], "b-")
    plt.ylim(0,100)
    plt.grid(True)
    
    return z[-1, :]

# %%
z = compare(train_data, v)
# Out:
# tensor([-0.2685,  0.0218,  0.5262,  0.2710,  0.4432, -0.3377,  0.0670,  0.8391,
#          0.4488, -1.9271,  0.5032, -0.0788,  0.3569, -0.8099,  0.6615, -0.6875,
#         -0.5644, -2.5548, -2.2896,  1.7071,  0.5787, -2.2155,  0.1569,  1.6117,
#          1.5730, -2.7363, -0.8810, -2.0466, -1.4723,  1.4603]) tensor([ 0.0555, -0.3319,  0.0840, -0.1020, -0.1355,  0.5514,  0.1110, -0.1420,
#          0.3078,  0.7035,  0.3251,  0.0170,  0.1786,  0.1025, -0.2395,  4.3286,
#         -9.1749, -2.8505, 14.5622, -2.2380,  4.7248,  3.3063,  0.1420, -1.0915,
#          0.6273,  0.4470,  4.4733, 12.2138, -0.0231, -4.1279])

# %%
z = compare(test_data, v)
# Out:
# tensor([-0.5514, -0.4143,  1.0008,  0.5868,  1.0135, -0.8534,  0.0369,  1.4516,
#          1.1142, -1.6827,  1.1157, -0.2145,  0.7566, -1.7341,  1.1271, -0.6875,
#         -0.5644, -2.5548, -2.2896,  1.7071,  0.5787, -2.2155,  0.1569,  1.6117,
#          1.5730, -2.7363, -0.8810, -2.0466, -1.4723,  1.4603]) tensor([ 0.2096, -0.6147,  0.0381,  0.0188,  0.0961,  0.1436,  0.0400, -0.3993,
#          0.3248, -0.7122,  0.0332,  0.0745,  0.1386,  0.0540, -0.2992,  4.3286,
#         -9.1749, -2.8505, 14.5622, -2.2380,  4.7248,  3.3063,  0.1420, -1.0915,
#          0.6273,  0.4470,  4.4733, 12.2138, -0.0231, -4.1279])

# %%
test(v, test_data, criterion, device)
# Out:
# ====> Test set loss: 40.7919

# %%
rec = []
for i in range(1000):
    z[16] = 0.01*i
    
    x_rec = v.decoder(z)

    rec.append(x_rec.detach().numpy())
print(len(rec))
plt.plot(rec)
# Out:
# 1000
# [<matplotlib.lines.Line2D at 0x7ff89f70b1f0>,
#  <matplotlib.lines.Line2D at 0x7ff89f70b250>,
#  <matplotlib.lines.Line2D at 0x7ff89f70b280>]

# %%
z = np.arange(0.001,1, 0.01)
z
# Out:
# array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091, 0.101, 0.111, 0.121, 0.131, 0.141, 0.151, 0.161, 0.171,
#        0.181, 0.191, 0.201, 0.211, 0.221, 0.231, 0.241, 0.251, 0.261,
#        0.271, 0.281, 0.291, 0.301, 0.311, 0.321, 0.331, 0.341, 0.351,
#        0.361, 0.371, 0.381, 0.391, 0.401, 0.411, 0.421, 0.431, 0.441,
#        0.451, 0.461, 0.471, 0.481, 0.491, 0.501, 0.511, 0.521, 0.531,
#        0.541, 0.551, 0.561, 0.571, 0.581, 0.591, 0.601, 0.611, 0.621,
#        0.631, 0.641, 0.651, 0.661, 0.671, 0.681, 0.691, 0.701, 0.711,
#        0.721, 0.731, 0.741, 0.751, 0.761, 0.771, 0.781, 0.791, 0.801,
#        0.811, 0.821, 0.831, 0.841, 0.851, 0.861, 0.871, 0.881, 0.891,
#        0.901, 0.911, 0.921, 0.931, 0.941, 0.951, 0.961, 0.971, 0.981,
#        0.991])

# %%
# %matplotlib 
# import ipywidgets as widgets

# z = np.arange(16)
# @interact(z, np.arange(0.001,10, 0.01))
def experiment(z,z_num):
    rec = []
    for i in range(1000):
        z[z_num] = 0.01*i

        x_rec = v.decoder(z)

        rec.append(x_rec.detach().numpy())
    print(len(rec))
    plt.plot(rec)
    
# widgets.interact(experiment, z)

# %%
experiment(z,3)
# Out:
# 1000

# %%
1) Pulse/ Rechteck
2) Trends (linear or not)
3) Periodicity
std. effects
5) coupling durch cov matrix
6) Noise
7) Effect of latent dim änderung, welche größe ist am besten  geeignet, soll latent_dim = n_channels sein? couploung durch hiarchie?
Modeling of interactions effects in die simulation hilft um die interpretation zu validieren, man kann die effecte aus der realen daten 
besser mathematisch verstehen
8) Short and long term effects durch die verschiedenen Convolutions weights"aktivierung von neuronen/ welche neuraonen sind mehr active in welche fälle"
idee is to know what layers capt long term effects and which layers capt short terms to be able to better interpret the data
9) also change the effects to be intern effects -> they happen on the level of mean and std rather than additif to the channels and let only be some random noise additif (y = x +epsilon)
all the rest (trends, seasonalities, pulses should happen on the level of mean and std)


Write and document all the steps I wanna do and make check list
try to make the data scales and dimention real (x axes represents tims -> days, hours, secs / are the seasonalities daily or weekly etc)

# %%
60/5
# Out:
# 12.0

# %%
12*24
# Out:
# 288

# %%
288*7
# Out:
# 2016

# %%
2016*4
# Out:
# 8064

# %%
60*24
# Out:
# 1440

# %%
array = np.random.randint(10, size=(5,5))

# %%
array
# Out:
# array([[1, 8, 4, 1, 3],
#        [6, 5, 3, 9, 6],
#        [9, 1, 9, 4, 2],
#        [6, 7, 8, 8, 9],
#        [2, 0, 6, 7, 8]])

# %%
channels = [2,4]
start_idx = [1,2]
end_idx = [4,4]
[array[channels[i],start_idx[i]:end_idx[i]] for i in range(len(channels))]
# array[channels[,]start_idx]
# Out:
# [array([1, 9, 4]), array([6, 7])]

# %%
720/24
# Out:
# 30.0

# %%
24*12*2
# Out:
# 576

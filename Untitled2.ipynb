# %%
# %load_ext autoreload
# %autoreload 2
from dataGen import Gen
from utils import compare, experiment
from train import slidingWindow, criterion, train, test, objective, train_vae
from Encoders import LongShort_TCVAE_Encoder, RnnEncoder, MST_VAE_Encoder, MST_VAE_Encoder_dist
from Decoders import LongShort_TCVAE_Decoder, RnnDecoder, MST_VAE_Decoder, MST_VAE_Decoder_dist
from vae import VariationalAutoencoder, VQ_MST_VAE, VQ_Quantizer

import torch; torch.manual_seed(955)
import torch.optim as optim
import torch.distributions as D
from torch.utils.data import DataLoader
import optuna
from optuna.samplers import TPESampler
import torchaudio

import torch.nn as nn
import torch.nn.functional as F
import torch.distributions as D


import numpy as np
import matplotlib.pyplot as plt
import pprint
# all parameters for generating the time series should be configured in this cell
periode = 15 #days
step = 5 # mess interval in minutes
val = 100
n_channels = 1
effects = {
    "Pulse": {
        "occurances":5,
        "max_amplitude":1.5,   
        "interval":40
        },
    "Trend": {
        "occurances":6,
        "max_slope":0.005,
        "type":"linear"
        },
    "Seasonality": {
        "occurances":3,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
# pprint.pprint(params)
pprint.pprint(e_params)
X.show()

def lin_size(n, num_layers, first_kernel = None):
    
    for i in range(0, num_layers):
        
        if i == 0 and first_kernel != None:
            n = 1 + ((n - first_kernel) // 2)
        else:
            n = 1 + ((n - 2) // 2)
            
    if n <= 0:
        raise ValueError("Window Length is too small in relation to the number of Layers")
            
    return n * 2 * num_layers

class TCVAE_Encoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L = 30, slope = 0.2, first_kernel = None):
        super(TCVAE_Encoder, self).__init__()   
        
        self.n =  lin_size(L, num_layers, first_kernel)        
        self.cnn_layers = nn.ModuleList()
        self.n_channels = input_size
        
        def init_weights(m):
            if isinstance(m, nn.Conv1d):
                torch.nn.init.kaiming_uniform_(m.weight, mode="fan_in", nonlinearity="leaky_relu")
                m.bias.data.fill_(0.01)
                
        # CNN Layers that double the channels each time
        for i in range(0, num_layers):            
            if i == 0:
                if first_kernel == None: first_kernel = 2
                self.cnn_layers.append(nn.Conv1d(input_size, input_size * 2, kernel_size=first_kernel, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size * 2))
            else:                
                self.cnn_layers.append(nn.Conv1d(input_size * 2 * i, input_size * 2 * (i+1), kernel_size=2, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size * 2 * (i+1)))
                
        # MLP Layers for Mu and logvar output
        self.encoder_mu = nn.Sequential(
            nn.Linear(self.n * input_size, latent_dims),
#             nn.Linear(self.n * input_size, self.n * input_size),
#             nn.ReLU(True)
        )
        self.encoder_logvar = nn.Sequential(
            nn.Linear(self.n * input_size, latent_dims),
#             nn.Linear(self.n * input_size, self.n * input_size),
#             nn.ReLU(True)
        )   
        
        #Init CNN
        self.cnn_layers.apply(init_weights)
         
    def forward(self, x):
        ### CNN
        for i, cnn in enumerate(self.cnn_layers):
#             print(x.shape)
            x = cnn(x)
        cnn_shape = x.shape
        x = x.view(x.size(0), -1)
#         print(x.shape)
        ### MLP
        mu = self.encoder_mu(x)  
        logvar = self.encoder_logvar(x)
#         print(mu.shape)
        mu = mu.view(mu.shape[0], self.n_channels, -1)
        logvar = logvar.view(logvar.shape[0], self.n_channels, -1)
#         print(mu.shape)
#         mu.reshape

        
        return mu, logvar
    
class LongShort_TCVAE_Encoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L = 30, slope = 0.2, first_kernel = None):
        super(LongShort_TCVAE_Encoder, self).__init__() 
        self.latent_dims = latent_dims
        
        self.short_encoder = TCVAE_Encoder(input_size, num_layers, latent_dims, L, slope, first_kernel= None)
        self.long_encoder = TCVAE_Encoder(input_size, num_layers, latent_dims, L, slope, first_kernel)
        
    def forward(self, x):        
        short_mu, short_logvar = self.short_encoder(x)        
        long_mu, long_logvar = self.long_encoder(x)

        mu = torch.cat((short_mu, long_mu), axis=1)
        logvar = torch.cat((short_logvar, long_logvar), axis=1)
        
#         print("Short Encoder mu: ", short_mu.shape)
#         print("Long Encoder mu: ", long_mu.shape)
        
#         print("After Cat: ", mu.shape)
        
        
        return mu, logvar
    
class VQ_Quantizer(nn.Module):
    def __init__(self, num_embed, dim_embed, commit_loss, decay, epsilon=1e-5):
        super(VQ_Quantizer, self).__init__()  
        
        self._num_embed = num_embed
        self._dim_embed = dim_embed
        self._commit_loss = commit_loss
        
        self._embedding = nn.Embedding(self._num_embed, self._dim_embed)
        self._embedding.weight.data.uniform_(-1/self._num_embed, 1/self._num_embed)      
        
        self.register_buffer('_ema_cluster_size', torch.zeros(num_embed))
        self._ema_w = nn.Parameter(torch.Tensor(num_embed, dim_embed))
        self._ema_w.data.normal_()
        
        self._decay = decay
        self._epsilon = epsilon

    def forward(self, x):
        # x : BCL -> BLC
#         print(x.shape)
        x = x.permute(0,2,1).contiguous()
        x_shape = x.shape
        
        # flaten the input to have the Channels as embedding space
        x_flat = x.view(-1, self._dim_embed)
        
        # Calculate the distance to embeddings
        
#         print("the non squared x", x_flat.shape )
#         print("the non squared embed weights", self._embedding.weight.t().shape)
#         print("the x ", torch.sum(x_flat**2, dim = 1, keepdim = True).shape)
#         print("the embed ", torch.sum(self._embedding.weight**2, dim = 1).shape)
#         print("the matmul ", torch.matmul(x_flat, self._embedding.weight.t()).shape)
        dist = (torch.sum(x_flat**2, dim = 1, keepdim = True) 
               + torch.sum(self._embedding.weight**2, dim = 1)
               - 2 * torch.matmul(x_flat, self._embedding.weight.t()))
#         print(dist.shape)
        
        embed_indices = torch.argmin(dist, dim = 1).unsqueeze(1)
#         print(embed_indices)
        embed_Matrix = torch.zeros_like(dist)
#         print(embed_Matrix.shape)
        embed_Matrix.scatter_(1, embed_indices, 1)
#         print("Embedding ", embed_Matrix[:10,:])

        # get the corresponding e vectors
        quantizer = torch.matmul(embed_Matrix, self._embedding.weight).view(x_shape)   
        
        # Use EMA to update the embedding vectors
        if self.training:
            self._ema_cluster_size = self._ema_cluster_size * self._decay + \
                                     (1 - self._decay) * torch.sum(embed_Matrix, 0)
            
            # Laplace smoothing of the cluster size
            n = torch.sum(self._ema_cluster_size.data)
            self._ema_cluster_size = (
                (self._ema_cluster_size + self._epsilon)
                / (n + self._num_embed * self._epsilon) * n)
            
            dw = torch.matmul(embed_Matrix.t(), x_flat)
            self._ema_w = nn.Parameter(self._ema_w * self._decay + (1 - self._decay) * dw)
            
            self._embedding.weight = nn.Parameter(self._ema_w / self._ema_cluster_size.unsqueeze(1))
#         print("quantizer ", quantizer.shape)
        
        # Loss
#         first_loss = F.mse_loss(quantizer, x.detach())
#         second_loss = F.mse_loss(quantizer.detach(), x)
#         loss = first_loss + self._commit_loss * second_loss
        
         # Loss EMA
        e_loss = F.mse_loss(quantizer.detach(), x)
        loss = self._commit_loss * e_loss
#         print(loss)
        
        # straigh-through gradient
        quantizer = x + (quantizer -x).detach()
        quantizer = quantizer.permute(0,2,1).contiguous()
#         print("quantizer ", quantizer.shape)       
     
        return quantizer, loss
    
class VQ_MST_VAE(nn.Module):
    def __init__(self, n_channels, num_layers, latent_dims, v_encoder, v_decoder, v_quantizer,
                 L = 30,
                 slope = 0.2,
                 first_kernel = None,
                 commit_loss = 0.25
                ):
        super(VQ_MST_VAE, self).__init__()
        
        self._n_channels = n_channels
        self._num_layers = num_layers
        self._latent_dims = latent_dims
        self._v_encoder = v_encoder
        self._v_decoder = v_decoder
        self._v_quantizer = v_quantizer
        self._L = L
        self._slope = slope
        self._first_kernel = first_kernel
        self._commit_loss = commit_loss
        
        
        self.encoder = self._v_encoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope, self._first_kernel)
        self.decoder = self._v_decoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope, self._first_kernel)
        self.quantizer = self._v_quantizer(self._latent_dims, self._n_channels,self._commit_loss, decay=0.99, epsilon=1e-5)
        
    def reparametrization_trick(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std
    
    def forward(self, x):
        mu, logvar = self.encoder(x)                
        
        z = self.reparametrization_trick(mu, logvar)
        
        e, loss_quantize = self.quantizer(z)

#         mu_dec, logvar_dec = self.decoder(e)
#         x_rec = self.reparametrization_trick(mu_dec, mu_dec)
        x_rec = self.decoder(e)
        loss_rec = F.mse_loss(x_rec, x, reduction='sum')
        loss = loss_rec + loss_quantize
#         print("----------------Encoder Output-------------")
#         print("mu and logvar", mu.shape, logvar.shape)
#         print("----------------Reparametrization-------------")
#         print("Z", z.shape)
#         print("----------------Quantizer-------------")
#         print("quantized shape", e.shape)
#         print("loss shape", loss_quantize)
#         print("----------------Decoding-------------")
        #print("----------------Decoder Output-------------")
#         print("mu and logvar Decoder", mu_dec.shape, logvar_dec.shape)
        #print("rec shape", x_rec.shape)
        return x_rec, loss, mu, logvar
# Out:
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [0.5514552880837025,
#                          0.9498055056619998,
#                          -0.4917852466063444,
#                          1.1724495920379674,
#                          -0.9056345609010892],
#            'channel': [0, 0, 0, 0, 0],
#            'index': ['2023-03-05T16:00:00',
#                      '2023-03-12T22:45:00',
#                      '2023-03-05T02:20:00',
#                      '2023-03-07T23:25:00',
#                      '2023-03-06T06:40:00']},
#  'Seasonality': {'amplitude': [13, 14, 7],
#                  'channel': [0, 0, 0],
#                  'frequency_per_week': [12.636562377829225,
#                                         10.651530066755438,
#                                         13.360542165660679],
#                  'phaseshift': [118, 71, 88]},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [0, 0, 0, 0, 0, 0],
#            'index': ['2023-03-02T10:05:00',
#                      '2023-03-05T21:10:00',
#                      '2023-03-03T06:25:00',
#                      '2023-03-14T15:40:00',
#                      '2023-03-05T17:50:00',
#                      '2023-03-14T10:30:00'],
#            'slope': [-0.0005816682557700393,
#                      -0.0006598600666670625,
#                      0.0011776697846931717,
#                      0.00013138242554390847,
#                      0.0015039718193146723,
#                      0.0010103895340454437]}}

# %%
class TCVAE_Decoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L = 30, slope = 0.2, first_kernel = None):
        super(TCVAE_Decoder, self).__init__() 
        
        def init_weights(m):
            if isinstance(m, nn.Conv1d):
                torch.nn.init.kaiming_uniform_(m.weight, mode="fan_in", nonlinearity="leaky_relu")
                m.bias.data.fill_(0.01)
                
        self.input_size = input_size
        self.latent_dims = latent_dims
        self.first_kernel = first_kernel
        self.num_layers = num_layers
        
        self.n =  lin_size(L, num_layers, first_kernel)
        
        
        
        self.cnn_layers = nn.ModuleList()
        
        if self.first_kernel == None: first_kernel = 2
        else: first_kernel = self.first_kernel
        input_lin = self.latent_dims  * 2 ** (self.num_layers-1) + first_kernel - 2
        self.decoder_lin = nn.Linear(input_lin, L)
        
#         # CNN Layers that double the channels each time
#         for i in range(num_layers, 0, -1):            
#             if i == 1:
#                 if first_kernel == None: first_kernel = 2
#                 self.cnn_layers.append(nn.ConvTranspose1d(input_size * 2, input_size, kernel_size=2, stride=2, padding=0))
#                 self.cnn_layers.append(nn.LeakyReLU(slope, True))
#             else:                
#                 self.cnn_layers.append(nn.ConvTranspose1d(input_size * 2 * i, input_size * 2 * (i-1), kernel_size=2, stride=2, padding=0))
#                 self.cnn_layers.append(nn.LeakyReLU(slope, True))
#                 self.cnn_layers.append(nn.BatchNorm1d(input_size * 2 * (i-1)))     
                
                
        # CNN Layers that double the channels each time
        for i in range(0, num_layers):            
            if i == 0:
                if first_kernel == None: first_kernel = 2
                self.cnn_layers.append(nn.ConvTranspose1d(input_size*2, input_size, kernel_size=2, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size))
            elif i == num_layers -1:
                if first_kernel == None: first_kernel = 2
                self.cnn_layers.append(nn.ConvTranspose1d(input_size, input_size, kernel_size=first_kernel, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size))
            else:                
                self.cnn_layers.append(nn.ConvTranspose1d(input_size , input_size, kernel_size=2, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size))
        
        # Init CNN
        self.cnn_layers.apply(init_weights)
                
        
    def forward(self, x):
#         print("Decoder Input ", z.shape)
#         x = x.view(x.shape[0], x.shape[1]* x.shape[2], -1)
#         print("Decoder Input reshaped ",x.shape)
#         x = self.decoder_lin(z) 
#         print("Decoder Input after lin ",x.shape)
#         x = x.view(x.shape[0],x.shape[1],1)
#         print("Decoder Input reshaped again",x.shape)
       
        for i, cnn in enumerate(self.cnn_layers):
#             print(x.shape)
            x = cnn(x)
        x = self.decoder_lin(x)
#         print(x.shape)

        return x #x[:,:,0]

# %%
class LongShort_TCVAE_Decoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L = 30, slope = 0.2, first_kernel = None):
        super(LongShort_TCVAE_Decoder, self).__init__()  
        
        self.longshort_decoder = TCVAE_Decoder(input_size, num_layers, 2 * latent_dims, L, slope, first_kernel)
        self.short_decoder = TCVAE_Decoder(input_size, num_layers, 2 * latent_dims, L, slope, first_kernel = None)
        
    def forward(self, z):
        x_long= self.longshort_decoder(z)
        x_short = self.short_decoder(z)
        return self.longshort_decoder(z)

# %%
### Init Model
latent_dims = 10
L=24*12
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# v = vae(n_channels, L, latent_dims)
# v = VariationalAutoencoder(input_size = n_channels,
#                       hidden_size = 30,
#                       num_layers = 3,
#                       latent_dims= latent_dims,
#                       v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder, # RnnEncoder, LongShort_TCVAE_Encoder,
#                       v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder, # RnnDecoder, LongShort_TCVAE_Decoder,
#                       L = L,
#                       slope = 0.2,
#                       first_kernel = 21)
v = VQ_MST_VAE(n_channels = n_channels,
                            num_layers = 3,
                            latent_dims= latent_dims,
                            v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
                            v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
                            v_quantizer = VQ_Quantizer,
                            L=L,
                            slope = 0.2,
                            first_kernel = 15,
                            commit_loss = 10)
enc = MST_VAE_Encoder_dist(     n_channels,
                           num_layers = 3,
                           slope = 0.2,
                           first_kernel = 15)
dec = MST_VAE_Decoder_dist(     n_channels,
                           num_layers = 3,
                           slope = 0.2,
                           first_kernel = 15)


v = v.to(device)
enc = enc.to(device)
dec = dec.to(device)
opt = optim.Adam(v.parameters(), lr = 0.001571)
# print(v)
# Create the dictionaries of probability distributions
# pnet = {'z': D.Normal(loc=torch.zeros(latent_dims), scale=torch.ones(latent_dims)), 'x': dec}
# qnet = {'z': enc}
# serie = torch.tensor(serie).float()
x = torch.FloatTensor(x)

x_normalized = F.normalize(x, p=2, dim=1)
n = x.shape[1]
# L = 30

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

train_data = DataLoader(slidingWindow(train_, L),
                        batch_size=100,
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=100,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=10,
                        shuffle = False
                        )

# %%
for epoch in range(1, 500):
    train(v, train_data, criterion, opt, device, epoch, VQ = True)
# Out:
# Train Epoch: 1 [0/3168 (0%)]	Loss: 7098.668750
# ====> Epoch: 1 Average loss: 2107.5055
# Train Epoch: 2 [0/3168 (0%)]	Loss: 2686.342500
# ====> Epoch: 2 Average loss: 2007.5383
# Train Epoch: 3 [0/3168 (0%)]	Loss: 3436.337500
# ====> Epoch: 3 Average loss: 2050.0860
# Train Epoch: 4 [0/3168 (0%)]	Loss: 5670.145625
# ====> Epoch: 4 Average loss: 2107.2207
# Train Epoch: 5 [0/3168 (0%)]	Loss: 2053.523594
# ====> Epoch: 5 Average loss: 2043.0794
# Train Epoch: 6 [0/3168 (0%)]	Loss: 2507.593125
# ====> Epoch: 6 Average loss: 1985.5243
# Train Epoch: 7 [0/3168 (0%)]	Loss: 2506.510938
# ====> Epoch: 7 Average loss: 1950.9665
# Train Epoch: 8 [0/3168 (0%)]	Loss: 2339.288281
# ====> Epoch: 8 Average loss: 2018.7224
# Train Epoch: 9 [0/3168 (0%)]	Loss: 5347.654375
# ====> Epoch: 9 Average loss: 2238.2540
# Train Epoch: 10 [0/3168 (0%)]	Loss: 3561.050000
# ====> Epoch: 10 Average loss: 2050.6789
# Train Epoch: 11 [0/3168 (0%)]	Loss: 2789.678438
# ====> Epoch: 11 Average loss: 2004.3869
# Train Epoch: 12 [0/3168 (0%)]	Loss: 4727.094375
# ====> Epoch: 12 Average loss: 2054.5448
# Train Epoch: 13 [0/3168 (0%)]	Loss: 4928.659375
# ====> Epoch: 13 Average loss: 2027.8055
# Train Epoch: 14 [0/3168 (0%)]	Loss: 6240.398750
# ====> Epoch: 14 Average loss: 2317.9658
# Train Epoch: 15 [0/3168 (0%)]	Loss: 5707.857500
# ====> Epoch: 15 Average loss: 2337.5545
# Train Epoch: 16 [0/3168 (0%)]	Loss: 5992.239375
# ====> Epoch: 16 Average loss: 2512.9942
# Train Epoch: 17 [0/3168 (0%)]	Loss: 6701.838125
# ====> Epoch: 17 Average loss: 2420.9601
# Train Epoch: 18 [0/3168 (0%)]	Loss: 5424.135000
# ====> Epoch: 18 Average loss: 2188.4331
# Train Epoch: 19 [0/3168 (0%)]	Loss: 2716.789375
# ====> Epoch: 19 Average loss: 2231.9055
# Train Epoch: 20 [0/3168 (0%)]	Loss: 2747.151250
# ====> Epoch: 20 Average loss: 2057.6911
# Train Epoch: 21 [0/3168 (0%)]	Loss: 1998.281875
# ====> Epoch: 21 Average loss: 2118.0146
# Train Epoch: 22 [0/3168 (0%)]	Loss: 3062.479688
# ====> Epoch: 22 Average loss: 2135.1499
# Train Epoch: 23 [0/3168 (0%)]	Loss: 2829.747500
# ====> Epoch: 23 Average loss: 2053.1314
# Train Epoch: 24 [0/3168 (0%)]	Loss: 5231.162812
# ====> Epoch: 24 Average loss: 2070.5105
# Train Epoch: 25 [0/3168 (0%)]	Loss: 4016.623750
# ====> Epoch: 25 Average loss: 1920.4708
# Train Epoch: 26 [0/3168 (0%)]	Loss: 2086.190312
# ====> Epoch: 26 Average loss: 1939.6194
# Train Epoch: 27 [0/3168 (0%)]	Loss: 3516.479688
# ====> Epoch: 27 Average loss: 1945.9493
# Train Epoch: 28 [0/3168 (0%)]	Loss: 2971.022188
# ====> Epoch: 28 Average loss: 1964.0066
# Train Epoch: 29 [0/3168 (0%)]	Loss: 4259.817187
# ====> Epoch: 29 Average loss: 2201.2782
# Train Epoch: 30 [0/3168 (0%)]	Loss: 1971.653125
# ====> Epoch: 30 Average loss: 1942.2031
# Train Epoch: 31 [0/3168 (0%)]	Loss: 2923.379063
# ====> Epoch: 31 Average loss: 1947.5790
# Train Epoch: 32 [0/3168 (0%)]	Loss: 2314.886875
# ====> Epoch: 32 Average loss: 1850.4200
# Train Epoch: 33 [0/3168 (0%)]	Loss: 2950.647812
# ====> Epoch: 33 Average loss: 1941.7145
# Train Epoch: 34 [0/3168 (0%)]	Loss: 3911.240625
# ====> Epoch: 34 Average loss: 1931.3356
# Train Epoch: 35 [0/3168 (0%)]	Loss: 5664.718750
# ====> Epoch: 35 Average loss: 2146.7447
# Train Epoch: 36 [0/3168 (0%)]	Loss: 4469.694688
# ====> Epoch: 36 Average loss: 1860.5929
# Train Epoch: 37 [0/3168 (0%)]	Loss: 4362.693125
# ====> Epoch: 37 Average loss: 1925.4675
# Train Epoch: 38 [0/3168 (0%)]	Loss: 3181.038125
# ====> Epoch: 38 Average loss: 1850.3077
# Train Epoch: 39 [0/3168 (0%)]	Loss: 2890.399063
# ====> Epoch: 39 Average loss: 1830.8450
# Train Epoch: 40 [0/3168 (0%)]	Loss: 2724.845000
# ====> Epoch: 40 Average loss: 1931.3915
# Train Epoch: 41 [0/3168 (0%)]	Loss: 4486.940000
# ====> Epoch: 41 Average loss: 2006.4053
# Train Epoch: 42 [0/3168 (0%)]	Loss: 3484.685000
# ====> Epoch: 42 Average loss: 1954.7285
# Train Epoch: 43 [0/3168 (0%)]	Loss: 1956.684688
# ====> Epoch: 43 Average loss: 1798.2318
# Train Epoch: 44 [0/3168 (0%)]	Loss: 1996.885469
# ====> Epoch: 44 Average loss: 1759.5434
# Train Epoch: 45 [0/3168 (0%)]	Loss: 1916.229687
# ====> Epoch: 45 Average loss: 1801.1294
# Train Epoch: 46 [0/3168 (0%)]	Loss: 3179.592500
# ====> Epoch: 46 Average loss: 2013.1364
# Train Epoch: 47 [0/3168 (0%)]	Loss: 5028.307187
# ====> Epoch: 47 Average loss: 2141.3056
# Train Epoch: 48 [0/3168 (0%)]	Loss: 3571.809688
# ====> Epoch: 48 Average loss: 1955.0174
# Train Epoch: 49 [0/3168 (0%)]	Loss: 3869.015625
# ====> Epoch: 49 Average loss: 2071.3085
# Train Epoch: 50 [0/3168 (0%)]	Loss: 3784.418750
# ====> Epoch: 50 Average loss: 2003.7767
# Train Epoch: 51 [0/3168 (0%)]	Loss: 3548.865000
# ====> Epoch: 51 Average loss: 2031.8722
# Train Epoch: 52 [0/3168 (0%)]	Loss: 3144.459688
# ====> Epoch: 52 Average loss: 1999.4035
# Train Epoch: 53 [0/3168 (0%)]	Loss: 2963.677813
# ====> Epoch: 53 Average loss: 2024.5806
# Train Epoch: 54 [0/3168 (0%)]	Loss: 2570.470938
# ====> Epoch: 54 Average loss: 1976.6920
# Train Epoch: 55 [0/3168 (0%)]	Loss: 2513.799844
# ====> Epoch: 55 Average loss: 1980.5015
# Train Epoch: 56 [0/3168 (0%)]	Loss: 2443.487813
# ====> Epoch: 56 Average loss: 2006.4380
# Train Epoch: 57 [0/3168 (0%)]	Loss: 2116.785625
# ====> Epoch: 57 Average loss: 1953.8645
# Train Epoch: 58 [0/3168 (0%)]	Loss: 2301.927344
# ====> Epoch: 58 Average loss: 2379.1873
# Train Epoch: 59 [0/3168 (0%)]	Loss: 3196.145000
# ====> Epoch: 59 Average loss: 2290.8306
# Train Epoch: 60 [0/3168 (0%)]	Loss: 4226.846875
# ====> Epoch: 60 Average loss: 2395.0209
# Train Epoch: 61 [0/3168 (0%)]	Loss: 2854.958437
# ====> Epoch: 61 Average loss: 2099.3430
# Train Epoch: 62 [0/3168 (0%)]	Loss: 1936.708281
# ====> Epoch: 62 Average loss: 2121.3147
# Train Epoch: 63 [0/3168 (0%)]	Loss: 3639.555000
# ====> Epoch: 63 Average loss: 2150.1857
# Train Epoch: 64 [0/3168 (0%)]	Loss: 1982.474688
# ====> Epoch: 64 Average loss: 2106.6097
# Train Epoch: 65 [0/3168 (0%)]	Loss: 1882.147813
# ====> Epoch: 65 Average loss: 1951.3757
# Train Epoch: 66 [0/3168 (0%)]	Loss: 2961.446875
# ====> Epoch: 66 Average loss: 1872.6806
# Train Epoch: 67 [0/3168 (0%)]	Loss: 3589.041875
# ====> Epoch: 67 Average loss: 1845.0660
# Train Epoch: 68 [0/3168 (0%)]	Loss: 2985.814063
# ====> Epoch: 68 Average loss: 1768.2261
# Train Epoch: 69 [0/3168 (0%)]	Loss: 1827.342500
# ====> Epoch: 69 Average loss: 1895.0491
# Train Epoch: 70 [0/3168 (0%)]	Loss: 3550.183125
# ====> Epoch: 70 Average loss: 1768.6158
# Train Epoch: 71 [0/3168 (0%)]	Loss: 2359.885000
# ====> Epoch: 71 Average loss: 1664.5919
# Train Epoch: 72 [0/3168 (0%)]	Loss: 3551.343438
# ====> Epoch: 72 Average loss: 1747.5511
# Train Epoch: 73 [0/3168 (0%)]	Loss: 3151.498125
# ====> Epoch: 73 Average loss: 1746.1541
# Train Epoch: 74 [0/3168 (0%)]	Loss: 2265.005156
# ====> Epoch: 74 Average loss: 1651.6974
# Train Epoch: 75 [0/3168 (0%)]	Loss: 1704.844063
# ====> Epoch: 75 Average loss: 1629.9310
# Train Epoch: 76 [0/3168 (0%)]	Loss: 1948.078906
# ====> Epoch: 76 Average loss: 1656.8438
# Train Epoch: 77 [0/3168 (0%)]	Loss: 1764.230625
# ====> Epoch: 77 Average loss: 1617.8987
# Train Epoch: 78 [0/3168 (0%)]	Loss: 1619.053750
# ====> Epoch: 78 Average loss: 1617.3199
# Train Epoch: 79 [0/3168 (0%)]	Loss: 1814.711094
# ====> Epoch: 79 Average loss: 1620.2980
# Train Epoch: 80 [0/3168 (0%)]	Loss: 2184.891094
# ====> Epoch: 80 Average loss: 1613.1184
# Train Epoch: 81 [0/3168 (0%)]	Loss: 1667.443125
# ====> Epoch: 81 Average loss: 1602.4861
# Train Epoch: 82 [0/3168 (0%)]	Loss: 1653.882969
# ====> Epoch: 82 Average loss: 1581.1789
# Train Epoch: 83 [0/3168 (0%)]	Loss: 1813.855000
# ====> Epoch: 83 Average loss: 1632.9135
# Train Epoch: 84 [0/3168 (0%)]	Loss: 2087.189219
# ====> Epoch: 84 Average loss: 1591.0771
# Train Epoch: 85 [0/3168 (0%)]	Loss: 1786.107031
# ====> Epoch: 85 Average loss: 1743.2439
# Train Epoch: 86 [0/3168 (0%)]	Loss: 1692.855781
# ====> Epoch: 86 Average loss: 1656.2500
# Train Epoch: 87 [0/3168 (0%)]	Loss: 1634.627031
# ====> Epoch: 87 Average loss: 1619.0189
# Train Epoch: 88 [0/3168 (0%)]	Loss: 1593.021875
# ====> Epoch: 88 Average loss: 1597.4964
# Train Epoch: 89 [0/3168 (0%)]	Loss: 1604.805000
# ====> Epoch: 89 Average loss: 1597.5805
# Train Epoch: 90 [0/3168 (0%)]	Loss: 1571.743750
# ====> Epoch: 90 Average loss: 1585.5234
# Train Epoch: 91 [0/3168 (0%)]	Loss: 1613.607500
# ====> Epoch: 91 Average loss: 1568.5198
# Train Epoch: 92 [0/3168 (0%)]	Loss: 1533.240156
# ====> Epoch: 92 Average loss: 1582.1117
# Train Epoch: 93 [0/3168 (0%)]	Loss: 1534.629062
# ====> Epoch: 93 Average loss: 1582.9191
# Train Epoch: 94 [0/3168 (0%)]	Loss: 1526.499844
# ====> Epoch: 94 Average loss: 1566.9772
# Train Epoch: 95 [0/3168 (0%)]	Loss: 1485.635937
# ====> Epoch: 95 Average loss: 1607.3147
# Train Epoch: 96 [0/3168 (0%)]	Loss: 1478.909375
# ====> Epoch: 96 Average loss: 1630.2450
# Train Epoch: 97 [0/3168 (0%)]	Loss: 1485.530469
# ====> Epoch: 97 Average loss: 1630.7657
# Train Epoch: 98 [0/3168 (0%)]	Loss: 1524.511094
# ====> Epoch: 98 Average loss: 1658.3816
# Train Epoch: 99 [0/3168 (0%)]	Loss: 1643.404063
# ====> Epoch: 99 Average loss: 1646.7078
# Train Epoch: 100 [0/3168 (0%)]	Loss: 1507.704844
# ====> Epoch: 100 Average loss: 1685.9544
# Train Epoch: 101 [0/3168 (0%)]	Loss: 1493.601094
# ====> Epoch: 101 Average loss: 1584.3455
# Train Epoch: 102 [0/3168 (0%)]	Loss: 1435.961406
# ====> Epoch: 102 Average loss: 1571.4702
# Train Epoch: 103 [0/3168 (0%)]	Loss: 1476.341875
# ====> Epoch: 103 Average loss: 1559.6107
# Train Epoch: 104 [0/3168 (0%)]	Loss: 1455.088906
# ====> Epoch: 104 Average loss: 1530.5776
# Train Epoch: 105 [0/3168 (0%)]	Loss: 1434.068906
# ====> Epoch: 105 Average loss: 1514.8211
# Train Epoch: 106 [0/3168 (0%)]	Loss: 1455.275938
# ====> Epoch: 106 Average loss: 1530.0159
# Train Epoch: 107 [0/3168 (0%)]	Loss: 1412.343437
# ====> Epoch: 107 Average loss: 1604.7209
# Train Epoch: 108 [0/3168 (0%)]	Loss: 1422.188437
# ====> Epoch: 108 Average loss: 1554.0601
# Train Epoch: 109 [0/3168 (0%)]	Loss: 1396.009531
# ====> Epoch: 109 Average loss: 1514.8239
# Train Epoch: 110 [0/3168 (0%)]	Loss: 1384.609531
# ====> Epoch: 110 Average loss: 1505.3534
# Train Epoch: 111 [0/3168 (0%)]	Loss: 1418.331719
# ====> Epoch: 111 Average loss: 1495.0274
# Train Epoch: 112 [0/3168 (0%)]	Loss: 1391.652031
# ====> Epoch: 112 Average loss: 1480.7011
# Train Epoch: 113 [0/3168 (0%)]	Loss: 1405.770937
# ====> Epoch: 113 Average loss: 1489.7108
# Train Epoch: 114 [0/3168 (0%)]	Loss: 1428.177813
# ====> Epoch: 114 Average loss: 1472.7722
# Train Epoch: 115 [0/3168 (0%)]	Loss: 1443.718125
# ====> Epoch: 115 Average loss: 1471.4103
# Train Epoch: 116 [0/3168 (0%)]	Loss: 1412.660469
# ====> Epoch: 116 Average loss: 1467.0541
# Train Epoch: 117 [0/3168 (0%)]	Loss: 1393.377031
# ====> Epoch: 117 Average loss: 1469.3487
# Train Epoch: 118 [0/3168 (0%)]	Loss: 1390.427969
# ====> Epoch: 118 Average loss: 1451.3939
# Train Epoch: 119 [0/3168 (0%)]	Loss: 1386.045156
# ====> Epoch: 119 Average loss: 1475.1927
# Train Epoch: 120 [0/3168 (0%)]	Loss: 1351.505312
# ====> Epoch: 120 Average loss: 1587.3596
# Train Epoch: 121 [0/3168 (0%)]	Loss: 1302.966250
# ====> Epoch: 121 Average loss: 1565.7748
# Train Epoch: 122 [0/3168 (0%)]	Loss: 1370.542344
# ====> Epoch: 122 Average loss: 1515.3529
# Train Epoch: 123 [0/3168 (0%)]	Loss: 1327.592187
# ====> Epoch: 123 Average loss: 1455.1764
# Train Epoch: 124 [0/3168 (0%)]	Loss: 1315.825781
# ====> Epoch: 124 Average loss: 1420.1719
# Train Epoch: 125 [0/3168 (0%)]	Loss: 1272.135703
# ====> Epoch: 125 Average loss: 1403.1396
# Train Epoch: 126 [0/3168 (0%)]	Loss: 1307.485859
# ====> Epoch: 126 Average loss: 1388.7524
# Train Epoch: 127 [0/3168 (0%)]	Loss: 1280.973438
# ====> Epoch: 127 Average loss: 1374.6746
# Train Epoch: 128 [0/3168 (0%)]	Loss: 1227.905313
# ====> Epoch: 128 Average loss: 1350.9265
# Train Epoch: 129 [0/3168 (0%)]	Loss: 1232.462812
# ====> Epoch: 129 Average loss: 1340.3553
# Train Epoch: 130 [0/3168 (0%)]	Loss: 1215.236953
# ====> Epoch: 130 Average loss: 1328.9792
# Train Epoch: 131 [0/3168 (0%)]	Loss: 1192.938672
# ====> Epoch: 131 Average loss: 1316.2126
# Train Epoch: 132 [0/3168 (0%)]	Loss: 1175.477578
# ====> Epoch: 132 Average loss: 1309.6486
# Train Epoch: 133 [0/3168 (0%)]	Loss: 1177.305391
# ====> Epoch: 133 Average loss: 1322.9254
# Train Epoch: 134 [0/3168 (0%)]	Loss: 1196.306172
# ====> Epoch: 134 Average loss: 1320.1639
# Train Epoch: 135 [0/3168 (0%)]	Loss: 1322.850000
# ====> Epoch: 135 Average loss: 1322.3456
# Train Epoch: 136 [0/3168 (0%)]	Loss: 1195.488516
# ====> Epoch: 136 Average loss: 1288.8522
# Train Epoch: 137 [0/3168 (0%)]	Loss: 1139.962266
# ====> Epoch: 137 Average loss: 1265.2486
# Train Epoch: 138 [0/3168 (0%)]	Loss: 1195.517266
# ====> Epoch: 138 Average loss: 1266.3465
# Train Epoch: 139 [0/3168 (0%)]	Loss: 1143.358203
# ====> Epoch: 139 Average loss: 1265.7638
# Train Epoch: 140 [0/3168 (0%)]	Loss: 1153.779609
# ====> Epoch: 140 Average loss: 1241.0147
# Train Epoch: 141 [0/3168 (0%)]	Loss: 1146.630156
# ====> Epoch: 141 Average loss: 1254.6094
# Train Epoch: 142 [0/3168 (0%)]	Loss: 1107.714609
# ====> Epoch: 142 Average loss: 1255.2765
# Train Epoch: 143 [0/3168 (0%)]	Loss: 1113.203359
# ====> Epoch: 143 Average loss: 1243.6670
# Train Epoch: 144 [0/3168 (0%)]	Loss: 1156.767812
# ====> Epoch: 144 Average loss: 1241.8061
# Train Epoch: 145 [0/3168 (0%)]	Loss: 1104.730781
# ====> Epoch: 145 Average loss: 1240.8101
# Train Epoch: 146 [0/3168 (0%)]	Loss: 1099.715547
# ====> Epoch: 146 Average loss: 1223.1421
# Train Epoch: 147 [0/3168 (0%)]	Loss: 1118.279219
# ====> Epoch: 147 Average loss: 1245.8772
# Train Epoch: 148 [0/3168 (0%)]	Loss: 1073.665000
# ====> Epoch: 148 Average loss: 1217.5917
# Train Epoch: 149 [0/3168 (0%)]	Loss: 1139.675313
# ====> Epoch: 149 Average loss: 1251.0633
# Train Epoch: 150 [0/3168 (0%)]	Loss: 1054.175391
# ====> Epoch: 150 Average loss: 1241.5005
# Train Epoch: 151 [0/3168 (0%)]	Loss: 1087.695234
# ====> Epoch: 151 Average loss: 1246.5559
# Train Epoch: 152 [0/3168 (0%)]	Loss: 1033.980859
# ====> Epoch: 152 Average loss: 1267.0212
# Train Epoch: 153 [0/3168 (0%)]	Loss: 1083.711875
# ====> Epoch: 153 Average loss: 1252.0657
# Train Epoch: 154 [0/3168 (0%)]	Loss: 1054.986797
# ====> Epoch: 154 Average loss: 1289.0487
# Train Epoch: 155 [0/3168 (0%)]	Loss: 1070.248672
# ====> Epoch: 155 Average loss: 1302.1453
# Train Epoch: 156 [0/3168 (0%)]	Loss: 1083.206328
# ====> Epoch: 156 Average loss: 1359.2996
# Train Epoch: 157 [0/3168 (0%)]	Loss: 1049.505938
# ====> Epoch: 157 Average loss: 1379.7014
# Train Epoch: 158 [0/3168 (0%)]	Loss: 1115.713516
# ====> Epoch: 158 Average loss: 1427.4706
# Train Epoch: 159 [0/3168 (0%)]	Loss: 1101.977422
# ====> Epoch: 159 Average loss: 1522.8583
# Train Epoch: 160 [0/3168 (0%)]	Loss: 1031.433828
# ====> Epoch: 160 Average loss: 1470.0130
# Train Epoch: 161 [0/3168 (0%)]	Loss: 1165.596406
# ====> Epoch: 161 Average loss: 1495.1221
# Train Epoch: 162 [0/3168 (0%)]	Loss: 1014.349766
# ====> Epoch: 162 Average loss: 1486.5451
# Train Epoch: 163 [0/3168 (0%)]	Loss: 980.445234
# ====> Epoch: 163 Average loss: 1421.9961
# Train Epoch: 164 [0/3168 (0%)]	Loss: 1133.373828
# ====> Epoch: 164 Average loss: 1432.2000
# Train Epoch: 165 [0/3168 (0%)]	Loss: 1706.165156
# ====> Epoch: 165 Average loss: 1431.2557
# Train Epoch: 166 [0/3168 (0%)]	Loss: 1737.757500
# ====> Epoch: 166 Average loss: 1595.5263
# Train Epoch: 167 [0/3168 (0%)]	Loss: 2416.632656
# ====> Epoch: 167 Average loss: 1853.4976
# Train Epoch: 168 [0/3168 (0%)]	Loss: 3418.734687
# ====> Epoch: 168 Average loss: 2387.8511
# Train Epoch: 169 [0/3168 (0%)]	Loss: 3899.534375
# ====> Epoch: 169 Average loss: 2756.5137
# Train Epoch: 170 [0/3168 (0%)]	Loss: 6096.637500
# ====> Epoch: 170 Average loss: 3169.9685
# Train Epoch: 171 [0/3168 (0%)]	Loss: 1759.425313
# ====> Epoch: 171 Average loss: 2179.6302
# Train Epoch: 172 [0/3168 (0%)]	Loss: 1218.357422
# ====> Epoch: 172 Average loss: 1753.0918
# Train Epoch: 173 [0/3168 (0%)]	Loss: 1513.003906
# ====> Epoch: 173 Average loss: 1539.8566
# Train Epoch: 174 [0/3168 (0%)]	Loss: 1837.198437
# ====> Epoch: 174 Average loss: 1470.2785
# Train Epoch: 175 [0/3168 (0%)]	Loss: 1103.156406
# ====> Epoch: 175 Average loss: 1327.2420
# Train Epoch: 176 [0/3168 (0%)]	Loss: 884.869297
# ====> Epoch: 176 Average loss: 1203.2063
# Train Epoch: 177 [0/3168 (0%)]	Loss: 983.814453
# ====> Epoch: 177 Average loss: 1170.8216
# Train Epoch: 178 [0/3168 (0%)]	Loss: 1093.228437
# ====> Epoch: 178 Average loss: 1177.9084
# Train Epoch: 179 [0/3168 (0%)]	Loss: 1131.744531
# ====> Epoch: 179 Average loss: 1178.5017
# Train Epoch: 180 [0/3168 (0%)]	Loss: 997.049844
# ====> Epoch: 180 Average loss: 1169.5395
# Train Epoch: 181 [0/3168 (0%)]	Loss: 929.257422
# ====> Epoch: 181 Average loss: 1149.2659
# Train Epoch: 182 [0/3168 (0%)]	Loss: 898.373906
# ====> Epoch: 182 Average loss: 1140.4605
# Train Epoch: 183 [0/3168 (0%)]	Loss: 889.446328
# ====> Epoch: 183 Average loss: 1131.7691
# Train Epoch: 184 [0/3168 (0%)]	Loss: 878.809453
# ====> Epoch: 184 Average loss: 1125.5023
# Train Epoch: 185 [0/3168 (0%)]	Loss: 867.398359
# ====> Epoch: 185 Average loss: 1123.6325
# Train Epoch: 186 [0/3168 (0%)]	Loss: 861.788125
# ====> Epoch: 186 Average loss: 1119.4412
# Train Epoch: 187 [0/3168 (0%)]	Loss: 854.493594
# ====> Epoch: 187 Average loss: 1115.0277
# Train Epoch: 188 [0/3168 (0%)]	Loss: 860.308984
# ====> Epoch: 188 Average loss: 1109.6386
# Train Epoch: 189 [0/3168 (0%)]	Loss: 864.824844
# ====> Epoch: 189 Average loss: 1102.9584
# Train Epoch: 190 [0/3168 (0%)]	Loss: 867.340469
# ====> Epoch: 190 Average loss: 1099.2977
# Train Epoch: 191 [0/3168 (0%)]	Loss: 868.195234
# ====> Epoch: 191 Average loss: 1098.4337
# Train Epoch: 192 [0/3168 (0%)]	Loss: 868.151562
# ====> Epoch: 192 Average loss: 1095.4119
# Train Epoch: 193 [0/3168 (0%)]	Loss: 874.942812
# ====> Epoch: 193 Average loss: 1094.7745
# Train Epoch: 194 [0/3168 (0%)]	Loss: 869.848047
# ====> Epoch: 194 Average loss: 1091.0725
# Train Epoch: 195 [0/3168 (0%)]	Loss: 871.587500
# ====> Epoch: 195 Average loss: 1092.2989
# Train Epoch: 196 [0/3168 (0%)]	Loss: 862.146172
# ====> Epoch: 196 Average loss: 1090.8257
# Train Epoch: 197 [0/3168 (0%)]	Loss: 867.793750
# ====> Epoch: 197 Average loss: 1088.5989
# Train Epoch: 198 [0/3168 (0%)]	Loss: 863.256484
# ====> Epoch: 198 Average loss: 1090.1860
# Train Epoch: 199 [0/3168 (0%)]	Loss: 856.248594
# ====> Epoch: 199 Average loss: 1092.3436
# Train Epoch: 200 [0/3168 (0%)]	Loss: 856.121250
# ====> Epoch: 200 Average loss: 1093.6007
# Train Epoch: 201 [0/3168 (0%)]	Loss: 862.138125
# ====> Epoch: 201 Average loss: 1094.0938
# Train Epoch: 202 [0/3168 (0%)]	Loss: 866.807500
# ====> Epoch: 202 Average loss: 1092.0324
# Train Epoch: 203 [0/3168 (0%)]	Loss: 864.371875
# ====> Epoch: 203 Average loss: 1087.4720
# Train Epoch: 204 [0/3168 (0%)]	Loss: 861.458750
# ====> Epoch: 204 Average loss: 1081.9544
# Train Epoch: 205 [0/3168 (0%)]	Loss: 863.152344
# ====> Epoch: 205 Average loss: 1076.0128
# Train Epoch: 206 [0/3168 (0%)]	Loss: 854.071797
# ====> Epoch: 206 Average loss: 1069.8983
# Train Epoch: 207 [0/3168 (0%)]	Loss: 849.046016
# ====> Epoch: 207 Average loss: 1068.2014
# Train Epoch: 208 [0/3168 (0%)]	Loss: 861.667969
# ====> Epoch: 208 Average loss: 1064.1229
# Train Epoch: 209 [0/3168 (0%)]	Loss: 868.300938
# ====> Epoch: 209 Average loss: 1060.4471
# Train Epoch: 210 [0/3168 (0%)]	Loss: 850.835312
# ====> Epoch: 210 Average loss: 1054.6241
# Train Epoch: 211 [0/3168 (0%)]	Loss: 847.341797
# ====> Epoch: 211 Average loss: 1054.7488
# Train Epoch: 212 [0/3168 (0%)]	Loss: 853.005391
# ====> Epoch: 212 Average loss: 1048.8521
# Train Epoch: 213 [0/3168 (0%)]	Loss: 846.441484
# ====> Epoch: 213 Average loss: 1050.2483
# Train Epoch: 214 [0/3168 (0%)]	Loss: 846.658281
# ====> Epoch: 214 Average loss: 1045.2112
# Train Epoch: 215 [0/3168 (0%)]	Loss: 844.061328
# ====> Epoch: 215 Average loss: 1046.1887
# Train Epoch: 216 [0/3168 (0%)]	Loss: 850.038203
# ====> Epoch: 216 Average loss: 1052.2856
# Train Epoch: 217 [0/3168 (0%)]	Loss: 835.478203
# ====> Epoch: 217 Average loss: 1056.3703
# Train Epoch: 218 [0/3168 (0%)]	Loss: 848.033359
# ====> Epoch: 218 Average loss: 1069.9149
# Train Epoch: 219 [0/3168 (0%)]	Loss: 862.221406
# ====> Epoch: 219 Average loss: 1079.0610
# Train Epoch: 220 [0/3168 (0%)]	Loss: 872.579062
# ====> Epoch: 220 Average loss: 1093.9451
# Train Epoch: 221 [0/3168 (0%)]	Loss: 900.243984
# ====> Epoch: 221 Average loss: 1116.2854
# Train Epoch: 222 [0/3168 (0%)]	Loss: 904.932031
# ====> Epoch: 222 Average loss: 1124.5353
# Train Epoch: 223 [0/3168 (0%)]	Loss: 956.530859
# ====> Epoch: 223 Average loss: 1142.4165
# Train Epoch: 224 [0/3168 (0%)]	Loss: 980.873359
# ====> Epoch: 224 Average loss: 1152.7709
# Train Epoch: 225 [0/3168 (0%)]	Loss: 943.025391
# ====> Epoch: 225 Average loss: 1165.0616
# Train Epoch: 226 [0/3168 (0%)]	Loss: 934.205938
# ====> Epoch: 226 Average loss: 1165.5948
# Train Epoch: 227 [0/3168 (0%)]	Loss: 931.742891
# ====> Epoch: 227 Average loss: 1171.3376
# Train Epoch: 228 [0/3168 (0%)]	Loss: 910.372891
# ====> Epoch: 228 Average loss: 1150.1017
# Train Epoch: 229 [0/3168 (0%)]	Loss: 882.683750
# ====> Epoch: 229 Average loss: 1130.3788
# Train Epoch: 230 [0/3168 (0%)]	Loss: 898.273516
# ====> Epoch: 230 Average loss: 1129.2713
# Train Epoch: 231 [0/3168 (0%)]	Loss: 1053.042656
# ====> Epoch: 231 Average loss: 1162.1013
# Train Epoch: 232 [0/3168 (0%)]	Loss: 1267.826875
# ====> Epoch: 232 Average loss: 1223.6487
# Train Epoch: 233 [0/3168 (0%)]	Loss: 1389.765938
# ====> Epoch: 233 Average loss: 1376.0906
# Train Epoch: 234 [0/3168 (0%)]	Loss: 2282.422031
# ====> Epoch: 234 Average loss: 1729.7413
# Train Epoch: 235 [0/3168 (0%)]	Loss: 2797.947500
# ====> Epoch: 235 Average loss: 2048.7920
# Train Epoch: 236 [0/3168 (0%)]	Loss: 4033.330625
# ====> Epoch: 236 Average loss: 2820.9792
# Train Epoch: 237 [0/3168 (0%)]	Loss: 4213.887813
# ====> Epoch: 237 Average loss: 2933.0060
# Train Epoch: 238 [0/3168 (0%)]	Loss: 2520.478906
# ====> Epoch: 238 Average loss: 2674.4874
# Train Epoch: 239 [0/3168 (0%)]	Loss: 1104.381875
# ====> Epoch: 239 Average loss: 2044.1986
# Train Epoch: 240 [0/3168 (0%)]	Loss: 1132.241719
# ====> Epoch: 240 Average loss: 1699.9612
# Train Epoch: 241 [0/3168 (0%)]	Loss: 1214.227422
# ====> Epoch: 241 Average loss: 1591.1749
# Train Epoch: 242 [0/3168 (0%)]	Loss: 1074.341797
# ====> Epoch: 242 Average loss: 1503.0131
# Train Epoch: 243 [0/3168 (0%)]	Loss: 820.786719
# ====> Epoch: 243 Average loss: 1260.2880
# Train Epoch: 244 [0/3168 (0%)]	Loss: 977.021875
# ====> Epoch: 244 Average loss: 1146.4912
# Train Epoch: 245 [0/3168 (0%)]	Loss: 1018.304531
# ====> Epoch: 245 Average loss: 1090.4315
# Train Epoch: 246 [0/3168 (0%)]	Loss: 1062.267812
# ====> Epoch: 246 Average loss: 1067.9086
# Train Epoch: 247 [0/3168 (0%)]	Loss: 1073.476250
# ====> Epoch: 247 Average loss: 1060.9201
# Train Epoch: 248 [0/3168 (0%)]	Loss: 883.867188
# ====> Epoch: 248 Average loss: 1049.3404
# Train Epoch: 249 [0/3168 (0%)]	Loss: 818.705391
# ====> Epoch: 249 Average loss: 1049.2642
# Train Epoch: 250 [0/3168 (0%)]	Loss: 807.988125
# ====> Epoch: 250 Average loss: 1055.2059
# Train Epoch: 251 [0/3168 (0%)]	Loss: 807.840156
# ====> Epoch: 251 Average loss: 1057.5266
# Train Epoch: 252 [0/3168 (0%)]	Loss: 803.701797
# ====> Epoch: 252 Average loss: 1057.0489
# Train Epoch: 253 [0/3168 (0%)]	Loss: 789.302500
# ====> Epoch: 253 Average loss: 1049.2255
# Train Epoch: 254 [0/3168 (0%)]	Loss: 789.907031
# ====> Epoch: 254 Average loss: 1037.2764
# Train Epoch: 255 [0/3168 (0%)]	Loss: 834.816016
# ====> Epoch: 255 Average loss: 1022.9683
# Train Epoch: 256 [0/3168 (0%)]	Loss: 871.003281
# ====> Epoch: 256 Average loss: 1016.7170
# Train Epoch: 257 [0/3168 (0%)]	Loss: 836.377734
# ====> Epoch: 257 Average loss: 1015.2217
# Train Epoch: 258 [0/3168 (0%)]	Loss: 832.453047
# ====> Epoch: 258 Average loss: 1014.7379
# Train Epoch: 259 [0/3168 (0%)]	Loss: 821.959141
# ====> Epoch: 259 Average loss: 1015.1365
# Train Epoch: 260 [0/3168 (0%)]	Loss: 804.288672
# ====> Epoch: 260 Average loss: 1015.5575
# Train Epoch: 261 [0/3168 (0%)]	Loss: 809.005703
# ====> Epoch: 261 Average loss: 1019.5025
# Train Epoch: 262 [0/3168 (0%)]	Loss: 802.768672
# ====> Epoch: 262 Average loss: 1020.4065
# Train Epoch: 263 [0/3168 (0%)]	Loss: 786.733359
# ====> Epoch: 263 Average loss: 1018.4775
# Train Epoch: 264 [0/3168 (0%)]	Loss: 782.746953
# ====> Epoch: 264 Average loss: 1019.7055
# Train Epoch: 265 [0/3168 (0%)]	Loss: 777.413281
# ====> Epoch: 265 Average loss: 1012.7913
# Train Epoch: 266 [0/3168 (0%)]	Loss: 778.707969
# ====> Epoch: 266 Average loss: 1003.8569
# Train Epoch: 267 [0/3168 (0%)]	Loss: 781.457734
# ====> Epoch: 267 Average loss: 997.9385
# Train Epoch: 268 [0/3168 (0%)]	Loss: 796.149297
# ====> Epoch: 268 Average loss: 998.7256
# Train Epoch: 269 [0/3168 (0%)]	Loss: 794.223125
# ====> Epoch: 269 Average loss: 995.0699
# Train Epoch: 270 [0/3168 (0%)]	Loss: 800.137734
# ====> Epoch: 270 Average loss: 994.6467
# Train Epoch: 271 [0/3168 (0%)]	Loss: 785.679531
# ====> Epoch: 271 Average loss: 993.2617
# Train Epoch: 272 [0/3168 (0%)]	Loss: 771.683516
# ====> Epoch: 272 Average loss: 993.5825
# Train Epoch: 273 [0/3168 (0%)]	Loss: 777.886328
# ====> Epoch: 273 Average loss: 996.2543
# Train Epoch: 274 [0/3168 (0%)]	Loss: 777.405156
# ====> Epoch: 274 Average loss: 999.9904
# Train Epoch: 275 [0/3168 (0%)]	Loss: 767.832734
# ====> Epoch: 275 Average loss: 1000.1040
# Train Epoch: 276 [0/3168 (0%)]	Loss: 779.531562
# ====> Epoch: 276 Average loss: 1001.9478
# Train Epoch: 277 [0/3168 (0%)]	Loss: 775.969844
# ====> Epoch: 277 Average loss: 1001.4326
# Train Epoch: 278 [0/3168 (0%)]	Loss: 782.654844
# ====> Epoch: 278 Average loss: 998.9127
# Train Epoch: 279 [0/3168 (0%)]	Loss: 769.153594
# ====> Epoch: 279 Average loss: 993.7903
# Train Epoch: 280 [0/3168 (0%)]	Loss: 771.707188
# ====> Epoch: 280 Average loss: 989.5658
# Train Epoch: 281 [0/3168 (0%)]	Loss: 766.952266
# ====> Epoch: 281 Average loss: 983.7796
# Train Epoch: 282 [0/3168 (0%)]	Loss: 775.631953
# ====> Epoch: 282 Average loss: 980.1259
# Train Epoch: 283 [0/3168 (0%)]	Loss: 779.375937
# ====> Epoch: 283 Average loss: 976.6663
# Train Epoch: 284 [0/3168 (0%)]	Loss: 777.370859
# ====> Epoch: 284 Average loss: 972.9380
# Train Epoch: 285 [0/3168 (0%)]	Loss: 776.073203
# ====> Epoch: 285 Average loss: 973.4739
# Train Epoch: 286 [0/3168 (0%)]	Loss: 782.446250
# ====> Epoch: 286 Average loss: 971.8191
# Train Epoch: 287 [0/3168 (0%)]	Loss: 776.633750
# ====> Epoch: 287 Average loss: 967.9393
# Train Epoch: 288 [0/3168 (0%)]	Loss: 783.245937
# ====> Epoch: 288 Average loss: 969.5080
# Train Epoch: 289 [0/3168 (0%)]	Loss: 771.583125
# ====> Epoch: 289 Average loss: 969.7959
# Train Epoch: 290 [0/3168 (0%)]	Loss: 763.658984
# ====> Epoch: 290 Average loss: 967.4420
# Train Epoch: 291 [0/3168 (0%)]	Loss: 761.037500
# ====> Epoch: 291 Average loss: 965.1215
# Train Epoch: 292 [0/3168 (0%)]	Loss: 756.547266
# ====> Epoch: 292 Average loss: 966.2466
# Train Epoch: 293 [0/3168 (0%)]	Loss: 763.921953
# ====> Epoch: 293 Average loss: 965.3675
# Train Epoch: 294 [0/3168 (0%)]	Loss: 760.735781
# ====> Epoch: 294 Average loss: 965.2883
# Train Epoch: 295 [0/3168 (0%)]	Loss: 764.927891
# ====> Epoch: 295 Average loss: 967.3020
# Train Epoch: 296 [0/3168 (0%)]	Loss: 758.941641
# ====> Epoch: 296 Average loss: 972.9635
# Train Epoch: 297 [0/3168 (0%)]	Loss: 765.527734
# ====> Epoch: 297 Average loss: 971.7624
# Train Epoch: 298 [0/3168 (0%)]	Loss: 780.080391
# ====> Epoch: 298 Average loss: 977.3262
# Train Epoch: 299 [0/3168 (0%)]	Loss: 767.195234
# ====> Epoch: 299 Average loss: 976.8521
# Train Epoch: 300 [0/3168 (0%)]	Loss: 786.661719
# ====> Epoch: 300 Average loss: 987.7772
# Train Epoch: 301 [0/3168 (0%)]	Loss: 796.760156
# ====> Epoch: 301 Average loss: 988.7462
# Train Epoch: 302 [0/3168 (0%)]	Loss: 762.615859
# ====> Epoch: 302 Average loss: 990.8566
# Train Epoch: 303 [0/3168 (0%)]	Loss: 770.854297
# ====> Epoch: 303 Average loss: 999.8459
# Train Epoch: 304 [0/3168 (0%)]	Loss: 780.486250
# ====> Epoch: 304 Average loss: 995.6306
# Train Epoch: 305 [0/3168 (0%)]	Loss: 796.908359
# ====> Epoch: 305 Average loss: 1013.4971
# Train Epoch: 306 [0/3168 (0%)]	Loss: 771.609766
# ====> Epoch: 306 Average loss: 1014.1015
# Train Epoch: 307 [0/3168 (0%)]	Loss: 773.900469
# ====> Epoch: 307 Average loss: 988.0256
# Train Epoch: 308 [0/3168 (0%)]	Loss: 766.967031
# ====> Epoch: 308 Average loss: 993.2743
# Train Epoch: 309 [0/3168 (0%)]	Loss: 763.881484
# ====> Epoch: 309 Average loss: 992.4990
# Train Epoch: 310 [0/3168 (0%)]	Loss: 778.034141
# ====> Epoch: 310 Average loss: 990.5381
# Train Epoch: 311 [0/3168 (0%)]	Loss: 779.437734
# ====> Epoch: 311 Average loss: 983.2253
# Train Epoch: 312 [0/3168 (0%)]	Loss: 765.604844
# ====> Epoch: 312 Average loss: 971.0339
# Train Epoch: 313 [0/3168 (0%)]	Loss: 846.656797
# ====> Epoch: 313 Average loss: 971.6507
# Train Epoch: 314 [0/3168 (0%)]	Loss: 889.205156
# ====> Epoch: 314 Average loss: 979.2249
# Train Epoch: 315 [0/3168 (0%)]	Loss: 902.971797
# ====> Epoch: 315 Average loss: 1002.9524
# Train Epoch: 316 [0/3168 (0%)]	Loss: 930.064609
# ====> Epoch: 316 Average loss: 1005.9539
# Train Epoch: 317 [0/3168 (0%)]	Loss: 1079.160312
# ====> Epoch: 317 Average loss: 1031.0826
# Train Epoch: 318 [0/3168 (0%)]	Loss: 1390.836875
# ====> Epoch: 318 Average loss: 1113.0731
# Train Epoch: 319 [0/3168 (0%)]	Loss: 1445.127031
# ====> Epoch: 319 Average loss: 1249.6168
# Train Epoch: 320 [0/3168 (0%)]	Loss: 1679.168281
# ====> Epoch: 320 Average loss: 1432.7027
# Train Epoch: 321 [0/3168 (0%)]	Loss: 2360.880312
# ====> Epoch: 321 Average loss: 1641.5037
# Train Epoch: 322 [0/3168 (0%)]	Loss: 3105.445312
# ====> Epoch: 322 Average loss: 2088.9528
# Train Epoch: 323 [0/3168 (0%)]	Loss: 3563.346875
# ====> Epoch: 323 Average loss: 2583.7605
# Train Epoch: 324 [0/3168 (0%)]	Loss: 3789.761250
# ====> Epoch: 324 Average loss: 2960.3446
# Train Epoch: 325 [0/3168 (0%)]	Loss: 1264.180547
# ====> Epoch: 325 Average loss: 3041.8675
# Train Epoch: 326 [0/3168 (0%)]	Loss: 1777.205000
# ====> Epoch: 326 Average loss: 2765.1367
# Train Epoch: 327 [0/3168 (0%)]	Loss: 1168.080000
# ====> Epoch: 327 Average loss: 2136.9737
# Train Epoch: 328 [0/3168 (0%)]	Loss: 1226.841641
# ====> Epoch: 328 Average loss: 1910.8584
# Train Epoch: 329 [0/3168 (0%)]	Loss: 957.752344
# ====> Epoch: 329 Average loss: 5725.2382
# Train Epoch: 330 [0/3168 (0%)]	Loss: 913.422422
# ====> Epoch: 330 Average loss: 1371.1546
# Train Epoch: 331 [0/3168 (0%)]	Loss: 1729.657969
# ====> Epoch: 331 Average loss: 1217.3851
# Train Epoch: 332 [0/3168 (0%)]	Loss: 1976.857812
# ====> Epoch: 332 Average loss: 1174.3282
# Train Epoch: 333 [0/3168 (0%)]	Loss: 1687.480469
# ====> Epoch: 333 Average loss: 1139.6607
# Train Epoch: 334 [0/3168 (0%)]	Loss: 1362.301875
# ====> Epoch: 334 Average loss: 1114.8639
# Train Epoch: 335 [0/3168 (0%)]	Loss: 1119.682578
# ====> Epoch: 335 Average loss: 1105.7692
# Train Epoch: 336 [0/3168 (0%)]	Loss: 1027.373359
# ====> Epoch: 336 Average loss: 1092.0477
# Train Epoch: 337 [0/3168 (0%)]	Loss: 976.523906
# ====> Epoch: 337 Average loss: 1072.6275
# Train Epoch: 338 [0/3168 (0%)]	Loss: 992.026797
# ====> Epoch: 338 Average loss: 1058.2470
# Train Epoch: 339 [0/3168 (0%)]	Loss: 1004.677578
# ====> Epoch: 339 Average loss: 1043.7275
# Train Epoch: 340 [0/3168 (0%)]	Loss: 1056.928984
# ====> Epoch: 340 Average loss: 1034.0709
# Train Epoch: 341 [0/3168 (0%)]	Loss: 1053.889453
# ====> Epoch: 341 Average loss: 1024.7823
# Train Epoch: 342 [0/3168 (0%)]	Loss: 1049.622656
# ====> Epoch: 342 Average loss: 1017.2044
# Train Epoch: 343 [0/3168 (0%)]	Loss: 1079.283906
# ====> Epoch: 343 Average loss: 1012.1324
# Train Epoch: 344 [0/3168 (0%)]	Loss: 1045.174297
# ====> Epoch: 344 Average loss: 1004.4083
# Train Epoch: 345 [0/3168 (0%)]	Loss: 1044.035156
# ====> Epoch: 345 Average loss: 1002.3299
# Train Epoch: 346 [0/3168 (0%)]	Loss: 997.041797
# ====> Epoch: 346 Average loss: 998.6607
# Train Epoch: 347 [0/3168 (0%)]	Loss: 989.414141
# ====> Epoch: 347 Average loss: 995.1207
# Train Epoch: 348 [0/3168 (0%)]	Loss: 922.657812
# ====> Epoch: 348 Average loss: 990.5737
# Train Epoch: 349 [0/3168 (0%)]	Loss: 922.221250
# ====> Epoch: 349 Average loss: 986.9975
# Train Epoch: 350 [0/3168 (0%)]	Loss: 898.794531
# ====> Epoch: 350 Average loss: 986.1932
# Train Epoch: 351 [0/3168 (0%)]	Loss: 862.195938
# ====> Epoch: 351 Average loss: 981.6627
# Train Epoch: 352 [0/3168 (0%)]	Loss: 842.536797
# ====> Epoch: 352 Average loss: 977.6846
# Train Epoch: 353 [0/3168 (0%)]	Loss: 817.570859
# ====> Epoch: 353 Average loss: 978.0008
# Train Epoch: 354 [0/3168 (0%)]	Loss: 802.193828
# ====> Epoch: 354 Average loss: 976.5851
# Train Epoch: 355 [0/3168 (0%)]	Loss: 788.000937
# ====> Epoch: 355 Average loss: 975.4312
# Train Epoch: 356 [0/3168 (0%)]	Loss: 787.534063
# ====> Epoch: 356 Average loss: 973.7353
# Train Epoch: 357 [0/3168 (0%)]	Loss: 771.529375
# ====> Epoch: 357 Average loss: 975.8841
# Train Epoch: 358 [0/3168 (0%)]	Loss: 764.311406
# ====> Epoch: 358 Average loss: 977.0416
# Train Epoch: 359 [0/3168 (0%)]	Loss: 754.914766
# ====> Epoch: 359 Average loss: 977.7327
# Train Epoch: 360 [0/3168 (0%)]	Loss: 755.483047
# ====> Epoch: 360 Average loss: 980.0118
# Train Epoch: 361 [0/3168 (0%)]	Loss: 754.987344
# ====> Epoch: 361 Average loss: 983.4166
# Train Epoch: 362 [0/3168 (0%)]	Loss: 755.487188
# ====> Epoch: 362 Average loss: 982.8894
# Train Epoch: 363 [0/3168 (0%)]	Loss: 752.321953
# ====> Epoch: 363 Average loss: 983.5744
# Train Epoch: 364 [0/3168 (0%)]	Loss: 751.698594
# ====> Epoch: 364 Average loss: 981.1114
# Train Epoch: 365 [0/3168 (0%)]	Loss: 754.837969
# ====> Epoch: 365 Average loss: 979.9987
# Train Epoch: 366 [0/3168 (0%)]	Loss: 758.187188
# ====> Epoch: 366 Average loss: 979.0531
# Train Epoch: 367 [0/3168 (0%)]	Loss: 753.400703
# ====> Epoch: 367 Average loss: 976.4200
# Train Epoch: 368 [0/3168 (0%)]	Loss: 751.601953
# ====> Epoch: 368 Average loss: 971.1782
# Train Epoch: 369 [0/3168 (0%)]	Loss: 743.934844
# ====> Epoch: 369 Average loss: 966.6238
# Train Epoch: 370 [0/3168 (0%)]	Loss: 738.549609
# ====> Epoch: 370 Average loss: 962.5457
# Train Epoch: 371 [0/3168 (0%)]	Loss: 730.879688
# ====> Epoch: 371 Average loss: 958.2110
# Train Epoch: 372 [0/3168 (0%)]	Loss: 730.637812
# ====> Epoch: 372 Average loss: 952.4305
# Train Epoch: 373 [0/3168 (0%)]	Loss: 735.463828
# ====> Epoch: 373 Average loss: 944.5010
# Train Epoch: 374 [0/3168 (0%)]	Loss: 740.112109
# ====> Epoch: 374 Average loss: 938.5906
# Train Epoch: 375 [0/3168 (0%)]	Loss: 751.617031
# ====> Epoch: 375 Average loss: 936.4709
# Train Epoch: 376 [0/3168 (0%)]	Loss: 784.206328
# ====> Epoch: 376 Average loss: 933.5396
# Train Epoch: 377 [0/3168 (0%)]	Loss: 812.702969
# ====> Epoch: 377 Average loss: 934.5203
# Train Epoch: 378 [0/3168 (0%)]	Loss: 841.194766
# ====> Epoch: 378 Average loss: 936.5099
# Train Epoch: 379 [0/3168 (0%)]	Loss: 840.772969
# ====> Epoch: 379 Average loss: 939.9973
# Train Epoch: 380 [0/3168 (0%)]	Loss: 819.876016
# ====> Epoch: 380 Average loss: 939.5861
# Train Epoch: 381 [0/3168 (0%)]	Loss: 869.487188
# ====> Epoch: 381 Average loss: 945.9402
# Train Epoch: 382 [0/3168 (0%)]	Loss: 858.124531
# ====> Epoch: 382 Average loss: 945.5241
# Train Epoch: 383 [0/3168 (0%)]	Loss: 852.329766
# ====> Epoch: 383 Average loss: 950.7693
# Train Epoch: 384 [0/3168 (0%)]	Loss: 851.577266
# ====> Epoch: 384 Average loss: 954.3781
# Train Epoch: 385 [0/3168 (0%)]	Loss: 864.581953
# ====> Epoch: 385 Average loss: 960.0070
# Train Epoch: 386 [0/3168 (0%)]	Loss: 884.586094
# ====> Epoch: 386 Average loss: 968.7717
# Train Epoch: 387 [0/3168 (0%)]	Loss: 874.681094
# ====> Epoch: 387 Average loss: 961.5162
# Train Epoch: 388 [0/3168 (0%)]	Loss: 866.725000
# ====> Epoch: 388 Average loss: 962.8580
# Train Epoch: 389 [0/3168 (0%)]	Loss: 847.459922
# ====> Epoch: 389 Average loss: 967.8740
# Train Epoch: 390 [0/3168 (0%)]	Loss: 854.154609
# ====> Epoch: 390 Average loss: 975.6768
# Train Epoch: 391 [0/3168 (0%)]	Loss: 840.960000
# ====> Epoch: 391 Average loss: 974.1811
# Train Epoch: 392 [0/3168 (0%)]	Loss: 838.355625
# ====> Epoch: 392 Average loss: 978.7314
# Train Epoch: 393 [0/3168 (0%)]	Loss: 764.391172
# ====> Epoch: 393 Average loss: 997.0874
# Train Epoch: 394 [0/3168 (0%)]	Loss: 753.669609
# ====> Epoch: 394 Average loss: 1038.8576
# Train Epoch: 395 [0/3168 (0%)]	Loss: 802.830938
# ====> Epoch: 395 Average loss: 1095.9628
# Train Epoch: 396 [0/3168 (0%)]	Loss: 898.772187
# ====> Epoch: 396 Average loss: 1175.3723
# Train Epoch: 397 [0/3168 (0%)]	Loss: 1003.769453
# ====> Epoch: 397 Average loss: 1237.4304
# Train Epoch: 398 [0/3168 (0%)]	Loss: 1259.750313
# ====> Epoch: 398 Average loss: 1354.7272
# Train Epoch: 399 [0/3168 (0%)]	Loss: 1266.848906
# ====> Epoch: 399 Average loss: 1472.4847
# Train Epoch: 400 [0/3168 (0%)]	Loss: 1543.233594
# ====> Epoch: 400 Average loss: 1565.7565
# Train Epoch: 401 [0/3168 (0%)]	Loss: 1827.638750
# ====> Epoch: 401 Average loss: 1637.4174
# Train Epoch: 402 [0/3168 (0%)]	Loss: 1706.652500
# ====> Epoch: 402 Average loss: 1623.9434
# Train Epoch: 403 [0/3168 (0%)]	Loss: 1148.148516
# ====> Epoch: 403 Average loss: 1581.7450
# Train Epoch: 404 [0/3168 (0%)]	Loss: 784.568125
# ====> Epoch: 404 Average loss: 1502.4776
# Train Epoch: 405 [0/3168 (0%)]	Loss: 943.707500
# ====> Epoch: 405 Average loss: 1390.0859
# Train Epoch: 406 [0/3168 (0%)]	Loss: 1718.576562
# ====> Epoch: 406 Average loss: 1430.4623
# Train Epoch: 407 [0/3168 (0%)]	Loss: 2673.104063
# ====> Epoch: 407 Average loss: 1590.1012
# Train Epoch: 408 [0/3168 (0%)]	Loss: 3257.391875
# ====> Epoch: 408 Average loss: 1729.2618
# Train Epoch: 409 [0/3168 (0%)]	Loss: 2647.821875
# ====> Epoch: 409 Average loss: 1662.9197
# Train Epoch: 410 [0/3168 (0%)]	Loss: 1985.907187
# ====> Epoch: 410 Average loss: 1488.5072
# Train Epoch: 411 [0/3168 (0%)]	Loss: 1324.987500
# ====> Epoch: 411 Average loss: 1265.8518
# Train Epoch: 412 [0/3168 (0%)]	Loss: 996.336953
# ====> Epoch: 412 Average loss: 1102.8295
# Train Epoch: 413 [0/3168 (0%)]	Loss: 797.830625
# ====> Epoch: 413 Average loss: 1007.7481
# Train Epoch: 414 [0/3168 (0%)]	Loss: 752.508359
# ====> Epoch: 414 Average loss: 971.6242
# Train Epoch: 415 [0/3168 (0%)]	Loss: 742.832031
# ====> Epoch: 415 Average loss: 955.1763
# Train Epoch: 416 [0/3168 (0%)]	Loss: 742.021172
# ====> Epoch: 416 Average loss: 942.2645
# Train Epoch: 417 [0/3168 (0%)]	Loss: 746.641953
# ====> Epoch: 417 Average loss: 937.1673
# Train Epoch: 418 [0/3168 (0%)]	Loss: 754.459297
# ====> Epoch: 418 Average loss: 930.1439
# Train Epoch: 419 [0/3168 (0%)]	Loss: 755.523594
# ====> Epoch: 419 Average loss: 920.0502
# Train Epoch: 420 [0/3168 (0%)]	Loss: 770.337813
# ====> Epoch: 420 Average loss: 911.1764
# Train Epoch: 421 [0/3168 (0%)]	Loss: 787.921953
# ====> Epoch: 421 Average loss: 909.1526
# Train Epoch: 422 [0/3168 (0%)]	Loss: 796.469922
# ====> Epoch: 422 Average loss: 905.6413
# Train Epoch: 423 [0/3168 (0%)]	Loss: 776.010703
# ====> Epoch: 423 Average loss: 903.3856
# Train Epoch: 424 [0/3168 (0%)]	Loss: 766.594062
# ====> Epoch: 424 Average loss: 901.4678
# Train Epoch: 425 [0/3168 (0%)]	Loss: 760.393828
# ====> Epoch: 425 Average loss: 901.8994
# Train Epoch: 426 [0/3168 (0%)]	Loss: 755.815234
# ====> Epoch: 426 Average loss: 900.1596
# Train Epoch: 427 [0/3168 (0%)]	Loss: 755.881406
# ====> Epoch: 427 Average loss: 899.1141
# Train Epoch: 428 [0/3168 (0%)]	Loss: 743.794297
# ====> Epoch: 428 Average loss: 898.6091
# Train Epoch: 429 [0/3168 (0%)]	Loss: 750.321250
# ====> Epoch: 429 Average loss: 900.5746
# Train Epoch: 430 [0/3168 (0%)]	Loss: 738.256172
# ====> Epoch: 430 Average loss: 902.6641
# Train Epoch: 431 [0/3168 (0%)]	Loss: 742.289922
# ====> Epoch: 431 Average loss: 903.5445
# Train Epoch: 432 [0/3168 (0%)]	Loss: 738.429141
# ====> Epoch: 432 Average loss: 904.8637
# Train Epoch: 433 [0/3168 (0%)]	Loss: 735.670781
# ====> Epoch: 433 Average loss: 902.4144
# Train Epoch: 434 [0/3168 (0%)]	Loss: 731.438594
# ====> Epoch: 434 Average loss: 904.7745
# Train Epoch: 435 [0/3168 (0%)]	Loss: 727.793281
# ====> Epoch: 435 Average loss: 902.1331
# Train Epoch: 436 [0/3168 (0%)]	Loss: 731.982188
# ====> Epoch: 436 Average loss: 900.8968
# Train Epoch: 437 [0/3168 (0%)]	Loss: 727.728281
# ====> Epoch: 437 Average loss: 899.4363
# Train Epoch: 438 [0/3168 (0%)]	Loss: 724.865547
# ====> Epoch: 438 Average loss: 898.4399
# Train Epoch: 439 [0/3168 (0%)]	Loss: 724.782500
# ====> Epoch: 439 Average loss: 893.0179
# Train Epoch: 440 [0/3168 (0%)]	Loss: 728.761719
# ====> Epoch: 440 Average loss: 890.3343
# Train Epoch: 441 [0/3168 (0%)]	Loss: 720.226562
# ====> Epoch: 441 Average loss: 888.0897
# Train Epoch: 442 [0/3168 (0%)]	Loss: 730.601797
# ====> Epoch: 442 Average loss: 887.6020
# Train Epoch: 443 [0/3168 (0%)]	Loss: 735.636797
# ====> Epoch: 443 Average loss: 886.7588
# Train Epoch: 444 [0/3168 (0%)]	Loss: 740.742813
# ====> Epoch: 444 Average loss: 886.0951
# Train Epoch: 445 [0/3168 (0%)]	Loss: 752.872344
# ====> Epoch: 445 Average loss: 887.1575
# Train Epoch: 446 [0/3168 (0%)]	Loss: 752.636406
# ====> Epoch: 446 Average loss: 885.7033
# Train Epoch: 447 [0/3168 (0%)]	Loss: 776.041016
# ====> Epoch: 447 Average loss: 893.5210
# Train Epoch: 448 [0/3168 (0%)]	Loss: 771.726562
# ====> Epoch: 448 Average loss: 888.3099
# Train Epoch: 449 [0/3168 (0%)]	Loss: 773.140625
# ====> Epoch: 449 Average loss: 894.3005
# Train Epoch: 450 [0/3168 (0%)]	Loss: 762.271953
# ====> Epoch: 450 Average loss: 895.3404
# Train Epoch: 451 [0/3168 (0%)]	Loss: 760.809531
# ====> Epoch: 451 Average loss: 900.9813
# Train Epoch: 452 [0/3168 (0%)]	Loss: 737.411562
# ====> Epoch: 452 Average loss: 906.5447
# Train Epoch: 453 [0/3168 (0%)]	Loss: 744.182422
# ====> Epoch: 453 Average loss: 910.0567
# Train Epoch: 454 [0/3168 (0%)]	Loss: 737.027891
# ====> Epoch: 454 Average loss: 923.7094
# Train Epoch: 455 [0/3168 (0%)]	Loss: 754.356094
# ====> Epoch: 455 Average loss: 944.0034
# Train Epoch: 456 [0/3168 (0%)]	Loss: 777.076328
# ====> Epoch: 456 Average loss: 977.4672
# Train Epoch: 457 [0/3168 (0%)]	Loss: 826.208125
# ====> Epoch: 457 Average loss: 1015.7787
# Train Epoch: 458 [0/3168 (0%)]	Loss: 943.762969
# ====> Epoch: 458 Average loss: 1084.8529
# Train Epoch: 459 [0/3168 (0%)]	Loss: 958.738047
# ====> Epoch: 459 Average loss: 1148.8488
# Train Epoch: 460 [0/3168 (0%)]	Loss: 970.172266
# ====> Epoch: 460 Average loss: 1184.6876
# Train Epoch: 461 [0/3168 (0%)]	Loss: 1065.632344
# ====> Epoch: 461 Average loss: 1229.6492
# Train Epoch: 462 [0/3168 (0%)]	Loss: 1087.944453
# ====> Epoch: 462 Average loss: 1322.3280
# Train Epoch: 463 [0/3168 (0%)]	Loss: 848.861094
# ====> Epoch: 463 Average loss: 1338.1088
# Train Epoch: 464 [0/3168 (0%)]	Loss: 833.970937
# ====> Epoch: 464 Average loss: 1310.1351
# Train Epoch: 465 [0/3168 (0%)]	Loss: 838.677031
# ====> Epoch: 465 Average loss: 1256.9844
# Train Epoch: 466 [0/3168 (0%)]	Loss: 1558.361094
# ====> Epoch: 466 Average loss: 1315.8161
# Train Epoch: 467 [0/3168 (0%)]	Loss: 2765.692812
# ====> Epoch: 467 Average loss: 1503.9663
# Train Epoch: 468 [0/3168 (0%)]	Loss: 2650.798750
# ====> Epoch: 468 Average loss: 1860.8948
# Train Epoch: 469 [0/3168 (0%)]	Loss: 4438.219375
# ====> Epoch: 469 Average loss: 2121.0655
# Train Epoch: 470 [0/3168 (0%)]	Loss: 2953.749688
# ====> Epoch: 470 Average loss: 2172.1497
# Train Epoch: 471 [0/3168 (0%)]	Loss: 1307.968672
# ====> Epoch: 471 Average loss: 1815.6212
# Train Epoch: 472 [0/3168 (0%)]	Loss: 829.091016
# ====> Epoch: 472 Average loss: 1318.7936
# Train Epoch: 473 [0/3168 (0%)]	Loss: 1020.388828
# ====> Epoch: 473 Average loss: 1145.9690
# Train Epoch: 474 [0/3168 (0%)]	Loss: 924.389375
# ====> Epoch: 474 Average loss: 1074.7619
# Train Epoch: 475 [0/3168 (0%)]	Loss: 758.901953
# ====> Epoch: 475 Average loss: 998.2736
# Train Epoch: 476 [0/3168 (0%)]	Loss: 733.574687
# ====> Epoch: 476 Average loss: 961.5929
# Train Epoch: 477 [0/3168 (0%)]	Loss: 807.126641
# ====> Epoch: 477 Average loss: 931.8527
# Train Epoch: 478 [0/3168 (0%)]	Loss: 875.280391
# ====> Epoch: 478 Average loss: 915.9803
# Train Epoch: 479 [0/3168 (0%)]	Loss: 844.708359
# ====> Epoch: 479 Average loss: 906.8040
# Train Epoch: 480 [0/3168 (0%)]	Loss: 842.423828
# ====> Epoch: 480 Average loss: 916.1087
# Train Epoch: 481 [0/3168 (0%)]	Loss: 746.270078
# ====> Epoch: 481 Average loss: 908.3709
# Train Epoch: 482 [0/3168 (0%)]	Loss: 726.950000
# ====> Epoch: 482 Average loss: 899.9155
# Train Epoch: 483 [0/3168 (0%)]	Loss: 723.916563
# ====> Epoch: 483 Average loss: 898.0609
# Train Epoch: 484 [0/3168 (0%)]	Loss: 724.484922
# ====> Epoch: 484 Average loss: 900.2502
# Train Epoch: 485 [0/3168 (0%)]	Loss: 726.285938
# ====> Epoch: 485 Average loss: 903.6911
# Train Epoch: 486 [0/3168 (0%)]	Loss: 737.209609
# ====> Epoch: 486 Average loss: 897.8811
# Train Epoch: 487 [0/3168 (0%)]	Loss: 736.798437
# ====> Epoch: 487 Average loss: 892.4056
# Train Epoch: 488 [0/3168 (0%)]	Loss: 737.694375
# ====> Epoch: 488 Average loss: 882.3131
# Train Epoch: 489 [0/3168 (0%)]	Loss: 736.889844
# ====> Epoch: 489 Average loss: 874.1565
# Train Epoch: 490 [0/3168 (0%)]	Loss: 754.012969
# ====> Epoch: 490 Average loss: 870.0554
# Train Epoch: 491 [0/3168 (0%)]	Loss: 754.744219
# ====> Epoch: 491 Average loss: 868.6380
# Train Epoch: 492 [0/3168 (0%)]	Loss: 745.107891
# ====> Epoch: 492 Average loss: 867.7444
# Train Epoch: 493 [0/3168 (0%)]	Loss: 738.491562
# ====> Epoch: 493 Average loss: 870.1833
# Train Epoch: 494 [0/3168 (0%)]	Loss: 733.583984
# ====> Epoch: 494 Average loss: 868.0754
# Train Epoch: 495 [0/3168 (0%)]	Loss: 731.632734
# ====> Epoch: 495 Average loss: 869.3163
# Train Epoch: 496 [0/3168 (0%)]	Loss: 735.389922
# ====> Epoch: 496 Average loss: 871.0134
# Train Epoch: 497 [0/3168 (0%)]	Loss: 720.820000
# ====> Epoch: 497 Average loss: 872.3728
# Train Epoch: 498 [0/3168 (0%)]	Loss: 719.065781
# ====> Epoch: 498 Average loss: 876.0557
# Train Epoch: 499 [0/3168 (0%)]	Loss: 719.758906
# ====> Epoch: 499 Average loss: 881.5182

# %%
def compare(dataset, model, VQ=True):
    model.eval()
    rec = []
    x = []
    with torch.no_grad():
        for i, data in enumerate(dataset):
            if VQ:
                x_rec, loss, mu, logvar = model(data)
            else:
                x_rec, mu, logvar = model(data)
            z = model.reparametrization_trick(mu, logvar)

            x.extend(data[:,:,0].detach().numpy())
            rec.extend(x_rec[:,:,0].detach().numpy())
        
    plt.plot(rec, "r--")
    plt.plot(x[:], "b-")
    plt.ylim(40,100)
    plt.grid(True)

# %%
v.cpu()
compare(train_data, v, VQ=True)
v.to(device)
# Out:
# VQ_MST_VAE(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Sequential(
#         (0): Linear(in_features=216, out_features=10, bias=True)
#       )
#       (encoder_logvar): Sequential(
#         (0): Linear(in_features=216, out_features=10, bias=True)
#       )
#     )
#     (long_encoder): TCVAE_Encoder(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(15,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Sequential(
#         (0): Linear(in_features=204, out_features=10, bias=True)
#       )
#       (encoder_logvar): Sequential(
#         (0): Linear(in_features=204, out_features=10, bias=True)
#       )
#     )
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(2, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(15,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=93, out_features=288, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(2, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=80, out_features=288, bias=True)
#     )
#   )
#   (quantizer): VQ_Quantizer(
#     (_embedding): Embedding(10, 1)
#   )
# )

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib
# matplotlib.use('Agg')
from dataGen import Gen
from utils import compare, experiment
from train import slidingWindow, criterion, train, test, objective, train_vae
from Encoders import LongShort_TCVAE_Encoder, RnnEncoder, MST_VAE_Encoder, MST_VAE_Encoder_dist
from Decoders import LongShort_TCVAE_Decoder, RnnDecoder, MST_VAE_Decoder, MST_VAE_Decoder_dist
from vae import VariationalAutoencoder, VQ_MST_VAE, VQ_Quantizer

import torch; torch.manual_seed(955)
import torch.optim as optim
import torch.distributions as D
from torch.utils.data import DataLoader
# import optuna
# from optuna.samplers import TPESampler
# import torchaudio

import torch.nn as nn
import torch.nn.functional as F
import torch.distributions as D


import numpy as np
import matplotlib.pyplot as plt
import pprint
# all parameters for generating the time series should be configured in this cell
periode = 15 #days
step = 5 # mess interval in minutes
val = 500
n_channels = 1
effects = {
    "Pulse": {
        "occurances":0,
        "max_amplitude":1.5,   
        "interval":40
        },
    "Trend": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        },
    "Seasonality": {
        "occurances":0,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
# pprint.pprint(params)
pprint.pprint(e_params)
X.show()

def lin_size(n, num_layers, first_kernel = None):
    
    for i in range(0, num_layers):
        
        if i == 0 and first_kernel != None:
            n = 1 + ((n - first_kernel) // 2)
        else:
            n = 1 + ((n - 2) // 2)
            
    if n <= 0:
        raise ValueError("Window Length is too small in relation to the number of Layers")
            
    return n * 2 * num_layers

class TCVAE_Encoder_unified(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None, modified=True):
        super(TCVAE_Encoder_unified, self).__init__()

        self.n = lin_size(L, num_layers, first_kernel)
        self.cnn_layers = nn.ModuleList()
        self.n_channels = input_size
        self.L = L
        self.num_layers = num_layers
        self.latent_dims = latent_dims
        self.modified = modified

        if self.modified:
            self.lin_input = self.n // (2 * self.num_layers)
            self.lin_output = self.latent_dims
        else:
            self.lin_input = self.n * self.n_channels
            self.lin_output = self.latent_dims * self.n_channels

        def init_weights(m):
            if isinstance(m, nn.Conv1d):
                torch.nn.init.kaiming_uniform_(m.weight, mode="fan_in", nonlinearity="leaky_relu")
                m.bias.data.fill_(0.01)

        # CNN Layers that double the channels each time
        for i in range(0, num_layers):
            if i == 0:
                if first_kernel == None: first_kernel = 2
                self.cnn_layers.append(
                    nn.Conv1d(input_size, input_size * 2, kernel_size=first_kernel, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size * 2))
            else:
                self.cnn_layers.append(
                    nn.Conv1d(input_size * 2 * i, input_size * 2 * (i + 1), kernel_size=2, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size * 2 * (i + 1)))

        # MLP Layers for Mu and logvar output
        self.encoder_mu = nn.Linear(self.lin_input, self.lin_output)
        self.encoder_logvar = nn.Linear(self.lin_input, self.lin_output)

        # Init CNN
        self.cnn_layers.apply(init_weights)

    def forward(self, x):
        ### CNN
        for i, cnn in enumerate(self.cnn_layers):
            #             print("Encoder Cnn", x.shape)
            x = cnn(x)
        cnn_shape = x.shape
        #         print("Encoder after Cnn ", x.shape)
        if not self.modified:
            x = x.view(x.size(0), -1)
        #             print("Encoder reshape after Cnn ", x.shape)
        # ### MLP
        mu = self.encoder_mu(x)
        logvar = self.encoder_logvar(x)
        #         print("Encoder mu after lin ", mu.shape)
        if not self.modified:
            mu = mu.view(mu.shape[0], self.n_channels, -1)
            logvar = logvar.view(logvar.shape[0], self.n_channels, -1)
        #             print("Encoder mu after reshape ", mu.shape)
        # mu.reshape

        return mu, logvar
    
class LongShort_TCVAE_Encoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None, modified=True,
                 reduction=False):
        super(LongShort_TCVAE_Encoder, self).__init__()
        self.latent_dims = latent_dims
        self.n_channels = input_size
        self._modified = modified
        self._reduction = reduction
        if modified:
            self.red_input = 2 * 2 * input_size * num_layers
        else:
            self.red_input = self.n_channels * 2

        self.short_encoder = TCVAE_Encoder_unified(input_size, num_layers, latent_dims, L, slope, first_kernel=None,
                                                   modified=self._modified)
        self.long_encoder = TCVAE_Encoder_unified(input_size, num_layers, latent_dims, L, slope, first_kernel,
                                                  modified=self._modified)

        self.reduction_layer = nn.Conv1d(self.red_input, self.red_input // 2, kernel_size=1, stride=1, padding=0)

    def forward(self, x):
        short_mu, short_logvar = self.short_encoder(x)
        long_mu, long_logvar = self.long_encoder(x)

        mu = torch.cat((short_mu, long_mu), axis=1)
        logvar = torch.cat((short_logvar, long_logvar), axis=1)

        # print("Short Encoder mu: ", short_mu.shape)
        # print("Long Encoder mu: ", long_mu.shape)
        #
        # print("After Cat: ", mu.shape)
        if self._reduction:
            mu = self.reduction_layer(mu)
            logvar = self.reduction_layer(logvar)

        return mu, logvar
    
class VQ_Quantizer(nn.Module):
    def __init__(self, num_embed, dim_embed, commit_loss, decay, epsilon=1e-5):
        super(VQ_Quantizer, self).__init__()

        self._num_embed = num_embed
        self._dim_embed = dim_embed
        self._commit_loss = commit_loss

        self._embedding = nn.Embedding(self._num_embed, self._dim_embed)
        self._embedding.weight.data.uniform_(-1 / self._num_embed, 1 / self._num_embed)

        self.register_buffer('_ema_cluster_size', torch.zeros(num_embed))
        self._ema_w = nn.Parameter(torch.Tensor(num_embed, dim_embed))
        self._ema_w.data.normal_()

        self._decay = decay
        self._epsilon = epsilon
        self._std = 0.8

    def forward(self, x):
        # x : BCL -> BLC
#         print(x.shape)
        x_shape = x.shape
        x = x.permute(0, 2, 1).contiguous()
        
#         print(x.shape)

        # flaten the input to have the Channels as embedding space
        x_flat = x.view(-1, self._dim_embed)
#         print(x_flat.shape)

        # Calculate the distance to embeddings

#         print("the non squared x", x_flat.shape )
#         print("the non squared embed weights", self._embedding.weight.t().shape)
#         print("the x ", torch.sum(x_flat**2, dim = 1, keepdim = True).shape)
#         print("the embed ", torch.sum(self._embedding.weight**2, dim = 1).shape)
#         print("the matmul ", torch.matmul(x_flat, self._embedding.weight.t()).shape)
        dist = (torch.sum(x_flat ** 2, dim=1, keepdim=True)
                + torch.sum(self._embedding.weight ** 2, dim=1)
                - 2 * torch.matmul(x_flat, self._embedding.weight.t()))
#         print(dist.shape)

        embed_indices = torch.argmin(dist, dim=1).unsqueeze(1)
#         print("embed indices",embed_indices)
        if self.training:
            noise = torch.randn(embed_indices.shape) * self._std
            noise = torch.round(noise).to(torch.int32).to(embed_indices)
            new_embed_indices = embed_indices + noise
            new_embed_indices = torch.clamp(new_embed_indices, max=self._num_embed-1, min =0)
#             embed_indices = new_embed_indices
        # print("noise ",noise.shape)
        # print("both together",new_embed_indices)
        embed_Matrix = torch.zeros_like(dist)
#         embed_Matrix = torch.zeros(embed_indices.shape[0], self._num_embed).to(x)
        #         print(embed_Matrix.shape)
        embed_Matrix.scatter_(1, embed_indices, 1)
#         print("embed_indices", embed_indices)
#         print("Embedding ", embed_Matrix.shape, embed_Matrix)
#         print("codebook", self._embedding.weight.shape, self._embedding.weight)
        

        # get the corresponding e vectors
        quantizer = torch.matmul(embed_Matrix, self._embedding.weight)
#         print("the quantizer", quantizer.shape, quantizer)
        quantizer = quantizer.view(x_shape).permute(0, 2, 1).contiguous()
#         print("the quantizer", quantizer.shape, quantizer)

        # Use EMA to update the embedding vectors
        if self.training:
            self._ema_cluster_size = self._ema_cluster_size * self._decay + \
                                     (1 - self._decay) * torch.sum(embed_Matrix, 0)

            # Laplace smoothing of the cluster size
            n = torch.sum(self._ema_cluster_size.data)
            self._ema_cluster_size = (
                    (self._ema_cluster_size + self._epsilon)
                    / (n + self._num_embed * self._epsilon) * n)

            dw = torch.matmul(embed_Matrix.t(), x_flat)
            self._ema_w = nn.Parameter(self._ema_w * self._decay + (1 - self._decay) * dw)

            self._embedding.weight = nn.Parameter(self._ema_w / self._ema_cluster_size.unsqueeze(1))
        #         print("quantizer ", quantizer.shape)

        # Loss
        #         first_loss = F.mse_loss(quantizer, x.detach())
        #         second_loss = F.mse_loss(quantizer.detach(), x)
        #         loss = first_loss + self._commit_loss * second_loss

        # Loss EMA
        e_loss = F.mse_loss(quantizer.detach(), x)
        loss = self._commit_loss * e_loss
        #         print(loss)

        # straigh-through gradient
        quantizer = x + (quantizer - x).detach()
        quantizer = quantizer.permute(0, 2, 1).contiguous()
        #         print("quantizer ", quantizer.shape)

        return quantizer, loss
    
class VQ_MST_VAE(nn.Module):
    def __init__(self, n_channels, num_layers, latent_dims, v_encoder, v_decoder, v_quantizer,
                 L=30,
                 slope=0.2,
                 first_kernel=None,
                 commit_loss=0.25,
                 modified=True,
                 reduction=False,
                 ):
        super(VQ_MST_VAE, self).__init__()

        self._n_channels = n_channels
        self._num_layers = num_layers
        self._latent_dims = latent_dims
        self._v_encoder = v_encoder
        self._v_decoder = v_decoder
        self._v_quantizer = v_quantizer
        self._L = L
        self._slope = slope
        self._first_kernel = first_kernel
        self._commit_loss = commit_loss
        self._reduction = reduction
        self._modified = modified
        if self._modified:
            self._num_embed = self._n_channels * 4 * self._num_layers
        else:
            self._num_embed = self._n_channels * 2
        if self._reduction:
            self._num_embed = self._num_embed // 2

        self.encoder = self._v_encoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope,
                                       self._first_kernel, self._modified, self._reduction)
        self.decoder = self._v_decoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope,
                                       self._first_kernel, self._modified, self._reduction)
        self.quantizer = self._v_quantizer(self._num_embed, self._latent_dims, self._commit_loss, decay=0.99,
                                           epsilon=1e-5)

        self.bn = nn.BatchNorm1d(self._num_embed)

    def reparametrization_trick(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu, logvar = self.encoder(x)

        z = self.reparametrization_trick(mu, logvar)
        # print(z.shape)
        # z = self.bn(self.quantizer._embedding.weight[None,:])
        # is_larger = torch.all(torch.gt(z[0], self.quantizer._embedding.weight))
        # print(z.shape)
        # print("Is encoder output larger than the set of vectors?", is_larger)
        e, loss_quantize = self.quantizer(z)

        # print("----------------Encoder Output-------------")
        # print("mu and logvar", mu.shape, logvar.shape)
        # print("----------------Reparametrization-------------")
        # print("Z", z.shape)
        # print("----------------Quantizer-------------")
        # print("quantized shape", e.shape)
#         print("loss shape", loss_quantize)

        #         mu_dec, logvar_dec = self.decoder(e)
        #         x_rec = self.reparametrization_trick(mu_dec, mu_dec)
        x_rec, mu_rec, logvar_rec = self.decoder(e)
        loss_rec = F.mse_loss(x_rec, x, reduction='sum')
        loss = loss_rec + loss_quantize

        # print("----------------Decoding-------------")
        # print("----------------Decoder Output-------------")
        # # print("mu and logvar Decoder", mu_dec.shape, logvar_dec.shape)
        # print("rec shape", x_rec.shape)
        return x_rec, loss, mu, logvar, mu_rec, logvar_rec
# Out:
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}

# %%
class TCVAE_Decoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None, modified=True, reduction= True):
        super(TCVAE_Decoder, self).__init__()

        def init_weights(m):
            if isinstance(m, nn.Conv1d):
                torch.nn.init.kaiming_uniform_(m.weight, mode="fan_in", nonlinearity="leaky_relu")
                m.bias.data.fill_(0.01)

        self.n_channels = input_size
        self.latent_dims = latent_dims
        self.first_kernel = first_kernel
        self.num_layers = num_layers
        self.n = lin_size(L, num_layers, first_kernel)

        self.modified = modified
        self.reduction = reduction
        self.cnn_layers = nn.ModuleList()
        self.decoder_input = self.n_channels
        if not self.reduction:
            self.decoder_input = self.decoder_input*2

        if self.first_kernel == None:
            first_kernel = 2
        else:
            first_kernel = self.first_kernel
        input_lin = self.latent_dims * 2 ** (self.num_layers - 1) + first_kernel - 2
#         input_lin = input_lin *2

        if self.modified:
            self.cnn_input = self.decoder_input * self.num_layers * 2
#             input_lin = input_lin // 2
            print(self.n_channels)
            print(self.cnn_input)
            # CNN Layers that double the channels each time
            for i in range(0, num_layers):
                if i == 0:
                    if first_kernel == None: first_kernel = 2
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input, self.cnn_input // 2, kernel_size=2, stride=2, padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // 2))
                elif i == num_layers - 1:
                    if first_kernel == None: first_kernel = 2
                    if self.reduction:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input // (2 * i), self.cnn_input // (2 * (i + 1)),
                                               kernel_size=first_kernel, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // (2 * (i + 1))))
                    else:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input // (2 * i), self.cnn_input // (4 * (i + 1)),
                                               kernel_size=first_kernel, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // (4 * (i + 1))))
                else:
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input // (2 * i), self.cnn_input // (2 * (i + 1)), kernel_size=2,
                                           stride=2, padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // (2 * (i + 1))))
        else:
            self.cnn_input = self.n_channels
            for i in range(0, num_layers):
                if i == 0:
                    if first_kernel == None: first_kernel = 2
                    if self.reduction:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input, self.cnn_input, kernel_size=2, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))
                    else:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input * 2, self.cnn_input, kernel_size=2, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))
                elif i == num_layers - 1:
                    if first_kernel == None: first_kernel = 2
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input, self.cnn_input, kernel_size=first_kernel, stride=2,
                                           padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))
                else:
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input, self.cnn_input, kernel_size=2, stride=2, padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))

        self.decoder_lin = nn.Linear(input_lin, L)
        # MLP Layers for Mu and logvar output
        self.decoder_mu = nn.Linear(input_lin, L)
        self.decoder_logvar = nn.Linear(input_lin, L)

        # Init CNN
        self.cnn_layers.apply(init_weights)

    def forward(self, x):
        # print("Decoder Input ", x.shape)
        #         x = x.view(x.shape[0], x.shape[1]* x.shape[2], -1)
        #         print("Decoder Input reshaped ",x.shape)
        #         x = self.decoder_lin(z)
        #         print("Decoder Input after lin ",x.shape)
        #         x = x.view(x.shape[0],x.shape[1],1)
        #         print("Decoder Input reshaped again",x.shape)

        for i, cnn in enumerate(self.cnn_layers):
            # print("Decoder Cnn ", x.shape)
            x = cnn(x)
          ########################################################################## Put back for old decoder  
#         #         print("Decoder shape after Cnn, should be reshaped? ", x.shape)
#         x = self.decoder_lin(x)
#         #         print("Decoder after lin ", x.shape)
        

#         return x
        ###################################################################################################################
        cnn_shape = x.shape
#         print("Decoder after Cnn ", x.shape)
#         if not self.modified:
#             x = x.view(x.size(0), -1)
#             print("Decoder reshape after Cnn ", x.shape)
        # ### MLP
        mu = self.decoder_mu(x)
        logvar = self.decoder_logvar(x)
#         print("Decoder mu after lin ", mu.shape)
        if not self.modified:
            mu = mu.view(mu.shape[0], self.n_channels, -1)
            logvar = logvar.view(logvar.shape[0], self.n_channels, -1)
#             print("Encoder mu after reshape ", mu.shape)
        # mu.reshape

        return mu, logvar

# %%
class LongShort_TCVAE_Decoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None,
                 modified=True, reduction=False):
        super(LongShort_TCVAE_Decoder, self).__init__()

        self._modified = modified
        self._reduction = reduction
        # if not self._reduction:
        #     input_size = input_size * 2
        # print("input to decoder", input_size)

        self.longshort_decoder = TCVAE_Decoder(input_size, num_layers, 2 * latent_dims, L, slope,
                                               first_kernel, modified=self._modified, reduction=self._reduction)

        self.short_decoder = TCVAE_Decoder(input_size, num_layers, 2 * latent_dims, L, slope,
                                           first_kernel=None, modified=self._modified, reduction=self._reduction)

        self.reduction_layer = nn.Conv1d(2 * input_size, input_size, kernel_size=1, stride=1, padding=0)
        
    def reparametrization_trick(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, z):
        ################################### old decoder ############################################################
#         x_long = self.longshort_decoder(z)
#         x_short = self.short_decoder(z)
#         # print("x_long ", x_long.shape)
#         # print("x_short ", x_short.shape)

#         x = torch.cat((x_short, x_long), dim=1)  # B.2C.L
#         # print("x_cat ", x.shape)
#         # if self._reduction:
#         x = self.reduction_layer(x)
#         # print("x_red ", x.shape)
#         return x
        #################################################################################################################
        short_mu, short_logvar = self.short_decoder(z)
        long_mu, long_logvar = self.longshort_decoder(z)

        mu = torch.cat((short_mu, long_mu), axis=1)
        logvar = torch.cat((short_logvar, long_logvar), axis=1)

#         print("Short Decoder mu: ", short_mu.shape)
#         print("Long Decoder mu: ", long_mu.shape)
        
#         print("After Cat: ", mu.shape)
#         if self._reduction:
        mu = self.reduction_layer(mu)
        logvar = self.reduction_layer(logvar)
        x = self.reparametrization_trick(mu, logvar)
        return x, mu, logvar

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
class slidingWindow(Dataset):
    def __init__(self, data, L):
        self.data = data
        self.L = L

    def __getitem__(self, index):
        if self.data.shape[1] - index >= self.L:            
            x = self.data[:,index:index+self.L]    
            v = torch.sum(x/self.L, axis=1).unsqueeze(1)
#             print(x.shape)
#             print(v.unsqueeze(1).shape)
            x = x#/v
            return (x, v)
        
    def __len__(self):
        return self.data.shape[1] - self.L
    
### Cost function
def criterion(recon_x, x, mu, logvar):
    ### reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')

    ### KL divergence loss
    kld_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    ### total loss
    loss = recon_loss + 1*kld_loss
    return loss

def sample_mean(model, batch, n):
    batch_size = batch.shape[0]
    n_channels = batch.shape[1]
    latent_dims = model.encoder.latent_dims
    L = model._L

    mu, logvar = (torch.empty((batch_size, 2 * n_channels, latent_dims, 0)).to(batch) for _ in range(2))
    REC = torch.empty(batch_size, n_channels, L, 0).to(batch)
#     print(REC.shape)
#     print(mu.shape)

    for i in range(n):
        rec, _mu, _logvar = model(batch)

        REC = torch.cat((REC, rec.unsqueeze(-1)), dim=-1)
        mu = torch.cat((mu, _mu.unsqueeze(-1)), dim=-1)
        logvar = torch.cat((logvar, _logvar.unsqueeze(-1)), dim=-1)

    # print("shapes after cat: mu, logvar, REC ", mu.shape, logvar.shape, REC.shape)
    mu, logvar = (torch.mean(t, dim=-1) for t in [mu, logvar])
    REC = torch.mean(REC, dim=-1)
    #     print("shapes after mean: mu, logvar, REC ", mu.shape, logvar.shape, REC.shape)

    return REC, mu, logvar

def train(model, train_loader, criterion, optimizer, device, epoch, VQ = True):
    model.train()
    train_loss = 0
    
    for batch_idx, (data, v) in enumerate(train_loader):
        
        data = data.to(device)
        v = v.to(device)
        optimizer.zero_grad()        

        if VQ:
            x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
        else:
#             x_rec, mu, logvar = model(data)
            x_rec, mu, logvar = sample_mean(model, data, 10)
            if v.dim() == 1:
                v = v.unsqueeze(-1)
                v = v.unsqueeze(-1)
            # x_rec_window_length = x_rec.shape[2]
            loss = criterion((x_rec*v)[:,:,0], data[:,:,0], mu, logvar)
        # print(x_rec.shape)
        # print(data[:, :, 0].shape)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(train_loader.dataset)))
    
    return  train_loss / len(train_loader.dataset)

# %%
### Init Model
latent_dims = 7 # 6 # 17
L= 3455# 39 #32
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# v = vae(n_channels, L, latent_dims)
# v = VariationalAutoencoder(input_size = n_channels,
#                       hidden_size = 30,
#                       num_layers = 3,
#                       latent_dims= latent_dims,
#                       v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder, # RnnEncoder, LongShort_TCVAE_Encoder,
#                       v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder, # RnnDecoder, LongShort_TCVAE_Decoder,
#                       L = L,
#                       slope = 0.2,
#                       first_kernel = 21)
v = VQ_MST_VAE(n_channels = n_channels,
                            num_layers =  3,#4, #3
                            latent_dims= latent_dims,
                            v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
                            v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
                            v_quantizer = VQ_Quantizer,
                            L=L,
                            slope = 0,
                            first_kernel = 30, #11, #20
                            commit_loss = 2,
                            modified=False,
                            reduction = True) #10 5
enc = MST_VAE_Encoder_dist(     n_channels,
                           num_layers = 3,
                           slope = 0.2,
                           first_kernel = 15)
dec = MST_VAE_Decoder_dist(     n_channels,
                           num_layers = 3,
                           slope = 0.2,
                           first_kernel = 15)


v = v.to(device)
enc = enc.to(device)
dec = dec.to(device)
opt = optim.Adam(v.parameters(), lr = 0.005043529186448577) # 0.005043529186448577 0.006819850049647945
print(v)
# Create the dictionaries of probability distributions
# pnet = {'z': D.Normal(loc=torch.zeros(latent_dims), scale=torch.ones(latent_dims)), 'x': dec}
# qnet = {'z': enc}
# serie = torch.tensor(serie).float()
x = torch.FloatTensor(x)

# x = F.normalize(x, p=2, dim=1)
n = x.shape[1]
# L = 30

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

train_data = DataLoader(slidingWindow(train_, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=22,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=22,
                        shuffle = False
                        )
# Out:
# VQ_MST_VAE(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=2586, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=2586, out_features=7, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(30,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=2568, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=2568, out_features=7, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(30,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=84, out_features=3455, bias=True)
#       (decoder_mu): Linear(in_features=84, out_features=3455, bias=True)
#       (decoder_logvar): Linear(in_features=84, out_features=3455, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=56, out_features=3455, bias=True)
#       (decoder_mu): Linear(in_features=56, out_features=3455, bias=True)
#       (decoder_logvar): Linear(in_features=56, out_features=3455, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (quantizer): VQ_Quantizer(
#     (_embedding): Embedding(1, 7)
#   )
#   (bn): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
effects = {
    "Pulse": {
        "occurances":0,
        "max_amplitude":1.5,   
        "interval":40
        },
    "Trend": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        },
    "Seasonality": {
        "occurances":0,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
# pprint.pprint(params)
pprint.pprint(e_params)
X.show()
x = torch.FloatTensor(x)

# x = F.normalize(x, p=2, dim=1)
n = x.shape[1]
# L = 30

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

train_data = DataLoader(slidingWindow(train_, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=22,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=22,
                        shuffle = False
                        )
# Out:
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}

# %%
for epoch in range(1, 1000):
    train(v, train_data, criterion, opt, device, epoch, VQ = True)
# Out:
# Train Epoch: 1 [0/1 (0%)]	Loss: 101.984367
# ====> Epoch: 1 Average loss: 101.9844
# Train Epoch: 2 [0/1 (0%)]	Loss: 111.771980
# ====> Epoch: 2 Average loss: 111.7720
# Train Epoch: 3 [0/1 (0%)]	Loss: 102.789459
# ====> Epoch: 3 Average loss: 102.7895
# Train Epoch: 4 [0/1 (0%)]	Loss: 81.927788
# ====> Epoch: 4 Average loss: 81.9278
# Train Epoch: 5 [0/1 (0%)]	Loss: 109.465927
# ====> Epoch: 5 Average loss: 109.4659
# Train Epoch: 6 [0/1 (0%)]	Loss: 87.443222
# ====> Epoch: 6 Average loss: 87.4432
# Train Epoch: 7 [0/1 (0%)]	Loss: 96.259125
# ====> Epoch: 7 Average loss: 96.2591
# Train Epoch: 8 [0/1 (0%)]	Loss: 85.107941
# ====> Epoch: 8 Average loss: 85.1079
# Train Epoch: 9 [0/1 (0%)]	Loss: 98.499695
# ====> Epoch: 9 Average loss: 98.4997
# Train Epoch: 10 [0/1 (0%)]	Loss: 128.911896
# ====> Epoch: 10 Average loss: 128.9119
# Train Epoch: 11 [0/1 (0%)]	Loss: 90.365112
# ====> Epoch: 11 Average loss: 90.3651
# Train Epoch: 12 [0/1 (0%)]	Loss: 107.537674
# ====> Epoch: 12 Average loss: 107.5377
# Train Epoch: 13 [0/1 (0%)]	Loss: 78.675751
# ====> Epoch: 13 Average loss: 78.6758
# Train Epoch: 14 [0/1 (0%)]	Loss: 92.732903
# ====> Epoch: 14 Average loss: 92.7329
# Train Epoch: 15 [0/1 (0%)]	Loss: 102.629471
# ====> Epoch: 15 Average loss: 102.6295
# Train Epoch: 16 [0/1 (0%)]	Loss: 85.561401
# ====> Epoch: 16 Average loss: 85.5614
# Train Epoch: 17 [0/1 (0%)]	Loss: 97.018509
# ====> Epoch: 17 Average loss: 97.0185
# Train Epoch: 18 [0/1 (0%)]	Loss: 90.612602
# ====> Epoch: 18 Average loss: 90.6126
# Train Epoch: 19 [0/1 (0%)]	Loss: 102.234695
# ====> Epoch: 19 Average loss: 102.2347
# Train Epoch: 20 [0/1 (0%)]	Loss: 94.826187
# ====> Epoch: 20 Average loss: 94.8262
# Train Epoch: 21 [0/1 (0%)]	Loss: 111.192528
# ====> Epoch: 21 Average loss: 111.1925
# Train Epoch: 22 [0/1 (0%)]	Loss: 103.687737
# ====> Epoch: 22 Average loss: 103.6877
# Train Epoch: 23 [0/1 (0%)]	Loss: 93.752640
# ====> Epoch: 23 Average loss: 93.7526
# Train Epoch: 24 [0/1 (0%)]	Loss: 90.636078
# ====> Epoch: 24 Average loss: 90.6361
# Train Epoch: 25 [0/1 (0%)]	Loss: 103.635574
# ====> Epoch: 25 Average loss: 103.6356
# Train Epoch: 26 [0/1 (0%)]	Loss: 93.780762
# ====> Epoch: 26 Average loss: 93.7808
# Train Epoch: 27 [0/1 (0%)]	Loss: 110.511574
# ====> Epoch: 27 Average loss: 110.5116
# Train Epoch: 28 [0/1 (0%)]	Loss: 95.564156
# ====> Epoch: 28 Average loss: 95.5642
# Train Epoch: 29 [0/1 (0%)]	Loss: 80.616875
# ====> Epoch: 29 Average loss: 80.6169
# Train Epoch: 30 [0/1 (0%)]	Loss: 103.504311
# ====> Epoch: 30 Average loss: 103.5043
# Train Epoch: 31 [0/1 (0%)]	Loss: 114.834396
# ====> Epoch: 31 Average loss: 114.8344
# Train Epoch: 32 [0/1 (0%)]	Loss: 141.464111
# ====> Epoch: 32 Average loss: 141.4641
# Train Epoch: 33 [0/1 (0%)]	Loss: 101.257935
# ====> Epoch: 33 Average loss: 101.2579
# Train Epoch: 34 [0/1 (0%)]	Loss: 104.005524
# ====> Epoch: 34 Average loss: 104.0055
# Train Epoch: 35 [0/1 (0%)]	Loss: 93.820534
# ====> Epoch: 35 Average loss: 93.8205
# Train Epoch: 36 [0/1 (0%)]	Loss: 93.261978
# ====> Epoch: 36 Average loss: 93.2620
# Train Epoch: 37 [0/1 (0%)]	Loss: 91.795677
# ====> Epoch: 37 Average loss: 91.7957
# Train Epoch: 38 [0/1 (0%)]	Loss: 118.654663
# ====> Epoch: 38 Average loss: 118.6547
# Train Epoch: 39 [0/1 (0%)]	Loss: 120.129051
# ====> Epoch: 39 Average loss: 120.1291
# Train Epoch: 40 [0/1 (0%)]	Loss: 88.551468
# ====> Epoch: 40 Average loss: 88.5515
# Train Epoch: 41 [0/1 (0%)]	Loss: 96.754242
# ====> Epoch: 41 Average loss: 96.7542
# Train Epoch: 42 [0/1 (0%)]	Loss: 92.587196
# ====> Epoch: 42 Average loss: 92.5872
# Train Epoch: 43 [0/1 (0%)]	Loss: 99.857689
# ====> Epoch: 43 Average loss: 99.8577
# Train Epoch: 44 [0/1 (0%)]	Loss: 93.895882
# ====> Epoch: 44 Average loss: 93.8959
# Train Epoch: 45 [0/1 (0%)]	Loss: 109.168999
# ====> Epoch: 45 Average loss: 109.1690
# Train Epoch: 46 [0/1 (0%)]	Loss: 97.756180
# ====> Epoch: 46 Average loss: 97.7562
# Train Epoch: 47 [0/1 (0%)]	Loss: 106.063896
# ====> Epoch: 47 Average loss: 106.0639
# Train Epoch: 48 [0/1 (0%)]	Loss: 109.820656
# ====> Epoch: 48 Average loss: 109.8207
# Train Epoch: 49 [0/1 (0%)]	Loss: 96.833298
# ====> Epoch: 49 Average loss: 96.8333
# Train Epoch: 50 [0/1 (0%)]	Loss: 109.049301
# ====> Epoch: 50 Average loss: 109.0493
# Train Epoch: 51 [0/1 (0%)]	Loss: 85.573784
# ====> Epoch: 51 Average loss: 85.5738
# Train Epoch: 52 [0/1 (0%)]	Loss: 90.327797
# ====> Epoch: 52 Average loss: 90.3278
# Train Epoch: 53 [0/1 (0%)]	Loss: 94.378044
# ====> Epoch: 53 Average loss: 94.3780
# Train Epoch: 54 [0/1 (0%)]	Loss: 127.728851
# ====> Epoch: 54 Average loss: 127.7289
# Train Epoch: 55 [0/1 (0%)]	Loss: 121.250771
# ====> Epoch: 55 Average loss: 121.2508
# Train Epoch: 56 [0/1 (0%)]	Loss: 81.709969
# ====> Epoch: 56 Average loss: 81.7100
# Train Epoch: 57 [0/1 (0%)]	Loss: 81.110786
# ====> Epoch: 57 Average loss: 81.1108
# Train Epoch: 58 [0/1 (0%)]	Loss: 86.579178
# ====> Epoch: 58 Average loss: 86.5792
# Train Epoch: 59 [0/1 (0%)]	Loss: 88.564812
# ====> Epoch: 59 Average loss: 88.5648
# Train Epoch: 60 [0/1 (0%)]	Loss: 89.170547
# ====> Epoch: 60 Average loss: 89.1705
# Train Epoch: 61 [0/1 (0%)]	Loss: 92.331200
# ====> Epoch: 61 Average loss: 92.3312
# Train Epoch: 62 [0/1 (0%)]	Loss: 83.132774
# ====> Epoch: 62 Average loss: 83.1328
# Train Epoch: 63 [0/1 (0%)]	Loss: 106.500893
# ====> Epoch: 63 Average loss: 106.5009
# Train Epoch: 64 [0/1 (0%)]	Loss: 93.446350
# ====> Epoch: 64 Average loss: 93.4464
# Train Epoch: 65 [0/1 (0%)]	Loss: 102.164047
# ====> Epoch: 65 Average loss: 102.1640
# Train Epoch: 66 [0/1 (0%)]	Loss: 91.095329
# ====> Epoch: 66 Average loss: 91.0953
# Train Epoch: 67 [0/1 (0%)]	Loss: 97.912682
# ====> Epoch: 67 Average loss: 97.9127
# Train Epoch: 68 [0/1 (0%)]	Loss: 99.304016
# ====> Epoch: 68 Average loss: 99.3040
# Train Epoch: 69 [0/1 (0%)]	Loss: 100.198128
# ====> Epoch: 69 Average loss: 100.1981
# Train Epoch: 70 [0/1 (0%)]	Loss: 82.090385
# ====> Epoch: 70 Average loss: 82.0904
# Train Epoch: 71 [0/1 (0%)]	Loss: 94.792809
# ====> Epoch: 71 Average loss: 94.7928
# Train Epoch: 72 [0/1 (0%)]	Loss: 106.193481
# ====> Epoch: 72 Average loss: 106.1935
# Train Epoch: 73 [0/1 (0%)]	Loss: 81.505959
# ====> Epoch: 73 Average loss: 81.5060
# Train Epoch: 74 [0/1 (0%)]	Loss: 79.590401
# ====> Epoch: 74 Average loss: 79.5904
# Train Epoch: 75 [0/1 (0%)]	Loss: 99.052635
# ====> Epoch: 75 Average loss: 99.0526
# Train Epoch: 76 [0/1 (0%)]	Loss: 99.916382
# ====> Epoch: 76 Average loss: 99.9164
# Train Epoch: 77 [0/1 (0%)]	Loss: 104.792023
# ====> Epoch: 77 Average loss: 104.7920
# Train Epoch: 78 [0/1 (0%)]	Loss: 122.494873
# ====> Epoch: 78 Average loss: 122.4949
# Train Epoch: 79 [0/1 (0%)]	Loss: 107.212654
# ====> Epoch: 79 Average loss: 107.2127
# Train Epoch: 80 [0/1 (0%)]	Loss: 103.956841
# ====> Epoch: 80 Average loss: 103.9568
# Train Epoch: 81 [0/1 (0%)]	Loss: 97.531113
# ====> Epoch: 81 Average loss: 97.5311
# Train Epoch: 82 [0/1 (0%)]	Loss: 104.069847
# ====> Epoch: 82 Average loss: 104.0698
# Train Epoch: 83 [0/1 (0%)]	Loss: 102.374184
# ====> Epoch: 83 Average loss: 102.3742
# Train Epoch: 84 [0/1 (0%)]	Loss: 76.366302
# ====> Epoch: 84 Average loss: 76.3663
# Train Epoch: 85 [0/1 (0%)]	Loss: 86.609093
# ====> Epoch: 85 Average loss: 86.6091
# Train Epoch: 86 [0/1 (0%)]	Loss: 94.475601
# ====> Epoch: 86 Average loss: 94.4756
# Train Epoch: 87 [0/1 (0%)]	Loss: 109.361267
# ====> Epoch: 87 Average loss: 109.3613
# Train Epoch: 88 [0/1 (0%)]	Loss: 109.439919
# ====> Epoch: 88 Average loss: 109.4399
# Train Epoch: 89 [0/1 (0%)]	Loss: 105.244888
# ====> Epoch: 89 Average loss: 105.2449
# Train Epoch: 90 [0/1 (0%)]	Loss: 112.555511
# ====> Epoch: 90 Average loss: 112.5555
# Train Epoch: 91 [0/1 (0%)]	Loss: 96.021942
# ====> Epoch: 91 Average loss: 96.0219
# Train Epoch: 92 [0/1 (0%)]	Loss: 77.322388
# ====> Epoch: 92 Average loss: 77.3224
# Train Epoch: 93 [0/1 (0%)]	Loss: 105.887199
# ====> Epoch: 93 Average loss: 105.8872
# Train Epoch: 94 [0/1 (0%)]	Loss: 88.570137
# ====> Epoch: 94 Average loss: 88.5701
# Train Epoch: 95 [0/1 (0%)]	Loss: 116.504845
# ====> Epoch: 95 Average loss: 116.5048
# Train Epoch: 96 [0/1 (0%)]	Loss: 83.240395
# ====> Epoch: 96 Average loss: 83.2404
# Train Epoch: 97 [0/1 (0%)]	Loss: 72.844528
# ====> Epoch: 97 Average loss: 72.8445
# Train Epoch: 98 [0/1 (0%)]	Loss: 96.650307
# ====> Epoch: 98 Average loss: 96.6503
# Train Epoch: 99 [0/1 (0%)]	Loss: 93.771645
# ====> Epoch: 99 Average loss: 93.7716
# Train Epoch: 100 [0/1 (0%)]	Loss: 87.427170
# ====> Epoch: 100 Average loss: 87.4272
# Train Epoch: 101 [0/1 (0%)]	Loss: 85.255165
# ====> Epoch: 101 Average loss: 85.2552
# Train Epoch: 102 [0/1 (0%)]	Loss: 90.527565
# ====> Epoch: 102 Average loss: 90.5276
# Train Epoch: 103 [0/1 (0%)]	Loss: 81.684708
# ====> Epoch: 103 Average loss: 81.6847
# Train Epoch: 104 [0/1 (0%)]	Loss: 94.080971
# ====> Epoch: 104 Average loss: 94.0810
# Train Epoch: 105 [0/1 (0%)]	Loss: 91.931862
# ====> Epoch: 105 Average loss: 91.9319
# Train Epoch: 106 [0/1 (0%)]	Loss: 94.125267
# ====> Epoch: 106 Average loss: 94.1253
# Train Epoch: 107 [0/1 (0%)]	Loss: 80.389679
# ====> Epoch: 107 Average loss: 80.3897
# Train Epoch: 108 [0/1 (0%)]	Loss: 99.698112
# ====> Epoch: 108 Average loss: 99.6981
# Train Epoch: 109 [0/1 (0%)]	Loss: 122.989059
# ====> Epoch: 109 Average loss: 122.9891
# Train Epoch: 110 [0/1 (0%)]	Loss: 92.279739
# ====> Epoch: 110 Average loss: 92.2797
# Train Epoch: 111 [0/1 (0%)]	Loss: 119.549873
# ====> Epoch: 111 Average loss: 119.5499
# Train Epoch: 112 [0/1 (0%)]	Loss: 95.505898
# ====> Epoch: 112 Average loss: 95.5059
# Train Epoch: 113 [0/1 (0%)]	Loss: 100.047836
# ====> Epoch: 113 Average loss: 100.0478
# Train Epoch: 114 [0/1 (0%)]	Loss: 84.617302
# ====> Epoch: 114 Average loss: 84.6173
# Train Epoch: 115 [0/1 (0%)]	Loss: 73.379852
# ====> Epoch: 115 Average loss: 73.3799
# Train Epoch: 116 [0/1 (0%)]	Loss: 94.444168
# ====> Epoch: 116 Average loss: 94.4442
# Train Epoch: 117 [0/1 (0%)]	Loss: 91.006577
# ====> Epoch: 117 Average loss: 91.0066
# Train Epoch: 118 [0/1 (0%)]	Loss: 98.343582
# ====> Epoch: 118 Average loss: 98.3436
# Train Epoch: 119 [0/1 (0%)]	Loss: 75.912872
# ====> Epoch: 119 Average loss: 75.9129
# Train Epoch: 120 [0/1 (0%)]	Loss: 86.374001
# ====> Epoch: 120 Average loss: 86.3740
# Train Epoch: 121 [0/1 (0%)]	Loss: 80.078621
# ====> Epoch: 121 Average loss: 80.0786
# Train Epoch: 122 [0/1 (0%)]	Loss: 77.286255
# ====> Epoch: 122 Average loss: 77.2863
# Train Epoch: 123 [0/1 (0%)]	Loss: 84.858749
# ====> Epoch: 123 Average loss: 84.8587
# Train Epoch: 124 [0/1 (0%)]	Loss: 81.265343
# ====> Epoch: 124 Average loss: 81.2653
# Train Epoch: 125 [0/1 (0%)]	Loss: 111.736786
# ====> Epoch: 125 Average loss: 111.7368
# Train Epoch: 126 [0/1 (0%)]	Loss: 84.151001
# ====> Epoch: 126 Average loss: 84.1510
# Train Epoch: 127 [0/1 (0%)]	Loss: 73.116081
# ====> Epoch: 127 Average loss: 73.1161
# Train Epoch: 128 [0/1 (0%)]	Loss: 90.966263
# ====> Epoch: 128 Average loss: 90.9663
# Train Epoch: 129 [0/1 (0%)]	Loss: 77.664772
# ====> Epoch: 129 Average loss: 77.6648
# Train Epoch: 130 [0/1 (0%)]	Loss: 88.178146
# ====> Epoch: 130 Average loss: 88.1781
# Train Epoch: 131 [0/1 (0%)]	Loss: 111.445358
# ====> Epoch: 131 Average loss: 111.4454
# Train Epoch: 132 [0/1 (0%)]	Loss: 97.238838
# ====> Epoch: 132 Average loss: 97.2388
# Train Epoch: 133 [0/1 (0%)]	Loss: 100.014130
# ====> Epoch: 133 Average loss: 100.0141
# Train Epoch: 134 [0/1 (0%)]	Loss: 88.736710
# ====> Epoch: 134 Average loss: 88.7367
# Train Epoch: 135 [0/1 (0%)]	Loss: 89.648811
# ====> Epoch: 135 Average loss: 89.6488
# Train Epoch: 136 [0/1 (0%)]	Loss: 96.930954
# ====> Epoch: 136 Average loss: 96.9310
# Train Epoch: 137 [0/1 (0%)]	Loss: 122.535187
# ====> Epoch: 137 Average loss: 122.5352
# Train Epoch: 138 [0/1 (0%)]	Loss: 87.402298
# ====> Epoch: 138 Average loss: 87.4023
# Train Epoch: 139 [0/1 (0%)]	Loss: 110.604721
# ====> Epoch: 139 Average loss: 110.6047
# Train Epoch: 140 [0/1 (0%)]	Loss: 89.120636
# ====> Epoch: 140 Average loss: 89.1206
# Train Epoch: 141 [0/1 (0%)]	Loss: 75.640205
# ====> Epoch: 141 Average loss: 75.6402
# Train Epoch: 142 [0/1 (0%)]	Loss: 104.685150
# ====> Epoch: 142 Average loss: 104.6852
# Train Epoch: 143 [0/1 (0%)]	Loss: 86.511581
# ====> Epoch: 143 Average loss: 86.5116
# Train Epoch: 144 [0/1 (0%)]	Loss: 103.201324
# ====> Epoch: 144 Average loss: 103.2013
# Train Epoch: 145 [0/1 (0%)]	Loss: 83.260696
# ====> Epoch: 145 Average loss: 83.2607
# Train Epoch: 146 [0/1 (0%)]	Loss: 82.754883
# ====> Epoch: 146 Average loss: 82.7549
# Train Epoch: 147 [0/1 (0%)]	Loss: 85.602707
# ====> Epoch: 147 Average loss: 85.6027
# Train Epoch: 148 [0/1 (0%)]	Loss: 91.629539
# ====> Epoch: 148 Average loss: 91.6295
# Train Epoch: 149 [0/1 (0%)]	Loss: 85.168236
# ====> Epoch: 149 Average loss: 85.1682
# Train Epoch: 150 [0/1 (0%)]	Loss: 88.395638
# ====> Epoch: 150 Average loss: 88.3956
# Train Epoch: 151 [0/1 (0%)]	Loss: 97.844070
# ====> Epoch: 151 Average loss: 97.8441
# Train Epoch: 152 [0/1 (0%)]	Loss: 82.973244
# ====> Epoch: 152 Average loss: 82.9732
# Train Epoch: 153 [0/1 (0%)]	Loss: 87.287346
# ====> Epoch: 153 Average loss: 87.2873
# Train Epoch: 154 [0/1 (0%)]	Loss: 84.146156
# ====> Epoch: 154 Average loss: 84.1462
# Train Epoch: 155 [0/1 (0%)]	Loss: 89.137390
# ====> Epoch: 155 Average loss: 89.1374
# Train Epoch: 156 [0/1 (0%)]	Loss: 105.989265
# ====> Epoch: 156 Average loss: 105.9893
# Train Epoch: 157 [0/1 (0%)]	Loss: 88.887978
# ====> Epoch: 157 Average loss: 88.8880
# Train Epoch: 158 [0/1 (0%)]	Loss: 109.963089
# ====> Epoch: 158 Average loss: 109.9631
# Train Epoch: 159 [0/1 (0%)]	Loss: 72.729721
# ====> Epoch: 159 Average loss: 72.7297
# Train Epoch: 160 [0/1 (0%)]	Loss: 85.415062
# ====> Epoch: 160 Average loss: 85.4151
# Train Epoch: 161 [0/1 (0%)]	Loss: 74.133965
# ====> Epoch: 161 Average loss: 74.1340
# Train Epoch: 162 [0/1 (0%)]	Loss: 82.785988
# ====> Epoch: 162 Average loss: 82.7860
# Train Epoch: 163 [0/1 (0%)]	Loss: 99.498428
# ====> Epoch: 163 Average loss: 99.4984
# Train Epoch: 164 [0/1 (0%)]	Loss: 78.533165
# ====> Epoch: 164 Average loss: 78.5332
# Train Epoch: 165 [0/1 (0%)]	Loss: 77.089363
# ====> Epoch: 165 Average loss: 77.0894
# Train Epoch: 166 [0/1 (0%)]	Loss: 87.290215
# ====> Epoch: 166 Average loss: 87.2902
# Train Epoch: 167 [0/1 (0%)]	Loss: 90.000603
# ====> Epoch: 167 Average loss: 90.0006
# Train Epoch: 168 [0/1 (0%)]	Loss: 78.344925
# ====> Epoch: 168 Average loss: 78.3449
# Train Epoch: 169 [0/1 (0%)]	Loss: 78.974083
# ====> Epoch: 169 Average loss: 78.9741
# Train Epoch: 170 [0/1 (0%)]	Loss: 105.424759
# ====> Epoch: 170 Average loss: 105.4248
# Train Epoch: 171 [0/1 (0%)]	Loss: 99.528137
# ====> Epoch: 171 Average loss: 99.5281
# Train Epoch: 172 [0/1 (0%)]	Loss: 88.750336
# ====> Epoch: 172 Average loss: 88.7503
# Train Epoch: 173 [0/1 (0%)]	Loss: 93.890045
# ====> Epoch: 173 Average loss: 93.8900
# Train Epoch: 174 [0/1 (0%)]	Loss: 74.656075
# ====> Epoch: 174 Average loss: 74.6561
# Train Epoch: 175 [0/1 (0%)]	Loss: 82.566650
# ====> Epoch: 175 Average loss: 82.5667
# Train Epoch: 176 [0/1 (0%)]	Loss: 79.876877
# ====> Epoch: 176 Average loss: 79.8769
# Train Epoch: 177 [0/1 (0%)]	Loss: 81.664536
# ====> Epoch: 177 Average loss: 81.6645
# Train Epoch: 178 [0/1 (0%)]	Loss: 93.568314
# ====> Epoch: 178 Average loss: 93.5683
# Train Epoch: 179 [0/1 (0%)]	Loss: 74.410339
# ====> Epoch: 179 Average loss: 74.4103
# Train Epoch: 180 [0/1 (0%)]	Loss: 84.078903
# ====> Epoch: 180 Average loss: 84.0789
# Train Epoch: 181 [0/1 (0%)]	Loss: 95.756920
# ====> Epoch: 181 Average loss: 95.7569
# Train Epoch: 182 [0/1 (0%)]	Loss: 87.023552
# ====> Epoch: 182 Average loss: 87.0236
# Train Epoch: 183 [0/1 (0%)]	Loss: 105.992500
# ====> Epoch: 183 Average loss: 105.9925
# Train Epoch: 184 [0/1 (0%)]	Loss: 88.084099
# ====> Epoch: 184 Average loss: 88.0841
# Train Epoch: 185 [0/1 (0%)]	Loss: 90.713043
# ====> Epoch: 185 Average loss: 90.7130
# Train Epoch: 186 [0/1 (0%)]	Loss: 69.214874
# ====> Epoch: 186 Average loss: 69.2149
# Train Epoch: 187 [0/1 (0%)]	Loss: 90.001480
# ====> Epoch: 187 Average loss: 90.0015
# Train Epoch: 188 [0/1 (0%)]	Loss: 83.620491
# ====> Epoch: 188 Average loss: 83.6205
# Train Epoch: 189 [0/1 (0%)]	Loss: 83.022186
# ====> Epoch: 189 Average loss: 83.0222
# Train Epoch: 190 [0/1 (0%)]	Loss: 75.074608
# ====> Epoch: 190 Average loss: 75.0746
# Train Epoch: 191 [0/1 (0%)]	Loss: 76.704254
# ====> Epoch: 191 Average loss: 76.7043
# Train Epoch: 192 [0/1 (0%)]	Loss: 89.925644
# ====> Epoch: 192 Average loss: 89.9256
# Train Epoch: 193 [0/1 (0%)]	Loss: 72.972237
# ====> Epoch: 193 Average loss: 72.9722
# Train Epoch: 194 [0/1 (0%)]	Loss: 83.972725
# ====> Epoch: 194 Average loss: 83.9727
# Train Epoch: 195 [0/1 (0%)]	Loss: 114.533943
# ====> Epoch: 195 Average loss: 114.5339
# Train Epoch: 196 [0/1 (0%)]	Loss: 80.919853
# ====> Epoch: 196 Average loss: 80.9199
# Train Epoch: 197 [0/1 (0%)]	Loss: 76.948685
# ====> Epoch: 197 Average loss: 76.9487
# Train Epoch: 198 [0/1 (0%)]	Loss: 89.812805
# ====> Epoch: 198 Average loss: 89.8128
# Train Epoch: 199 [0/1 (0%)]	Loss: 92.251541
# ====> Epoch: 199 Average loss: 92.2515
# Train Epoch: 200 [0/1 (0%)]	Loss: 73.375984
# ====> Epoch: 200 Average loss: 73.3760
# Train Epoch: 201 [0/1 (0%)]	Loss: 91.500778
# ====> Epoch: 201 Average loss: 91.5008
# Train Epoch: 202 [0/1 (0%)]	Loss: 78.708557
# ====> Epoch: 202 Average loss: 78.7086
# Train Epoch: 203 [0/1 (0%)]	Loss: 100.266129
# ====> Epoch: 203 Average loss: 100.2661
# Train Epoch: 204 [0/1 (0%)]	Loss: 88.411514
# ====> Epoch: 204 Average loss: 88.4115
# Train Epoch: 205 [0/1 (0%)]	Loss: 97.967201
# ====> Epoch: 205 Average loss: 97.9672
# Train Epoch: 206 [0/1 (0%)]	Loss: 100.957855
# ====> Epoch: 206 Average loss: 100.9579
# Train Epoch: 207 [0/1 (0%)]	Loss: 123.585663
# ====> Epoch: 207 Average loss: 123.5857
# Train Epoch: 208 [0/1 (0%)]	Loss: 78.208817
# ====> Epoch: 208 Average loss: 78.2088
# Train Epoch: 209 [0/1 (0%)]	Loss: 88.464569
# ====> Epoch: 209 Average loss: 88.4646
# Train Epoch: 210 [0/1 (0%)]	Loss: 101.776939
# ====> Epoch: 210 Average loss: 101.7769
# Train Epoch: 211 [0/1 (0%)]	Loss: 102.920410
# ====> Epoch: 211 Average loss: 102.9204
# Train Epoch: 212 [0/1 (0%)]	Loss: 92.995667
# ====> Epoch: 212 Average loss: 92.9957
# Train Epoch: 213 [0/1 (0%)]	Loss: 69.239525
# ====> Epoch: 213 Average loss: 69.2395
# Train Epoch: 214 [0/1 (0%)]	Loss: 80.724815
# ====> Epoch: 214 Average loss: 80.7248
# Train Epoch: 215 [0/1 (0%)]	Loss: 96.769783
# ====> Epoch: 215 Average loss: 96.7698
# Train Epoch: 216 [0/1 (0%)]	Loss: 79.466820
# ====> Epoch: 216 Average loss: 79.4668
# Train Epoch: 217 [0/1 (0%)]	Loss: 72.764481
# ====> Epoch: 217 Average loss: 72.7645
# Train Epoch: 218 [0/1 (0%)]	Loss: 77.756432
# ====> Epoch: 218 Average loss: 77.7564
# Train Epoch: 219 [0/1 (0%)]	Loss: 77.687050
# ====> Epoch: 219 Average loss: 77.6870
# Train Epoch: 220 [0/1 (0%)]	Loss: 99.832489
# ====> Epoch: 220 Average loss: 99.8325
# Train Epoch: 221 [0/1 (0%)]	Loss: 83.584869
# ====> Epoch: 221 Average loss: 83.5849
# Train Epoch: 222 [0/1 (0%)]	Loss: 102.203049
# ====> Epoch: 222 Average loss: 102.2030
# Train Epoch: 223 [0/1 (0%)]	Loss: 79.580109
# ====> Epoch: 223 Average loss: 79.5801
# Train Epoch: 224 [0/1 (0%)]	Loss: 65.939026
# ====> Epoch: 224 Average loss: 65.9390
# Train Epoch: 225 [0/1 (0%)]	Loss: 81.586861
# ====> Epoch: 225 Average loss: 81.5869
# Train Epoch: 226 [0/1 (0%)]	Loss: 87.061333
# ====> Epoch: 226 Average loss: 87.0613
# Train Epoch: 227 [0/1 (0%)]	Loss: 76.035912
# ====> Epoch: 227 Average loss: 76.0359
# Train Epoch: 228 [0/1 (0%)]	Loss: 76.464531
# ====> Epoch: 228 Average loss: 76.4645
# Train Epoch: 229 [0/1 (0%)]	Loss: 80.518257
# ====> Epoch: 229 Average loss: 80.5183
# Train Epoch: 230 [0/1 (0%)]	Loss: 129.402557
# ====> Epoch: 230 Average loss: 129.4026
# Train Epoch: 231 [0/1 (0%)]	Loss: 83.383453
# ====> Epoch: 231 Average loss: 83.3835
# Train Epoch: 232 [0/1 (0%)]	Loss: 73.613907
# ====> Epoch: 232 Average loss: 73.6139
# Train Epoch: 233 [0/1 (0%)]	Loss: 80.460335
# ====> Epoch: 233 Average loss: 80.4603
# Train Epoch: 234 [0/1 (0%)]	Loss: 86.752472
# ====> Epoch: 234 Average loss: 86.7525
# Train Epoch: 235 [0/1 (0%)]	Loss: 71.447823
# ====> Epoch: 235 Average loss: 71.4478
# Train Epoch: 236 [0/1 (0%)]	Loss: 94.725662
# ====> Epoch: 236 Average loss: 94.7257
# Train Epoch: 237 [0/1 (0%)]	Loss: 104.694496
# ====> Epoch: 237 Average loss: 104.6945
# Train Epoch: 238 [0/1 (0%)]	Loss: 90.814957
# ====> Epoch: 238 Average loss: 90.8150
# Train Epoch: 239 [0/1 (0%)]	Loss: 79.571999
# ====> Epoch: 239 Average loss: 79.5720
# Train Epoch: 240 [0/1 (0%)]	Loss: 81.842651
# ====> Epoch: 240 Average loss: 81.8427
# Train Epoch: 241 [0/1 (0%)]	Loss: 99.278419
# ====> Epoch: 241 Average loss: 99.2784
# Train Epoch: 242 [0/1 (0%)]	Loss: 74.737259
# ====> Epoch: 242 Average loss: 74.7373
# Train Epoch: 243 [0/1 (0%)]	Loss: 74.272049
# ====> Epoch: 243 Average loss: 74.2720
# Train Epoch: 244 [0/1 (0%)]	Loss: 82.278725
# ====> Epoch: 244 Average loss: 82.2787
# Train Epoch: 245 [0/1 (0%)]	Loss: 77.021149
# ====> Epoch: 245 Average loss: 77.0211
# Train Epoch: 246 [0/1 (0%)]	Loss: 89.023415
# ====> Epoch: 246 Average loss: 89.0234
# Train Epoch: 247 [0/1 (0%)]	Loss: 74.211273
# ====> Epoch: 247 Average loss: 74.2113
# Train Epoch: 248 [0/1 (0%)]	Loss: 76.515526
# ====> Epoch: 248 Average loss: 76.5155
# Train Epoch: 249 [0/1 (0%)]	Loss: 92.047577
# ====> Epoch: 249 Average loss: 92.0476
# Train Epoch: 250 [0/1 (0%)]	Loss: 89.537209
# ====> Epoch: 250 Average loss: 89.5372
# Train Epoch: 251 [0/1 (0%)]	Loss: 82.477386
# ====> Epoch: 251 Average loss: 82.4774
# Train Epoch: 252 [0/1 (0%)]	Loss: 85.557045
# ====> Epoch: 252 Average loss: 85.5570
# Train Epoch: 253 [0/1 (0%)]	Loss: 105.890274
# ====> Epoch: 253 Average loss: 105.8903
# Train Epoch: 254 [0/1 (0%)]	Loss: 78.395576
# ====> Epoch: 254 Average loss: 78.3956
# Train Epoch: 255 [0/1 (0%)]	Loss: 76.038116
# ====> Epoch: 255 Average loss: 76.0381
# Train Epoch: 256 [0/1 (0%)]	Loss: 84.322304
# ====> Epoch: 256 Average loss: 84.3223
# Train Epoch: 257 [0/1 (0%)]	Loss: 80.226265
# ====> Epoch: 257 Average loss: 80.2263
# Train Epoch: 258 [0/1 (0%)]	Loss: 94.562294
# ====> Epoch: 258 Average loss: 94.5623
# Train Epoch: 259 [0/1 (0%)]	Loss: 85.927734
# ====> Epoch: 259 Average loss: 85.9277
# Train Epoch: 260 [0/1 (0%)]	Loss: 87.286011
# ====> Epoch: 260 Average loss: 87.2860
# Train Epoch: 261 [0/1 (0%)]	Loss: 101.794518
# ====> Epoch: 261 Average loss: 101.7945
# Train Epoch: 262 [0/1 (0%)]	Loss: 107.154648
# ====> Epoch: 262 Average loss: 107.1546
# Train Epoch: 263 [0/1 (0%)]	Loss: 85.188896
# ====> Epoch: 263 Average loss: 85.1889
# Train Epoch: 264 [0/1 (0%)]	Loss: 83.125008
# ====> Epoch: 264 Average loss: 83.1250
# Train Epoch: 265 [0/1 (0%)]	Loss: 76.530190
# ====> Epoch: 265 Average loss: 76.5302
# Train Epoch: 266 [0/1 (0%)]	Loss: 74.052734
# ====> Epoch: 266 Average loss: 74.0527
# Train Epoch: 267 [0/1 (0%)]	Loss: 83.561234
# ====> Epoch: 267 Average loss: 83.5612
# Train Epoch: 268 [0/1 (0%)]	Loss: 83.072189
# ====> Epoch: 268 Average loss: 83.0722
# Train Epoch: 269 [0/1 (0%)]	Loss: 74.944237
# ====> Epoch: 269 Average loss: 74.9442
# Train Epoch: 270 [0/1 (0%)]	Loss: 92.365829
# ====> Epoch: 270 Average loss: 92.3658
# Train Epoch: 271 [0/1 (0%)]	Loss: 88.852776
# ====> Epoch: 271 Average loss: 88.8528
# Train Epoch: 272 [0/1 (0%)]	Loss: 71.664452
# ====> Epoch: 272 Average loss: 71.6645
# Train Epoch: 273 [0/1 (0%)]	Loss: 74.121315
# ====> Epoch: 273 Average loss: 74.1213
# Train Epoch: 274 [0/1 (0%)]	Loss: 81.950294
# ====> Epoch: 274 Average loss: 81.9503
# Train Epoch: 275 [0/1 (0%)]	Loss: 76.626831
# ====> Epoch: 275 Average loss: 76.6268
# Train Epoch: 276 [0/1 (0%)]	Loss: 85.272598
# ====> Epoch: 276 Average loss: 85.2726
# Train Epoch: 277 [0/1 (0%)]	Loss: 73.478638
# ====> Epoch: 277 Average loss: 73.4786
# Train Epoch: 278 [0/1 (0%)]	Loss: 93.111588
# ====> Epoch: 278 Average loss: 93.1116
# Train Epoch: 279 [0/1 (0%)]	Loss: 75.516930
# ====> Epoch: 279 Average loss: 75.5169
# Train Epoch: 280 [0/1 (0%)]	Loss: 81.528687
# ====> Epoch: 280 Average loss: 81.5287
# Train Epoch: 281 [0/1 (0%)]	Loss: 92.176064
# ====> Epoch: 281 Average loss: 92.1761
# Train Epoch: 282 [0/1 (0%)]	Loss: 86.848915
# ====> Epoch: 282 Average loss: 86.8489
# Train Epoch: 283 [0/1 (0%)]	Loss: 71.277092
# ====> Epoch: 283 Average loss: 71.2771
# Train Epoch: 284 [0/1 (0%)]	Loss: 78.373070
# ====> Epoch: 284 Average loss: 78.3731
# Train Epoch: 285 [0/1 (0%)]	Loss: 96.130257
# ====> Epoch: 285 Average loss: 96.1303
# Train Epoch: 286 [0/1 (0%)]	Loss: 75.512383
# ====> Epoch: 286 Average loss: 75.5124
# Train Epoch: 287 [0/1 (0%)]	Loss: 72.567612
# ====> Epoch: 287 Average loss: 72.5676
# Train Epoch: 288 [0/1 (0%)]	Loss: 111.214355
# ====> Epoch: 288 Average loss: 111.2144
# Train Epoch: 289 [0/1 (0%)]	Loss: 63.304718
# ====> Epoch: 289 Average loss: 63.3047
# Train Epoch: 290 [0/1 (0%)]	Loss: 78.390335
# ====> Epoch: 290 Average loss: 78.3903
# Train Epoch: 291 [0/1 (0%)]	Loss: 71.639595
# ====> Epoch: 291 Average loss: 71.6396
# Train Epoch: 292 [0/1 (0%)]	Loss: 97.972481
# ====> Epoch: 292 Average loss: 97.9725
# Train Epoch: 293 [0/1 (0%)]	Loss: 74.895653
# ====> Epoch: 293 Average loss: 74.8957
# Train Epoch: 294 [0/1 (0%)]	Loss: 87.263947
# ====> Epoch: 294 Average loss: 87.2639
# Train Epoch: 295 [0/1 (0%)]	Loss: 81.268044
# ====> Epoch: 295 Average loss: 81.2680
# Train Epoch: 296 [0/1 (0%)]	Loss: 64.455315
# ====> Epoch: 296 Average loss: 64.4553
# Train Epoch: 297 [0/1 (0%)]	Loss: 87.453773
# ====> Epoch: 297 Average loss: 87.4538
# Train Epoch: 298 [0/1 (0%)]	Loss: 73.481796
# ====> Epoch: 298 Average loss: 73.4818
# Train Epoch: 299 [0/1 (0%)]	Loss: 74.188240
# ====> Epoch: 299 Average loss: 74.1882
# Train Epoch: 300 [0/1 (0%)]	Loss: 77.918694
# ====> Epoch: 300 Average loss: 77.9187
# Train Epoch: 301 [0/1 (0%)]	Loss: 65.369461
# ====> Epoch: 301 Average loss: 65.3695
# Train Epoch: 302 [0/1 (0%)]	Loss: 71.408424
# ====> Epoch: 302 Average loss: 71.4084
# Train Epoch: 303 [0/1 (0%)]	Loss: 94.703346
# ====> Epoch: 303 Average loss: 94.7033
# Train Epoch: 304 [0/1 (0%)]	Loss: 66.245758
# ====> Epoch: 304 Average loss: 66.2458
# Train Epoch: 305 [0/1 (0%)]	Loss: 92.188850
# ====> Epoch: 305 Average loss: 92.1889
# Train Epoch: 306 [0/1 (0%)]	Loss: 98.468719
# ====> Epoch: 306 Average loss: 98.4687
# Train Epoch: 307 [0/1 (0%)]	Loss: 57.402336
# ====> Epoch: 307 Average loss: 57.4023
# Train Epoch: 308 [0/1 (0%)]	Loss: 72.929260
# ====> Epoch: 308 Average loss: 72.9293
# Train Epoch: 309 [0/1 (0%)]	Loss: 95.069542
# ====> Epoch: 309 Average loss: 95.0695
# Train Epoch: 310 [0/1 (0%)]	Loss: 76.987732
# ====> Epoch: 310 Average loss: 76.9877
# Train Epoch: 311 [0/1 (0%)]	Loss: 62.547333
# ====> Epoch: 311 Average loss: 62.5473
# Train Epoch: 312 [0/1 (0%)]	Loss: 78.075768
# ====> Epoch: 312 Average loss: 78.0758
# Train Epoch: 313 [0/1 (0%)]	Loss: 72.297325
# ====> Epoch: 313 Average loss: 72.2973
# Train Epoch: 314 [0/1 (0%)]	Loss: 74.768379
# ====> Epoch: 314 Average loss: 74.7684
# Train Epoch: 315 [0/1 (0%)]	Loss: 84.376892
# ====> Epoch: 315 Average loss: 84.3769
# Train Epoch: 316 [0/1 (0%)]	Loss: 84.735352
# ====> Epoch: 316 Average loss: 84.7354
# Train Epoch: 317 [0/1 (0%)]	Loss: 77.567291
# ====> Epoch: 317 Average loss: 77.5673
# Train Epoch: 318 [0/1 (0%)]	Loss: 78.757385
# ====> Epoch: 318 Average loss: 78.7574
# Train Epoch: 319 [0/1 (0%)]	Loss: 93.268799
# ====> Epoch: 319 Average loss: 93.2688
# Train Epoch: 320 [0/1 (0%)]	Loss: 68.684288
# ====> Epoch: 320 Average loss: 68.6843
# Train Epoch: 321 [0/1 (0%)]	Loss: 82.613022
# ====> Epoch: 321 Average loss: 82.6130
# Train Epoch: 322 [0/1 (0%)]	Loss: 73.490211
# ====> Epoch: 322 Average loss: 73.4902
# Train Epoch: 323 [0/1 (0%)]	Loss: 109.065926
# ====> Epoch: 323 Average loss: 109.0659
# Train Epoch: 324 [0/1 (0%)]	Loss: 84.610703
# ====> Epoch: 324 Average loss: 84.6107
# Train Epoch: 325 [0/1 (0%)]	Loss: 78.529594
# ====> Epoch: 325 Average loss: 78.5296
# Train Epoch: 326 [0/1 (0%)]	Loss: 78.026314
# ====> Epoch: 326 Average loss: 78.0263
# Train Epoch: 327 [0/1 (0%)]	Loss: 91.092934
# ====> Epoch: 327 Average loss: 91.0929
# Train Epoch: 328 [0/1 (0%)]	Loss: 70.337288
# ====> Epoch: 328 Average loss: 70.3373
# Train Epoch: 329 [0/1 (0%)]	Loss: 74.600349
# ====> Epoch: 329 Average loss: 74.6003
# Train Epoch: 330 [0/1 (0%)]	Loss: 93.767548
# ====> Epoch: 330 Average loss: 93.7675
# Train Epoch: 331 [0/1 (0%)]	Loss: 84.185387
# ====> Epoch: 331 Average loss: 84.1854
# Train Epoch: 332 [0/1 (0%)]	Loss: 68.226944
# ====> Epoch: 332 Average loss: 68.2269
# Train Epoch: 333 [0/1 (0%)]	Loss: 75.687805
# ====> Epoch: 333 Average loss: 75.6878
# Train Epoch: 334 [0/1 (0%)]	Loss: 108.679962
# ====> Epoch: 334 Average loss: 108.6800
# Train Epoch: 335 [0/1 (0%)]	Loss: 67.456108
# ====> Epoch: 335 Average loss: 67.4561
# Train Epoch: 336 [0/1 (0%)]	Loss: 75.335320
# ====> Epoch: 336 Average loss: 75.3353
# Train Epoch: 337 [0/1 (0%)]	Loss: 67.567909
# ====> Epoch: 337 Average loss: 67.5679
# Train Epoch: 338 [0/1 (0%)]	Loss: 87.029655
# ====> Epoch: 338 Average loss: 87.0297
# Train Epoch: 339 [0/1 (0%)]	Loss: 74.046738
# ====> Epoch: 339 Average loss: 74.0467
# Train Epoch: 340 [0/1 (0%)]	Loss: 72.758202
# ====> Epoch: 340 Average loss: 72.7582
# Train Epoch: 341 [0/1 (0%)]	Loss: 78.398849
# ====> Epoch: 341 Average loss: 78.3988
# Train Epoch: 342 [0/1 (0%)]	Loss: 70.671112
# ====> Epoch: 342 Average loss: 70.6711
# Train Epoch: 343 [0/1 (0%)]	Loss: 79.337654
# ====> Epoch: 343 Average loss: 79.3377
# Train Epoch: 344 [0/1 (0%)]	Loss: 74.443787
# ====> Epoch: 344 Average loss: 74.4438
# Train Epoch: 345 [0/1 (0%)]	Loss: 83.591629
# ====> Epoch: 345 Average loss: 83.5916
# Train Epoch: 346 [0/1 (0%)]	Loss: 85.570930
# ====> Epoch: 346 Average loss: 85.5709
# Train Epoch: 347 [0/1 (0%)]	Loss: 79.203415
# ====> Epoch: 347 Average loss: 79.2034
# Train Epoch: 348 [0/1 (0%)]	Loss: 98.503189
# ====> Epoch: 348 Average loss: 98.5032
# Train Epoch: 349 [0/1 (0%)]	Loss: 66.937988
# ====> Epoch: 349 Average loss: 66.9380
# Train Epoch: 350 [0/1 (0%)]	Loss: 76.743675
# ====> Epoch: 350 Average loss: 76.7437
# Train Epoch: 351 [0/1 (0%)]	Loss: 81.389282
# ====> Epoch: 351 Average loss: 81.3893
# Train Epoch: 352 [0/1 (0%)]	Loss: 84.372314
# ====> Epoch: 352 Average loss: 84.3723
# Train Epoch: 353 [0/1 (0%)]	Loss: 82.165848
# ====> Epoch: 353 Average loss: 82.1658
# Train Epoch: 354 [0/1 (0%)]	Loss: 72.919266
# ====> Epoch: 354 Average loss: 72.9193
# Train Epoch: 355 [0/1 (0%)]	Loss: 85.484566
# ====> Epoch: 355 Average loss: 85.4846
# Train Epoch: 356 [0/1 (0%)]	Loss: 63.432205
# ====> Epoch: 356 Average loss: 63.4322
# Train Epoch: 357 [0/1 (0%)]	Loss: 89.785492
# ====> Epoch: 357 Average loss: 89.7855
# Train Epoch: 358 [0/1 (0%)]	Loss: 75.224525
# ====> Epoch: 358 Average loss: 75.2245
# Train Epoch: 359 [0/1 (0%)]	Loss: 80.663567
# ====> Epoch: 359 Average loss: 80.6636
# Train Epoch: 360 [0/1 (0%)]	Loss: 84.698914
# ====> Epoch: 360 Average loss: 84.6989
# Train Epoch: 361 [0/1 (0%)]	Loss: 68.858871
# ====> Epoch: 361 Average loss: 68.8589
# Train Epoch: 362 [0/1 (0%)]	Loss: 65.332420
# ====> Epoch: 362 Average loss: 65.3324
# Train Epoch: 363 [0/1 (0%)]	Loss: 73.973106
# ====> Epoch: 363 Average loss: 73.9731
# Train Epoch: 364 [0/1 (0%)]	Loss: 78.436768
# ====> Epoch: 364 Average loss: 78.4368
# Train Epoch: 365 [0/1 (0%)]	Loss: 78.106606
# ====> Epoch: 365 Average loss: 78.1066
# Train Epoch: 366 [0/1 (0%)]	Loss: 65.757553
# ====> Epoch: 366 Average loss: 65.7576
# Train Epoch: 367 [0/1 (0%)]	Loss: 73.122673
# ====> Epoch: 367 Average loss: 73.1227
# Train Epoch: 368 [0/1 (0%)]	Loss: 75.272705
# ====> Epoch: 368 Average loss: 75.2727
# Train Epoch: 369 [0/1 (0%)]	Loss: 85.330444
# ====> Epoch: 369 Average loss: 85.3304
# Train Epoch: 370 [0/1 (0%)]	Loss: 80.036568
# ====> Epoch: 370 Average loss: 80.0366
# Train Epoch: 371 [0/1 (0%)]	Loss: 72.048462
# ====> Epoch: 371 Average loss: 72.0485
# Train Epoch: 372 [0/1 (0%)]	Loss: 82.296341
# ====> Epoch: 372 Average loss: 82.2963
# Train Epoch: 373 [0/1 (0%)]	Loss: 81.946945
# ====> Epoch: 373 Average loss: 81.9469
# Train Epoch: 374 [0/1 (0%)]	Loss: 84.486542
# ====> Epoch: 374 Average loss: 84.4865
# Train Epoch: 375 [0/1 (0%)]	Loss: 83.110214
# ====> Epoch: 375 Average loss: 83.1102
# Train Epoch: 376 [0/1 (0%)]	Loss: 87.215172
# ====> Epoch: 376 Average loss: 87.2152
# Train Epoch: 377 [0/1 (0%)]	Loss: 77.043587
# ====> Epoch: 377 Average loss: 77.0436
# Train Epoch: 378 [0/1 (0%)]	Loss: 65.895607
# ====> Epoch: 378 Average loss: 65.8956
# Train Epoch: 379 [0/1 (0%)]	Loss: 75.930138
# ====> Epoch: 379 Average loss: 75.9301
# Train Epoch: 380 [0/1 (0%)]	Loss: 81.198097
# ====> Epoch: 380 Average loss: 81.1981
# Train Epoch: 381 [0/1 (0%)]	Loss: 86.447342
# ====> Epoch: 381 Average loss: 86.4473
# Train Epoch: 382 [0/1 (0%)]	Loss: 75.425865
# ====> Epoch: 382 Average loss: 75.4259
# Train Epoch: 383 [0/1 (0%)]	Loss: 65.649254
# ====> Epoch: 383 Average loss: 65.6493
# Train Epoch: 384 [0/1 (0%)]	Loss: 87.991142
# ====> Epoch: 384 Average loss: 87.9911
# Train Epoch: 385 [0/1 (0%)]	Loss: 75.132332
# ====> Epoch: 385 Average loss: 75.1323
# Train Epoch: 386 [0/1 (0%)]	Loss: 65.140694
# ====> Epoch: 386 Average loss: 65.1407
# Train Epoch: 387 [0/1 (0%)]	Loss: 97.725365
# ====> Epoch: 387 Average loss: 97.7254
# Train Epoch: 388 [0/1 (0%)]	Loss: 68.024170
# ====> Epoch: 388 Average loss: 68.0242
# Train Epoch: 389 [0/1 (0%)]	Loss: 63.136349
# ====> Epoch: 389 Average loss: 63.1363
# Train Epoch: 390 [0/1 (0%)]	Loss: 74.867737
# ====> Epoch: 390 Average loss: 74.8677
# Train Epoch: 391 [0/1 (0%)]	Loss: 67.523430
# ====> Epoch: 391 Average loss: 67.5234
# Train Epoch: 392 [0/1 (0%)]	Loss: 86.030235
# ====> Epoch: 392 Average loss: 86.0302
# Train Epoch: 393 [0/1 (0%)]	Loss: 74.095055
# ====> Epoch: 393 Average loss: 74.0951
# Train Epoch: 394 [0/1 (0%)]	Loss: 63.645222
# ====> Epoch: 394 Average loss: 63.6452
# Train Epoch: 395 [0/1 (0%)]	Loss: 74.582855
# ====> Epoch: 395 Average loss: 74.5829
# Train Epoch: 396 [0/1 (0%)]	Loss: 69.075012
# ====> Epoch: 396 Average loss: 69.0750
# Train Epoch: 397 [0/1 (0%)]	Loss: 76.315842
# ====> Epoch: 397 Average loss: 76.3158
# Train Epoch: 398 [0/1 (0%)]	Loss: 89.537102
# ====> Epoch: 398 Average loss: 89.5371
# Train Epoch: 399 [0/1 (0%)]	Loss: 83.837318
# ====> Epoch: 399 Average loss: 83.8373
# Train Epoch: 400 [0/1 (0%)]	Loss: 80.729698
# ====> Epoch: 400 Average loss: 80.7297
# Train Epoch: 401 [0/1 (0%)]	Loss: 67.424736
# ====> Epoch: 401 Average loss: 67.4247
# Train Epoch: 402 [0/1 (0%)]	Loss: 101.148460
# ====> Epoch: 402 Average loss: 101.1485
# Train Epoch: 403 [0/1 (0%)]	Loss: 71.729050
# ====> Epoch: 403 Average loss: 71.7290
# Train Epoch: 404 [0/1 (0%)]	Loss: 73.821960
# ====> Epoch: 404 Average loss: 73.8220
# Train Epoch: 405 [0/1 (0%)]	Loss: 74.523926
# ====> Epoch: 405 Average loss: 74.5239
# Train Epoch: 406 [0/1 (0%)]	Loss: 66.998116
# ====> Epoch: 406 Average loss: 66.9981
# Train Epoch: 407 [0/1 (0%)]	Loss: 120.921806
# ====> Epoch: 407 Average loss: 120.9218
# Train Epoch: 408 [0/1 (0%)]	Loss: 72.723976
# ====> Epoch: 408 Average loss: 72.7240
# Train Epoch: 409 [0/1 (0%)]	Loss: 83.955711
# ====> Epoch: 409 Average loss: 83.9557
# Train Epoch: 410 [0/1 (0%)]	Loss: 68.887253
# ====> Epoch: 410 Average loss: 68.8873
# Train Epoch: 411 [0/1 (0%)]	Loss: 61.831429
# ====> Epoch: 411 Average loss: 61.8314
# Train Epoch: 412 [0/1 (0%)]	Loss: 79.488152
# ====> Epoch: 412 Average loss: 79.4882
# Train Epoch: 413 [0/1 (0%)]	Loss: 62.629128
# ====> Epoch: 413 Average loss: 62.6291
# Train Epoch: 414 [0/1 (0%)]	Loss: 82.244698
# ====> Epoch: 414 Average loss: 82.2447
# Train Epoch: 415 [0/1 (0%)]	Loss: 75.701904
# ====> Epoch: 415 Average loss: 75.7019
# Train Epoch: 416 [0/1 (0%)]	Loss: 74.748878
# ====> Epoch: 416 Average loss: 74.7489
# Train Epoch: 417 [0/1 (0%)]	Loss: 69.662529
# ====> Epoch: 417 Average loss: 69.6625
# Train Epoch: 418 [0/1 (0%)]	Loss: 85.794632
# ====> Epoch: 418 Average loss: 85.7946
# Train Epoch: 419 [0/1 (0%)]	Loss: 76.181427
# ====> Epoch: 419 Average loss: 76.1814
# Train Epoch: 420 [0/1 (0%)]	Loss: 72.187233
# ====> Epoch: 420 Average loss: 72.1872
# Train Epoch: 421 [0/1 (0%)]	Loss: 71.489929
# ====> Epoch: 421 Average loss: 71.4899
# Train Epoch: 422 [0/1 (0%)]	Loss: 72.103271
# ====> Epoch: 422 Average loss: 72.1033
# Train Epoch: 423 [0/1 (0%)]	Loss: 72.770050
# ====> Epoch: 423 Average loss: 72.7701
# Train Epoch: 424 [0/1 (0%)]	Loss: 69.397041
# ====> Epoch: 424 Average loss: 69.3970
# Train Epoch: 425 [0/1 (0%)]	Loss: 73.206429
# ====> Epoch: 425 Average loss: 73.2064
# Train Epoch: 426 [0/1 (0%)]	Loss: 78.936966
# ====> Epoch: 426 Average loss: 78.9370
# Train Epoch: 427 [0/1 (0%)]	Loss: 72.911316
# ====> Epoch: 427 Average loss: 72.9113
# Train Epoch: 428 [0/1 (0%)]	Loss: 59.648308
# ====> Epoch: 428 Average loss: 59.6483
# Train Epoch: 429 [0/1 (0%)]	Loss: 71.664925
# ====> Epoch: 429 Average loss: 71.6649
# Train Epoch: 430 [0/1 (0%)]	Loss: 59.072723
# ====> Epoch: 430 Average loss: 59.0727
# Train Epoch: 431 [0/1 (0%)]	Loss: 71.007645
# ====> Epoch: 431 Average loss: 71.0076
# Train Epoch: 432 [0/1 (0%)]	Loss: 63.894707
# ====> Epoch: 432 Average loss: 63.8947
# Train Epoch: 433 [0/1 (0%)]	Loss: 80.989914
# ====> Epoch: 433 Average loss: 80.9899
# Train Epoch: 434 [0/1 (0%)]	Loss: 79.111328
# ====> Epoch: 434 Average loss: 79.1113
# Train Epoch: 435 [0/1 (0%)]	Loss: 60.925987
# ====> Epoch: 435 Average loss: 60.9260
# Train Epoch: 436 [0/1 (0%)]	Loss: 67.203323
# ====> Epoch: 436 Average loss: 67.2033
# Train Epoch: 437 [0/1 (0%)]	Loss: 65.222244
# ====> Epoch: 437 Average loss: 65.2222
# Train Epoch: 438 [0/1 (0%)]	Loss: 72.100159
# ====> Epoch: 438 Average loss: 72.1002
# Train Epoch: 439 [0/1 (0%)]	Loss: 78.899200
# ====> Epoch: 439 Average loss: 78.8992
# Train Epoch: 440 [0/1 (0%)]	Loss: 65.733780
# ====> Epoch: 440 Average loss: 65.7338
# Train Epoch: 441 [0/1 (0%)]	Loss: 72.746567
# ====> Epoch: 441 Average loss: 72.7466
# Train Epoch: 442 [0/1 (0%)]	Loss: 76.105621
# ====> Epoch: 442 Average loss: 76.1056
# Train Epoch: 443 [0/1 (0%)]	Loss: 85.142738
# ====> Epoch: 443 Average loss: 85.1427
# Train Epoch: 444 [0/1 (0%)]	Loss: 81.148315
# ====> Epoch: 444 Average loss: 81.1483
# Train Epoch: 445 [0/1 (0%)]	Loss: 65.681488
# ====> Epoch: 445 Average loss: 65.6815
# Train Epoch: 446 [0/1 (0%)]	Loss: 71.986038
# ====> Epoch: 446 Average loss: 71.9860
# Train Epoch: 447 [0/1 (0%)]	Loss: 68.893448
# ====> Epoch: 447 Average loss: 68.8934
# Train Epoch: 448 [0/1 (0%)]	Loss: 57.954903
# ====> Epoch: 448 Average loss: 57.9549
# Train Epoch: 449 [0/1 (0%)]	Loss: 79.642769
# ====> Epoch: 449 Average loss: 79.6428
# Train Epoch: 450 [0/1 (0%)]	Loss: 78.148453
# ====> Epoch: 450 Average loss: 78.1485
# Train Epoch: 451 [0/1 (0%)]	Loss: 65.199303
# ====> Epoch: 451 Average loss: 65.1993
# Train Epoch: 452 [0/1 (0%)]	Loss: 60.674313
# ====> Epoch: 452 Average loss: 60.6743
# Train Epoch: 453 [0/1 (0%)]	Loss: 82.579483
# ====> Epoch: 453 Average loss: 82.5795
# Train Epoch: 454 [0/1 (0%)]	Loss: 64.529358
# ====> Epoch: 454 Average loss: 64.5294
# Train Epoch: 455 [0/1 (0%)]	Loss: 62.858200
# ====> Epoch: 455 Average loss: 62.8582
# Train Epoch: 456 [0/1 (0%)]	Loss: 66.996887
# ====> Epoch: 456 Average loss: 66.9969
# Train Epoch: 457 [0/1 (0%)]	Loss: 76.667931
# ====> Epoch: 457 Average loss: 76.6679
# Train Epoch: 458 [0/1 (0%)]	Loss: 67.363487
# ====> Epoch: 458 Average loss: 67.3635
# Train Epoch: 459 [0/1 (0%)]	Loss: 86.262192
# ====> Epoch: 459 Average loss: 86.2622
# Train Epoch: 460 [0/1 (0%)]	Loss: 63.274857
# ====> Epoch: 460 Average loss: 63.2749
# Train Epoch: 461 [0/1 (0%)]	Loss: 64.431732
# ====> Epoch: 461 Average loss: 64.4317
# Train Epoch: 462 [0/1 (0%)]	Loss: 68.450386
# ====> Epoch: 462 Average loss: 68.4504
# Train Epoch: 463 [0/1 (0%)]	Loss: 57.924774
# ====> Epoch: 463 Average loss: 57.9248
# Train Epoch: 464 [0/1 (0%)]	Loss: 67.183952
# ====> Epoch: 464 Average loss: 67.1840
# Train Epoch: 465 [0/1 (0%)]	Loss: 66.733528
# ====> Epoch: 465 Average loss: 66.7335
# Train Epoch: 466 [0/1 (0%)]	Loss: 66.430115
# ====> Epoch: 466 Average loss: 66.4301
# Train Epoch: 467 [0/1 (0%)]	Loss: 68.981026
# ====> Epoch: 467 Average loss: 68.9810
# Train Epoch: 468 [0/1 (0%)]	Loss: 78.390564
# ====> Epoch: 468 Average loss: 78.3906
# Train Epoch: 469 [0/1 (0%)]	Loss: 66.653351
# ====> Epoch: 469 Average loss: 66.6534
# Train Epoch: 470 [0/1 (0%)]	Loss: 72.138741
# ====> Epoch: 470 Average loss: 72.1387
# Train Epoch: 471 [0/1 (0%)]	Loss: 89.380486
# ====> Epoch: 471 Average loss: 89.3805
# Train Epoch: 472 [0/1 (0%)]	Loss: 83.198227
# ====> Epoch: 472 Average loss: 83.1982
# Train Epoch: 473 [0/1 (0%)]	Loss: 59.096386
# ====> Epoch: 473 Average loss: 59.0964
# Train Epoch: 474 [0/1 (0%)]	Loss: 60.398262
# ====> Epoch: 474 Average loss: 60.3983
# Train Epoch: 475 [0/1 (0%)]	Loss: 63.133976
# ====> Epoch: 475 Average loss: 63.1340
# Train Epoch: 476 [0/1 (0%)]	Loss: 75.848701
# ====> Epoch: 476 Average loss: 75.8487
# Train Epoch: 477 [0/1 (0%)]	Loss: 77.275803
# ====> Epoch: 477 Average loss: 77.2758
# Train Epoch: 478 [0/1 (0%)]	Loss: 81.848175
# ====> Epoch: 478 Average loss: 81.8482
# Train Epoch: 479 [0/1 (0%)]	Loss: 68.876068
# ====> Epoch: 479 Average loss: 68.8761
# Train Epoch: 480 [0/1 (0%)]	Loss: 84.873131
# ====> Epoch: 480 Average loss: 84.8731
# Train Epoch: 481 [0/1 (0%)]	Loss: 72.794037
# ====> Epoch: 481 Average loss: 72.7940
# Train Epoch: 482 [0/1 (0%)]	Loss: 74.512993
# ====> Epoch: 482 Average loss: 74.5130
# Train Epoch: 483 [0/1 (0%)]	Loss: 66.300468
# ====> Epoch: 483 Average loss: 66.3005
# Train Epoch: 484 [0/1 (0%)]	Loss: 68.120628
# ====> Epoch: 484 Average loss: 68.1206
# Train Epoch: 485 [0/1 (0%)]	Loss: 65.820633
# ====> Epoch: 485 Average loss: 65.8206
# Train Epoch: 486 [0/1 (0%)]	Loss: 73.959534
# ====> Epoch: 486 Average loss: 73.9595
# Train Epoch: 487 [0/1 (0%)]	Loss: 58.737938
# ====> Epoch: 487 Average loss: 58.7379
# Train Epoch: 488 [0/1 (0%)]	Loss: 57.337955
# ====> Epoch: 488 Average loss: 57.3380
# Train Epoch: 489 [0/1 (0%)]	Loss: 58.741257
# ====> Epoch: 489 Average loss: 58.7413
# Train Epoch: 490 [0/1 (0%)]	Loss: 61.287369
# ====> Epoch: 490 Average loss: 61.2874
# Train Epoch: 491 [0/1 (0%)]	Loss: 62.676781
# ====> Epoch: 491 Average loss: 62.6768
# Train Epoch: 492 [0/1 (0%)]	Loss: 78.557449
# ====> Epoch: 492 Average loss: 78.5574
# Train Epoch: 493 [0/1 (0%)]	Loss: 68.195412
# ====> Epoch: 493 Average loss: 68.1954
# Train Epoch: 494 [0/1 (0%)]	Loss: 60.233482
# ====> Epoch: 494 Average loss: 60.2335
# Train Epoch: 495 [0/1 (0%)]	Loss: 63.676674
# ====> Epoch: 495 Average loss: 63.6767
# Train Epoch: 496 [0/1 (0%)]	Loss: 68.088890
# ====> Epoch: 496 Average loss: 68.0889
# Train Epoch: 497 [0/1 (0%)]	Loss: 60.870750
# ====> Epoch: 497 Average loss: 60.8708
# Train Epoch: 498 [0/1 (0%)]	Loss: 69.644981
# ====> Epoch: 498 Average loss: 69.6450
# Train Epoch: 499 [0/1 (0%)]	Loss: 60.362835
# ====> Epoch: 499 Average loss: 60.3628
# Train Epoch: 500 [0/1 (0%)]	Loss: 79.817192
# ====> Epoch: 500 Average loss: 79.8172
# Train Epoch: 501 [0/1 (0%)]	Loss: 66.439972
# ====> Epoch: 501 Average loss: 66.4400
# Train Epoch: 502 [0/1 (0%)]	Loss: 67.582924
# ====> Epoch: 502 Average loss: 67.5829
# Train Epoch: 503 [0/1 (0%)]	Loss: 69.214592
# ====> Epoch: 503 Average loss: 69.2146
# Train Epoch: 504 [0/1 (0%)]	Loss: 57.721474
# ====> Epoch: 504 Average loss: 57.7215
# Train Epoch: 505 [0/1 (0%)]	Loss: 70.144905
# ====> Epoch: 505 Average loss: 70.1449
# Train Epoch: 506 [0/1 (0%)]	Loss: 60.402756
# ====> Epoch: 506 Average loss: 60.4028
# Train Epoch: 507 [0/1 (0%)]	Loss: 70.960686
# ====> Epoch: 507 Average loss: 70.9607
# Train Epoch: 508 [0/1 (0%)]	Loss: 56.338314
# ====> Epoch: 508 Average loss: 56.3383
# Train Epoch: 509 [0/1 (0%)]	Loss: 72.935547
# ====> Epoch: 509 Average loss: 72.9355
# Train Epoch: 510 [0/1 (0%)]	Loss: 87.558266
# ====> Epoch: 510 Average loss: 87.5583
# Train Epoch: 511 [0/1 (0%)]	Loss: 73.122871
# ====> Epoch: 511 Average loss: 73.1229
# Train Epoch: 512 [0/1 (0%)]	Loss: 59.526299
# ====> Epoch: 512 Average loss: 59.5263
# Train Epoch: 513 [0/1 (0%)]	Loss: 65.917953
# ====> Epoch: 513 Average loss: 65.9180
# Train Epoch: 514 [0/1 (0%)]	Loss: 58.802307
# ====> Epoch: 514 Average loss: 58.8023
# Train Epoch: 515 [0/1 (0%)]	Loss: 83.703842
# ====> Epoch: 515 Average loss: 83.7038
# Train Epoch: 516 [0/1 (0%)]	Loss: 59.782661
# ====> Epoch: 516 Average loss: 59.7827
# Train Epoch: 517 [0/1 (0%)]	Loss: 61.480579
# ====> Epoch: 517 Average loss: 61.4806
# Train Epoch: 518 [0/1 (0%)]	Loss: 78.634567
# ====> Epoch: 518 Average loss: 78.6346
# Train Epoch: 519 [0/1 (0%)]	Loss: 57.952271
# ====> Epoch: 519 Average loss: 57.9523
# Train Epoch: 520 [0/1 (0%)]	Loss: 62.572060
# ====> Epoch: 520 Average loss: 62.5721
# Train Epoch: 521 [0/1 (0%)]	Loss: 58.926846
# ====> Epoch: 521 Average loss: 58.9268
# Train Epoch: 522 [0/1 (0%)]	Loss: 60.126930
# ====> Epoch: 522 Average loss: 60.1269
# Train Epoch: 523 [0/1 (0%)]	Loss: 65.952660
# ====> Epoch: 523 Average loss: 65.9527
# Train Epoch: 524 [0/1 (0%)]	Loss: 65.728714
# ====> Epoch: 524 Average loss: 65.7287
# Train Epoch: 525 [0/1 (0%)]	Loss: 62.360176
# ====> Epoch: 525 Average loss: 62.3602
# Train Epoch: 526 [0/1 (0%)]	Loss: 66.595024
# ====> Epoch: 526 Average loss: 66.5950
# Train Epoch: 527 [0/1 (0%)]	Loss: 78.910065
# ====> Epoch: 527 Average loss: 78.9101
# Train Epoch: 528 [0/1 (0%)]	Loss: 47.638615
# ====> Epoch: 528 Average loss: 47.6386
# Train Epoch: 529 [0/1 (0%)]	Loss: 56.911716
# ====> Epoch: 529 Average loss: 56.9117
# Train Epoch: 530 [0/1 (0%)]	Loss: 71.700531
# ====> Epoch: 530 Average loss: 71.7005
# Train Epoch: 531 [0/1 (0%)]	Loss: 64.505333
# ====> Epoch: 531 Average loss: 64.5053
# Train Epoch: 532 [0/1 (0%)]	Loss: 59.971264
# ====> Epoch: 532 Average loss: 59.9713
# Train Epoch: 533 [0/1 (0%)]	Loss: 61.157925
# ====> Epoch: 533 Average loss: 61.1579
# Train Epoch: 534 [0/1 (0%)]	Loss: 88.876518
# ====> Epoch: 534 Average loss: 88.8765
# Train Epoch: 535 [0/1 (0%)]	Loss: 68.635559
# ====> Epoch: 535 Average loss: 68.6356
# Train Epoch: 536 [0/1 (0%)]	Loss: 56.022491
# ====> Epoch: 536 Average loss: 56.0225
# Train Epoch: 537 [0/1 (0%)]	Loss: 102.904045
# ====> Epoch: 537 Average loss: 102.9040
# Train Epoch: 538 [0/1 (0%)]	Loss: 56.009632
# ====> Epoch: 538 Average loss: 56.0096
# Train Epoch: 539 [0/1 (0%)]	Loss: 64.936066
# ====> Epoch: 539 Average loss: 64.9361
# Train Epoch: 540 [0/1 (0%)]	Loss: 59.572693
# ====> Epoch: 540 Average loss: 59.5727
# Train Epoch: 541 [0/1 (0%)]	Loss: 65.514519
# ====> Epoch: 541 Average loss: 65.5145
# Train Epoch: 542 [0/1 (0%)]	Loss: 58.700344
# ====> Epoch: 542 Average loss: 58.7003
# Train Epoch: 543 [0/1 (0%)]	Loss: 70.181412
# ====> Epoch: 543 Average loss: 70.1814
# Train Epoch: 544 [0/1 (0%)]	Loss: 56.061752
# ====> Epoch: 544 Average loss: 56.0618
# Train Epoch: 545 [0/1 (0%)]	Loss: 66.232025
# ====> Epoch: 545 Average loss: 66.2320
# Train Epoch: 546 [0/1 (0%)]	Loss: 74.657524
# ====> Epoch: 546 Average loss: 74.6575
# Train Epoch: 547 [0/1 (0%)]	Loss: 61.583752
# ====> Epoch: 547 Average loss: 61.5838
# Train Epoch: 548 [0/1 (0%)]	Loss: 64.804008
# ====> Epoch: 548 Average loss: 64.8040
# Train Epoch: 549 [0/1 (0%)]	Loss: 74.797653
# ====> Epoch: 549 Average loss: 74.7977
# Train Epoch: 550 [0/1 (0%)]	Loss: 69.590019
# ====> Epoch: 550 Average loss: 69.5900
# Train Epoch: 551 [0/1 (0%)]	Loss: 69.962166
# ====> Epoch: 551 Average loss: 69.9622
# Train Epoch: 552 [0/1 (0%)]	Loss: 72.567749
# ====> Epoch: 552 Average loss: 72.5677
# Train Epoch: 553 [0/1 (0%)]	Loss: 55.294930
# ====> Epoch: 553 Average loss: 55.2949
# Train Epoch: 554 [0/1 (0%)]	Loss: 64.000740
# ====> Epoch: 554 Average loss: 64.0007
# Train Epoch: 555 [0/1 (0%)]	Loss: 75.745453
# ====> Epoch: 555 Average loss: 75.7455
# Train Epoch: 556 [0/1 (0%)]	Loss: 62.094273
# ====> Epoch: 556 Average loss: 62.0943
# Train Epoch: 557 [0/1 (0%)]	Loss: 65.289627
# ====> Epoch: 557 Average loss: 65.2896
# Train Epoch: 558 [0/1 (0%)]	Loss: 67.911766
# ====> Epoch: 558 Average loss: 67.9118
# Train Epoch: 559 [0/1 (0%)]	Loss: 56.321304
# ====> Epoch: 559 Average loss: 56.3213
# Train Epoch: 560 [0/1 (0%)]	Loss: 61.825790
# ====> Epoch: 560 Average loss: 61.8258
# Train Epoch: 561 [0/1 (0%)]	Loss: 53.612640
# ====> Epoch: 561 Average loss: 53.6126
# Train Epoch: 562 [0/1 (0%)]	Loss: 51.912582
# ====> Epoch: 562 Average loss: 51.9126
# Train Epoch: 563 [0/1 (0%)]	Loss: 66.682762
# ====> Epoch: 563 Average loss: 66.6828
# Train Epoch: 564 [0/1 (0%)]	Loss: 69.009888
# ====> Epoch: 564 Average loss: 69.0099
# Train Epoch: 565 [0/1 (0%)]	Loss: 81.348473
# ====> Epoch: 565 Average loss: 81.3485
# Train Epoch: 566 [0/1 (0%)]	Loss: 52.443592
# ====> Epoch: 566 Average loss: 52.4436
# Train Epoch: 567 [0/1 (0%)]	Loss: 61.420982
# ====> Epoch: 567 Average loss: 61.4210
# Train Epoch: 568 [0/1 (0%)]	Loss: 85.226204
# ====> Epoch: 568 Average loss: 85.2262
# Train Epoch: 569 [0/1 (0%)]	Loss: 81.305107
# ====> Epoch: 569 Average loss: 81.3051
# Train Epoch: 570 [0/1 (0%)]	Loss: 63.288879
# ====> Epoch: 570 Average loss: 63.2889
# Train Epoch: 571 [0/1 (0%)]	Loss: 69.998436
# ====> Epoch: 571 Average loss: 69.9984
# Train Epoch: 572 [0/1 (0%)]	Loss: 59.160053
# ====> Epoch: 572 Average loss: 59.1601
# Train Epoch: 573 [0/1 (0%)]	Loss: 56.552063
# ====> Epoch: 573 Average loss: 56.5521
# Train Epoch: 574 [0/1 (0%)]	Loss: 86.162621
# ====> Epoch: 574 Average loss: 86.1626
# Train Epoch: 575 [0/1 (0%)]	Loss: 63.511456
# ====> Epoch: 575 Average loss: 63.5115
# Train Epoch: 576 [0/1 (0%)]	Loss: 61.540264
# ====> Epoch: 576 Average loss: 61.5403
# Train Epoch: 577 [0/1 (0%)]	Loss: 65.115791
# ====> Epoch: 577 Average loss: 65.1158
# Train Epoch: 578 [0/1 (0%)]	Loss: 58.779076
# ====> Epoch: 578 Average loss: 58.7791
# Train Epoch: 579 [0/1 (0%)]	Loss: 67.256874
# ====> Epoch: 579 Average loss: 67.2569
# ...
# ====> Epoch: 807 Average loss: 50.9757
# Train Epoch: 808 [0/1 (0%)]	Loss: 50.146778
# ====> Epoch: 808 Average loss: 50.1468
# Train Epoch: 809 [0/1 (0%)]	Loss: 50.241241
# ====> Epoch: 809 Average loss: 50.2412
# Train Epoch: 810 [0/1 (0%)]	Loss: 53.120335
# ====> Epoch: 810 Average loss: 53.1203
# Train Epoch: 811 [0/1 (0%)]	Loss: 53.229794
# ====> Epoch: 811 Average loss: 53.2298
# Train Epoch: 812 [0/1 (0%)]	Loss: 59.438053
# ====> Epoch: 812 Average loss: 59.4381
# Train Epoch: 813 [0/1 (0%)]	Loss: 59.110668
# ====> Epoch: 813 Average loss: 59.1107
# Train Epoch: 814 [0/1 (0%)]	Loss: 52.591892
# ====> Epoch: 814 Average loss: 52.5919
# Train Epoch: 815 [0/1 (0%)]	Loss: 41.238586
# ====> Epoch: 815 Average loss: 41.2386
# Train Epoch: 816 [0/1 (0%)]	Loss: 57.529469
# ====> Epoch: 816 Average loss: 57.5295
# Train Epoch: 817 [0/1 (0%)]	Loss: 63.213799
# ====> Epoch: 817 Average loss: 63.2138
# Train Epoch: 818 [0/1 (0%)]	Loss: 59.256973
# ====> Epoch: 818 Average loss: 59.2570
# Train Epoch: 819 [0/1 (0%)]	Loss: 49.978546
# ====> Epoch: 819 Average loss: 49.9785
# Train Epoch: 820 [0/1 (0%)]	Loss: 60.709930
# ====> Epoch: 820 Average loss: 60.7099
# Train Epoch: 821 [0/1 (0%)]	Loss: 63.293789
# ====> Epoch: 821 Average loss: 63.2938
# Train Epoch: 822 [0/1 (0%)]	Loss: 50.164902
# ====> Epoch: 822 Average loss: 50.1649
# Train Epoch: 823 [0/1 (0%)]	Loss: 67.628151
# ====> Epoch: 823 Average loss: 67.6282
# Train Epoch: 824 [0/1 (0%)]	Loss: 59.523811
# ====> Epoch: 824 Average loss: 59.5238
# Train Epoch: 825 [0/1 (0%)]	Loss: 54.302067
# ====> Epoch: 825 Average loss: 54.3021
# Train Epoch: 826 [0/1 (0%)]	Loss: 59.656391
# ====> Epoch: 826 Average loss: 59.6564
# Train Epoch: 827 [0/1 (0%)]	Loss: 83.484138
# ====> Epoch: 827 Average loss: 83.4841
# Train Epoch: 828 [0/1 (0%)]	Loss: 51.791210
# ====> Epoch: 828 Average loss: 51.7912
# Train Epoch: 829 [0/1 (0%)]	Loss: 57.968948
# ====> Epoch: 829 Average loss: 57.9689
# Train Epoch: 830 [0/1 (0%)]	Loss: 54.256485
# ====> Epoch: 830 Average loss: 54.2565
# Train Epoch: 831 [0/1 (0%)]	Loss: 51.391369
# ====> Epoch: 831 Average loss: 51.3914
# Train Epoch: 832 [0/1 (0%)]	Loss: 50.912262
# ====> Epoch: 832 Average loss: 50.9123
# Train Epoch: 833 [0/1 (0%)]	Loss: 61.145580
# ====> Epoch: 833 Average loss: 61.1456
# Train Epoch: 834 [0/1 (0%)]	Loss: 48.080189
# ====> Epoch: 834 Average loss: 48.0802
# Train Epoch: 835 [0/1 (0%)]	Loss: 62.989838
# ====> Epoch: 835 Average loss: 62.9898
# Train Epoch: 836 [0/1 (0%)]	Loss: 45.047321
# ====> Epoch: 836 Average loss: 45.0473
# Train Epoch: 837 [0/1 (0%)]	Loss: 45.427578
# ====> Epoch: 837 Average loss: 45.4276
# Train Epoch: 838 [0/1 (0%)]	Loss: 47.081699
# ====> Epoch: 838 Average loss: 47.0817
# Train Epoch: 839 [0/1 (0%)]	Loss: 50.639194
# ====> Epoch: 839 Average loss: 50.6392
# Train Epoch: 840 [0/1 (0%)]	Loss: 57.344780
# ====> Epoch: 840 Average loss: 57.3448
# Train Epoch: 841 [0/1 (0%)]	Loss: 58.481552
# ====> Epoch: 841 Average loss: 58.4816
# Train Epoch: 842 [0/1 (0%)]	Loss: 59.721191
# ====> Epoch: 842 Average loss: 59.7212
# Train Epoch: 843 [0/1 (0%)]	Loss: 62.667358
# ====> Epoch: 843 Average loss: 62.6674
# Train Epoch: 844 [0/1 (0%)]	Loss: 55.215824
# ====> Epoch: 844 Average loss: 55.2158
# Train Epoch: 845 [0/1 (0%)]	Loss: 52.319431
# ====> Epoch: 845 Average loss: 52.3194
# Train Epoch: 846 [0/1 (0%)]	Loss: 62.162388
# ====> Epoch: 846 Average loss: 62.1624
# Train Epoch: 847 [0/1 (0%)]	Loss: 63.519573
# ====> Epoch: 847 Average loss: 63.5196
# Train Epoch: 848 [0/1 (0%)]	Loss: 57.708523
# ====> Epoch: 848 Average loss: 57.7085
# Train Epoch: 849 [0/1 (0%)]	Loss: 61.126614
# ====> Epoch: 849 Average loss: 61.1266
# Train Epoch: 850 [0/1 (0%)]	Loss: 52.073868
# ====> Epoch: 850 Average loss: 52.0739
# Train Epoch: 851 [0/1 (0%)]	Loss: 56.699806
# ====> Epoch: 851 Average loss: 56.6998
# Train Epoch: 852 [0/1 (0%)]	Loss: 48.061031
# ====> Epoch: 852 Average loss: 48.0610
# Train Epoch: 853 [0/1 (0%)]	Loss: 57.697113
# ====> Epoch: 853 Average loss: 57.6971
# Train Epoch: 854 [0/1 (0%)]	Loss: 46.897015
# ====> Epoch: 854 Average loss: 46.8970
# Train Epoch: 855 [0/1 (0%)]	Loss: 47.401379
# ====> Epoch: 855 Average loss: 47.4014
# Train Epoch: 856 [0/1 (0%)]	Loss: 51.476147
# ====> Epoch: 856 Average loss: 51.4761
# Train Epoch: 857 [0/1 (0%)]	Loss: 46.389431
# ====> Epoch: 857 Average loss: 46.3894
# Train Epoch: 858 [0/1 (0%)]	Loss: 55.113491
# ====> Epoch: 858 Average loss: 55.1135
# Train Epoch: 859 [0/1 (0%)]	Loss: 55.814678
# ====> Epoch: 859 Average loss: 55.8147
# Train Epoch: 860 [0/1 (0%)]	Loss: 54.871449
# ====> Epoch: 860 Average loss: 54.8714
# Train Epoch: 861 [0/1 (0%)]	Loss: 65.404137
# ====> Epoch: 861 Average loss: 65.4041
# Train Epoch: 862 [0/1 (0%)]	Loss: 65.899551
# ====> Epoch: 862 Average loss: 65.8996
# Train Epoch: 863 [0/1 (0%)]	Loss: 59.873642
# ====> Epoch: 863 Average loss: 59.8736
# Train Epoch: 864 [0/1 (0%)]	Loss: 61.945473
# ====> Epoch: 864 Average loss: 61.9455
# Train Epoch: 865 [0/1 (0%)]	Loss: 63.820404
# ====> Epoch: 865 Average loss: 63.8204
# Train Epoch: 866 [0/1 (0%)]	Loss: 56.237617
# ====> Epoch: 866 Average loss: 56.2376
# Train Epoch: 867 [0/1 (0%)]	Loss: 57.468502
# ====> Epoch: 867 Average loss: 57.4685
# Train Epoch: 868 [0/1 (0%)]	Loss: 43.804115
# ====> Epoch: 868 Average loss: 43.8041
# Train Epoch: 869 [0/1 (0%)]	Loss: 62.023064
# ====> Epoch: 869 Average loss: 62.0231
# Train Epoch: 870 [0/1 (0%)]	Loss: 54.323013
# ====> Epoch: 870 Average loss: 54.3230
# Train Epoch: 871 [0/1 (0%)]	Loss: 48.347221
# ====> Epoch: 871 Average loss: 48.3472
# Train Epoch: 872 [0/1 (0%)]	Loss: 63.397255
# ====> Epoch: 872 Average loss: 63.3973
# Train Epoch: 873 [0/1 (0%)]	Loss: 54.470806
# ====> Epoch: 873 Average loss: 54.4708
# Train Epoch: 874 [0/1 (0%)]	Loss: 49.225807
# ====> Epoch: 874 Average loss: 49.2258
# Train Epoch: 875 [0/1 (0%)]	Loss: 51.827515
# ====> Epoch: 875 Average loss: 51.8275
# Train Epoch: 876 [0/1 (0%)]	Loss: 58.675835
# ====> Epoch: 876 Average loss: 58.6758
# Train Epoch: 877 [0/1 (0%)]	Loss: 59.661438
# ====> Epoch: 877 Average loss: 59.6614
# Train Epoch: 878 [0/1 (0%)]	Loss: 63.957573
# ====> Epoch: 878 Average loss: 63.9576
# Train Epoch: 879 [0/1 (0%)]	Loss: 55.405685
# ====> Epoch: 879 Average loss: 55.4057
# Train Epoch: 880 [0/1 (0%)]	Loss: 59.162155
# ====> Epoch: 880 Average loss: 59.1622
# Train Epoch: 881 [0/1 (0%)]	Loss: 56.681580
# ====> Epoch: 881 Average loss: 56.6816
# Train Epoch: 882 [0/1 (0%)]	Loss: 48.867146
# ====> Epoch: 882 Average loss: 48.8671
# Train Epoch: 883 [0/1 (0%)]	Loss: 63.377346
# ====> Epoch: 883 Average loss: 63.3773
# Train Epoch: 884 [0/1 (0%)]	Loss: 67.559494
# ====> Epoch: 884 Average loss: 67.5595
# Train Epoch: 885 [0/1 (0%)]	Loss: 57.956779
# ====> Epoch: 885 Average loss: 57.9568
# Train Epoch: 886 [0/1 (0%)]	Loss: 51.439030
# ====> Epoch: 886 Average loss: 51.4390
# Train Epoch: 887 [0/1 (0%)]	Loss: 46.008190
# ====> Epoch: 887 Average loss: 46.0082
# Train Epoch: 888 [0/1 (0%)]	Loss: 53.920197
# ====> Epoch: 888 Average loss: 53.9202
# Train Epoch: 889 [0/1 (0%)]	Loss: 49.214218
# ====> Epoch: 889 Average loss: 49.2142
# Train Epoch: 890 [0/1 (0%)]	Loss: 54.126923
# ====> Epoch: 890 Average loss: 54.1269
# Train Epoch: 891 [0/1 (0%)]	Loss: 47.779137
# ====> Epoch: 891 Average loss: 47.7791
# Train Epoch: 892 [0/1 (0%)]	Loss: 53.857346
# ====> Epoch: 892 Average loss: 53.8573
# Train Epoch: 893 [0/1 (0%)]	Loss: 52.985008
# ====> Epoch: 893 Average loss: 52.9850
# Train Epoch: 894 [0/1 (0%)]	Loss: 50.696373
# ====> Epoch: 894 Average loss: 50.6964
# Train Epoch: 895 [0/1 (0%)]	Loss: 46.450932
# ====> Epoch: 895 Average loss: 46.4509
# Train Epoch: 896 [0/1 (0%)]	Loss: 70.690651
# ====> Epoch: 896 Average loss: 70.6907
# Train Epoch: 897 [0/1 (0%)]	Loss: 56.495735
# ====> Epoch: 897 Average loss: 56.4957
# Train Epoch: 898 [0/1 (0%)]	Loss: 56.710648
# ====> Epoch: 898 Average loss: 56.7106
# Train Epoch: 899 [0/1 (0%)]	Loss: 49.359203
# ====> Epoch: 899 Average loss: 49.3592
# Train Epoch: 900 [0/1 (0%)]	Loss: 65.445358
# ====> Epoch: 900 Average loss: 65.4454
# Train Epoch: 901 [0/1 (0%)]	Loss: 49.065704
# ====> Epoch: 901 Average loss: 49.0657
# Train Epoch: 902 [0/1 (0%)]	Loss: 51.634560
# ====> Epoch: 902 Average loss: 51.6346
# Train Epoch: 903 [0/1 (0%)]	Loss: 51.747505
# ====> Epoch: 903 Average loss: 51.7475
# Train Epoch: 904 [0/1 (0%)]	Loss: 46.017693
# ====> Epoch: 904 Average loss: 46.0177
# Train Epoch: 905 [0/1 (0%)]	Loss: 60.653545
# ====> Epoch: 905 Average loss: 60.6535
# Train Epoch: 906 [0/1 (0%)]	Loss: 52.274097
# ====> Epoch: 906 Average loss: 52.2741
# Train Epoch: 907 [0/1 (0%)]	Loss: 51.429142
# ====> Epoch: 907 Average loss: 51.4291
# Train Epoch: 908 [0/1 (0%)]	Loss: 43.274609
# ====> Epoch: 908 Average loss: 43.2746
# Train Epoch: 909 [0/1 (0%)]	Loss: 66.623390
# ====> Epoch: 909 Average loss: 66.6234
# Train Epoch: 910 [0/1 (0%)]	Loss: 53.943645
# ====> Epoch: 910 Average loss: 53.9436
# Train Epoch: 911 [0/1 (0%)]	Loss: 48.810936
# ====> Epoch: 911 Average loss: 48.8109
# Train Epoch: 912 [0/1 (0%)]	Loss: 55.318687
# ====> Epoch: 912 Average loss: 55.3187
# Train Epoch: 913 [0/1 (0%)]	Loss: 52.194691
# ====> Epoch: 913 Average loss: 52.1947
# Train Epoch: 914 [0/1 (0%)]	Loss: 54.541710
# ====> Epoch: 914 Average loss: 54.5417
# Train Epoch: 915 [0/1 (0%)]	Loss: 49.688099
# ====> Epoch: 915 Average loss: 49.6881
# Train Epoch: 916 [0/1 (0%)]	Loss: 41.411118
# ====> Epoch: 916 Average loss: 41.4111
# Train Epoch: 917 [0/1 (0%)]	Loss: 49.547401
# ====> Epoch: 917 Average loss: 49.5474
# Train Epoch: 918 [0/1 (0%)]	Loss: 40.419636
# ====> Epoch: 918 Average loss: 40.4196
# Train Epoch: 919 [0/1 (0%)]	Loss: 46.459122
# ====> Epoch: 919 Average loss: 46.4591
# Train Epoch: 920 [0/1 (0%)]	Loss: 60.351170
# ====> Epoch: 920 Average loss: 60.3512
# Train Epoch: 921 [0/1 (0%)]	Loss: 58.813435
# ====> Epoch: 921 Average loss: 58.8134
# Train Epoch: 922 [0/1 (0%)]	Loss: 51.784977
# ====> Epoch: 922 Average loss: 51.7850
# Train Epoch: 923 [0/1 (0%)]	Loss: 63.896763
# ====> Epoch: 923 Average loss: 63.8968
# Train Epoch: 924 [0/1 (0%)]	Loss: 51.150082
# ====> Epoch: 924 Average loss: 51.1501
# Train Epoch: 925 [0/1 (0%)]	Loss: 57.597134
# ====> Epoch: 925 Average loss: 57.5971
# Train Epoch: 926 [0/1 (0%)]	Loss: 49.165012
# ====> Epoch: 926 Average loss: 49.1650
# Train Epoch: 927 [0/1 (0%)]	Loss: 54.220089
# ====> Epoch: 927 Average loss: 54.2201
# Train Epoch: 928 [0/1 (0%)]	Loss: 49.364655
# ====> Epoch: 928 Average loss: 49.3647
# Train Epoch: 929 [0/1 (0%)]	Loss: 54.046486
# ====> Epoch: 929 Average loss: 54.0465
# Train Epoch: 930 [0/1 (0%)]	Loss: 60.841133
# ====> Epoch: 930 Average loss: 60.8411
# Train Epoch: 931 [0/1 (0%)]	Loss: 59.279285
# ====> Epoch: 931 Average loss: 59.2793
# Train Epoch: 932 [0/1 (0%)]	Loss: 56.892193
# ====> Epoch: 932 Average loss: 56.8922
# Train Epoch: 933 [0/1 (0%)]	Loss: 62.701935
# ====> Epoch: 933 Average loss: 62.7019
# Train Epoch: 934 [0/1 (0%)]	Loss: 49.202511
# ====> Epoch: 934 Average loss: 49.2025
# Train Epoch: 935 [0/1 (0%)]	Loss: 60.105835
# ====> Epoch: 935 Average loss: 60.1058
# Train Epoch: 936 [0/1 (0%)]	Loss: 54.316196
# ====> Epoch: 936 Average loss: 54.3162
# Train Epoch: 937 [0/1 (0%)]	Loss: 45.928104
# ====> Epoch: 937 Average loss: 45.9281
# Train Epoch: 938 [0/1 (0%)]	Loss: 50.100822
# ====> Epoch: 938 Average loss: 50.1008
# Train Epoch: 939 [0/1 (0%)]	Loss: 55.479298
# ====> Epoch: 939 Average loss: 55.4793
# Train Epoch: 940 [0/1 (0%)]	Loss: 55.060032
# ====> Epoch: 940 Average loss: 55.0600
# Train Epoch: 941 [0/1 (0%)]	Loss: 49.466080
# ====> Epoch: 941 Average loss: 49.4661
# Train Epoch: 942 [0/1 (0%)]	Loss: 54.218227
# ====> Epoch: 942 Average loss: 54.2182
# Train Epoch: 943 [0/1 (0%)]	Loss: 61.566349
# ====> Epoch: 943 Average loss: 61.5663
# Train Epoch: 944 [0/1 (0%)]	Loss: 51.178829
# ====> Epoch: 944 Average loss: 51.1788
# Train Epoch: 945 [0/1 (0%)]	Loss: 43.633751
# ====> Epoch: 945 Average loss: 43.6338
# Train Epoch: 946 [0/1 (0%)]	Loss: 46.056152
# ====> Epoch: 946 Average loss: 46.0562
# Train Epoch: 947 [0/1 (0%)]	Loss: 44.612904
# ====> Epoch: 947 Average loss: 44.6129
# Train Epoch: 948 [0/1 (0%)]	Loss: 52.310875
# ====> Epoch: 948 Average loss: 52.3109
# Train Epoch: 949 [0/1 (0%)]	Loss: 47.052483
# ====> Epoch: 949 Average loss: 47.0525
# Train Epoch: 950 [0/1 (0%)]	Loss: 54.659492
# ====> Epoch: 950 Average loss: 54.6595
# Train Epoch: 951 [0/1 (0%)]	Loss: 53.944923
# ====> Epoch: 951 Average loss: 53.9449
# Train Epoch: 952 [0/1 (0%)]	Loss: 44.853363
# ====> Epoch: 952 Average loss: 44.8534
# Train Epoch: 953 [0/1 (0%)]	Loss: 53.961178
# ====> Epoch: 953 Average loss: 53.9612
# Train Epoch: 954 [0/1 (0%)]	Loss: 50.224388
# ====> Epoch: 954 Average loss: 50.2244
# Train Epoch: 955 [0/1 (0%)]	Loss: 65.639450
# ====> Epoch: 955 Average loss: 65.6395
# Train Epoch: 956 [0/1 (0%)]	Loss: 56.556385
# ====> Epoch: 956 Average loss: 56.5564
# Train Epoch: 957 [0/1 (0%)]	Loss: 53.611469
# ====> Epoch: 957 Average loss: 53.6115
# Train Epoch: 958 [0/1 (0%)]	Loss: 51.202011
# ====> Epoch: 958 Average loss: 51.2020
# Train Epoch: 959 [0/1 (0%)]	Loss: 59.419941
# ====> Epoch: 959 Average loss: 59.4199
# Train Epoch: 960 [0/1 (0%)]	Loss: 43.563625
# ====> Epoch: 960 Average loss: 43.5636
# Train Epoch: 961 [0/1 (0%)]	Loss: 50.240295
# ====> Epoch: 961 Average loss: 50.2403
# Train Epoch: 962 [0/1 (0%)]	Loss: 52.891670
# ====> Epoch: 962 Average loss: 52.8917
# Train Epoch: 963 [0/1 (0%)]	Loss: 66.194252
# ====> Epoch: 963 Average loss: 66.1943
# Train Epoch: 964 [0/1 (0%)]	Loss: 45.612274
# ====> Epoch: 964 Average loss: 45.6123
# Train Epoch: 965 [0/1 (0%)]	Loss: 49.668800
# ====> Epoch: 965 Average loss: 49.6688
# Train Epoch: 966 [0/1 (0%)]	Loss: 44.851063
# ====> Epoch: 966 Average loss: 44.8511
# Train Epoch: 967 [0/1 (0%)]	Loss: 56.737747
# ====> Epoch: 967 Average loss: 56.7377
# Train Epoch: 968 [0/1 (0%)]	Loss: 59.365978
# ====> Epoch: 968 Average loss: 59.3660
# Train Epoch: 969 [0/1 (0%)]	Loss: 47.916325
# ====> Epoch: 969 Average loss: 47.9163
# Train Epoch: 970 [0/1 (0%)]	Loss: 54.395657
# ====> Epoch: 970 Average loss: 54.3957
# Train Epoch: 971 [0/1 (0%)]	Loss: 63.966908
# ====> Epoch: 971 Average loss: 63.9669
# Train Epoch: 972 [0/1 (0%)]	Loss: 49.586281
# ====> Epoch: 972 Average loss: 49.5863
# Train Epoch: 973 [0/1 (0%)]	Loss: 61.631172
# ====> Epoch: 973 Average loss: 61.6312
# Train Epoch: 974 [0/1 (0%)]	Loss: 46.084019
# ====> Epoch: 974 Average loss: 46.0840
# Train Epoch: 975 [0/1 (0%)]	Loss: 49.242870
# ====> Epoch: 975 Average loss: 49.2429
# Train Epoch: 976 [0/1 (0%)]	Loss: 50.338966
# ====> Epoch: 976 Average loss: 50.3390
# Train Epoch: 977 [0/1 (0%)]	Loss: 48.113838
# ====> Epoch: 977 Average loss: 48.1138
# Train Epoch: 978 [0/1 (0%)]	Loss: 44.285004
# ====> Epoch: 978 Average loss: 44.2850
# Train Epoch: 979 [0/1 (0%)]	Loss: 46.884151
# ====> Epoch: 979 Average loss: 46.8842
# Train Epoch: 980 [0/1 (0%)]	Loss: 58.124561
# ====> Epoch: 980 Average loss: 58.1246
# Train Epoch: 981 [0/1 (0%)]	Loss: 60.651154
# ====> Epoch: 981 Average loss: 60.6512
# Train Epoch: 982 [0/1 (0%)]	Loss: 52.018673
# ====> Epoch: 982 Average loss: 52.0187
# Train Epoch: 983 [0/1 (0%)]	Loss: 55.344543
# ====> Epoch: 983 Average loss: 55.3445
# Train Epoch: 984 [0/1 (0%)]	Loss: 48.529587
# ====> Epoch: 984 Average loss: 48.5296
# Train Epoch: 985 [0/1 (0%)]	Loss: 45.157017
# ====> Epoch: 985 Average loss: 45.1570
# Train Epoch: 986 [0/1 (0%)]	Loss: 53.287968
# ====> Epoch: 986 Average loss: 53.2880
# Train Epoch: 987 [0/1 (0%)]	Loss: 45.378113
# ====> Epoch: 987 Average loss: 45.3781
# Train Epoch: 988 [0/1 (0%)]	Loss: 52.499287
# ====> Epoch: 988 Average loss: 52.4993
# Train Epoch: 989 [0/1 (0%)]	Loss: 47.645443
# ====> Epoch: 989 Average loss: 47.6454
# Train Epoch: 990 [0/1 (0%)]	Loss: 51.110085
# ====> Epoch: 990 Average loss: 51.1101
# Train Epoch: 991 [0/1 (0%)]	Loss: 47.862263
# ====> Epoch: 991 Average loss: 47.8623
# Train Epoch: 992 [0/1 (0%)]	Loss: 51.760361
# ====> Epoch: 992 Average loss: 51.7604
# Train Epoch: 993 [0/1 (0%)]	Loss: 44.647240
# ====> Epoch: 993 Average loss: 44.6472
# Train Epoch: 994 [0/1 (0%)]	Loss: 46.883896
# ====> Epoch: 994 Average loss: 46.8839
# Train Epoch: 995 [0/1 (0%)]	Loss: 38.416061
# ====> Epoch: 995 Average loss: 38.4161
# Train Epoch: 996 [0/1 (0%)]	Loss: 47.292255
# ====> Epoch: 996 Average loss: 47.2923
# Train Epoch: 997 [0/1 (0%)]	Loss: 50.360008
# ====> Epoch: 997 Average loss: 50.3600
# Train Epoch: 998 [0/1 (0%)]	Loss: 49.310844
# ====> Epoch: 998 Average loss: 49.3108
# Train Epoch: 999 [0/1 (0%)]	Loss: 45.186958
# ====> Epoch: 999 Average loss: 45.1870

# %%
def compare(dataset, model, VQ=True):
    model.eval()
    rec = []
    x = []
    T = dataset.dataset.data.shape[1]- L
    idx = 0
    _mu_rec, _logvar_rec = [], []
    _mu, _logvar = [], []
#     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
#     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
    with torch.no_grad():
        for i, (data, v) in enumerate(dataset):
            bs = data.shape[0]
            if VQ:
                x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
            else:
                x_rec, mu, logvar = model(data)
            z = model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
#             print(i)
#             print(mu.shape)

            x.extend((data)[0,:,:].detach().numpy())
            rec.extend(((x_rec)[0,:,:]).detach().numpy())
            _mu_rec.extend((mu_rec)[0,:,:].detach().numpy())
            _logvar_rec.extend(((torch.exp(0.5 * logvar_rec)))[0,:,:].detach().numpy())
            
            _mu.extend((mu)[0,:,0].detach().numpy())
            _logvar.extend(((torch.exp(0.5 * logvar)))[0,:,:].detach().numpy())
#             _mu[idx: idx + bs, :, :] = mu
#             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
#     print(np.array(_mu).shape)
    
    x = np.array(x).T
    rec = np.array(rec).T
    _mu = np.tile(np.array(_mu), (3455, 1))
    _logvar = np.tile(np.array(_logvar), (3455, 1))
    _mu_rec = np.tile(np.array(_mu_rec), (3455, 1))
    _logvar_rec = np.tile(np.array(_logvar_rec), (3455, 1))
    print(_logvar.shape)
    print(x.shape)
    print(rec.shape)
    print(T)
#     print(params["cov"][0,:,:L].T)
    fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10, 15))
    ax = axs[0]
    ax.plot(rec, "r-")
    ax.plot(x[:], "b-", alpha=0.2)
    ax.plot(_mu_rec)
    ax.plot(params["mu"].T[:_mu.shape[0],:])
    ax.grid()
    
    ax_std = axs[1]
    ax_std.plot(_logvar_rec, "r")
    ax_std.plot(params["cov"][0,:,:L].T, "b")
    ax_std.grid()
    
    ax_enc = axs[2]
    for (i,l) in enumerate(_mu.T):        
        ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
#     ax_enc.plot(_mu, alpha = 0.2)
    ax_enc.grid()
    
    ax_log = axs[3]
    for (i,l) in enumerate(_logvar.T):        
        ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
    ax_log.grid()
    
    # Setting legend
    blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
    red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
    titles = ['Prediction of Train Data', 'Std plot', 'mu encoder vs mu from gen', 'logvar encoder vs cov']
    for (i,ax) in enumerate(axs):
        # ax.set_title('Reconstruction of Train Data')
        ax.set_title(titles[i])
        ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
    # Axes labels
    ax_std.set_xlabel('Time')
    ax.set_ylabel('Values')
    ax_std.set_ylabel('Values')
#     plt.ylim(-100,500)
#     plt.grid(True)
    fig.tight_layout()
    plt.show()
# def compare(dataset, model, VQ=True):
#     model.eval()
#     rec = []
#     x = []
#     T = dataset.dataset.data.shape[1]- L
#     idx = 0
#     _mu_rec, _logvar_rec = [], []
#     _mu, _logvar = [], []
# #     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
# #     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
#     with torch.no_grad():
#         for i, (data, v) in enumerate(dataset):
#             bs = data.shape[0]
#             if VQ:
#                 x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
#             else:
#                 x_rec, mu, logvar = model(data)
#             z = model.reparametrization_trick(mu, logvar)
#             print(v.shape)
#             if v.dim() == 1:
#                 v = v.unsqueeze(0)
#                 v = v.T
#                 v = v.unsqueeze(-1)
# #             print(v.shape)
# #             print(x_rec.shape)
# #             print((x_rec * v).shape)
# #             print(i)
# #             print(mu.shape)

#             x.extend((data)[:,:,:].detach().numpy())
#             rec.extend(((x_rec)[:,:,:]).detach().numpy())
# #             _mu_rec.extend((mu_rec*v)[:,:,0].detach().numpy())
# #             _logvar_rec.extend(((torch.exp(0.5 * logvar_rec))*v)[:,:,0].detach().numpy())
            
# #             _mu.extend((mu*v)[:,:,0].detach().numpy())
# #             _logvar.extend(((torch.exp(0.5 * logvar))*v)[:,:,0].detach().numpy())
# #             _mu[idx: idx + bs, :, :] = mu
# #             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
# #     print(np.array(rec).shape)
# #     _mu = np.array(_mu)
# #     _logvar = np.array(_logvar)
    
#     rec = np.array(rec).squeeze(0).T
#     x = np.array(x).squeeze(0).T
# #     print(x.shape)
# #     print(rec)
#     fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(10, 4))
#     ax = axs#[0]
#     ax.plot(rec, "r-")
#     ax.plot(x, "b-", alpha=0.2)
# #     ax.plot(_mu_rec)
# #     ax.plot(params["mu"].T[:_mu.shape[0],:])
#     ax.grid()
    
# #     ax_std = axs[1]
# #     ax_std.plot(_logvar_rec, "r")
# #     ax_std.plot(params["cov"][0,:,:T].T, "b")
# #     ax_std.grid()
    
# #     ax_enc = axs[2]
# #     for (i,l) in enumerate(_mu.T):        
# #         ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
# # #     ax_enc.plot(_mu, alpha = 0.2)
# #     ax_enc.grid()
    
# #     ax_log = axs[3]
# #     for (i,l) in enumerate(_logvar.T):        
# #         ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
# #     ax_log.grid()
    
#     # Setting legend
#     blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
#     red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
# #     for ax in axs:
#         # ax.set_title('Reconstruction of Train Data')
#     ax.set_title('Prediction of Test (unseen) Data')
#     ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
#     # Axes labels
# #     ax_std.set_xlabel('Time')
# #     ax.set_ylabel('Values')
# #     ax_std.set_ylabel('Values')
# #     plt.ylim(-100,500)
#     plt.grid(True)
#     fig.tight_layout()
#     plt.show()

# %%
a = torch.randn(1,7).to(x)
# v.quantizer._embedding.weight.detach()[0] = a
v.cpu()
compare(train_data, v, VQ=True)
v.to(device)
# Out:
# (3455, 7)
# (1, 3455)
# (1, 3455)
# 1
# VQ_MST_VAE(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=2586, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=2586, out_features=7, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(30,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=2568, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=2568, out_features=7, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(30,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=84, out_features=3455, bias=True)
#       (decoder_mu): Linear(in_features=84, out_features=3455, bias=True)
#       (decoder_logvar): Linear(in_features=84, out_features=3455, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=56, out_features=3455, bias=True)
#       (decoder_mu): Linear(in_features=56, out_features=3455, bias=True)
#       (decoder_logvar): Linear(in_features=56, out_features=3455, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (quantizer): VQ_Quantizer(
#     (_embedding): Embedding(1, 7)
#   )
#   (bn): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def plot_heatmap(ax_heatmap, codebook):
    ax_heatmap.clear()
    heatmap = ax_heatmap.imshow(codebook)
    ax_heatmap.set_title('Codebook Heatmap')
    ax_heatmap


    return heatmap
def create_heatmap(codebook):
    fig, ax_heatmap = plt.subplots(figsize=(12, 6), dpi=100)
    heatmap = plot_heatmap(ax_heatmap, codebook.T)
#     heatmap_canvas = FigureCanvasTkAgg(fig, master=heatmap_frame)
#     heatmap_canvas.draw()
#     heatmap_canvas.get_tk_widget().pack(fill="both", expand=True)
    cbar = fig.colorbar(heatmap)
    ax_heatmap.set_xlabel('Num of Embeddings')
    ax_heatmap.set_ylabel('Latent Dimensions')
    
    return ax_heatmap

# %%
from matplotlib.figure import Figure
np.set_printoptions(suppress=True)
codebook = v.quantizer._embedding.weight.cpu().detach().numpy()
heatmap = create_heatmap(codebook)
print((codebook))
# Out:
# [[-0.45098442 -0.4689001   2.5947247   2.7749112   0.40284613  1.2883936
#   -0.32179105]]

# %%
a = torch.randn(1,6).to(x)
# v.cpu().detach()
v.quantizer._embedding.weight.detach()[:] = a

# %%
torch.argmin(torch.cdist(a, b, p=2), dim=1).shape
# Out:
# torch.Size([1])

# %%
v.quantizer._embedding.weight
# Out:
# Parameter containing:
# tensor([[-0.6104, -0.3924,  0.4000, -0.5450, -0.2600, -0.4867]],
#        device='cuda:0', requires_grad=True)

# %%
print(v.quantizer._embedding.weight.grad)
# Out:
# None

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(params["mu"].T)
plt.show()

# %%
params["cov"][0]
# Out:
# array([[1., 1., 1., ..., 1., 1., 1.]], dtype=float32)

# %%
a = np.random.randn(100, 10)
a.shape
# Out:
# (100, 10)

# %%
for i in a.T:
    print(i.shape)
# Out:
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)

# %%
print(params["cov"][0,:,:3455].T)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib
# matplotlib.use('Agg')
from dataGen import Gen
from utils import compare, experiment
from train import slidingWindow, criterion, train, test, objective, train_vae
from Encoders import LongShort_TCVAE_Encoder, RnnEncoder, MST_VAE_Encoder, MST_VAE_Encoder_dist
from Decoders import LongShort_TCVAE_Decoder, RnnDecoder, MST_VAE_Decoder, MST_VAE_Decoder_dist
from vae import VariationalAutoencoder, VQ_MST_VAE, VQ_Quantizer

import torch; torch.manual_seed(955)
import torch.optim as optim
import torch.distributions as D
from torch.utils.data import DataLoader
# import optuna
# from optuna.samplers import TPESampler
# import torchaudio

import torch.nn as nn
import torch.nn.functional as F
import torch.distributions as D


import numpy as np
import matplotlib.pyplot as plt
import pprint
# all parameters for generating the time series should be configured in this cell
periode = 15 #days
step = 5 # mess interval in minutes
val = 500
n_channels = 1
effects = {
    "Pulse": {
        "occurances":0,
        "max_amplitude":1.5,   
        "interval":40
        },
    "Trend": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        },
    "Seasonality": {
        "occurances":0,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
# pprint.pprint(params)
pprint.pprint(e_params)
X.show()

def lin_size(n, num_layers, first_kernel = None):
    
    for i in range(0, num_layers):
        
        if i == 0 and first_kernel != None:
            n = 1 + ((n - first_kernel) // 2)
        else:
            n = 1 + ((n - 2) // 2)
            
    if n <= 0:
        raise ValueError("Window Length is too small in relation to the number of Layers")
            
    return n * 2 * num_layers

class TCVAE_Encoder_unified(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None, modified=True):
        super(TCVAE_Encoder_unified, self).__init__()

        self.n = lin_size(L, num_layers, first_kernel)
        self.cnn_layers = nn.ModuleList()
        self.n_channels = input_size
        self.L = L
        self.num_layers = num_layers
        self.latent_dims = latent_dims
        self.modified = modified

        if self.modified:
            self.lin_input = self.n // (2 * self.num_layers)
            self.lin_output = self.latent_dims
        else:
            self.lin_input = self.n * self.n_channels
            self.lin_output = self.latent_dims * self.n_channels

        def init_weights(m):
            if isinstance(m, nn.Conv1d):
                torch.nn.init.kaiming_uniform_(m.weight, mode="fan_in", nonlinearity="leaky_relu")
                m.bias.data.fill_(0.01)

        # CNN Layers that double the channels each time
        for i in range(0, num_layers):
            if i == 0:
                if first_kernel == None: first_kernel = 2
                self.cnn_layers.append(
                    nn.Conv1d(input_size, input_size * 2, kernel_size=first_kernel, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size * 2))
            else:
                self.cnn_layers.append(
                    nn.Conv1d(input_size * 2 * i, input_size * 2 * (i + 1), kernel_size=2, stride=2, padding=0))
                self.cnn_layers.append(nn.LeakyReLU(slope, True))
                self.cnn_layers.append(nn.BatchNorm1d(input_size * 2 * (i + 1)))

        # MLP Layers for Mu and logvar output
        self.encoder_mu = nn.Linear(self.lin_input, self.lin_output)
        self.encoder_logvar = nn.Linear(self.lin_input, self.lin_output)

        # Init CNN
        self.cnn_layers.apply(init_weights)

    def forward(self, x):
        ### CNN
        for i, cnn in enumerate(self.cnn_layers):
            #             print("Encoder Cnn", x.shape)
            x = cnn(x)
        cnn_shape = x.shape
#         print("Encoder after Cnn ", x.shape)
        if not self.modified:
            x = x.view(x.size(0), -1)
#             print("Encoder reshape after Cnn ", x.shape)
        # ### MLP
        mu = self.encoder_mu(x)
        logvar = self.encoder_logvar(x)
        #         print("Encoder mu after lin ", mu.shape)
        if not self.modified:
            mu = mu.view(mu.shape[0], self.n_channels, -1)
            logvar = logvar.view(logvar.shape[0], self.n_channels, -1)
#             print("Encoder mu after reshape ", mu.shape)
        # mu.reshape

        return mu, logvar
    
class LongShort_TCVAE_Encoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None, modified=True,
                 reduction=False):
        super(LongShort_TCVAE_Encoder, self).__init__()
        self.latent_dims = latent_dims
        self.n_channels = input_size
        self._modified = modified
        self._reduction = reduction
        if modified:
            self.red_input = 2 * 2 * input_size * num_layers
        else:
            self.red_input = self.n_channels * 2

        self.short_encoder = TCVAE_Encoder_unified(input_size, num_layers, latent_dims, L, slope, first_kernel=None,
                                                   modified=self._modified)
        self.long_encoder = TCVAE_Encoder_unified(input_size, num_layers, latent_dims, L, slope, first_kernel,
                                                  modified=self._modified)

        self.reduction_layer = nn.Conv1d(self.red_input, self.red_input // 2, kernel_size=1, stride=1, padding=0)

    def forward(self, x):
        short_mu, short_logvar = self.short_encoder(x)
        long_mu, long_logvar = self.long_encoder(x)

        mu = torch.cat((short_mu, long_mu), axis=1)
        logvar = torch.cat((short_logvar, long_logvar), axis=1)

#         print("Short Encoder mu: ", short_mu.shape)
#         print("Long Encoder mu: ", long_mu.shape)
        
#         print("After Cat: ", mu.shape)
        if self._reduction:
            mu = self.reduction_layer(mu)
            logvar = self.reduction_layer(logvar)

        return mu, logvar
    
class VQ_Quantizer(nn.Module):
    def __init__(self, num_embed, dim_embed, commit_loss, decay, epsilon=1e-5):
        super(VQ_Quantizer, self).__init__()

        self._num_embed = num_embed
        self._dim_embed = dim_embed
        self._commit_loss = commit_loss

        self._embedding = nn.Embedding(self._num_embed, self._dim_embed)
        self._embedding.weight.data.uniform_(-1 / self._num_embed, 1 / self._num_embed)

        self.register_buffer('_ema_cluster_size', torch.zeros(num_embed))
        self._ema_w = nn.Parameter(torch.Tensor(num_embed, dim_embed))
        self._ema_w.data.normal_()

        self._decay = decay
        self._epsilon = epsilon
        self._std = 0.8

    def forward(self, x):
        # x : BCL -> BLC
#         print(x.shape)
        x_shape = x.shape
        x = x.permute(0, 2, 1).contiguous()
        
#         print(x.shape)

        # flaten the input to have the Channels as embedding space
        x_flat = x.view(-1, self._dim_embed)
#         print(x_flat.shape)

        # Calculate the distance to embeddings

#         print("the non squared x", x_flat.shape )
#         print("the non squared embed weights", self._embedding.weight.t().shape)
#         print("the x ", torch.sum(x_flat**2, dim = 1, keepdim = True).shape)
#         print("the embed ", torch.sum(self._embedding.weight**2, dim = 1).shape)
#         print("the matmul ", torch.matmul(x_flat, self._embedding.weight.t()).shape)
        dist = (torch.sum(x_flat ** 2, dim=1, keepdim=True)
                + torch.sum(self._embedding.weight ** 2, dim=1)
                - 2 * torch.matmul(x_flat, self._embedding.weight.t()))
#         print(dist.shape)

        embed_indices = torch.argmin(dist, dim=1).unsqueeze(1)
#         print("embed indices",embed_indices)
        if self.training:
            noise = torch.randn(embed_indices.shape) * self._std
            noise = torch.round(noise).to(torch.int32).to(embed_indices)
            new_embed_indices = embed_indices + noise
            new_embed_indices = torch.clamp(new_embed_indices, max=self._num_embed-1, min =0)
#             embed_indices = new_embed_indices
        # print("noise ",noise.shape)
        # print("both together",new_embed_indices)
        embed_Matrix = torch.zeros_like(dist)
#         embed_Matrix = torch.zeros(embed_indices.shape[0], self._num_embed).to(x)
        #         print(embed_Matrix.shape)
        embed_Matrix.scatter_(1, embed_indices, 1)
#         print("embed_indices", embed_indices)
#         print("Embedding ", embed_Matrix.shape, embed_Matrix)
#         print("codebook", self._embedding.weight.shape, self._embedding.weight)
        

        # get the corresponding e vectors
        quantizer = torch.matmul(embed_Matrix, self._embedding.weight)
#         print("the quantizer", quantizer.shape, quantizer)
        quantizer = quantizer.view(x_shape).permute(0, 2, 1).contiguous()
#         print("the quantizer", quantizer.shape, quantizer)

        # Use EMA to update the embedding vectors
        if self.training:
            self._ema_cluster_size = self._ema_cluster_size * self._decay + \
                                     (1 - self._decay) * torch.sum(embed_Matrix, 0)

            # Laplace smoothing of the cluster size
            n = torch.sum(self._ema_cluster_size.data)
            self._ema_cluster_size = (
                    (self._ema_cluster_size + self._epsilon)
                    / (n + self._num_embed * self._epsilon) * n)

            dw = torch.matmul(embed_Matrix.t(), x_flat)
            self._ema_w = nn.Parameter(self._ema_w * self._decay + (1 - self._decay) * dw)

            self._embedding.weight = nn.Parameter(self._ema_w / self._ema_cluster_size.unsqueeze(1))
        #         print("quantizer ", quantizer.shape)

        # Loss
        #         first_loss = F.mse_loss(quantizer, x.detach())
        #         second_loss = F.mse_loss(quantizer.detach(), x)
        #         loss = first_loss + self._commit_loss * second_loss

        # Loss EMA
        e_loss = F.mse_loss(quantizer.detach(), x)
        loss = self._commit_loss * e_loss
        #         print(loss)

        # straigh-through gradient
        quantizer = x + (quantizer - x).detach()
        quantizer = quantizer.permute(0, 2, 1).contiguous()
        #         print("quantizer ", quantizer.shape)

        return quantizer, loss
    
class VQ_MST_VAE(nn.Module):
    def __init__(self, n_channels, num_layers, latent_dims, v_encoder, v_decoder, v_quantizer,
                 L=30,
                 slope=0.2,
                 first_kernel=None,
                 commit_loss=0.25,
                 modified=True,
                 reduction=False,
                 ):
        super(VQ_MST_VAE, self).__init__()

        self._n_channels = n_channels
        self._num_layers = num_layers
        self._latent_dims = latent_dims
        self._v_encoder = v_encoder
        self._v_decoder = v_decoder
        self._v_quantizer = v_quantizer
        self._L = L
        self._slope = slope
        self._first_kernel = first_kernel
        self._commit_loss = commit_loss
        self._reduction = reduction
        self._modified = modified
        if self._modified:
            self._num_embed = self._n_channels * 4 * self._num_layers
        else:
            self._num_embed = self._n_channels * 2
        if self._reduction:
            self._num_embed = self._num_embed // 2

        self.encoder = self._v_encoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope,
                                       self._first_kernel, self._modified, self._reduction)
        self.decoder = self._v_decoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope,
                                       self._first_kernel, self._modified, self._reduction)
        self.quantizer = self._v_quantizer(self._num_embed, self._latent_dims, self._commit_loss, decay=0.99,
                                           epsilon=1e-5)

        self.bn = nn.BatchNorm1d(self._num_embed)

    def reparametrization_trick(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu, logvar = self.encoder(x)

        z = self.reparametrization_trick(mu, logvar)
        # print(z.shape)
        # z = self.bn(self.quantizer._embedding.weight[None,:])
        # is_larger = torch.all(torch.gt(z[0], self.quantizer._embedding.weight))
        # print(z.shape)
        # print("Is encoder output larger than the set of vectors?", is_larger)
        e, loss_quantize = self.quantizer(z)

#         print("----------------Encoder Output-------------")
#         print("mu and logvar", mu.shape, logvar.shape)
#         print("----------------Reparametrization-------------")
#         print("Z", z.shape)
#         print("----------------Quantizer-------------")
#         print("quantized shape", e.shape)
#         print("loss shape", loss_quantize)

        #         mu_dec, logvar_dec = self.decoder(e)
        #         x_rec = self.reparametrization_trick(mu_dec, mu_dec)
        x_rec, mu_rec, logvar_rec = self.decoder(e)
        loss_rec = F.mse_loss(x_rec, x, reduction='sum')
        loss = loss_rec + loss_quantize

#         print("----------------Decoding-------------")
#         print("----------------Decoder Output-------------")
#         # print("mu and logvar Decoder", mu_dec.shape, logvar_dec.shape)
#         print("rec shape", x_rec.shape)
        return x_rec, loss, mu, logvar, mu_rec, logvar_rec
    
class Variational_Autoencoder(nn.Module):
    def __init__(self, n_channels, num_layers, latent_dims, v_encoder, v_decoder,
                 L=30,
                 slope=0.2,
                 first_kernel=None,
                 ß=0.25,
                 modified=True,
                 reduction=False,
                 ):
        super(Variational_Autoencoder, self).__init__()

        self._n_channels = n_channels
        self._num_layers = num_layers
        self._latent_dims = latent_dims
        self._v_encoder = v_encoder
        self._v_decoder = v_decoder
#         self._v_quantizer = v_quantizer
        self._L = L
        self._slope = slope
        self._first_kernel = first_kernel
        self._ß = ß
        self._reduction = reduction
        self._modified = modified
#         if self._modified:
#             self._num_embed = self._n_channels * 4 * self._num_layers
#         else:
#             self._num_embed = self._n_channels * 2
#         if self._reduction:
#             self._num_embed = self._num_embed // 2

        self.encoder = self._v_encoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope,
                                       self._first_kernel, self._modified, self._reduction)
        self.decoder = self._v_decoder(self._n_channels, self._num_layers, self._latent_dims, self._L, self._slope,
                                       self._first_kernel, self._modified, self._reduction)
#         self.quantizer = self._v_quantizer(self._num_embed, self._latent_dims, self._commit_loss, decay=0.99,
#                                            epsilon=1e-5)

#         self.bn = nn.BatchNorm1d(self._num_embed)

    def reparametrization_trick(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu, logvar = self.encoder(x)
        loss_kld = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

        z = self.reparametrization_trick(mu, logvar)
        # print(z.shape)
        # z = self.bn(self.quantizer._embedding.weight[None,:])
        # is_larger = torch.all(torch.gt(z[0], self.quantizer._embedding.weight))
        # print(z.shape)
        # print("Is encoder output larger than the set of vectors?", is_larger)
#         e, loss_quantize = self.quantizer(z)

#         print("----------------Encoder Output-------------")
#         print("mu and logvar", mu.shape, logvar.shape)
#         print("----------------Reparametrization-------------")
#         print("Z", z.shape)
#         print("----------------Quantizer-------------")
#         print("quantized shape", e.shape)
#         print("loss shape", loss_quantize)

        #         mu_dec, logvar_dec = self.decoder(e)
        #         x_rec = self.reparametrization_trick(mu_dec, mu_dec)
        x_rec, mu_rec, logvar_rec = self.decoder(z)
        
        loss_rec = F.mse_loss(x_rec, x, reduction='sum')
        loss = loss_rec + self._ß * loss_kld

#         print("----------------Decoding-------------")
#         print("----------------Decoder Output-------------")
#         # print("mu and logvar Decoder", mu_dec.shape, logvar_dec.shape)
#         print("rec shape", x_rec.shape)
        return x_rec, loss, mu, logvar, mu_rec, logvar_rec
# Out:
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}

# %%
class TCVAE_Decoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None, modified=True, reduction= True):
        super(TCVAE_Decoder, self).__init__()

        def init_weights(m):
            if isinstance(m, nn.Conv1d):
                torch.nn.init.kaiming_uniform_(m.weight, mode="fan_in", nonlinearity="leaky_relu")
                m.bias.data.fill_(0.01)

        self.n_channels = input_size
        self.latent_dims = latent_dims
        self.first_kernel = first_kernel
        self.num_layers = num_layers
        self.n = lin_size(L, num_layers, first_kernel)

        self.modified = modified
        self.reduction = reduction
        self.cnn_layers = nn.ModuleList()
        self.decoder_input = self.n_channels
        if not self.reduction:
            self.decoder_input = self.decoder_input*2

        if self.first_kernel == None:
            first_kernel = 2
        else:
            first_kernel = self.first_kernel
        input_lin = self.latent_dims * 2 ** (self.num_layers - 1) + first_kernel - 2
#         input_lin = input_lin *2

        if self.modified:
            self.cnn_input = self.decoder_input * self.num_layers * 2
#             input_lin = input_lin // 2
            print(self.n_channels)
            print(self.cnn_input)
            # CNN Layers that double the channels each time
            for i in range(0, num_layers):
                if i == 0:
                    if first_kernel == None: first_kernel = 2
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input, self.cnn_input // 2, kernel_size=2, stride=2, padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // 2))
                elif i == num_layers - 1:
                    if first_kernel == None: first_kernel = 2
                    if self.reduction:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input // (2 * i), self.cnn_input // (2 * (i + 1)),
                                               kernel_size=first_kernel, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // (2 * (i + 1))))
                    else:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input // (2 * i), self.cnn_input // (4 * (i + 1)),
                                               kernel_size=first_kernel, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // (4 * (i + 1))))
                else:
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input // (2 * i), self.cnn_input // (2 * (i + 1)), kernel_size=2,
                                           stride=2, padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input // (2 * (i + 1))))
        else:
            self.cnn_input = self.n_channels
            for i in range(0, num_layers):
                if i == 0:
                    if first_kernel == None: first_kernel = 2
                    if self.reduction:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input, self.cnn_input, kernel_size=2, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))
                    else:
                        self.cnn_layers.append(
                            nn.ConvTranspose1d(self.cnn_input * 2, self.cnn_input, kernel_size=2, stride=2, padding=0))
                        self.cnn_layers.append(nn.LeakyReLU(slope, True))
                        self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))
                elif i == num_layers - 1:
                    if first_kernel == None: first_kernel = 2
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input, self.cnn_input, kernel_size=first_kernel, stride=2,
                                           padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))
                else:
                    self.cnn_layers.append(
                        nn.ConvTranspose1d(self.cnn_input, self.cnn_input, kernel_size=2, stride=2, padding=0))
                    self.cnn_layers.append(nn.LeakyReLU(slope, True))
                    self.cnn_layers.append(nn.BatchNorm1d(self.cnn_input))

        self.decoder_lin = nn.Linear(input_lin, L)
        # MLP Layers for Mu and logvar output
        self.decoder_mu = nn.Linear(input_lin, L)
        self.decoder_logvar = nn.Linear(input_lin, L)

        # Init CNN
        self.cnn_layers.apply(init_weights)

    def forward(self, x):
        # print("Decoder Input ", x.shape)
        #         x = x.view(x.shape[0], x.shape[1]* x.shape[2], -1)
        #         print("Decoder Input reshaped ",x.shape)
        #         x = self.decoder_lin(z)
        #         print("Decoder Input after lin ",x.shape)
        #         x = x.view(x.shape[0],x.shape[1],1)
        #         print("Decoder Input reshaped again",x.shape)

        for i, cnn in enumerate(self.cnn_layers):
            # print("Decoder Cnn ", x.shape)
            x = cnn(x)
          ########################################################################## Put back for old decoder  
#         #         print("Decoder shape after Cnn, should be reshaped? ", x.shape)
#         x = self.decoder_lin(x)
#         #         print("Decoder after lin ", x.shape)
        

#         return x
        ###################################################################################################################
        cnn_shape = x.shape
#         print("Decoder after Cnn ", x.shape)
#         if not self.modified:
#             x = x.view(x.size(0), -1)
#             print("Decoder reshape after Cnn ", x.shape)
        # ### MLP
        mu = self.decoder_mu(x)
        logvar = self.decoder_logvar(x)
#         print("Decoder mu after lin ", mu.shape)
        if not self.modified:
            mu = mu.view(mu.shape[0], self.n_channels, -1)
            logvar = logvar.view(logvar.shape[0], self.n_channels, -1)
#             print("Encoder mu after reshape ", mu.shape)
        # mu.reshape

        return mu, logvar

# %%
class LongShort_TCVAE_Decoder(nn.Module):
    def __init__(self, input_size, num_layers, latent_dims, L=30, slope=0.2, first_kernel=None,
                 modified=True, reduction=False):
        super(LongShort_TCVAE_Decoder, self).__init__()

        self._modified = modified
        self._reduction = reduction
        # if not self._reduction:
        #     input_size = input_size * 2
        # print("input to decoder", input_size)

        self.longshort_decoder = TCVAE_Decoder(input_size, num_layers, 2 * latent_dims, L, slope,
                                               first_kernel, modified=self._modified, reduction=self._reduction)

        self.short_decoder = TCVAE_Decoder(input_size, num_layers, 2 * latent_dims, L, slope,
                                           first_kernel=None, modified=self._modified, reduction=self._reduction)

        self.reduction_layer = nn.Conv1d(2 * input_size, input_size, kernel_size=1, stride=1, padding=0)
        
    def reparametrization_trick(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, z):
        ################################### old decoder ############################################################
#         x_long = self.longshort_decoder(z)
#         x_short = self.short_decoder(z)
#         # print("x_long ", x_long.shape)
#         # print("x_short ", x_short.shape)

#         x = torch.cat((x_short, x_long), dim=1)  # B.2C.L
#         # print("x_cat ", x.shape)
#         # if self._reduction:
#         x = self.reduction_layer(x)
#         # print("x_red ", x.shape)
#         return x
        #################################################################################################################
        short_mu, short_logvar = self.short_decoder(z)
        long_mu, long_logvar = self.longshort_decoder(z)

        mu = torch.cat((short_mu, long_mu), axis=1)
        logvar = torch.cat((short_logvar, long_logvar), axis=1)

#         print("Short Decoder mu: ", short_mu.shape)
#         print("Long Decoder mu: ", long_mu.shape)
        
#         print("After Cat: ", mu.shape)
#         if self._reduction:
        mu = self.reduction_layer(mu)
        logvar = self.reduction_layer(logvar)
        x = self.reparametrization_trick(mu, logvar)
#         print("Reconstruction at the end: ", x.shape)
        return x, mu, logvar

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
class slidingWindow(Dataset):
    def __init__(self, data, L):
        self.data = data
        self.L = L

    def __getitem__(self, index):
        if self.data.shape[1] - index >= self.L:            
            x = self.data[:,index:index+self.L]    
            v = torch.sum(x/self.L, axis=1).unsqueeze(1)
#             print(x.shape)
#             print(v.unsqueeze(1).shape)
            x = x/v
            return (x, v)
        
    def __len__(self):
        return self.data.shape[1] - self.L
    
### Cost function
def criterion(recon_x, x, mu, logvar):
    ### reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')

    ### KL divergence loss
    kld_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    ### total loss
    loss = recon_loss + 1*kld_loss
    return loss

def sample_mean(model, batch, n):
    batch_size = batch.shape[0]
    n_channels = batch.shape[1]
    latent_dims = model.encoder.latent_dims
    L = model._L

    mu, logvar = (torch.empty((batch_size, 2 * n_channels, latent_dims, 0)).to(batch) for _ in range(2))
    REC = torch.empty(batch_size, n_channels, L, 0).to(batch)
#     print(REC.shape)
#     print(mu.shape)

    for i in range(n):
        rec, _mu, _logvar = model(batch)

        REC = torch.cat((REC, rec.unsqueeze(-1)), dim=-1)
        mu = torch.cat((mu, _mu.unsqueeze(-1)), dim=-1)
        logvar = torch.cat((logvar, _logvar.unsqueeze(-1)), dim=-1)

    # print("shapes after cat: mu, logvar, REC ", mu.shape, logvar.shape, REC.shape)
    mu, logvar = (torch.mean(t, dim=-1) for t in [mu, logvar])
    REC = torch.mean(REC, dim=-1)
    #     print("shapes after mean: mu, logvar, REC ", mu.shape, logvar.shape, REC.shape)

    return REC, mu, logvar

def train(model, train_loader, criterion, optimizer, device, epoch, VQ = True):
    model.train()
    train_loss = 0
    
    for batch_idx, (data, v) in enumerate(train_loader):
        
        data = data.to(device)
        v = v.to(device)
        optimizer.zero_grad()        

        if VQ:
            x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
        else:
#             x_rec, mu, logvar = model(data)
            x_rec, mu, logvar = sample_mean(model, data, 10)
            if v.dim() == 1:
                v = v.unsqueeze(-1)
                v = v.unsqueeze(-1)
            # x_rec_window_length = x_rec.shape[2]
            loss = criterion((x_rec*v)[:,:,0], data[:,:,0], mu, logvar)
        # print(x_rec.shape)
        # print(data[:, :, 0].shape)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(train_loader.dataset)))
    
    return  train_loss / len(train_loader.dataset)

# %%
### Init Model
n_channels = 1
latent_dims = 7 # 6 # 17
L= 60# 39 #32
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# v = vae(n_channels, L, latent_dims)
v = Variational_Autoencoder(n_channels = n_channels,
                            num_layers =  3,#4, #3
                            latent_dims= latent_dims,
                            v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
                            v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
                            L=L,
                            slope = 0,
                            first_kernel = 20, #11, #20
                            ß = 1.5,
                            modified=False,
                            reduction = True)
# v = VQ_MST_VAE(n_channels = n_channels,
#                             num_layers =  3,#4, #3
#                             latent_dims= latent_dims,
#                             v_encoder = LongShort_TCVAE_Encoder, #MST_VAE_Encoder,
#                             v_decoder = LongShort_TCVAE_Decoder, #MST_VAE_Decoder,
#                             v_quantizer = VQ_Quantizer,
#                             L=L,
#                             slope = 0,
#                             first_kernel = 30, #11, #20
#                             commit_loss = 2,
#                             modified=False,
#                             reduction = True) #10 5
enc = MST_VAE_Encoder_dist(     n_channels,
                           num_layers = 3,
                           slope = 0.2,
                           first_kernel = 15)
dec = MST_VAE_Decoder_dist(     n_channels,
                           num_layers = 3,
                           slope = 0.2,
                           first_kernel = 15)


v = v.to(device)
enc = enc.to(device)
dec = dec.to(device)
opt = optim.Adam(v.parameters(), lr = 0.005043529186448577) # 0.005043529186448577 0.006819850049647945
print(v)
# Create the dictionaries of probability distributions
# pnet = {'z': D.Normal(loc=torch.zeros(latent_dims), scale=torch.ones(latent_dims)), 'x': dec}
# qnet = {'z': enc}
# serie = torch.tensor(serie).float()
x = torch.FloatTensor(x)

# x = F.normalize(x, p=2, dim=1)
n = x.shape[1]
# L = 30

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

train_data = DataLoader(slidingWindow(train_, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=22,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=22,
                        shuffle = False
                        )
# Out:
# Variational_Autoencoder(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=42, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=42, out_features=7, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(20,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=30, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=30, out_features=7, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(20,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=74, out_features=60, bias=True)
#       (decoder_mu): Linear(in_features=74, out_features=60, bias=True)
#       (decoder_logvar): Linear(in_features=74, out_features=60, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=56, out_features=60, bias=True)
#       (decoder_mu): Linear(in_features=56, out_features=60, bias=True)
#       (decoder_logvar): Linear(in_features=56, out_features=60, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
# )

# %%
def set_effect(effect):
    if effect == "no_effect":
        effects = {
            "Pulse": {
                "occurances":0,
                "max_amplitude":1.5,   
                "interval":40
                },
            "Trend": {
                "occurances":0,
                "max_slope":0.005,
                "type":"linear"
                },
            "Seasonality": {
                "occurances":0,
                "frequency_per_week":(7, 14), # min and max occurances per week
                "amplitude_range":(5, 20),
                },
            "std_variation": {
                "occurances":0,
                "max_value":10,
                "interval":1000,
                },
            "channels_coupling":{
                "occurances":0,
                "coupling_strengh":20
                },
            "Noise": {
                "occurances":0,
                "max_slope":0.005,
                "type":"linear"
                }
            }
    elif effect == "trend":
        effects = {
            "Pulse": {
                "occurances":0,
                "max_amplitude":1.5,   
                "interval":40
                },
            "Trend": {
                "occurances":1,
                "max_slope":0.005,
                "type":"linear"
                },
            "Seasonality": {
                "occurances":0,
                "frequency_per_week":(7, 14), # min and max occurances per week
                "amplitude_range":(5, 20),
                },
            "std_variation": {
                "occurances":0,
                "max_value":10,
                "interval":1000,
                },
            "channels_coupling":{
                "occurances":0,
                "coupling_strengh":20
                },
            "Noise": {
                "occurances":0,
                "max_slope":0.005,
                "type":"linear"
                }
            }
    elif effect == "seasonality":
                effects = {
            "Pulse": {
                "occurances":0,
                "max_amplitude":1.5,   
                "interval":40
                },
            "Trend": {
                "occurances":0,
                "max_slope":0.005,
                "type":"linear"
                },
            "Seasonality": {
                "occurances":1,
                "frequency_per_week":(7, 14), # min and max occurances per week
                "amplitude_range":(5, 20),
                },
            "std_variation": {
                "occurances":0,
                "max_value":10,
                "interval":1000,
                },
            "channels_coupling":{
                "occurances":0,
                "coupling_strengh":20
                },
            "Noise": {
                "occurances":0,
                "max_slope":0.005,
                "type":"linear"
                }
            }
            
    return effects

# %%
def generate_data(n_channels, effect):
    effects = set_effect(effect)
    X = Gen(periode, step, val, n_channels, effects)
    x, params, e_params = X.parameters()
    pprint.pprint(params)
    pprint.pprint(e_params)
    X.show()
    x = torch.FloatTensor(x)

    # x = F.normalize(x, p=2, dim=1)
    n = x.shape[1]
    # L = 30

    train_ = x[:, :int(0.8*n)]
    val_   = x[:, int(0.8*n):int(0.9*n)]
    test_  = x[:, int(0.9*n):]

    train_data = DataLoader(slidingWindow(train_, L),
                            batch_size= 22,# 59, # 22
                            shuffle = False
                            )
    val_data = DataLoader(slidingWindow(val_, L),
                            batch_size=22,
                            shuffle = False
                            )
    test_data = DataLoader(slidingWindow(test_, L),
                            batch_size=22,
                            shuffle = False
                            )
    return X, train_data, test_data

# %%
def train_on_effect(model, n_channels=1, effect='no_effect', n_samples=10, epochs_per_sample=50):
    for i in range(n_samples):
        X, train_data, test_data = generate_data(n_channels, effect)
        
        for epoch in range(1, epochs_per_sample):
            train(model, train_data, criterion, opt, device, epoch, VQ = True)
    return model, X, train_data

# %%
v, X, train_data = train_on_effect(v, effect='no_effect', n_samples=10)
v, X, train_data = train_on_effect(v, effect='trend', n_samples=10)
v, X, train_data = train_on_effect(v, effect='seasonality', n_samples=10)
# Out:
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[271., 271., 271., ..., 271., 271., 271.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 132.510320
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.733657
# ====> Epoch: 1 Average loss: 10.5348
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.335975
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.157564
# ====> Epoch: 2 Average loss: 0.1970
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.125258
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.083230
# ====> Epoch: 3 Average loss: 0.1049
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.133288
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.088582
# ====> Epoch: 4 Average loss: 0.0691
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.044380
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.064475
# ====> Epoch: 5 Average loss: 0.0591
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.031508
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.027611
# ====> Epoch: 6 Average loss: 0.0329
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.038853
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.023534
# ====> Epoch: 7 Average loss: 0.0288
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.019786
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.026669
# ====> Epoch: 8 Average loss: 0.0204
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.017276
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.014739
# ====> Epoch: 9 Average loss: 0.0167
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.013432
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.013378
# ====> Epoch: 10 Average loss: 0.0159
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.045424
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.011625
# ====> Epoch: 11 Average loss: 0.0191
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.009612
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.022047
# ====> Epoch: 12 Average loss: 0.0119
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.017222
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.006905
# ====> Epoch: 13 Average loss: 0.0111
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.048968
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.006216
# ====> Epoch: 14 Average loss: 0.0117
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.022938
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.006446
# ====> Epoch: 15 Average loss: 0.0106
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.012098
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.007274
# ====> Epoch: 16 Average loss: 0.0134
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.015683
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.013125
# ====> Epoch: 17 Average loss: 0.0141
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.046124
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.012452
# ====> Epoch: 18 Average loss: 0.0117
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.049738
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.006123
# ====> Epoch: 19 Average loss: 0.0104
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.008432
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.013880
# ====> Epoch: 20 Average loss: 0.0150
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.058436
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.005264
# ====> Epoch: 21 Average loss: 0.0218
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.009840
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.009082
# ====> Epoch: 22 Average loss: 0.0071
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.007375
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.006921
# ====> Epoch: 23 Average loss: 0.0097
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.016554
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.004157
# ====> Epoch: 24 Average loss: 0.0094
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.009508
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.004556
# ====> Epoch: 25 Average loss: 0.0083
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.008201
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.006019
# ====> Epoch: 26 Average loss: 0.0078
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.012844
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.003215
# ====> Epoch: 27 Average loss: 0.0092
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.023981
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.009405
# ====> Epoch: 28 Average loss: 0.0068
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.018844
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.006115
# ====> Epoch: 29 Average loss: 0.0064
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.007214
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.004574
# ====> Epoch: 30 Average loss: 0.0056
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.006508
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.030853
# ====> Epoch: 31 Average loss: 0.0077
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.013825
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.009053
# ====> Epoch: 32 Average loss: 0.0097
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.004999
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.003968
# ====> Epoch: 33 Average loss: 0.0052
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.006406
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.003855
# ====> Epoch: 34 Average loss: 0.0055
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.017074
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.016908
# ====> Epoch: 35 Average loss: 0.0062
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.005341
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.007980
# ====> Epoch: 36 Average loss: 0.0045
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.013846
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.004178
# ====> Epoch: 37 Average loss: 0.0089
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.005569
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.003439
# ====> Epoch: 38 Average loss: 0.0052
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.007505
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.003734
# ====> Epoch: 39 Average loss: 0.0039
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.007427
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.002622
# ====> Epoch: 40 Average loss: 0.0050
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.014623
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.001940
# ====> Epoch: 41 Average loss: 0.0044
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.004821
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.002492
# ====> Epoch: 42 Average loss: 0.0033
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.018503
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.001876
# ====> Epoch: 43 Average loss: 0.0030
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.009103
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.002125
# ====> Epoch: 44 Average loss: 0.0029
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.011916
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.001728
# ====> Epoch: 45 Average loss: 0.0043
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.006745
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.002825
# ====> Epoch: 46 Average loss: 0.0030
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.002835
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.002281
# ====> Epoch: 47 Average loss: 0.0027
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.003004
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.002624
# ====> Epoch: 48 Average loss: 0.0033
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.005121
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.003664
# ====> Epoch: 49 Average loss: 0.0041
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[139., 139., 139., ..., 139., 139., 139.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.010532
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.007694
# ====> Epoch: 1 Average loss: 0.0070
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.014099
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.005411
# ====> Epoch: 2 Average loss: 0.0071
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.011697
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.004442
# ====> Epoch: 3 Average loss: 0.0057
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.013489
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.005204
# ====> Epoch: 4 Average loss: 0.0059
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.013839
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.004338
# ====> Epoch: 5 Average loss: 0.0052
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.007659
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.004534
# ====> Epoch: 6 Average loss: 0.0049
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.008111
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.004663
# ====> Epoch: 7 Average loss: 0.0049
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.008542
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.005455
# ====> Epoch: 8 Average loss: 0.0051
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.005725
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.004005
# ====> Epoch: 9 Average loss: 0.0046
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.007312
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.005202
# ====> Epoch: 10 Average loss: 0.0049
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.005027
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.004279
# ====> Epoch: 11 Average loss: 0.0044
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.006237
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.003798
# ====> Epoch: 12 Average loss: 0.0045
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.005496
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.003570
# ====> Epoch: 13 Average loss: 0.0045
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.005747
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.003678
# ====> Epoch: 14 Average loss: 0.0043
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.005071
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.003575
# ====> Epoch: 15 Average loss: 0.0043
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.005232
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.003690
# ====> Epoch: 16 Average loss: 0.0042
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.004977
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.003768
# ====> Epoch: 17 Average loss: 0.0042
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.004749
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.003710
# ====> Epoch: 18 Average loss: 0.0042
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.004611
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.003654
# ====> Epoch: 19 Average loss: 0.0041
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.004720
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.003544
# ====> Epoch: 20 Average loss: 0.0041
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.004646
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.003446
# ====> Epoch: 21 Average loss: 0.0041
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.004407
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.003452
# ====> Epoch: 22 Average loss: 0.0040
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.004388
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.003652
# ====> Epoch: 23 Average loss: 0.0040
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.004615
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.003526
# ====> Epoch: 24 Average loss: 0.0040
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.004744
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.003547
# ====> Epoch: 25 Average loss: 0.0040
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.004477
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.003610
# ====> Epoch: 26 Average loss: 0.0040
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.004423
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.003593
# ====> Epoch: 27 Average loss: 0.0039
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.004512
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.003673
# ====> Epoch: 28 Average loss: 0.0040
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.004465
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.003586
# ====> Epoch: 29 Average loss: 0.0039
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.004627
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.003631
# ====> Epoch: 30 Average loss: 0.0040
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.004589
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.003633
# ====> Epoch: 31 Average loss: 0.0039
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.004688
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.003688
# ====> Epoch: 32 Average loss: 0.0039
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.004420
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.003664
# ====> Epoch: 33 Average loss: 0.0038
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.004444
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.003727
# ====> Epoch: 34 Average loss: 0.0038
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.004463
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.003652
# ====> Epoch: 35 Average loss: 0.0038
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.004768
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.003677
# ====> Epoch: 36 Average loss: 0.0040
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.004533
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.003671
# ====> Epoch: 37 Average loss: 0.0037
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.004486
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.003649
# ====> Epoch: 38 Average loss: 0.0037
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.004720
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.003630
# ====> Epoch: 39 Average loss: 0.0039
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.004515
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.003620
# ====> Epoch: 40 Average loss: 0.0037
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.004451
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.003606
# ====> Epoch: 41 Average loss: 0.0037
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.004637
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.003651
# ====> Epoch: 42 Average loss: 0.0038
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.004590
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.003598
# ====> Epoch: 43 Average loss: 0.0037
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.004764
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.003577
# ====> Epoch: 44 Average loss: 0.0037
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.004521
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.003494
# ====> Epoch: 45 Average loss: 0.0037
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.004493
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.003512
# ====> Epoch: 46 Average loss: 0.0037
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.004528
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.003450
# ====> Epoch: 47 Average loss: 0.0037
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.004562
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.003448
# ====> Epoch: 48 Average loss: 0.0037
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.004530
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.003398
# ====> Epoch: 49 Average loss: 0.0037
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[406., 406., 406., ..., 406., 406., 406.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.001918
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.000757
# ====> Epoch: 1 Average loss: 0.0006
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.000825
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.000675
# ====> Epoch: 2 Average loss: 0.0006
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.000670
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.000671
# ====> Epoch: 3 Average loss: 0.0006
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.000623
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.000634
# ====> Epoch: 4 Average loss: 0.0007
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.000489
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.000569
# ====> Epoch: 5 Average loss: 0.0006
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.001774
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.000562
# ====> Epoch: 6 Average loss: 0.0009
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.000474
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.000497
# ====> Epoch: 7 Average loss: 0.0005
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.000568
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.000440
# ====> Epoch: 8 Average loss: 0.0005
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.000697
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.000434
# ====> Epoch: 9 Average loss: 0.0006
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.001700
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.000459
# ====> Epoch: 10 Average loss: 0.0011
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.000611
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.000404
# ====> Epoch: 11 Average loss: 0.0005
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.000741
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.000382
# ====> Epoch: 12 Average loss: 0.0006
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.000843
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.000384
# ====> Epoch: 13 Average loss: 0.0006
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.001119
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.000412
# ====> Epoch: 14 Average loss: 0.0010
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.000768
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.000384
# ====> Epoch: 15 Average loss: 0.0006
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.000846
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.000388
# ====> Epoch: 16 Average loss: 0.0006
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.001474
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.000404
# ====> Epoch: 17 Average loss: 0.0010
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.000736
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.000378
# ====> Epoch: 18 Average loss: 0.0005
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.000800
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.000385
# ====> Epoch: 19 Average loss: 0.0006
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.000958
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.000374
# ====> Epoch: 20 Average loss: 0.0008
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.000791
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.000382
# ====> Epoch: 21 Average loss: 0.0006
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.000850
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.000377
# ====> Epoch: 22 Average loss: 0.0007
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.001892
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.000452
# ====> Epoch: 23 Average loss: 0.0011
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.000620
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.000406
# ====> Epoch: 24 Average loss: 0.0005
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.000722
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.000379
# ====> Epoch: 25 Average loss: 0.0005
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.000798
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.000399
# ====> Epoch: 26 Average loss: 0.0006
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.000832
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.000455
# ====> Epoch: 27 Average loss: 0.0007
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.000959
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.000389
# ====> Epoch: 28 Average loss: 0.0008
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.000730
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.000378
# ====> Epoch: 29 Average loss: 0.0005
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.000827
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.000400
# ====> Epoch: 30 Average loss: 0.0007
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.000761
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.000497
# ====> Epoch: 31 Average loss: 0.0006
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.001384
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.000470
# ====> Epoch: 32 Average loss: 0.0010
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.000552
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.000434
# ====> Epoch: 33 Average loss: 0.0005
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.000661
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.000396
# ====> Epoch: 34 Average loss: 0.0005
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.000723
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.000385
# ====> Epoch: 35 Average loss: 0.0007
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.000859
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.000397
# ====> Epoch: 36 Average loss: 0.0006
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.000742
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.000398
# ====> Epoch: 37 Average loss: 0.0007
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.003658
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.000555
# ====> Epoch: 38 Average loss: 0.0015
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.000428
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.000526
# ====> Epoch: 39 Average loss: 0.0005
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.000423
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.000493
# ====> Epoch: 40 Average loss: 0.0005
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.000508
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.000456
# ====> Epoch: 41 Average loss: 0.0005
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.000599
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.000414
# ====> Epoch: 42 Average loss: 0.0005
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.000691
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.000393
# ====> Epoch: 43 Average loss: 0.0006
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.001540
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.000507
# ====> Epoch: 44 Average loss: 0.0010
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.000472
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.000465
# ====> Epoch: 45 Average loss: 0.0005
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.000566
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.000432
# ====> Epoch: 46 Average loss: 0.0005
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.000658
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.000403
# ====> Epoch: 47 Average loss: 0.0006
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.001447
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.000507
# ====> Epoch: 48 Average loss: 0.0009
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.000467
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.000470
# ====> Epoch: 49 Average loss: 0.0005
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[268., 268., 268., ..., 268., 268., 268.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.000886
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.001835
# ====> Epoch: 1 Average loss: 0.0012
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.004163
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.001482
# ====> Epoch: 2 Average loss: 0.0013
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.002453
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.001387
# ====> Epoch: 3 Average loss: 0.0012
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.002026
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.001360
# ====> Epoch: 4 Average loss: 0.0011
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.002118
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.001312
# ====> Epoch: 5 Average loss: 0.0013
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.001768
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.001328
# ====> Epoch: 6 Average loss: 0.0011
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.002001
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.001288
# ====> Epoch: 7 Average loss: 0.0012
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.001818
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.001307
# ====> Epoch: 8 Average loss: 0.0011
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.001977
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.001264
# ====> Epoch: 9 Average loss: 0.0012
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.001819
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.001297
# ====> Epoch: 10 Average loss: 0.0011
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.001964
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.001244
# ====> Epoch: 11 Average loss: 0.0012
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.001903
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.001279
# ====> Epoch: 12 Average loss: 0.0011
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.002132
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.001216
# ====> Epoch: 13 Average loss: 0.0013
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.001965
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.001254
# ====> Epoch: 14 Average loss: 0.0010
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.002077
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.001251
# ====> Epoch: 15 Average loss: 0.0011
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.002235
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.001200
# ====> Epoch: 16 Average loss: 0.0012
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.001998
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.001232
# ====> Epoch: 17 Average loss: 0.0010
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.002262
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.001192
# ====> Epoch: 18 Average loss: 0.0012
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.001998
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.001230
# ====> Epoch: 19 Average loss: 0.0010
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.002267
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.001177
# ====> Epoch: 20 Average loss: 0.0013
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.001914
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.001207
# ====> Epoch: 21 Average loss: 0.0010
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.002142
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.001189
# ====> Epoch: 22 Average loss: 0.0011
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.002005
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.001205
# ====> Epoch: 23 Average loss: 0.0011
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.002148
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.001168
# ====> Epoch: 24 Average loss: 0.0012
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.001743
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.001191
# ====> Epoch: 25 Average loss: 0.0010
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.002095
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.001166
# ====> Epoch: 26 Average loss: 0.0012
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.001677
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.001185
# ====> Epoch: 27 Average loss: 0.0010
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.002062
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.001150
# ====> Epoch: 28 Average loss: 0.0013
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.001535
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.001167
# ====> Epoch: 29 Average loss: 0.0010
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.001728
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.001176
# ====> Epoch: 30 Average loss: 0.0011
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.001947
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.001145
# ====> Epoch: 31 Average loss: 0.0013
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.001438
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.001156
# ====> Epoch: 32 Average loss: 0.0010
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.001607
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.001164
# ====> Epoch: 33 Average loss: 0.0011
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.001849
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.001137
# ====> Epoch: 34 Average loss: 0.0013
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.001335
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.001143
# ====> Epoch: 35 Average loss: 0.0010
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.001509
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.001151
# ====> Epoch: 36 Average loss: 0.0011
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.001713
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.001147
# ====> Epoch: 37 Average loss: 0.0012
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.001303
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.001151
# ====> Epoch: 38 Average loss: 0.0010
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.001493
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.001155
# ====> Epoch: 39 Average loss: 0.0011
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.001492
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.001148
# ====> Epoch: 40 Average loss: 0.0011
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.001376
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.001148
# ====> Epoch: 41 Average loss: 0.0011
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.001574
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.001144
# ====> Epoch: 42 Average loss: 0.0012
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.001204
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.001148
# ====> Epoch: 43 Average loss: 0.0010
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.001322
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.001144
# ====> Epoch: 44 Average loss: 0.0011
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.001486
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.001138
# ====> Epoch: 45 Average loss: 0.0012
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.001143
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.001143
# ====> Epoch: 46 Average loss: 0.0010
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.001259
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.001145
# ====> Epoch: 47 Average loss: 0.0011
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.001388
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.001135
# ====> Epoch: 48 Average loss: 0.0012
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.001116
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.001138
# ====> Epoch: 49 Average loss: 0.0010
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[28., 28., 28., ..., 28., 28., 28.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.067447
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.072914
# ====> Epoch: 1 Average loss: 0.0770
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.069784
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.071539
# ====> Epoch: 2 Average loss: 0.0730
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.070073
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.071592
# ====> Epoch: 3 Average loss: 0.0725
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.070361
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.071615
# ====> Epoch: 4 Average loss: 0.0724
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.070096
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.071457
# ====> Epoch: 5 Average loss: 0.0722
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.069906
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.071251
# ====> Epoch: 6 Average loss: 0.0722
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.069987
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.071205
# ====> Epoch: 7 Average loss: 0.0721
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.069910
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.071084
# ====> Epoch: 8 Average loss: 0.0722
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.069626
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.070913
# ====> Epoch: 9 Average loss: 0.0720
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.069466
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.071014
# ====> Epoch: 10 Average loss: 0.0720
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.069474
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.070892
# ====> Epoch: 11 Average loss: 0.0720
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.069457
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.070784
# ====> Epoch: 12 Average loss: 0.0721
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.069269
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.070930
# ====> Epoch: 13 Average loss: 0.0719
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.069246
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.070910
# ====> Epoch: 14 Average loss: 0.0719
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.069296
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.070929
# ====> Epoch: 15 Average loss: 0.0720
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.069174
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.070882
# ====> Epoch: 16 Average loss: 0.0719
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.069245
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.070806
# ====> Epoch: 17 Average loss: 0.0719
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.069096
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.070879
# ====> Epoch: 18 Average loss: 0.0719
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.069013
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.070735
# ====> Epoch: 19 Average loss: 0.0719
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.069071
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.070867
# ====> Epoch: 20 Average loss: 0.0719
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.068933
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.071113
# ====> Epoch: 21 Average loss: 0.0719
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.068914
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.070871
# ====> Epoch: 22 Average loss: 0.0719
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.068993
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.070955
# ====> Epoch: 23 Average loss: 0.0719
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.069042
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.070872
# ====> Epoch: 24 Average loss: 0.0719
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.069027
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.070843
# ====> Epoch: 25 Average loss: 0.0718
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.068795
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.071005
# ====> Epoch: 26 Average loss: 0.0718
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.068797
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.070866
# ====> Epoch: 27 Average loss: 0.0718
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.068797
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.071056
# ====> Epoch: 28 Average loss: 0.0719
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.068837
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.070878
# ====> Epoch: 29 Average loss: 0.0718
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.068865
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.070821
# ====> Epoch: 30 Average loss: 0.0718
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.068948
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.070946
# ====> Epoch: 31 Average loss: 0.0718
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.068710
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.071034
# ====> Epoch: 32 Average loss: 0.0718
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.068854
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.070743
# ====> Epoch: 33 Average loss: 0.0718
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.069138
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.070851
# ====> Epoch: 34 Average loss: 0.0719
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.068659
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.070990
# ====> Epoch: 35 Average loss: 0.0717
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.068742
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.070855
# ====> Epoch: 36 Average loss: 0.0717
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.068629
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.070753
# ====> Epoch: 37 Average loss: 0.0718
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.068926
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.070964
# ====> Epoch: 38 Average loss: 0.0719
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.068534
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.070844
# ====> Epoch: 39 Average loss: 0.0717
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.068449
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.070745
# ====> Epoch: 40 Average loss: 0.0717
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.068564
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.070804
# ====> Epoch: 41 Average loss: 0.0717
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.068606
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.070756
# ====> Epoch: 42 Average loss: 0.0717
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.068688
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.070822
# ====> Epoch: 43 Average loss: 0.0718
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.068541
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.070860
# ====> Epoch: 44 Average loss: 0.0717
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.068384
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.070875
# ====> Epoch: 45 Average loss: 0.0717
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.068486
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.070891
# ====> Epoch: 46 Average loss: 0.0720
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.068619
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.070891
# ====> Epoch: 47 Average loss: 0.0717
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.068394
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.070826
# ====> Epoch: 48 Average loss: 0.0717
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.068681
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.070909
# ====> Epoch: 49 Average loss: 0.0718
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[290., 290., 290., ..., 290., 290., 290.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.001119
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.000942
# ====> Epoch: 1 Average loss: 0.0008
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.000619
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.000945
# ====> Epoch: 2 Average loss: 0.0008
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.000696
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.000940
# ====> Epoch: 3 Average loss: 0.0008
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.000589
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.000947
# ====> Epoch: 4 Average loss: 0.0007
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.000609
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.000944
# ====> Epoch: 5 Average loss: 0.0008
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.000591
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.001055
# ====> Epoch: 6 Average loss: 0.0008
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.000645
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.000910
# ====> Epoch: 7 Average loss: 0.0008
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.000585
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.000968
# ====> Epoch: 8 Average loss: 0.0008
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.000649
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.000922
# ====> Epoch: 9 Average loss: 0.0008
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.000593
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.001104
# ====> Epoch: 10 Average loss: 0.0008
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.000596
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.000952
# ====> Epoch: 11 Average loss: 0.0008
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.001163
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.000959
# ====> Epoch: 12 Average loss: 0.0010
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.000594
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.000960
# ====> Epoch: 13 Average loss: 0.0007
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.000598
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.000954
# ====> Epoch: 14 Average loss: 0.0007
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.000595
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.000944
# ====> Epoch: 15 Average loss: 0.0007
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.000618
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.000954
# ====> Epoch: 16 Average loss: 0.0008
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.000711
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.000926
# ====> Epoch: 17 Average loss: 0.0008
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.000650
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.000938
# ====> Epoch: 18 Average loss: 0.0008
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.000692
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.000919
# ====> Epoch: 19 Average loss: 0.0008
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.000668
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.001036
# ====> Epoch: 20 Average loss: 0.0008
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.000673
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.000954
# ====> Epoch: 21 Average loss: 0.0008
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.000678
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.000960
# ====> Epoch: 22 Average loss: 0.0008
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.000824
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.000965
# ====> Epoch: 23 Average loss: 0.0008
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.000675
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.000986
# ====> Epoch: 24 Average loss: 0.0008
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.000772
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.000971
# ====> Epoch: 25 Average loss: 0.0009
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.000667
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.000981
# ====> Epoch: 26 Average loss: 0.0008
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.000674
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.001028
# ====> Epoch: 27 Average loss: 0.0008
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.000874
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.000965
# ====> Epoch: 28 Average loss: 0.0010
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.000668
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.000973
# ====> Epoch: 29 Average loss: 0.0008
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.000674
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.000990
# ====> Epoch: 30 Average loss: 0.0008
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.000680
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.000997
# ====> Epoch: 31 Average loss: 0.0008
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.000747
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.000980
# ====> Epoch: 32 Average loss: 0.0009
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.000673
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.000993
# ====> Epoch: 33 Average loss: 0.0008
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.000672
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.001090
# ====> Epoch: 34 Average loss: 0.0008
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.000777
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.000985
# ====> Epoch: 35 Average loss: 0.0009
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.000669
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.000994
# ====> Epoch: 36 Average loss: 0.0008
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.000676
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.001005
# ====> Epoch: 37 Average loss: 0.0009
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.000736
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.000993
# ====> Epoch: 38 Average loss: 0.0008
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.000674
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.000994
# ====> Epoch: 39 Average loss: 0.0008
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.000688
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.000987
# ====> Epoch: 40 Average loss: 0.0008
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.000804
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.000974
# ====> Epoch: 41 Average loss: 0.0009
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.000670
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.000983
# ====> Epoch: 42 Average loss: 0.0008
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.000698
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.001561
# ====> Epoch: 43 Average loss: 0.0008
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.000693
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.000986
# ====> Epoch: 44 Average loss: 0.0008
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.000718
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.000981
# ====> Epoch: 45 Average loss: 0.0008
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.000676
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.000978
# ====> Epoch: 46 Average loss: 0.0008
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.000826
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.000955
# ====> Epoch: 47 Average loss: 0.0009
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.000669
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.000970
# ====> Epoch: 48 Average loss: 0.0008
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.000670
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.000980
# ====> Epoch: 49 Average loss: 0.0008
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[431., 431., 431., ..., 431., 431., 431.]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.000830
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.000426
# ====> Epoch: 1 Average loss: 0.0006
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.000342
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.000433
# ====> Epoch: 2 Average loss: 0.0003
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.000338
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.000437
# ====> Epoch: 3 Average loss: 0.0003
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.000340
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.000433
# ====> Epoch: 4 Average loss: 0.0003
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.000350
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.000436
# ====> Epoch: 5 Average loss: 0.0004
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.000345
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.000464
# ====> Epoch: 6 Average loss: 0.0004
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.000344
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.001056
# ====> Epoch: 7 Average loss: 0.0004
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.000353
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.000897
# ====> Epoch: 8 Average loss: 0.0004
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.000350
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.000421
# ====> Epoch: 9 Average loss: 0.0004
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.000350
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.000663
# ====> Epoch: 10 Average loss: 0.0004
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.000352
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.000465
# ====> Epoch: 11 Average loss: 0.0004
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.000349
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.000414
# ====> Epoch: 12 Average loss: 0.0004
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.000368
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.000416
# ====> Epoch: 13 Average loss: 0.0004
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.000350
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.000414
# ====> Epoch: 14 Average loss: 0.0004
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.000370
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.000412
# ====> Epoch: 15 Average loss: 0.0004
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.000568
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.000428
# ====> Epoch: 16 Average loss: 0.0005
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.000342
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.000421
# ====> Epoch: 17 Average loss: 0.0003
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.000347
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.000414
# ====> Epoch: 18 Average loss: 0.0003
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.000348
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.000500
# ====> Epoch: 19 Average loss: 0.0004
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.000348
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.000416
# ====> Epoch: 20 Average loss: 0.0004
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.000503
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.000417
# ====> Epoch: 21 Average loss: 0.0004
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.000347
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.000412
# ====> Epoch: 22 Average loss: 0.0003
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.000347
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.000416
# ====> Epoch: 23 Average loss: 0.0004
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.000769
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.000428
# ====> Epoch: 24 Average loss: 0.0005
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.000344
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.000418
# ====> Epoch: 25 Average loss: 0.0003
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.000346
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.000412
# ====> Epoch: 26 Average loss: 0.0003
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.000351
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.000435
# ====> Epoch: 27 Average loss: 0.0004
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.000363
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.000413
# ====> Epoch: 28 Average loss: 0.0004
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.000350
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.000425
# ====> Epoch: 29 Average loss: 0.0004
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.000346
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.000443
# ====> Epoch: 30 Average loss: 0.0004
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.000347
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.000520
# ====> Epoch: 31 Average loss: 0.0004
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.000346
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.000412
# ====> Epoch: 32 Average loss: 0.0004
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.000347
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.000415
# ====> Epoch: 33 Average loss: 0.0004
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.000346
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.000415
# ====> Epoch: 34 Average loss: 0.0004
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.000350
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.000418
# ====> Epoch: 35 Average loss: 0.0004
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.000417
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.000418
# ====> Epoch: 36 Average loss: 0.0004
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.000346
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.000411
# ====> Epoch: 37 Average loss: 0.0003
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.000403
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.000418
# ====> Epoch: 38 Average loss: 0.0004
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.000344
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.000412
# ====> Epoch: 39 Average loss: 0.0003
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.000350
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.000475
# ====> Epoch: 40 Average loss: 0.0004
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.000347
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.000416
# ====> Epoch: 41 Average loss: 0.0004
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.000376
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.000414
# ...
# ====> Epoch: 35 Average loss: 0.0056
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.012301
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.001912
# ====> Epoch: 36 Average loss: 0.0056
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.012301
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.001916
# ====> Epoch: 37 Average loss: 0.0056
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.012340
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.001926
# ====> Epoch: 38 Average loss: 0.0056
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.012346
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.001921
# ====> Epoch: 39 Average loss: 0.0056
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.012322
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.001908
# ====> Epoch: 40 Average loss: 0.0056
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.012354
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.001922
# ====> Epoch: 41 Average loss: 0.0056
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.012331
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.001935
# ====> Epoch: 42 Average loss: 0.0056
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.012324
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.001918
# ====> Epoch: 43 Average loss: 0.0056
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.012350
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.001928
# ====> Epoch: 44 Average loss: 0.0056
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.012350
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.001921
# ====> Epoch: 45 Average loss: 0.0056
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.012321
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.001910
# ====> Epoch: 46 Average loss: 0.0056
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.012361
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.001920
# ====> Epoch: 47 Average loss: 0.0056
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.012319
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.001917
# ====> Epoch: 48 Average loss: 0.0056
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.012318
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.001914
# ====> Epoch: 49 Average loss: 0.0056
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[350.     , 350.     , 350.     , ..., 355.3388 , 354.99176,
#         354.63834]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [11],
#                  'channel': [0],
#                  'frequency_per_week': [11.466756785368387],
#                  'phaseshift': [18]},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.007920
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.001241
# ====> Epoch: 1 Average loss: 0.0041
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.007556
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.001250
# ====> Epoch: 2 Average loss: 0.0041
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.007516
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.001250
# ====> Epoch: 3 Average loss: 0.0041
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.007527
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.001239
# ====> Epoch: 4 Average loss: 0.0041
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.007520
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.001255
# ====> Epoch: 5 Average loss: 0.0041
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.007513
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.001245
# ====> Epoch: 6 Average loss: 0.0041
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.007517
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.001253
# ====> Epoch: 7 Average loss: 0.0041
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.007530
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.001258
# ====> Epoch: 8 Average loss: 0.0041
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.007536
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.001247
# ====> Epoch: 9 Average loss: 0.0041
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.007530
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.001245
# ====> Epoch: 10 Average loss: 0.0041
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.007511
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.001247
# ====> Epoch: 11 Average loss: 0.0041
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.007509
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.001264
# ====> Epoch: 12 Average loss: 0.0041
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.007542
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.001245
# ====> Epoch: 13 Average loss: 0.0041
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.007525
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.001248
# ====> Epoch: 14 Average loss: 0.0041
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.007538
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.001254
# ====> Epoch: 15 Average loss: 0.0041
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.007530
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.001245
# ====> Epoch: 16 Average loss: 0.0041
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.007531
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.001257
# ====> Epoch: 17 Average loss: 0.0041
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.007518
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.001249
# ====> Epoch: 18 Average loss: 0.0041
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.007527
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.001250
# ====> Epoch: 19 Average loss: 0.0041
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.007540
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.001254
# ====> Epoch: 20 Average loss: 0.0041
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.007545
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.001254
# ====> Epoch: 21 Average loss: 0.0041
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.007525
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.001640
# ====> Epoch: 22 Average loss: 0.0050
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.007375
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.001239
# ====> Epoch: 23 Average loss: 0.0041
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.007512
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.001254
# ====> Epoch: 24 Average loss: 0.0041
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.007523
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.001245
# ====> Epoch: 25 Average loss: 0.0041
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.007521
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.001247
# ====> Epoch: 26 Average loss: 0.0041
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.007521
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.001253
# ====> Epoch: 27 Average loss: 0.0041
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.007533
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.001255
# ====> Epoch: 28 Average loss: 0.0041
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.007556
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.001238
# ====> Epoch: 29 Average loss: 0.0041
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.007526
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.001251
# ====> Epoch: 30 Average loss: 0.0041
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.007523
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.001240
# ====> Epoch: 31 Average loss: 0.0041
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.007541
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.001255
# ====> Epoch: 32 Average loss: 0.0041
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.007515
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.001247
# ====> Epoch: 33 Average loss: 0.0041
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.007530
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.001241
# ====> Epoch: 34 Average loss: 0.0041
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.007516
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.001250
# ====> Epoch: 35 Average loss: 0.0041
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.007519
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.001248
# ====> Epoch: 36 Average loss: 0.0041
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.007534
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.001256
# ====> Epoch: 37 Average loss: 0.0041
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.007511
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.001249
# ====> Epoch: 38 Average loss: 0.0041
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.007512
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.001291
# ====> Epoch: 39 Average loss: 0.0041
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.007499
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.001244
# ====> Epoch: 40 Average loss: 0.0041
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.007522
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.001255
# ====> Epoch: 41 Average loss: 0.0041
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.007538
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.001250
# ====> Epoch: 42 Average loss: 0.0041
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.007550
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.001249
# ====> Epoch: 43 Average loss: 0.0041
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.007519
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.001258
# ====> Epoch: 44 Average loss: 0.0041
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.007517
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.001251
# ====> Epoch: 45 Average loss: 0.0041
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.007530
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.001252
# ====> Epoch: 46 Average loss: 0.0041
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.007526
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.001259
# ====> Epoch: 47 Average loss: 0.0048
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.007547
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.001247
# ====> Epoch: 48 Average loss: 0.0041
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.007539
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.001256
# ====> Epoch: 49 Average loss: 0.0041
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[53.     , 53.     , 53.     , ..., 58.39959, 58.22387, 58.04039]],
#       dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [7],
#                  'channel': [0],
#                  'frequency_per_week': [12.370292762688425],
#                  'phaseshift': [106]},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [], 'index': [], 'slope': []}}
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.150541
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.029761
# ====> Epoch: 1 Average loss: 0.0838
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.152739
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.029518
# ====> Epoch: 2 Average loss: 0.0829
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.152895
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.029402
# ====> Epoch: 3 Average loss: 0.0828
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.152987
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.029307
# ====> Epoch: 4 Average loss: 0.0828
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.152870
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.029372
# ====> Epoch: 5 Average loss: 0.0827
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.152569
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.029263
# ====> Epoch: 6 Average loss: 0.0827
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.152681
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.029283
# ====> Epoch: 7 Average loss: 0.0827
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.152589
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.029210
# ====> Epoch: 8 Average loss: 0.0827
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.152749
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.029197
# ====> Epoch: 9 Average loss: 0.0827
# Train Epoch: 10 [0/3396 (0%)]	Loss: 0.152639
# Train Epoch: 10 [2200/3396 (65%)]	Loss: 0.029213
# ====> Epoch: 10 Average loss: 0.0827
# Train Epoch: 11 [0/3396 (0%)]	Loss: 0.152705
# Train Epoch: 11 [2200/3396 (65%)]	Loss: 0.029351
# ====> Epoch: 11 Average loss: 0.0827
# Train Epoch: 12 [0/3396 (0%)]	Loss: 0.152820
# Train Epoch: 12 [2200/3396 (65%)]	Loss: 0.029331
# ====> Epoch: 12 Average loss: 0.0827
# Train Epoch: 13 [0/3396 (0%)]	Loss: 0.152782
# Train Epoch: 13 [2200/3396 (65%)]	Loss: 0.029313
# ====> Epoch: 13 Average loss: 0.0827
# Train Epoch: 14 [0/3396 (0%)]	Loss: 0.152722
# Train Epoch: 14 [2200/3396 (65%)]	Loss: 0.029399
# ====> Epoch: 14 Average loss: 0.0827
# Train Epoch: 15 [0/3396 (0%)]	Loss: 0.152650
# Train Epoch: 15 [2200/3396 (65%)]	Loss: 0.029333
# ====> Epoch: 15 Average loss: 0.0878
# Train Epoch: 16 [0/3396 (0%)]	Loss: 0.151650
# Train Epoch: 16 [2200/3396 (65%)]	Loss: 0.029188
# ====> Epoch: 16 Average loss: 0.0826
# Train Epoch: 17 [0/3396 (0%)]	Loss: 0.152539
# Train Epoch: 17 [2200/3396 (65%)]	Loss: 0.029177
# ====> Epoch: 17 Average loss: 0.0826
# Train Epoch: 18 [0/3396 (0%)]	Loss: 0.152621
# Train Epoch: 18 [2200/3396 (65%)]	Loss: 0.029178
# ====> Epoch: 18 Average loss: 0.0826
# Train Epoch: 19 [0/3396 (0%)]	Loss: 0.152499
# Train Epoch: 19 [2200/3396 (65%)]	Loss: 0.029215
# ====> Epoch: 19 Average loss: 0.0826
# Train Epoch: 20 [0/3396 (0%)]	Loss: 0.152318
# Train Epoch: 20 [2200/3396 (65%)]	Loss: 0.029274
# ====> Epoch: 20 Average loss: 0.0826
# Train Epoch: 21 [0/3396 (0%)]	Loss: 0.152595
# Train Epoch: 21 [2200/3396 (65%)]	Loss: 0.029255
# ====> Epoch: 21 Average loss: 0.0826
# Train Epoch: 22 [0/3396 (0%)]	Loss: 0.152380
# Train Epoch: 22 [2200/3396 (65%)]	Loss: 0.029286
# ====> Epoch: 22 Average loss: 0.0826
# Train Epoch: 23 [0/3396 (0%)]	Loss: 0.152601
# Train Epoch: 23 [2200/3396 (65%)]	Loss: 0.029243
# ====> Epoch: 23 Average loss: 0.0826
# Train Epoch: 24 [0/3396 (0%)]	Loss: 0.152480
# Train Epoch: 24 [2200/3396 (65%)]	Loss: 0.029230
# ====> Epoch: 24 Average loss: 0.0826
# Train Epoch: 25 [0/3396 (0%)]	Loss: 0.152545
# Train Epoch: 25 [2200/3396 (65%)]	Loss: 0.029262
# ====> Epoch: 25 Average loss: 0.0826
# Train Epoch: 26 [0/3396 (0%)]	Loss: 0.152657
# Train Epoch: 26 [2200/3396 (65%)]	Loss: 0.029117
# ====> Epoch: 26 Average loss: 0.0826
# Train Epoch: 27 [0/3396 (0%)]	Loss: 0.152598
# Train Epoch: 27 [2200/3396 (65%)]	Loss: 0.029259
# ====> Epoch: 27 Average loss: 0.0826
# Train Epoch: 28 [0/3396 (0%)]	Loss: 0.152389
# Train Epoch: 28 [2200/3396 (65%)]	Loss: 0.029324
# ====> Epoch: 28 Average loss: 0.0826
# Train Epoch: 29 [0/3396 (0%)]	Loss: 0.152524
# Train Epoch: 29 [2200/3396 (65%)]	Loss: 0.029325
# ====> Epoch: 29 Average loss: 0.0826
# Train Epoch: 30 [0/3396 (0%)]	Loss: 0.152478
# Train Epoch: 30 [2200/3396 (65%)]	Loss: 0.029222
# ====> Epoch: 30 Average loss: 0.0826
# Train Epoch: 31 [0/3396 (0%)]	Loss: 0.152629
# Train Epoch: 31 [2200/3396 (65%)]	Loss: 0.029264
# ====> Epoch: 31 Average loss: 0.0826
# Train Epoch: 32 [0/3396 (0%)]	Loss: 0.152684
# Train Epoch: 32 [2200/3396 (65%)]	Loss: 0.029270
# ====> Epoch: 32 Average loss: 0.0826
# Train Epoch: 33 [0/3396 (0%)]	Loss: 0.152767
# Train Epoch: 33 [2200/3396 (65%)]	Loss: 0.029285
# ====> Epoch: 33 Average loss: 0.0826
# Train Epoch: 34 [0/3396 (0%)]	Loss: 0.152571
# Train Epoch: 34 [2200/3396 (65%)]	Loss: 0.029145
# ====> Epoch: 34 Average loss: 0.0826
# Train Epoch: 35 [0/3396 (0%)]	Loss: 0.152569
# Train Epoch: 35 [2200/3396 (65%)]	Loss: 0.029365
# ====> Epoch: 35 Average loss: 0.0826
# Train Epoch: 36 [0/3396 (0%)]	Loss: 0.152891
# Train Epoch: 36 [2200/3396 (65%)]	Loss: 0.029280
# ====> Epoch: 36 Average loss: 0.0827
# Train Epoch: 37 [0/3396 (0%)]	Loss: 0.152801
# Train Epoch: 37 [2200/3396 (65%)]	Loss: 0.029325
# ====> Epoch: 37 Average loss: 0.0827
# Train Epoch: 38 [0/3396 (0%)]	Loss: 0.152746
# Train Epoch: 38 [2200/3396 (65%)]	Loss: 0.029241
# ====> Epoch: 38 Average loss: 0.0827
# Train Epoch: 39 [0/3396 (0%)]	Loss: 0.152836
# Train Epoch: 39 [2200/3396 (65%)]	Loss: 0.029261
# ====> Epoch: 39 Average loss: 0.0827
# Train Epoch: 40 [0/3396 (0%)]	Loss: 0.152475
# Train Epoch: 40 [2200/3396 (65%)]	Loss: 0.029218
# ====> Epoch: 40 Average loss: 0.0827
# Train Epoch: 41 [0/3396 (0%)]	Loss: 0.152539
# Train Epoch: 41 [2200/3396 (65%)]	Loss: 0.029330
# ====> Epoch: 41 Average loss: 0.0827
# Train Epoch: 42 [0/3396 (0%)]	Loss: 0.152696
# Train Epoch: 42 [2200/3396 (65%)]	Loss: 0.029256
# ====> Epoch: 42 Average loss: 0.0827
# Train Epoch: 43 [0/3396 (0%)]	Loss: 0.152748
# Train Epoch: 43 [2200/3396 (65%)]	Loss: 0.029372
# ====> Epoch: 43 Average loss: 0.0827
# Train Epoch: 44 [0/3396 (0%)]	Loss: 0.152733
# Train Epoch: 44 [2200/3396 (65%)]	Loss: 0.029212
# ====> Epoch: 44 Average loss: 0.0827
# Train Epoch: 45 [0/3396 (0%)]	Loss: 0.152506
# Train Epoch: 45 [2200/3396 (65%)]	Loss: 0.029162
# ====> Epoch: 45 Average loss: 0.0826
# Train Epoch: 46 [0/3396 (0%)]	Loss: 0.152622
# Train Epoch: 46 [2200/3396 (65%)]	Loss: 0.029333
# ====> Epoch: 46 Average loss: 0.0827
# Train Epoch: 47 [0/3396 (0%)]	Loss: 0.152557
# Train Epoch: 47 [2200/3396 (65%)]	Loss: 0.029283
# ====> Epoch: 47 Average loss: 0.0827
# Train Epoch: 48 [0/3396 (0%)]	Loss: 0.152537
# Train Epoch: 48 [2200/3396 (65%)]	Loss: 0.029264
# ====> Epoch: 48 Average loss: 0.0827
# Train Epoch: 49 [0/3396 (0%)]	Loss: 0.152843
# Train Epoch: 49 [2200/3396 (65%)]	Loss: 0.029228
# ====> Epoch: 49 Average loss: 0.0827

# %%
effects = {
    "Pulse": {
        "occurances":0,
        "max_amplitude":1.5,   
        "interval":40
        },
    "Trend": {
        "occurances":1,
        "max_slope":0.005,
        "type":"linear"
        },
    "Seasonality": {
        "occurances":0,
        "frequency_per_week":(7, 14), # min and max occurances per week
        "amplitude_range":(5, 20),
        },
    "std_variation": {
        "occurances":0,
        "max_value":10,
        "interval":1000,
        },
    "channels_coupling":{
        "occurances":0,
        "coupling_strengh":20
        },
    "Noise": {
        "occurances":0,
        "max_slope":0.005,
        "type":"linear"
        }
    }

X = Gen(periode, step, val, n_channels, effects)
x, params, e_params = X.parameters()
pprint.pprint(params)
pprint.pprint(e_params)
X.show()
x = torch.FloatTensor(x)

# x = F.normalize(x, p=2, dim=1)
n = x.shape[1]
# L = 30

train_ = x[:, :int(0.8*n)]
val_   = x[:, int(0.8*n):int(0.9*n)]
test_  = x[:, int(0.9*n):]

train_data = DataLoader(slidingWindow(train_, L),
                        batch_size= 22,# 59, # 22
                        shuffle = False
                        )
val_data = DataLoader(slidingWindow(val_, L),
                        batch_size=22,
                        shuffle = False
                        )
test_data = DataLoader(slidingWindow(test_, L),
                        batch_size=22,
                        shuffle = False
                        )
# Out:
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[375.     , 375.     , 375.     , ..., 446.3793 , 446.40134,
#         446.4234 ]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [0],
#            'index': ['2023-03-04T17:55:00'],
#            'slope': [0.004407490789110276]}}

# %%
for epoch in range(1, 10):
    train(v, train_data, criterion, opt, device, epoch, VQ = True)
# Out:
# Train Epoch: 1 [0/3396 (0%)]	Loss: 0.000364
# Train Epoch: 1 [2200/3396 (65%)]	Loss: 0.000270
# ====> Epoch: 1 Average loss: 0.0004
# Train Epoch: 2 [0/3396 (0%)]	Loss: 0.000424
# Train Epoch: 2 [2200/3396 (65%)]	Loss: 0.000268
# ====> Epoch: 2 Average loss: 0.0004
# Train Epoch: 3 [0/3396 (0%)]	Loss: 0.000424
# Train Epoch: 3 [2200/3396 (65%)]	Loss: 0.000268
# ====> Epoch: 3 Average loss: 0.0004
# Train Epoch: 4 [0/3396 (0%)]	Loss: 0.000425
# Train Epoch: 4 [2200/3396 (65%)]	Loss: 0.000267
# ====> Epoch: 4 Average loss: 0.0004
# Train Epoch: 5 [0/3396 (0%)]	Loss: 0.000422
# Train Epoch: 5 [2200/3396 (65%)]	Loss: 0.000261
# ====> Epoch: 5 Average loss: 0.0004
# Train Epoch: 6 [0/3396 (0%)]	Loss: 0.000423
# Train Epoch: 6 [2200/3396 (65%)]	Loss: 0.000262
# ====> Epoch: 6 Average loss: 0.0004
# Train Epoch: 7 [0/3396 (0%)]	Loss: 0.000423
# Train Epoch: 7 [2200/3396 (65%)]	Loss: 0.000264
# ====> Epoch: 7 Average loss: 0.0004
# Train Epoch: 8 [0/3396 (0%)]	Loss: 0.000423
# Train Epoch: 8 [2200/3396 (65%)]	Loss: 0.000267
# ====> Epoch: 8 Average loss: 0.0004
# Train Epoch: 9 [0/3396 (0%)]	Loss: 0.000423
# Train Epoch: 9 [2200/3396 (65%)]	Loss: 0.000265
# ====> Epoch: 9 Average loss: 0.0004

# %%
def compare(dataset, model, VQ=True):
    model.eval()
    rec = []
    x = []
    T = dataset.dataset.data.shape[1]- L
    idx = 0
    _mu_rec, _logvar_rec = [], []
    _mu, _logvar = [], []
#     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
#     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
    with torch.no_grad():
        for i, (data, v) in enumerate(dataset):
            bs = data.shape[0]
            if VQ:
                x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
            else:
                x_rec, mu, logvar = model(data)
            z = model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
#             print(i)
#             print(mu.shape)

            x.extend((data)[0,:,0].detach().numpy())
            rec.extend(((x_rec)[0,:,0]).detach().numpy())
            _mu_rec.extend((mu_rec)[0,:,:].detach().numpy())
            _logvar_rec.extend(((torch.exp(0.5 * logvar_rec)))[0,:,:].detach().numpy())
            
            _mu.extend((mu)[0,:,0].detach().numpy())
            _logvar.extend(((torch.exp(0.5 * logvar)))[0,:,:].detach().numpy())
#             _mu[idx: idx + bs, :, :] = mu
#             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
#     print(np.array(_mu).shape)
    
#     x = np.array(x).T
#     rec = np.array(rec).T
#     _mu = np.tile(np.array(_mu), (3455, 1))
#     _logvar = np.tile(np.array(_logvar), (3455, 1))
#     _mu_rec = np.tile(np.array(_mu_rec), (3455, 1))
#     _logvar_rec = np.tile(np.array(_logvar_rec), (3455, 1))
    print(_logvar.shape)
    print(x.shape)
    print(rec.shape)
    print(T)
#     print(params["cov"][0,:,:L].T)
    fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10, 15))
    ax = axs[0]
    ax.plot(rec, "r-")
    ax.plot(x[:], "b-", alpha=0.2)
    ax.plot(_mu_rec)
    ax.plot(params["mu"].T[:_mu.shape[0],:])
    ax.grid()
    
    ax_std = axs[1]
    ax_std.plot(_logvar_rec, "r")
    ax_std.plot(params["cov"][0,:,:L].T, "b")
    ax_std.grid()
    
    ax_enc = axs[2]
    for (i,l) in enumerate(_mu.T):        
        ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
#     ax_enc.plot(_mu, alpha = 0.2)
    ax_enc.grid()
    
    ax_log = axs[3]
    for (i,l) in enumerate(_logvar.T):        
        ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
    ax_log.grid()
    
    # Setting legend
    blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
    red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
    titles = ['Prediction of Train Data', 'Std plot', 'mu encoder vs mu from gen', 'logvar encoder vs cov']
    for (i,ax) in enumerate(axs):
        # ax.set_title('Reconstruction of Train Data')
        ax.set_title(titles[i])
        ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
    # Axes labels
    ax_std.set_xlabel('Time')
    ax.set_ylabel('Values')
    ax_std.set_ylabel('Values')
#     plt.ylim(-100,500)
#     plt.grid(True)
    fig.tight_layout()
    plt.show()
# def compare(dataset, model, VQ=True):
#     model.eval()
#     rec = []
#     x = []
#     T = dataset.dataset.data.shape[1]- L
#     idx = 0
#     _mu_rec, _logvar_rec = [], []
#     _mu, _logvar = [], []
# #     _mu, _logvar = (torch.empty((n_channels * 2, T, L)) for _ in range(2))
# #     _mu_rec, _logvar_rec = (torch.empty((T, n_channels)) for _ in range(2))
#     with torch.no_grad():
#         for i, (data, v) in enumerate(dataset):
#             bs = data.shape[0]
#             if VQ:
#                 x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
#             else:
#                 x_rec, mu, logvar = model(data)
#             z = model.reparametrization_trick(mu, logvar)
#             print(v.shape)
#             if v.dim() == 1:
#                 v = v.unsqueeze(0)
#                 v = v.T
#                 v = v.unsqueeze(-1)
# #             print(v.shape)
# #             print(x_rec.shape)
# #             print((x_rec * v).shape)
# #             print(i)
# #             print(mu.shape)

#             x.extend((data)[:,:,:].detach().numpy())
#             rec.extend(((x_rec)[:,:,:]).detach().numpy())
# #             _mu_rec.extend((mu_rec*v)[:,:,0].detach().numpy())
# #             _logvar_rec.extend(((torch.exp(0.5 * logvar_rec))*v)[:,:,0].detach().numpy())
            
# #             _mu.extend((mu*v)[:,:,0].detach().numpy())
# #             _logvar.extend(((torch.exp(0.5 * logvar))*v)[:,:,0].detach().numpy())
# #             _mu[idx: idx + bs, :, :] = mu
# #             _mu_rec[idx: idx + bs, :] = (mu_rec*v)[:,:,0]
# #     print(np.array(rec).shape)
# #     _mu = np.array(_mu)
# #     _logvar = np.array(_logvar)
    
#     rec = np.array(rec).squeeze(0).T
#     x = np.array(x).squeeze(0).T
# #     print(x.shape)
# #     print(rec)
#     fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(10, 4))
#     ax = axs#[0]
#     ax.plot(rec, "r-")
#     ax.plot(x, "b-", alpha=0.2)
# #     ax.plot(_mu_rec)
# #     ax.plot(params["mu"].T[:_mu.shape[0],:])
#     ax.grid()
    
# #     ax_std = axs[1]
# #     ax_std.plot(_logvar_rec, "r")
# #     ax_std.plot(params["cov"][0,:,:T].T, "b")
# #     ax_std.grid()
    
# #     ax_enc = axs[2]
# #     for (i,l) in enumerate(_mu.T):        
# #         ax_enc.plot(l.T, alpha = (0.2 + 0.1*i))
# # #     ax_enc.plot(_mu, alpha = 0.2)
# #     ax_enc.grid()
    
# #     ax_log = axs[3]
# #     for (i,l) in enumerate(_logvar.T):        
# #         ax_log.plot(l.T, alpha = (0.2 + 0.1*i))
# #     ax_log.grid()
    
#     # Setting legend
#     blue_handle = plt.Line2D([], [], color='b', label='Original Data', alpha=0.2)
#     red_handle = plt.Line2D([], [], color='r', label='Reconstructions mean')
# #     for ax in axs:
#         # ax.set_title('Reconstruction of Train Data')
#     ax.set_title('Prediction of Test (unseen) Data')
#     ax.legend(handles=[blue_handle, red_handle], loc="upper right")
    
    
#     # Axes labels
# #     ax_std.set_xlabel('Time')
# #     ax.set_ylabel('Values')
# #     ax_std.set_ylabel('Values')
# #     plt.ylim(-100,500)
#     plt.grid(True)
#     fig.tight_layout()
#     plt.show()

# %%
def compare(dataset, model, VQ=True):
    model.eval()
    rec = []
    x = []
    with torch.no_grad():
        for i, (data, v) in enumerate(dataset):
            if VQ:
                x_rec, loss, mu, logvar, mu_rec, logvar_rec = model(data)
            else:
                x_rec, mu, logvar = model(data)
            z = model.reparametrization_trick(mu, logvar)
            if v.dim() == 1:
                v = v.unsqueeze(0)
                v = v.T
                v = v.unsqueeze(-1)
#             print(v.shape)
#             print(x_rec.shape)
#             print((x_rec * v).shape)
#             print(i)

            x.extend(((data*v)[:,:,0].detach().numpy()))
            rec.extend((((x_rec*v)[:,:,0]).detach().numpy()))
#     print(rec)
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(rec, "r--")
    ax.plot(x[:], "b-", alpha=0.2)
#     plt.ylim(50,600)
    plt.grid(True)
    plt.show()

# %%
a = torch.randn(1,7).to(x)
# v.quantizer._embedding.weight.detach()[0] = a
v.cpu()
compare(train_data, v, VQ=True)
v.to(device)
# Out:
# Variational_Autoencoder(
#   (encoder): LongShort_TCVAE_Encoder(
#     (short_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=42, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=42, out_features=7, bias=True)
#     )
#     (long_encoder): TCVAE_Encoder_unified(
#       (cnn_layers): ModuleList(
#         (0): Conv1d(1, 2, kernel_size=(20,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(2, 4, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Conv1d(4, 6, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (encoder_mu): Linear(in_features=30, out_features=7, bias=True)
#       (encoder_logvar): Linear(in_features=30, out_features=7, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
#   (decoder): LongShort_TCVAE_Decoder(
#     (longshort_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(20,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=74, out_features=60, bias=True)
#       (decoder_mu): Linear(in_features=74, out_features=60, bias=True)
#       (decoder_logvar): Linear(in_features=74, out_features=60, bias=True)
#     )
#     (short_decoder): TCVAE_Decoder(
#       (cnn_layers): ModuleList(
#         (0): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (1): LeakyReLU(negative_slope=0, inplace=True)
#         (2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (4): LeakyReLU(negative_slope=0, inplace=True)
#         (5): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ConvTranspose1d(1, 1, kernel_size=(2,), stride=(2,))
#         (7): LeakyReLU(negative_slope=0, inplace=True)
#         (8): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder_lin): Linear(in_features=56, out_features=60, bias=True)
#       (decoder_mu): Linear(in_features=56, out_features=60, bias=True)
#       (decoder_logvar): Linear(in_features=56, out_features=60, bias=True)
#     )
#     (reduction_layer): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   )
# )

# %%
def plot_heatmap(ax_heatmap, codebook):
    ax_heatmap.clear()
    heatmap = ax_heatmap.imshow(codebook)
    ax_heatmap.set_title('Codebook Heatmap')
    ax_heatmap


    return heatmap
def create_heatmap(codebook):
    fig, ax_heatmap = plt.subplots(figsize=(12, 6), dpi=100)
    heatmap = plot_heatmap(ax_heatmap, codebook.T)
#     heatmap_canvas = FigureCanvasTkAgg(fig, master=heatmap_frame)
#     heatmap_canvas.draw()
#     heatmap_canvas.get_tk_widget().pack(fill="both", expand=True)
    cbar = fig.colorbar(heatmap)
    ax_heatmap.set_xlabel('Num of Embeddings')
    ax_heatmap.set_ylabel('Latent Dimensions')
    
    return ax_heatmap

def get_average_norm_scale(train_data, model):
    n_channels = model._n_channels
    n_batchs = x_size = len(train_data)
    
    norm = torch.empty(n_channels, 0)

    for i, (data, norm_scale) in enumerate(train_data):
        reshaped_norm = norm_scale.permute(1,0,2).flatten(1)
        norm = torch.cat((norm, reshaped_norm), 1)
        
    avg_norm = torch.mean(norm, dim=1)
    return avg_norm

def get_latent_variables(train_data, model):
    model.eval()
    
    n_channels = model._n_channels
    latent_dims = model._latent_dims
    n_batchs = x_size = len(train_data)
    
    latents = torch.empty(n_channels, latent_dims, 0, device = device)

    for i, (data, norm_scale) in enumerate(train_data):
        data = data.to(device)
        
        mu, logvar = model.encoder(data)
        z = model.reparametrization_trick(mu, logvar)
        
        reshaped_mu, reshaped_logvar, reshaped_z = (t.permute(1,2,0) for t in [mu, logvar, z])

        latents = torch.cat((latents, reshaped_z), 2)

        
    avg_latents = torch.mean(latents, dim=2)
    return latents, avg_latents

# %%
get_latent_variables(train_data, v)
x, params, e_params = X.parameters()

# %%
pprint.pprint(params)
pprint.pprint(e_params)
# Out:
# {'cov': array([[[1., 1., 1., ..., 1., 1., 1.]]], dtype=float32),
#  'mu': array([[375.     , 375.     , 375.     , ..., 446.3793 , 446.40134,
#         446.4234 ]], dtype=float32),
#  'n': 4320,
#  'nchannels': 1}
# {'Channels_Coupling': {'amplitude': [], 'channels': []},
#  'Noise': {'channel': [], 'index': [], 'slope': []},
#  'Pulse': {'amplitude': [], 'channel': [], 'index': []},
#  'Seasonality': {'amplitude': [],
#                  'channel': [],
#                  'frequency_per_week': [],
#                  'phaseshift': []},
#  'Std_variation': {'amplitude': [], 'channel': [], 'interval': []},
#  'Trend': {'channel': [0],
#            'index': ['2023-03-04T17:55:00'],
#            'slope': [0.004407490789110276]}}

# %%
from matplotlib.figure import Figure
np.set_printoptions(suppress=True)
avg_norm = get_average_norm_scale(train_data, v)
print(avg_norm)
latents, avg_latents = get_latent_variables(train_data, v)
# codebook = v.quantizer._embedding.weight.cpu().detach().numpy()
heatmap = create_heatmap(avg_latents.cpu().detach().numpy() * avg_norm.numpy())
print((avg_latents.cpu().detach().numpy() * avg_norm.numpy() ))
# Out:
# tensor([392.8546])
# [[ 3.9460828  1.2336978  8.61439   -1.1386664  9.041162  -4.1221404
#    5.4258857]]

# %%
a = torch.randn(1,6).to(x)
# v.cpu().detach()
v.quantizer._embedding.weight.detach()[:] = a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 3
#       1 a = torch.randn(1,6).to(x)
#       2 # v.cpu().detach()
# ----> 3 v.quantizer._embedding.weight.detach()[:] = a
#
# File ~/testenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615     type(self).__name__, name))
#
# AttributeError: 'Variational_Autoencoder' object has no attribute 'quantizer'

# %%
torch.argmin(torch.cdist(a, b, p=2), dim=1).shape
# Out:
# torch.Size([1])

# %%
v.quantizer._embedding.weight
# Out:
# Parameter containing:
# tensor([[-0.6104, -0.3924,  0.4000, -0.5450, -0.2600, -0.4867]],
#        device='cuda:0', requires_grad=True)

# %%
print(v.quantizer._embedding.weight.grad)
# Out:
# None

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(params["mu"].T)
plt.show()

# %%
params["cov"][0]
# Out:
# array([[1., 1., 1., ..., 1., 1., 1.]], dtype=float32)

# %%
a = np.random.randn(100, 10)
a.shape
# Out:
# (100, 10)

# %%
for i in a.T:
    print(i.shape)
# Out:
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)

# %%
print(params["cov"][0,:,:3455].T)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]
